# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/lt_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/lt_tcdf.csv'])
#
#  Dataset:  lt_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.011894
# Epoch: 500 [50%] 	Loss: 0.000017
# Epoch: 1000 [100%] 	Loss: 0.000116
# Potential causes:  [1, 18, 6]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.012648
# Epoch: 500 [50%] 	Loss: 0.000035
# Epoch: 1000 [100%] 	Loss: 0.000017
# Potential causes:  [6, 17]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.010723
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 8, 3]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.009197
# Epoch: 500 [50%] 	Loss: 0.000130
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [9, 14, 1]
# Validated causes:  [9, 1]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.011044
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 14, 3, 12, 4, 15, 19, 16]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.013460
# Epoch: 500 [50%] 	Loss: 0.000080
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [7, 13, 4, 14]
# Validated causes:  [7]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.012854
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 1, 16, 14]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.013355
# Epoch: 500 [50%] 	Loss: 0.000044
# Epoch: 1000 [100%] 	Loss: 0.000140
# Potential causes:  [20, 14, 6, 1]
# Validated causes:  [14]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.009961
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000584
# Potential causes:  [4, 1, 3, 17, 15]
# Validated causes:  [4]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.012621
# Epoch: 500 [50%] 	Loss: 0.000054
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 8, 14, 18, 1, 16]
# Validated causes:  [3]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.012731
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 12]
# Validated causes:  [1, 12]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.010995
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 8, 0, 13, 1, 18]
# Validated causes:  [8]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.010298
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 14, 18, 1]
# Validated causes:  [16, 14, 18, 1]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.011631
# Epoch: 500 [50%] 	Loss: 0.000021
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 10, 3]
# Validated causes:  [1]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.014106
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [19, 1, 7, 13, 18]
# Validated causes:  [19, 1]
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.013296
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000018
# Potential causes:  [1, 16, 18, 14, 6]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.013618
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [19, 1, 14, 6, 18]
# Validated causes:  [19]
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.013225
# Epoch: 500 [50%] 	Loss: 0.000125
# Epoch: 1000 [100%] 	Loss: 0.000382
# Potential causes:  [1, 16, 7, 14]
# Validated causes:  [1]
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.014289
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 0]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.012387
# Epoch: 500 [50%] 	Loss: 0.000104
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 14, 16, 4]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.011094
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000052
# Potential causes:  [1, 19, 16, 4, 14]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.012895
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000012
# Potential causes:  [7, 13, 3, 16, 14, 20, 1, 12]
# Validated causes:  [7, 3]
# ===================Results for lt_tcdf.csv ==================================
# LBGD causes QOA with a delay of 0 time steps.
# VABI causes QOA with a delay of 1 time steps.
# EBSG causes YUA with a delay of 2 time steps.
# PAM causes EBSG with a delay of 0 time steps.
# QOR causes GGFC with a delay of 0 time steps.
# QOA causes LBGD with a delay of 1 time steps.
# VABI causes FDI with a delay of 1 time steps.
# ARP causes FDI with a delay of 1 time steps.
# GGFC causes PC with a delay of 1 time steps.
# GE causes ARP with a delay of 2 time steps.
# PAM causes ARP with a delay of 3 time steps.
# RQ causes ARP with a delay of 0 time steps.
# VABI causes ARP with a delay of 2 time steps.
# VABI causes CO2C with a delay of 1 time steps.
# SSB causes PAM with a delay of 1 time steps.
# VABI causes PAM with a delay of 0 time steps.
# SSB causes GE with a delay of 1 time steps.
# VABI causes COC with a delay of 0 time steps.
# EBSG causes EUPC with a delay of 3 time steps.
# QOA causes EUPC with a delay of 3 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/lt_tcdf.csv=data/demo_groundtruth_lt_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/lt_tcdf.csv': 'data/demo_groundtruth_lt_tcdf.csv'}, data=None)
#
#  Dataset:  lt_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.002190
# Epoch: 250 [50%] 	Loss: 0.000216
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [9, 12, 17]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.005248
# Epoch: 250 [50%] 	Loss: 0.000442
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [9, 14, 8, 10, 2, 21, 18, 13]
# Validated causes:  [9]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.002720
# Epoch: 250 [50%] 	Loss: 0.000062
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [11, 1, 10, 17, 8, 21, 16]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.999044
# Epoch: 250 [50%] 	Loss: 0.000529
# Epoch: 500 [100%] 	Loss: 0.000033
# Potential causes:  [13, 9, 17, 21, 18, 8, 1, 0, 6, 5]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.003312
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [23, 8, 5, 20]
# Validated causes:  [23, 8, 5, 20]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.996859
# Epoch: 250 [50%] 	Loss: 0.000501
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [23, 13, 1, 10, 8, 4, 6]
# Validated causes:  [13]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.005216
# Epoch: 250 [50%] 	Loss: 0.000269
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [16, 14]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.007386
# Epoch: 250 [50%] 	Loss: 0.000284
# Epoch: 500 [100%] 	Loss: 0.000039
# Potential causes:  [11, 14]
# Validated causes:  [11]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002746
# Epoch: 250 [50%] 	Loss: 0.000142
# Epoch: 500 [100%] 	Loss: 0.000502
# Potential causes:  [12, 10, 1, 21]
# Validated causes:  [12, 10]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.003119
# Epoch: 250 [50%] 	Loss: 0.000072
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [17, 0, 11, 18]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.001168
# Epoch: 250 [50%] 	Loss: 0.000459
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 8, 23, 17, 2]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.003837
# Epoch: 250 [50%] 	Loss: 0.000090
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [22, 9]
# Validated causes:  [22]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.001518
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [5, 8, 16, 10, 22]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.004075
# Epoch: 250 [50%] 	Loss: 0.000709
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [14, 6, 17, 5, 7, 11]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.999111
# Epoch: 250 [50%] 	Loss: 0.000082
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [13, 23, 5, 1, 18, 21, 17, 10, 9, 16, 4]
# Validated causes:  [13]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.001019
# Epoch: 250 [50%] 	Loss: 0.000102
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 12, 8]
# Validated causes:  [1]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.000396
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [16, 23, 8, 1, 18, 9]
# Validated causes:  [16, 23]
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.003137
# Epoch: 250 [50%] 	Loss: 0.001233
# Epoch: 500 [100%] 	Loss: 0.000027
# Potential causes:  [9, 18, 11, 21]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.003577
# Epoch: 250 [50%] 	Loss: 0.000127
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [21, 17, 9]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.003871
# Epoch: 250 [50%] 	Loss: 0.002124
# Epoch: 500 [100%] 	Loss: 0.000045
# Potential causes:  [11, 17, 22, 18, 9]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.001983
# Epoch: 250 [50%] 	Loss: 0.000048
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [12, 0, 9, 17, 16, 18, 23, 21]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.002007
# Epoch: 250 [50%] 	Loss: 0.000854
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [11, 17, 16, 18, 10, 9, 12]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.001330
# Epoch: 250 [50%] 	Loss: 0.000268
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [6, 5, 21, 16, 9, 18, 17, 23, 10]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004071
# Epoch: 250 [50%] 	Loss: 0.000283
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [12, 22, 11, 5, 23]
# Validated causes:  [12, 22, 11]
# ===================Results for lt_tcdf.csv ==================================
# REST causes GDPCG with a delay of 0 time steps.
# EUPC causes PAG with a delay of 3 time steps.
# GGAG causes PAG with a delay of 0 time steps.
# QOA causes PAG with a delay of 0 time steps.
# RQ causes PAG with a delay of 3 time steps.
# GGFC causes QOA with a delay of 0 time steps.
# EBSG causes YUA with a delay of 0 time steps.
# FDI causes GGAG with a delay of 0 time steps.
# CO2 causes GGAG with a delay of 0 time steps.
# PT causes EBSG with a delay of 0 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# GDPCG causes PC with a delay of 1 time steps.
# ARP causes ARP with a delay of 4 time steps.
# EUPC causes ARP with a delay of 1 time steps.
# FDI causes EUPC with a delay of 3 time steps.
# PT causes EUPC with a delay of 0 time steps.
# EBSG causes EUPC with a delay of 3 time steps.
#
# ===================Evaluation for lt_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  17
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  17
# TPs':  [(1, 9), (4, 23), (4, 8), (4, 5), (4, 20), (5, 13), (7, 11), (8, 12), (8, 10), (11, 22), (14, 13), (15, 1), (16, 16), (16, 23), (23, 12), (23, 22), (23, 11)]
# FPs':  []
# TPs direct:  [(1, 9), (4, 23), (4, 8), (4, 5), (4, 20), (5, 13), (7, 11), (8, 12), (8, 10), (11, 22), (14, 13), (15, 1), (16, 16), (16, 23), (23, 12), (23, 22), (23, 11)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/lt_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/lt_tcdf.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.580377
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.257546
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.952561
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.959596
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.172629
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.005884
# Epoch: 500 [50%] 	Loss: 0.000060
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.212419
# Epoch: 500 [50%] 	Loss: 0.000394
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.174302
# Epoch: 500 [50%] 	Loss: 0.000130
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.320954
# Epoch: 500 [50%] 	Loss: 0.000036
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.894224
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.188512
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.944366
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.817141
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.228561
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000035
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.033419
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000012
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.593089
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.302344
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 0.950630
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.179194
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.850132
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.920973
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.123633
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 0.807336
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.962381
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/lt_tcdf.csv : 2.8367135922967974 with standard deviation 3.8397077515278277
