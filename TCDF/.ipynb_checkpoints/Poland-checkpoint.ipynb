# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/pl_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/pl_tcdf.csv'])
#
#  Dataset:  pl_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.016739
# Epoch: 500 [50%] 	Loss: 0.000019
# Epoch: 1000 [100%] 	Loss: 0.000003
# Potential causes:  [16, 12]
# Validated causes:  [12]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.008507
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 14]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.017527
# Epoch: 500 [50%] 	Loss: 0.000116
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 16]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.013657
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [8, 16]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.013039
# Epoch: 500 [50%] 	Loss: 0.000040
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 16]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.007376
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [20, 18]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.015868
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000153
# Potential causes:  [14, 12, 17]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.015524
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000133
# Potential causes:  [17, 13, 6, 3, 19, 14, 0]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.011038
# Epoch: 500 [50%] 	Loss: 0.000107
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [13, 17, 16, 9, 1, 19, 14]
# Validated causes:  [13, 17]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.013325
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 8]
# Validated causes:  [8]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.015976
# Epoch: 500 [50%] 	Loss: 0.000042
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [1, 14, 17]
# Validated causes:  [1, 17]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.007896
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 18, 3, 9]
# Validated causes:  [18]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.007355
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [3, 20, 6, 18, 7, 19, 13]
# Validated causes:  []
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.012661
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000031
# Potential causes:  [1, 13, 9, 15, 10, 11]
# Validated causes:  [1, 10, 11]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.012017
# Epoch: 500 [50%] 	Loss: 0.000016
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 16, 19, 13, 20, 18]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.007384
# Epoch: 500 [50%] 	Loss: 0.000029
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 4, 18, 3]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.006760
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000034
# Potential causes:  [3, 18, 1, 13, 6, 4, 16, 17]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.011689
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 13]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.008165
# Epoch: 500 [50%] 	Loss: 0.000013
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 1, 19]
# Validated causes:  [13]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.012274
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 3, 16, 17, 18, 6, 0, 14]
# Validated causes:  [0]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.014019
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [19, 1, 17, 3, 16, 14]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.013680
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 6, 12, 14, 13, 15, 18, 17, 0, 11]
# Validated causes:  [1]
# ===================Results for pl_tcdf.csv ==================================
# ARP causes GDPC with a delay of 0 time steps.
# CO2C causes GGFC with a delay of 1 time steps.
# COC causes GGFC with a delay of 3 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# VABI causes FDI with a delay of 0 time steps.
# COC causes FDI with a delay of 1 time steps.
# RQ causes PC with a delay of 0 time steps.
# VABI causes CO2C with a delay of 1 time steps.
# FDI causes CO2C with a delay of 1 time steps.
# PC causes CO2C with a delay of 2 time steps.
# CO2C causes RQ with a delay of 0 time steps.
# GDPC causes SSB with a delay of 3 time steps.
# VABI causes EUPC with a delay of 1 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/pl_tcdf.csv=data/demo_groundtruth_pl_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/pl_tcdf.csv': 'data/demo_groundtruth_pl_tcdf.csv'}, data=None)
#
#  Dataset:  pl_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.004667
# Epoch: 250 [50%] 	Loss: 0.000459
# Epoch: 500 [100%] 	Loss: 0.000017
# Potential causes:  [15, 16, 21, 9, 5]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.002024
# Epoch: 250 [50%] 	Loss: 0.000013
# Epoch: 500 [100%] 	Loss: 0.000039
# Potential causes:  [15, 12, 14]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.002124
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [8, 18, 21, 12, 17]
# Validated causes:  [8]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.003361
# Epoch: 250 [50%] 	Loss: 0.000465
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [21, 9, 17, 16]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.000967
# Epoch: 250 [50%] 	Loss: 0.000057
# Epoch: 500 [100%] 	Loss: 0.000014
# Potential causes:  [23, 12, 1]
# Validated causes:  [23, 12]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.000578
# Epoch: 250 [50%] 	Loss: 0.000143
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [18, 6]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.001747
# Epoch: 250 [50%] 	Loss: 0.000025
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [5, 18, 17, 21, 22, 13, 9]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.002811
# Epoch: 250 [50%] 	Loss: 0.000038
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [14, 17, 6]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.001111
# Epoch: 250 [50%] 	Loss: 0.000014
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [23, 10, 2, 8, 12, 21]
# Validated causes:  [23, 10, 2]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.005013
# Epoch: 250 [50%] 	Loss: 0.000697
# Epoch: 500 [100%] 	Loss: 0.000047
# Potential causes:  [16, 21, 0, 5, 22, 8]
# Validated causes:  [16]
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.999513
# Epoch: 250 [50%] 	Loss: 0.000011
# Epoch: 500 [100%] 	Loss: 0.000015
# Potential causes:  [14, 12, 23, 8, 1]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.004696
# Epoch: 250 [50%] 	Loss: 0.000080
# Epoch: 500 [100%] 	Loss: 0.000166
# Potential causes:  [16, 5, 9, 21, 19, 22, 6]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003035
# Epoch: 250 [50%] 	Loss: 0.000040
# Epoch: 500 [100%] 	Loss: 0.000413
# Potential causes:  [19, 1, 2, 20, 8, 22]
# Validated causes:  [19, 2, 22]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006771
# Epoch: 250 [50%] 	Loss: 0.001512
# Epoch: 500 [100%] 	Loss: 0.000025
# Potential causes:  [1, 8, 14, 19, 16, 11, 21, 18, 17, 20]
# Validated causes:  [8]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.998321
# Epoch: 250 [50%] 	Loss: 0.000293
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 13, 17, 10, 8, 21]
# Validated causes:  [13]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.998265
# Epoch: 250 [50%] 	Loss: 0.000063
# Epoch: 500 [100%] 	Loss: 0.000651
# Potential causes:  [8, 14, 1, 10, 23]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.002221
# Epoch: 250 [50%] 	Loss: 0.000084
# Epoch: 500 [100%] 	Loss: 0.000041
# Potential causes:  [18, 23, 21, 17, 11, 6, 0, 8]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.005185
# Epoch: 250 [50%] 	Loss: 0.000032
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14]
# Validated causes:  [12]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.002042
# Epoch: 250 [50%] 	Loss: 0.000371
# Epoch: 500 [100%] 	Loss: 0.000009
# Potential causes:  [12, 5, 2, 18, 17, 6, 16, 11, 3]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.003489
# Epoch: 250 [50%] 	Loss: 0.000356
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 17, 21, 9, 0, 18]
# Validated causes:  [0]
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.003746
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [18, 8, 23, 12, 21, 11, 17, 6]
# Validated causes:  [8, 23]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.004279
# Epoch: 250 [50%] 	Loss: 0.000021
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [9, 11]
# Validated causes:  [9]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.002992
# Epoch: 250 [50%] 	Loss: 0.000121
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 9, 21, 5, 18, 8, 6]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004565
# Epoch: 250 [50%] 	Loss: 0.000099
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [16, 21]
# Validated causes:  [16]
# ===================Results for pl_tcdf.csv ==================================
# GGAG causes VABI with a delay of 3 time steps.
# EUPC causes PAG with a delay of 2 time steps.
# FDI causes PAG with a delay of 1 time steps.
# EUPC causes GGAG with a delay of 0 time steps.
# CO2 causes GGAG with a delay of 1 time steps.
# VABI causes GGAG with a delay of 1 time steps.
# ARP causes REST with a delay of 0 time steps.
# COC causes FDI with a delay of 2 time steps.
# VABI causes FDI with a delay of 0 time steps.
# PT causes FDI with a delay of 1 time steps.
# GGAG causes GGFC with a delay of 1 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# FDI causes ROL with a delay of 2 time steps.
# GDPC causes COC with a delay of 0 time steps.
# GGAG causes RQ with a delay of 0 time steps.
# EUPC causes RQ with a delay of 0 time steps.
# REST causes SSB with a delay of 0 time steps.
# ARP causes EUPC with a delay of 1 time steps.
#
# ===================Evaluation for pl_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  18
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  18
# TPs':  [(2, 8), (4, 23), (4, 12), (8, 23), (8, 10), (8, 2), (9, 16), (12, 19), (12, 2), (12, 22), (13, 8), (14, 13), (17, 12), (19, 0), (20, 8), (20, 23), (21, 9), (23, 16)]
# FPs':  []
# TPs direct:  [(2, 8), (4, 23), (4, 12), (8, 23), (8, 10), (8, 2), (9, 16), (12, 19), (12, 2), (12, 22), (13, 8), (14, 13), (17, 12), (19, 0), (20, 8), (20, 23), (21, 9), (23, 16)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  94.44444444444444 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/pl_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/pl_tcdf.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.552336
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 0.591598
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.005723
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.700881
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 0.953070
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.003428
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.151014
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000132
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.746133
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000106
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 0.978173
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000008
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.744386
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.850898
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.951863
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000106
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.932219
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000008
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.079362
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.807784
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.101812
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.660868
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.028263
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000786
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.631897
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000051
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.284815
# Epoch: 500 [50%] 	Loss: 0.000039
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.843464
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.258700
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000060
#
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.215103
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.975826
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/pl_tcdf.csv : 2.555212141962254 with standard deviation 2.1777217902181
