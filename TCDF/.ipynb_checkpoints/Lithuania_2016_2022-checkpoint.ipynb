# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/lt_2016_2022_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/lt_2016_2022_tcdf.csv'])
#
#  Dataset:  lt_2016_2022_tcdf.csv
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 0.997122
# Epoch: 500 [50%] 	Loss: 0.000020
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 24, 1, 25, 21, 9, 3, 0, 16]
# Validated causes:  []
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 0.995851
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 24, 0, 21, 25, 29, 3, 16, 9]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.995959
# Epoch: 500 [50%] 	Loss: 0.000031
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [24, 0, 1, 4, 25, 21, 29, 3, 16]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998498
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 24, 21, 0, 25, 9, 11, 16]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.999479
# Epoch: 500 [50%] 	Loss: 0.000021
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 9, 17, 22, 24, 21, 4, 18, 0, 7]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.000616
# Epoch: 500 [50%] 	Loss: 0.000081
# Epoch: 1000 [100%] 	Loss: 0.000009
# Potential causes:  [14, 20, 22, 0, 21, 24, 25, 18, 7, 28, 3, 11]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.001425
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [17, 8, 18, 20, 27, 9, 10, 28, 11]
# Validated causes:  []
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.999753
# Epoch: 500 [50%] 	Loss: 0.001489
# Epoch: 1000 [100%] 	Loss: 0.000026
# Potential causes:  [4, 8, 9, 17, 22, 0, 10, 24, 18]
# Validated causes:  []
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.998290
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000007
# Potential causes:  [4, 21, 17, 11, 9, 22, 20, 18, 16, 3]
# Validated causes:  []
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 0.998790
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000114
# Potential causes:  [4, 20, 17, 18, 22, 11, 21]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.999863
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 22, 20, 21, 17, 9, 11, 3, 29, 31]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.003757
# Epoch: 500 [50%] 	Loss: 0.000167
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [9, 8, 18, 13]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.003991
# Epoch: 500 [50%] 	Loss: 0.000344
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 5, 13, 2, 20, 22, 21]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.995714
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 1, 29, 11, 21, 9, 25, 3, 16, 24]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.000948
# Epoch: 500 [50%] 	Loss: 0.000028
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 2, 19, 24]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 0.999121
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 4, 11, 2, 24, 21]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.997082
# Epoch: 500 [50%] 	Loss: 0.000100
# Epoch: 1000 [100%] 	Loss: 0.000017
# Potential causes:  [18, 11, 3, 21, 25, 0, 28, 23, 24]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001708
# Epoch: 500 [50%] 	Loss: 0.000119
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 21, 9, 20, 22, 11, 2]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.998753
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [4, 24, 9, 21, 11, 17, 16, 3, 29]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.004149
# Epoch: 500 [50%] 	Loss: 0.000040
# Epoch: 1000 [100%] 	Loss: 0.000021
# Potential causes:  [14, 24, 2, 5, 13, 18, 25, 8, 20]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002365
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000055
# Potential causes:  [4, 11, 21, 22, 17, 5, 2, 9, 7, 24, 12]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 0.998522
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 8, 9, 24, 0, 25, 17, 21]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.003688
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000167
# Potential causes:  [4, 21, 9, 20, 5, 17, 11, 2]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.000790
# Epoch: 500 [50%] 	Loss: 0.000290
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 14, 9, 22, 21, 24, 17]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.002494
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 9, 8, 24, 4, 25, 0, 23]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 0.999624
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 7, 24, 20, 22, 21, 8, 11]
# Validated causes:  []
#  Analysis started for target:  EC
# Epoch:  1 [0%] 	Loss: 0.000096
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [25, 26, 30]
# Validated causes:  []
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 1.003357
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 8, 13, 14, 25, 18, 28, 7, 10]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 0.997490
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 9, 22, 21, 11, 24, 3]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.998465
# Epoch: 500 [50%] 	Loss: 0.000094
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 17, 9, 3, 11, 4, 24, 16, 29]
# Validated causes:  []
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 1.001433
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 2, 17, 9, 20, 22, 21, 29, 3, 11]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.996580
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000003
# Potential causes:  [24, 4, 21, 9, 11, 16, 3, 25, 18, 29]
# Validated causes:  [24]
# ===================Results for lt_2016_2022_tcdf.csv ==================================
# EPFRG causes EUPC with a delay of 2 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/lt_2016_2022_tcdf.csv=data/demo_groundtruth_lt_2016_2022_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/lt_2016_2022_tcdf.csv': 'data/demo_groundtruth_lt_2016_2022_tcdf.csv'}, data=None)
#
#  Dataset:  lt_2016_2022_tcdf.csv
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 0.997122
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000020
# Potential causes:  [4, 24, 1, 25, 21, 9, 3, 0, 16]
# Validated causes:  []
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 0.995851
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 24, 0, 21, 25, 29, 3, 16, 9]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.995959
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000031
# Potential causes:  [24, 0, 1, 4, 25, 21, 29, 3, 16]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998498
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [18, 24, 21, 0, 25, 9, 11, 16]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.999479
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000021
# Potential causes:  [8, 9, 17, 22, 24, 21, 4, 18, 0, 7]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.000616
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000081
# Potential causes:  [14, 20, 22, 0, 21, 25, 24, 18, 7, 28, 3, 11]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.001425
# Epoch: 250 [50%] 	Loss: 0.000053
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [17, 8, 18, 20, 27, 9, 10, 28, 11]
# Validated causes:  []
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.999753
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.001489
# Potential causes:  [4, 8, 9, 17, 22, 0, 10, 24, 18]
# Validated causes:  []
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.998290
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 21, 17, 11, 9, 22, 20, 18, 16, 3]
# Validated causes:  []
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 0.998790
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [4, 20, 17, 18, 22, 11, 21]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.999863
# Epoch: 250 [50%] 	Loss: 0.000016
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 22, 20, 21, 17, 9, 11, 3, 29, 31]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.003757
# Epoch: 250 [50%] 	Loss: 0.000327
# Epoch: 500 [100%] 	Loss: 0.000167
# Potential causes:  [9, 8, 18, 13]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.003991
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000344
# Potential causes:  [17, 5, 13, 2, 20, 22, 21]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.995714
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [0, 1, 29, 11, 21, 9, 25, 3, 16, 24]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.000948
# Epoch: 250 [50%] 	Loss: 0.000043
# Epoch: 500 [100%] 	Loss: 0.000028
# Potential causes:  [5, 2, 19, 24]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 0.999121
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [5, 4, 11, 2, 24, 21]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.997082
# Epoch: 250 [50%] 	Loss: 0.000024
# Epoch: 500 [100%] 	Loss: 0.000100
# Potential causes:  [18, 11, 3, 21, 25, 0, 28, 23, 24]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001708
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000119
# Potential causes:  [4, 21, 9, 20, 22, 11, 2]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.998753
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 24, 9, 21, 11, 17, 16, 3, 29]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.004149
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000040
# Potential causes:  [14, 24, 2, 5, 13, 18, 25, 8, 20]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002365
# Epoch: 250 [50%] 	Loss: 0.000198
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [4, 11, 21, 22, 17, 5, 2, 9, 7, 24, 12]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 0.998522
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 8, 9, 24, 0, 25, 17, 21]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.003688
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 21, 9, 20, 5, 17, 11, 2]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.000790
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000290
# Potential causes:  [4, 14, 9, 22, 21, 24, 17]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.002494
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [21, 9, 8, 24, 4, 25, 0, 23]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 0.999624
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 7, 24, 20, 22, 21, 8, 11]
# Validated causes:  []
#  Analysis started for target:  EC
# Epoch:  1 [0%] 	Loss: 0.000096
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [25, 26, 30]
# Validated causes:  []
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 1.003357
# Epoch: 250 [50%] 	Loss: 0.000496
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [5, 8, 13, 14, 25, 18, 28, 7, 10]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 0.997490
# Epoch: 250 [50%] 	Loss: 0.000046
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [18, 9, 22, 21, 11, 24, 3]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.998465
# Epoch: 250 [50%] 	Loss: 0.000008
# Epoch: 500 [100%] 	Loss: 0.000094
# Potential causes:  [21, 17, 9, 3, 11, 4, 24, 16, 29]
# Validated causes:  []
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 1.001433
# Epoch: 250 [50%] 	Loss: 0.000038
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 2, 17, 9, 20, 22, 21, 29, 3, 11]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.996580
# Epoch: 250 [50%] 	Loss: 0.000024
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [24, 4, 21, 9, 11, 16, 3, 18, 25, 29]
# Validated causes:  [24]
# ===================Results for lt_2016_2022_tcdf.csv ==================================
# EPFRG causes EUPC with a delay of 2 time steps.
#
# ===================Evaluation for lt_2016_2022_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  1
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  1
# TPs':  [(31, 24)]
# FPs':  []
# TPs direct:  [(31, 24)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/lt_2007_2015_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/lt_2007_2015_tcdf.csv'])
#
#  Analysis started for target:  Unnamed: 0
# Epoch:  1 [0%] 	Loss: 14.267530
# Epoch: 500 [50%] 	Loss: 0.000117
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 1.322566
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 1.325094
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.293854
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.268160
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.028078
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.280629
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.281607
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000156
#
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.880988
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.795147
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 1.026746
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 1.074849
# Epoch: 500 [50%] 	Loss: 0.000094
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.246971
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.270931
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000183
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.048966
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.286378
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.162768
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.128827
# Epoch: 500 [50%] 	Loss: 0.000490
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.738039
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.218011
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.001275
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.093579
# Epoch: 500 [50%] 	Loss: 0.000044
# Epoch: 1000 [100%] 	Loss: 0.000006
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.035815
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.171911
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.062833
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.035217
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.117760
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.244405
# Epoch: 500 [50%] 	Loss: 0.000073
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 1.085931
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.687850
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.742117
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 0.571219
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 0.684850
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.853796
# Epoch: 500 [50%] 	Loss: 0.000017
# Epoch: 1000 [100%] 	Loss: 0.000118
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/lt_2007_2015_tcdf.csv : 3.291879415509284 with standard deviation 4.326573923395454
