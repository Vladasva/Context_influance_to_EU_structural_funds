# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/fi_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/fi_tcdf.csv'])
#
#  Dataset:  fi_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001141
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 9, 16, 6, 15, 10, 11, 17, 3]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.002046
# Epoch: 500 [50%] 	Loss: 0.000050
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [2, 14, 21, 8, 17, 20, 12, 10]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.998644
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [20, 12, 10, 17, 13, 11, 23]
# Validated causes:  [20]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.999358
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 16, 0, 15, 17, 9, 4, 21, 7]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 0.999915
# Epoch: 500 [50%] 	Loss: 0.000075
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 23, 17, 15, 12]
# Validated causes:  [5]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.997786
# Epoch: 500 [50%] 	Loss: 0.000038
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 8, 13]
# Validated causes:  [17]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.006673
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000012
# Potential causes:  [6, 15, 17, 18, 16, 10, 0]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.006903
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 21, 17, 18, 6, 4, 23]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.003265
# Epoch: 500 [50%] 	Loss: 0.000013
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [8, 12, 1, 21, 23]
# Validated causes:  [8, 12, 23]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.002966
# Epoch: 500 [50%] 	Loss: 0.000041
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 14, 0, 11, 17, 22, 16, 15, 9]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.002438
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.001152
# Potential causes:  [20, 13]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.998226
# Epoch: 500 [50%] 	Loss: 0.000049
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 13, 21, 20, 14, 10, 2, 1]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.000732
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 1, 12]
# Validated causes:  [8, 1, 12]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.007785
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 21, 14]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997385
# Epoch: 500 [50%] 	Loss: 0.000013
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 10, 2, 20, 1, 23, 21]
# Validated causes:  [13]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.004678
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 6]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.003437
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 17]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.004387
# Epoch: 500 [50%] 	Loss: 0.000115
# Epoch: 1000 [100%] 	Loss: 0.001400
# Potential causes:  [16, 11, 21, 8, 22]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.004017
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.001069
# Potential causes:  [12, 23, 18, 10, 17, 16]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.000286
# Epoch: 500 [50%] 	Loss: 0.000117
# Epoch: 1000 [100%] 	Loss: 0.000008
# Potential causes:  [12, 17, 21, 2, 23, 20]
# Validated causes:  [12]
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.006777
# Epoch: 500 [50%] 	Loss: 0.000035
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 14, 21, 19, 9, 17]
# Validated causes:  [11, 14]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.004902
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 19]
# Validated causes:  [14, 19]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.004862
# Epoch: 500 [50%] 	Loss: 0.000043
# Epoch: 1000 [100%] 	Loss: 0.000021
# Potential causes:  [21, 19, 11, 14]
# Validated causes:  [19]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004442
# Epoch: 500 [50%] 	Loss: 0.000611
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 17, 21, 14, 23, 18, 12, 8]
# Validated causes:  [17]
# ===================Results for fi_tcdf.csv ==================================
# RQ causes VABI with a delay of 0 time steps.
# QOA causes PAG with a delay of 2 time steps.
# ROL causes QOA with a delay of 1 time steps.
# GGAG causes GGAG with a delay of 1 time steps.
# FDI causes GGAG with a delay of 0 time steps.
# EUPC causes GGAG with a delay of 1 time steps.
# GGAG causes FDI with a delay of 0 time steps.
# GDPCG causes FDI with a delay of 1 time steps.
# FDI causes FDI with a delay of 1 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# FDI causes COC with a delay of 1 time steps.
# EBSG causes RQ with a delay of 2 time steps.
# LBGD causes RQ with a delay of 1 time steps.
# LBGD causes SSB with a delay of 1 time steps.
# COC causes SSB with a delay of 0 time steps.
# COC causes PT with a delay of 0 time steps.
# ROL causes EUPC with a delay of 3 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/fi_tcdf.csv=data/demo_groundtruth_fi_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/fi_tcdf.csv': 'data/demo_groundtruth_fi_tcdf.csv'}, data=None)
#
#  Dataset:  fi_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001141
# Epoch: 250 [50%] 	Loss: 0.000148
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [21, 9, 16, 6, 15, 10, 11, 17, 3]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.002046
# Epoch: 250 [50%] 	Loss: 0.000010
# Epoch: 500 [100%] 	Loss: 0.000050
# Potential causes:  [2, 14, 21, 8, 17, 20, 12, 10]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.998644
# Epoch: 250 [50%] 	Loss: 0.000311
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [20, 12, 10, 17, 13, 11, 23]
# Validated causes:  [20]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.999358
# Epoch: 250 [50%] 	Loss: 0.000045
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [6, 16, 0, 15, 17, 9, 4, 21, 7]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 0.999915
# Epoch: 250 [50%] 	Loss: 0.000104
# Epoch: 500 [100%] 	Loss: 0.000075
# Potential causes:  [5, 23, 17, 15, 12]
# Validated causes:  [5]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.997786
# Epoch: 250 [50%] 	Loss: 0.000019
# Epoch: 500 [100%] 	Loss: 0.000038
# Potential causes:  [17, 8, 13]
# Validated causes:  [17]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.006673
# Epoch: 250 [50%] 	Loss: 0.000239
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [6, 15, 17, 18, 16, 10, 0]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.006903
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 21, 17, 18, 6, 4, 23]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.003265
# Epoch: 250 [50%] 	Loss: 0.000010
# Epoch: 500 [100%] 	Loss: 0.000013
# Potential causes:  [8, 12, 1, 21, 23]
# Validated causes:  [8, 12, 23]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.002966
# Epoch: 250 [50%] 	Loss: 0.000055
# Epoch: 500 [100%] 	Loss: 0.000041
# Potential causes:  [21, 14, 0, 11, 17, 22, 16, 15, 9]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.002438
# Epoch: 250 [50%] 	Loss: 0.000956
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [20, 13]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.998226
# Epoch: 250 [50%] 	Loss: 0.000025
# Epoch: 500 [100%] 	Loss: 0.000049
# Potential causes:  [12, 13, 21, 20, 14, 10, 2, 1]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.000732
# Epoch: 250 [50%] 	Loss: 0.000033
# Epoch: 500 [100%] 	Loss: 0.000014
# Potential causes:  [8, 1, 12]
# Validated causes:  [8, 1, 12]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.007785
# Epoch: 250 [50%] 	Loss: 0.000012
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 21, 14]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997385
# Epoch: 250 [50%] 	Loss: 0.000086
# Epoch: 500 [100%] 	Loss: 0.000013
# Potential causes:  [13, 10, 2, 20, 1, 23, 21]
# Validated causes:  [13]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.004678
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [17, 6]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.003437
# Epoch: 250 [50%] 	Loss: 0.000031
# Epoch: 500 [100%] 	Loss: 0.000014
# Potential causes:  [8, 17]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.004387
# Epoch: 250 [50%] 	Loss: 0.000014
# Epoch: 500 [100%] 	Loss: 0.000115
# Potential causes:  [16, 11, 21, 8, 22]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.004017
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [12, 23, 18, 10, 17, 16]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.000286
# Epoch: 250 [50%] 	Loss: 0.000008
# Epoch: 500 [100%] 	Loss: 0.000117
# Potential causes:  [12, 17, 21, 2, 23, 20]
# Validated causes:  [12]
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.006777
# Epoch: 250 [50%] 	Loss: 0.000127
# Epoch: 500 [100%] 	Loss: 0.000035
# Potential causes:  [11, 14, 21, 19, 9, 17]
# Validated causes:  [11, 14]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.004902
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 19]
# Validated causes:  [14, 19]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.004862
# Epoch: 250 [50%] 	Loss: 0.000058
# Epoch: 500 [100%] 	Loss: 0.000043
# Potential causes:  [21, 19, 11, 14]
# Validated causes:  [19]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004442
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000611
# Potential causes:  [11, 17, 21, 14, 23, 18, 12, 8]
# Validated causes:  [17]
# ===================Results for fi_tcdf.csv ==================================
# RQ causes VABI with a delay of 0 time steps.
# QOA causes PAG with a delay of 2 time steps.
# ROL causes QOA with a delay of 1 time steps.
# GGAG causes GGAG with a delay of 1 time steps.
# FDI causes GGAG with a delay of 0 time steps.
# EUPC causes GGAG with a delay of 1 time steps.
# GGAG causes FDI with a delay of 0 time steps.
# GDPCG causes FDI with a delay of 1 time steps.
# FDI causes FDI with a delay of 1 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# FDI causes COC with a delay of 1 time steps.
# EBSG causes RQ with a delay of 2 time steps.
# LBGD causes RQ with a delay of 1 time steps.
# LBGD causes SSB with a delay of 1 time steps.
# COC causes SSB with a delay of 0 time steps.
# COC causes PT with a delay of 0 time steps.
# ROL causes EUPC with a delay of 3 time steps.
#
# ===================Evaluation for fi_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  17
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  17
# TPs':  [(2, 20), (4, 5), (5, 17), (8, 8), (8, 12), (8, 23), (12, 8), (12, 1), (12, 12), (14, 13), (19, 12), (20, 11), (20, 14), (21, 14), (21, 19), (22, 19), (23, 17)]
# FPs':  []
# TPs direct:  [(2, 20), (4, 5), (5, 17), (8, 8), (8, 12), (8, 23), (12, 8), (12, 1), (12, 12), (14, 13), (19, 12), (20, 11), (20, 14), (21, 14), (21, 19), (22, 19), (23, 17)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  94.11764705882352 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/fi_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/fi_tcdf.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.618368
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.204120
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.285742
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.545739
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 0.669309
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.284063
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000077
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.781174
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.739054
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.284457
# Epoch: 500 [50%] 	Loss: 0.001312
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.804582
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.776825
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.183162
# Epoch: 500 [50%] 	Loss: 0.000744
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.109061
# Epoch: 500 [50%] 	Loss: 0.000160
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.194004
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000006
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.954211
# Epoch: 500 [50%] 	Loss: 0.000033
# Epoch: 1000 [100%] 	Loss: 0.000065
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.942507
# Epoch: 500 [50%] 	Loss: 0.000045
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.888530
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.268095
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.938490
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.052554
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000408
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.220492
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 0.778174
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.220417
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.284658
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/fi_tcdf.csv : 1.4793203494855387 with standard deviation 1.0738103834247958
