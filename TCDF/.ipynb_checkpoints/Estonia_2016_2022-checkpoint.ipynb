# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/ee_2016_2022_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/ee_2016_2022_tcdf.csv'])
#
#  Dataset:  ee_2016_2022_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.004666
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [20, 8, 16, 9, 21, 18, 17, 12, 11, 3]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.000103
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 8, 4]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.996602
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [23, 8, 10, 5, 16, 12, 1]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002143
# Epoch: 500 [50%] 	Loss: 0.000030
# Epoch: 1000 [100%] 	Loss: 0.000024
# Potential causes:  [8, 21, 20]
# Validated causes:  [8]
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.002017
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 14, 5, 3, 12, 22, 11, 8, 4, 1]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.000485
# Epoch: 500 [50%] 	Loss: 0.000062
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 17, 20, 23]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.002639
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [19, 4, 6, 16]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.008574
# Epoch: 500 [50%] 	Loss: 0.000129
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 14, 20, 18, 11, 5]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.001027
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [20, 23]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.004553
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [20, 16, 8, 14, 12, 21, 18, 17, 11]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.996409
# Epoch: 500 [50%] 	Loss: 0.000013
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [23, 8, 17, 5, 10, 12, 19]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.996743
# Epoch: 500 [50%] 	Loss: 0.000021
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 8, 23, 10]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.008300
# Epoch: 500 [50%] 	Loss: 0.000110
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 7, 4, 20, 8, 21, 17, 18, 9, 1, 22]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.009974
# Epoch: 500 [50%] 	Loss: 0.000351
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 7, 21, 18, 22]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.995774
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 8, 10, 2, 23, 4]
# Validated causes:  []
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.000947
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000758
# Potential causes:  [1, 16, 8, 9]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.999282
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 1, 12, 8, 2, 9, 10]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.007074
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [20, 21, 12, 18, 7, 14, 11, 8, 9]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.007907
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [20, 17, 9, 21, 7, 14, 12, 8, 11, 18]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.006476
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 18, 21, 20, 9, 12, 3, 23, 8]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.999579
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 17, 23]
# Validated causes:  [11]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.004137
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000012
# Potential causes:  [3, 9]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.006106
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [16, 1, 21, 8, 5]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.005299
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [20, 17, 9, 18, 12, 8, 3, 21]
# Validated causes:  []
# ===================Results for ee_2016_2022_tcdf.csv ==================================
# GGAG causes EMP with a delay of 1 time steps.
# EBSG causes RQ with a delay of 1 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/ee_2016_2022_tcdf.csv=data/demo_groundtruth_ee_2016_2022_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/ee_2016_2022_tcdf.csv': 'data/demo_groundtruth_ee_2016_2022_tcdf.csv'}, data=None)
#
#  Dataset:  ee_2016_2022_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.004666
# Epoch: 250 [50%] 	Loss: 0.000006
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [20, 8, 16, 9, 21, 18, 17, 12, 11, 3]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.000103
# Epoch: 250 [50%] 	Loss: 0.000006
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [14, 8, 4]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.996602
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [23, 8, 10, 5, 16, 12, 1]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002143
# Epoch: 250 [50%] 	Loss: 0.000246
# Epoch: 500 [100%] 	Loss: 0.000030
# Potential causes:  [8, 21, 20]
# Validated causes:  [8]
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.002017
# Epoch: 250 [50%] 	Loss: 0.000015
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [16, 14, 5, 3, 12, 22, 11, 8, 4, 1]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.000485
# Epoch: 250 [50%] 	Loss: 0.000101
# Epoch: 500 [100%] 	Loss: 0.000062
# Potential causes:  [17, 21, 20, 23]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.002639
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [19, 4, 6, 16]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.008574
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000129
# Potential causes:  [21, 14, 20, 18, 11, 5]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.001027
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [20, 23]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.004553
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [20, 16, 8, 14, 12, 21, 18, 17, 11, 7]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.996409
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000013
# Potential causes:  [23, 8, 17, 5, 10, 12, 19]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.996743
# Epoch: 250 [50%] 	Loss: 0.000022
# Epoch: 500 [100%] 	Loss: 0.000021
# Potential causes:  [17, 8, 23, 10]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.008300
# Epoch: 250 [50%] 	Loss: 0.000006
# Epoch: 500 [100%] 	Loss: 0.000110
# Potential causes:  [14, 7, 4, 20, 8, 21, 17, 18, 9, 1, 22]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.009974
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000351
# Potential causes:  [5, 7, 21, 18, 22]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.995774
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [16, 8, 10, 2, 23, 4]
# Validated causes:  [16]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.000947
# Epoch: 250 [50%] 	Loss: 0.000022
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [1, 16, 8, 9]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.999282
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000012
# Potential causes:  [5, 1, 12, 8, 2, 9, 10]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.007074
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [20, 21, 12, 18, 7, 14, 11, 8, 9]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.007907
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [20, 17, 9, 21, 7, 14, 12, 8, 11, 18]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.006476
# Epoch: 250 [50%] 	Loss: 0.000320
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [17, 18, 21, 20, 9, 12, 23, 3, 8]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.999579
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 17, 23]
# Validated causes:  [11]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.004137
# Epoch: 250 [50%] 	Loss: 0.000012
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [3, 9]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.006106
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [16, 1, 21, 8, 5]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.005299
# Epoch: 250 [50%] 	Loss: 0.000040
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [20, 17, 9, 18, 12, 8, 3, 21]
# Validated causes:  []
# ===================Results for ee_2016_2022_tcdf.csv ==================================
# GGAG causes EMP with a delay of 1 time steps.
# ARP causes LBGD with a delay of 0 time steps.
# EBSG causes RQ with a delay of 1 time steps.
#
# ===================Evaluation for ee_2016_2022_tcdf.csv ===============================
# Total False Positives':  1
# Total True Positives':  2
# Total False Negatives:  0
# Total Direct False Positives:  1
# Total Direct True Positives:  2
# TPs':  [(3, 8), (20, 11)]
# FPs':  [(14, 16)]
# TPs direct:  [(3, 8), (20, 11)]
# FPs direct:  [(14, 16)]
# FNs:  []
# Precision':  0.6666666666666666
# Recall':  1.0
# F1' score:  0.8 (includes direct and indirect causal relationships)
# Precision:  0.6666666666666666
# Recall:  1.0
# F1 score:  0.8 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/ee_2016_2022_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/ee_2016_2022_tcdf.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.635734
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 0.767195
# Epoch: 500 [50%] 	Loss: 0.000038
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.217168
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.838507
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.331914
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.348751
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.002701
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.025185
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.382261
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.504389
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.081841
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.814352
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.456952
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.299018
# Epoch: 500 [50%] 	Loss: 0.000023
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.324504
# Epoch: 500 [50%] 	Loss: 0.000019
# Epoch: 1000 [100%] 	Loss: 0.000004
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.228548
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.442199
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 0.717588
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.866927
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.279300
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.265334
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.322618
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 0.947753
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.098054
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/ee_2016_2022_tcdf.csv : 3.859795985298596 with standard deviation 10.666848614693503
