# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/se_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/se_tcdf.csv'])
#
#  Dataset:  se_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.002482
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [16, 9, 6, 17]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.004124
# Epoch: 500 [50%] 	Loss: 0.000060
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 16, 13, 2]
# Validated causes:  [14]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999302
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 20, 1, 23, 12, 16, 15, 6]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.001008
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000005
# Potential causes:  [6, 17, 16, 1, 11]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.003076
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 8, 12, 23, 18, 4]
# Validated causes:  [8]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.999845
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000046
# Potential causes:  [12, 20]
# Validated causes:  [20]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.000828
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [17, 12, 23, 16]
# Validated causes:  [17]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.005161
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000018
# Potential causes:  [15, 14]
# Validated causes:  [15, 14]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002045
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 8]
# Validated causes:  [16, 8]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.003639
# Epoch: 500 [50%] 	Loss: 0.000017
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 0, 6]
# Validated causes:  [0]
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.001423
# Epoch: 500 [50%] 	Loss: 0.000147
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 13, 23, 0]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001728
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 16, 21]
# Validated causes:  [18]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.000097
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [23, 10]
# Validated causes:  [23]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006163
# Epoch: 500 [50%] 	Loss: 0.000102
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 16, 12, 21, 11, 23, 1, 17]
# Validated causes:  [14, 16]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997936
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000013
# Potential causes:  [23, 1, 6, 12, 14, 10]
# Validated causes:  []
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.003427
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000007
# Potential causes:  [14, 17, 23, 21, 16, 12, 11, 19, 1]
# Validated causes:  [17, 23]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.005197
# Epoch: 500 [50%] 	Loss: 0.000162
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [9, 12, 0]
# Validated causes:  [9, 0]
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.004856
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 17, 18]
# Validated causes:  [0]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.001269
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 6]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.002928
# Epoch: 500 [50%] 	Loss: 0.000031
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 18]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.004004
# Epoch: 500 [50%] 	Loss: 0.000143
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 12, 21, 5, 8, 3, 17, 0]
# Validated causes:  [16, 0]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.003052
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 22, 11, 12, 8, 23, 16, 6]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.003120
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [16, 11]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002936
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14]
# Validated causes:  []
# ===================Results for se_tcdf.csv ==================================
# LBGD causes GDPCG with a delay of 1 time steps.
# GGAG causes PAG with a delay of 0 time steps.
# RQ causes QOA with a delay of 3 time steps.
# ROL causes QOR with a delay of 2 time steps.
# PC causes YUA with a delay of 2 time steps.
# LBGD causes YUA with a delay of 0 time steps.
# ARP causes GGAG with a delay of 1 time steps.
# GGAG causes GGAG with a delay of 1 time steps.
# GDPC causes REST with a delay of 0 time steps.
# GE causes EBSG with a delay of 1 time steps.
# EUPC causes FDI with a delay of 0 time steps.
# LBGD causes GGFC with a delay of 3 time steps.
# ARP causes GGFC with a delay of 0 time steps.
# ROL causes PC with a delay of 0 time steps.
# EUPC causes PC with a delay of 1 time steps.
# REST causes ARP with a delay of 0 time steps.
# GDPC causes ARP with a delay of 0 time steps.
# GDPC causes ROL with a delay of 0 time steps.
# ARP causes RQ with a delay of 0 time steps.
# GDPC causes RQ with a delay of 1 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/se_tcdf.csv=data/demo_groundtruth_se_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/se_tcdf.csv': 'data/demo_groundtruth_se_tcdf.csv'}, data=None)
#
#  Dataset:  se_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.002482
# Epoch: 250 [50%] 	Loss: 0.000048
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [16, 9, 6, 17]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.004124
# Epoch: 250 [50%] 	Loss: 0.000255
# Epoch: 500 [100%] 	Loss: 0.000060
# Potential causes:  [14, 16, 13, 2]
# Validated causes:  [14]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999302
# Epoch: 250 [50%] 	Loss: 0.000038
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [13, 20, 1, 23, 12, 16, 15, 6]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.001008
# Epoch: 250 [50%] 	Loss: 0.000036
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [6, 17, 16, 1, 11]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.003076
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [1, 8, 12, 23, 18, 4]
# Validated causes:  [8]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.999845
# Epoch: 250 [50%] 	Loss: 0.000653
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 20]
# Validated causes:  [20]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.000828
# Epoch: 250 [50%] 	Loss: 0.001359
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [17, 12, 23, 16]
# Validated causes:  [17]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.005161
# Epoch: 250 [50%] 	Loss: 0.000141
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [15, 14]
# Validated causes:  [14]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002045
# Epoch: 250 [50%] 	Loss: 0.000220
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [16, 8]
# Validated causes:  [16, 8]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.003639
# Epoch: 250 [50%] 	Loss: 0.000674
# Epoch: 500 [100%] 	Loss: 0.000017
# Potential causes:  [16, 0, 6]
# Validated causes:  [0]
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.001423
# Epoch: 250 [50%] 	Loss: 0.000039
# Epoch: 500 [100%] 	Loss: 0.000147
# Potential causes:  [16, 13, 23, 0]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001728
# Epoch: 250 [50%] 	Loss: 0.000025
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [18, 16, 21]
# Validated causes:  [18]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.000097
# Epoch: 250 [50%] 	Loss: 0.000171
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [23, 10]
# Validated causes:  [23]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006163
# Epoch: 250 [50%] 	Loss: 0.000187
# Epoch: 500 [100%] 	Loss: 0.000102
# Potential causes:  [14, 16, 12, 21, 11, 23, 1, 17]
# Validated causes:  [14, 16]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997936
# Epoch: 250 [50%] 	Loss: 0.000014
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [23, 1, 6, 12, 14, 10]
# Validated causes:  []
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.003427
# Epoch: 250 [50%] 	Loss: 0.000385
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [17, 14, 23, 21, 16, 12, 11, 19, 1]
# Validated causes:  [17, 23]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.005197
# Epoch: 250 [50%] 	Loss: 0.000554
# Epoch: 500 [100%] 	Loss: 0.000162
# Potential causes:  [9, 12, 0]
# Validated causes:  [9, 0]
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.004856
# Epoch: 250 [50%] 	Loss: 0.000085
# Epoch: 500 [100%] 	Loss: 0.000011
# Potential causes:  [0, 17, 18]
# Validated causes:  [0]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.001269
# Epoch: 250 [50%] 	Loss: 0.000120
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [16, 6]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.002928
# Epoch: 250 [50%] 	Loss: 0.000898
# Epoch: 500 [100%] 	Loss: 0.000031
# Potential causes:  [16, 18]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.004004
# Epoch: 250 [50%] 	Loss: 0.000134
# Epoch: 500 [100%] 	Loss: 0.000143
# Potential causes:  [16, 12, 21, 5, 8, 3, 17, 0]
# Validated causes:  [16, 0]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.003052
# Epoch: 250 [50%] 	Loss: 0.000553
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [17, 22, 11, 12, 8, 23, 16, 6]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.003120
# Epoch: 250 [50%] 	Loss: 0.000013
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [16, 11]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002936
# Epoch: 250 [50%] 	Loss: 0.000008
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14]
# Validated causes:  []
# ===================Results for se_tcdf.csv ==================================
# LBGD causes GDPCG with a delay of 1 time steps.
# GGAG causes PAG with a delay of 0 time steps.
# RQ causes QOA with a delay of 3 time steps.
# ROL causes QOR with a delay of 2 time steps.
# LBGD causes YUA with a delay of 0 time steps.
# ARP causes GGAG with a delay of 1 time steps.
# GGAG causes GGAG with a delay of 1 time steps.
# GDPC causes REST with a delay of 0 time steps.
# GE causes EBSG with a delay of 1 time steps.
# EUPC causes FDI with a delay of 0 time steps.
# LBGD causes GGFC with a delay of 3 time steps.
# ARP causes GGFC with a delay of 0 time steps.
# ROL causes PC with a delay of 0 time steps.
# EUPC causes PC with a delay of 1 time steps.
# REST causes ARP with a delay of 0 time steps.
# GDPC causes ARP with a delay of 0 time steps.
# GDPC causes ROL with a delay of 0 time steps.
# ARP causes RQ with a delay of 0 time steps.
# GDPC causes RQ with a delay of 1 time steps.
#
# ===================Evaluation for se_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  19
# Total False Negatives:  1
# Total Direct False Positives:  0
# Total Direct True Positives:  19
# TPs':  [(1, 14), (4, 8), (5, 20), (6, 17), (7, 14), (8, 16), (8, 8), (9, 0), (11, 18), (12, 23), (13, 14), (13, 16), (15, 17), (15, 23), (16, 9), (16, 0), (17, 0), (20, 16), (20, 0)]
# FPs':  []
# TPs direct:  [(1, 14), (4, 8), (5, 20), (6, 17), (7, 14), (8, 16), (8, 8), (9, 0), (11, 18), (12, 23), (13, 14), (13, 16), (15, 17), (15, 23), (16, 9), (16, 0), (17, 0), (20, 16), (20, 0)]
# FPs direct:  []
# FNs:  [(7, 15)]
# Precision':  1.0
# Recall':  0.95
# F1' score:  0.9743589743589743 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  0.95
# F1 score:  0.9743589743589743 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/se_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/se_tcdf.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.645744
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 0.930168
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.091452
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.021784
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.330425
# Epoch: 500 [50%] 	Loss: 0.000143
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.238002
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.764941
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.129066
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000018
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.334112
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.585570
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.888428
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.107747
# Epoch: 500 [50%] 	Loss: 0.000075
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.904595
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.186327
# Epoch: 500 [50%] 	Loss: 0.000144
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.840818
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.906503
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.194790
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 0.560841
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.956468
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.904577
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.206976
# Epoch: 500 [50%] 	Loss: 0.000294
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.309817
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.055697
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.317201
# Epoch: 500 [50%] 	Loss: 0.000044
# Epoch: 1000 [100%] 	Loss: 0.000002
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/se_tcdf.csv : 2.145211857343624 with standard deviation 1.9190718210693944
