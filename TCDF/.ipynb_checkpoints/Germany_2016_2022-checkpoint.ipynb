# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/de_2016_2022_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/de_2016_2022_tcdf.csv'])
#
#  Dataset:  de_2016_2022_tcdf.csv
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 0.999673
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [24, 4, 9, 1, 12, 26, 17, 16, 8]
# Validated causes:  []
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 0.999032
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 4, 9, 16, 24, 12, 26, 17]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.998528
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 1, 5, 26, 0, 3, 24, 23, 30, 27]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.999477
# Epoch: 500 [50%] 	Loss: 0.000039
# Epoch: 1000 [100%] 	Loss: 0.000023
# Potential causes:  [10, 24, 11, 4, 25, 3, 23, 12, 30]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.998920
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [24, 8, 1, 9, 0, 25, 21]
# Validated causes:  [24]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.997981
# Epoch: 500 [50%] 	Loss: 0.000026
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 4, 21, 9, 10, 11, 1]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 0.998930
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 9, 13, 25, 1, 16, 24, 0, 21, 17, 26, 4]
# Validated causes:  [13]
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.001673
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 11, 3]
# Validated causes:  []
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.999244
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 4, 9, 21, 11, 25, 22, 17, 31, 18, 2]
# Validated causes:  []
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 1.000260
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000072
# Potential causes:  [10, 4, 17, 11, 21, 31, 25, 12]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.997962
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [9, 3, 8, 24, 13, 21, 4, 25, 14, 18]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999716
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [24, 29, 8, 9, 25, 13, 16, 4, 5, 21]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 0.999739
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 20, 25, 2, 4, 17, 31, 22, 11, 9, 21]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.999240
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 4, 9, 25, 21, 11]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.001422
# Epoch: 500 [50%] 	Loss: 0.000497
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [24, 2, 3, 29, 18, 1, 25, 21]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.000421
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [24, 0, 1, 26, 29, 3, 14, 2, 16]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001597
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 25, 29, 8, 26, 12, 5, 24, 17]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.000326
# Epoch: 500 [50%] 	Loss: 0.000976
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 4, 18, 9, 20, 22, 21, 11, 2, 31]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.000210
# Epoch: 500 [50%] 	Loss: 0.000021
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 3, 2, 20, 24, 22, 14, 17, 21]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.001134
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000008
# Potential causes:  [29, 14, 25, 5]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.001054
# Epoch: 500 [50%] 	Loss: 0.000107
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 2, 17, 18, 22, 10, 21, 12, 11]
# Validated causes:  [18]
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 0.998962
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000057
# Potential causes:  [21, 17, 25, 8, 9, 16, 12, 26, 29, 13, 24]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.001434
# Epoch: 500 [50%] 	Loss: 0.000036
# Epoch: 1000 [100%] 	Loss: 0.000206
# Potential causes:  [10, 4, 17, 9, 18, 20, 2, 11, 21]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.000251
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [3, 13, 5, 24, 25, 14, 18, 2, 29, 21, 4, 30]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.000379
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 24, 3]
# Validated causes:  [4, 3]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 0.999223
# Epoch: 500 [50%] 	Loss: 0.000015
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [9, 24, 8, 13, 21, 14, 4, 1, 16, 25, 2]
# Validated causes:  []
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 0.998713
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 20, 22, 18, 4, 21, 2, 11, 9]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.001580
# Epoch: 500 [50%] 	Loss: 0.000106
# Epoch: 1000 [100%] 	Loss: 0.000306
# Potential causes:  [3, 24, 20, 18, 4, 25, 12, 22, 14, 11, 0, 5, 31]
# Validated causes:  []
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 1.000401
# Epoch: 500 [50%] 	Loss: 0.000077
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [8, 0, 24, 16, 12, 26, 9, 17, 1, 29, 25]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.001911
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.001753
# Potential causes:  [3, 24, 14, 25, 5, 8, 16, 26]
# Validated causes:  []
#  Analysis started for target:  VAA
# Epoch:  1 [0%] 	Loss: 1.000252
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 3, 1, 20]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.000834
# Epoch: 500 [50%] 	Loss: 0.000335
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 4, 3, 20, 12, 2, 21, 11, 17]
# Validated causes:  []
# ===================Results for de_2016_2022_tcdf.csv ==================================
# EPFRG causes QOR with a delay of 0 time steps.
# GGFC causes EIAP with a delay of 1 time steps.
# EIS causes EMP with a delay of 1 time steps.
# QOR causes EPFRG with a delay of 1 time steps.
# FDI causes EPFRG with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/de_2016_2022_tcdf.csv=data/demo_groundtruth_de_2016_2022_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/de_2016_2022_tcdf.csv': 'data/demo_groundtruth_de_2016_2022_tcdf.csv'}, data=None)
#
#  Dataset:  de_2016_2022_tcdf.csv
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 0.999673
# Epoch: 250 [50%] 	Loss: 0.000142
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [24, 4, 9, 1, 12, 26, 17, 16, 8]
# Validated causes:  []
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 0.999032
# Epoch: 250 [50%] 	Loss: 0.000176
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [0, 4, 9, 16, 24, 26, 12, 17]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.998528
# Epoch: 250 [50%] 	Loss: 0.000023
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 1, 5, 26, 0, 3, 24, 23, 30, 27]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.999477
# Epoch: 250 [50%] 	Loss: 0.000040
# Epoch: 500 [100%] 	Loss: 0.000039
# Potential causes:  [10, 24, 11, 4, 25, 3, 23, 12, 30]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.998920
# Epoch: 250 [50%] 	Loss: 0.000089
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [24, 8, 1, 9]
# Validated causes:  [24]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.997981
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000026
# Potential causes:  [0, 4, 21, 9, 10, 11, 1]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 0.998930
# Epoch: 250 [50%] 	Loss: 0.000022
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [8, 9, 13, 25, 1, 16, 24, 0, 21, 17, 26, 4]
# Validated causes:  [13]
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.001673
# Epoch: 250 [50%] 	Loss: 0.000010
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [10, 11, 3]
# Validated causes:  []
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.999244
# Epoch: 250 [50%] 	Loss: 0.000009
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [10, 4, 9, 21, 11, 25, 22, 17, 31, 18, 2]
# Validated causes:  []
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 1.000260
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [10, 4, 17, 11, 21, 31, 25, 12]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.997962
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [9, 3, 8, 24, 13, 21, 4, 25, 14, 18]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999716
# Epoch: 250 [50%] 	Loss: 0.000123
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [24, 29, 8, 9, 25, 13, 16, 4, 5, 21]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 0.999739
# Epoch: 250 [50%] 	Loss: 0.000016
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [10, 20, 25, 2, 4, 17, 31, 22, 11, 9, 21]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.999240
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [10, 4, 9, 25, 21, 11]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.001422
# Epoch: 250 [50%] 	Loss: 0.000024
# Epoch: 500 [100%] 	Loss: 0.000497
# Potential causes:  [24, 2, 3, 29, 18, 1, 25, 21]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.000421
# Epoch: 250 [50%] 	Loss: 0.000011
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [24, 0, 1, 26, 29, 3, 14, 2, 16]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001597
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000008
# Potential causes:  [0, 25, 29, 8, 26, 12, 5, 24, 17]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.000326
# Epoch: 250 [50%] 	Loss: 0.000018
# Epoch: 500 [100%] 	Loss: 0.000976
# Potential causes:  [10, 4, 18, 9, 20, 22, 21, 11, 2]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.000210
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000021
# Potential causes:  [4, 3, 2, 20, 24, 22, 14, 17, 21]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.001134
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [29, 14, 25, 5]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.001054
# Epoch: 250 [50%] 	Loss: 0.000098
# Epoch: 500 [100%] 	Loss: 0.000107
# Potential causes:  [4, 2, 17, 18, 22, 10, 21, 12, 11]
# Validated causes:  [18]
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 0.998962
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [21, 17, 25, 8, 9, 16, 12, 26, 29, 13, 24]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.001434
# Epoch: 250 [50%] 	Loss: 0.000046
# Epoch: 500 [100%] 	Loss: 0.000036
# Potential causes:  [10, 4, 17, 9, 18, 20, 2, 11, 21]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.000251
# Epoch: 250 [50%] 	Loss: 0.000021
# Epoch: 500 [100%] 	Loss: 0.000008
# Potential causes:  [3, 13, 5, 24, 25, 14, 18, 2, 29, 21, 4]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.000379
# Epoch: 250 [50%] 	Loss: 0.000051
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 24, 3]
# Validated causes:  [4, 3]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 0.999223
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000015
# Potential causes:  [9, 24, 8, 13, 21, 14, 4, 1, 16, 25, 2]
# Validated causes:  []
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 0.998713
# Epoch: 250 [50%] 	Loss: 0.001166
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [17, 20, 22, 18, 4, 21, 2, 11, 9]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.001580
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000106
# Potential causes:  [3, 24, 20, 18, 4, 25, 12, 22, 14, 11, 0, 5, 31]
# Validated causes:  []
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 1.000401
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000077
# Potential causes:  [8, 0, 24, 16, 12, 26, 9, 17, 1, 29, 25]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.001911
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [3, 24, 14, 25, 5, 8, 16, 26]
# Validated causes:  []
#  Analysis started for target:  VAA
# Epoch:  1 [0%] 	Loss: 1.000252
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [12, 3, 1, 20]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.000834
# Epoch: 250 [50%] 	Loss: 0.000060
# Epoch: 500 [100%] 	Loss: 0.000335
# Potential causes:  [10, 4, 3, 20, 12, 2, 21, 11, 17]
# Validated causes:  []
# ===================Results for de_2016_2022_tcdf.csv ==================================
# EPFRG causes QOR with a delay of 0 time steps.
# GGFC causes EIAP with a delay of 1 time steps.
# EIS causes EMP with a delay of 1 time steps.
# QOR causes EPFRG with a delay of 1 time steps.
# FDI causes EPFRG with a delay of 0 time steps.
#
# ===================Evaluation for de_2016_2022_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  5
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  5
# TPs':  [(4, 24), (6, 13), (20, 18), (24, 4), (24, 3)]
# FPs':  []
# TPs direct:  [(4, 24), (6, 13), (20, 18), (24, 4), (24, 3)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/de_2016_2022_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/de_2016_2022_tcdf.csv'])
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 1.046245
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 1.182639
# Epoch: 500 [50%] 	Loss: 0.000057
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.216025
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000060
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.278850
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000379
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.387851
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.984184
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.379777
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.001929
#
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.508916
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.624715
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 0.823903
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.790685
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.011345
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 0.749416
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.921239
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.086464
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 0.212569
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000005
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.496377
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.547692
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.331950
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.934872
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.731936
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.121083
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000022
#
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 0.695917
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 0.983863
# Epoch: 500 [50%] 	Loss: 0.000036
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 0.544778
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.310574
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 0.441052
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.157550
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 0.742587
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.033661
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VAA
# Epoch:  1 [0%] 	Loss: 1.282865
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.979351
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/de_2016_2022_tcdf.csv : 1.9249161942835114 with standard deviation 2.1916835520311655
