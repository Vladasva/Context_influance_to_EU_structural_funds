# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/pl_2016_2022_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/pl_2016_2022_tcdf.csv'])
#
#  Dataset:  pl_2016_2022_tcdf.csv
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 1.001424
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 1, 27, 25, 24, 8, 17, 20, 2, 9]
# Validated causes:  []
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 1.001684
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [25, 0, 27, 4, 24, 8, 17, 20, 2, 11, 9]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.001212
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 1, 17, 0, 8, 20, 9, 25, 27, 21, 26]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998279
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000120
# Potential causes:  [22, 9]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.001303
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 24, 14, 26, 21, 0, 25, 20]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.002507
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 11, 26, 24, 25, 2, 8, 13, 14, 18, 20]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.002246
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 27, 1, 4, 24, 14, 0, 18, 8, 25, 2, 20]
# Validated causes:  []
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.002250
# Epoch: 500 [50%] 	Loss: 0.000135
# Epoch: 1000 [100%] 	Loss: 0.000476
# Potential causes:  [12, 14, 24, 13, 23, 16, 4, 25, 5, 8]
# Validated causes:  []
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.997444
# Epoch: 500 [50%] 	Loss: 0.000033
# Epoch: 1000 [100%] 	Loss: 0.000237
# Potential causes:  [11, 26, 21, 9, 22, 0, 17, 3]
# Validated causes:  []
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 0.998579
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 26, 21, 24, 0, 16, 18, 5, 4]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 1.000700
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000491
# Potential causes:  [16, 4, 24, 12, 14, 18, 8, 20, 0]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.000464
# Epoch: 500 [50%] 	Loss: 0.000107
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 1, 8, 25, 22, 17, 26, 13, 9, 14]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 0.999247
# Epoch: 500 [50%] 	Loss: 0.000092
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [12, 3, 26, 25, 19, 14]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.997635
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [24, 16, 21, 5, 11, 9, 0, 26, 25]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.000064
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 19, 4]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.002077
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [26, 14, 4, 24, 16, 8, 18, 25, 20]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.000979
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [12, 5, 14, 24, 21, 4]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.998337
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 22, 26, 9, 3, 21, 2, 5, 0]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.997654
# Epoch: 500 [50%] 	Loss: 0.000081
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [9, 26, 11, 5, 3, 21, 0, 22, 2]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.001666
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14, 4, 25, 11, 24, 5, 13, 26, 2, 8]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.997881
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000787
# Potential causes:  [11, 9, 26, 22, 21, 0, 3, 18, 5, 17]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.000277
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.001092
# Potential causes:  [1, 0, 17, 8, 25, 9, 2, 11]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 0.998594
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 9, 26, 2, 21, 3, 0, 5, 18, 17]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 0.999887
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000150
# Potential causes:  [4, 19, 28, 12, 13, 25, 9, 14]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 0.998271
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [0, 11, 4, 21, 24, 26, 9]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.001174
# Epoch: 500 [50%] 	Loss: 0.000150
# Epoch: 1000 [100%] 	Loss: 0.000212
# Potential causes:  [4, 2, 1, 8, 0, 28, 25, 9, 21, 13, 11]
# Validated causes:  []
#  Analysis started for target:  JI
# Epoch:  1 [0%] 	Loss: 1.001278
# Epoch: 500 [50%] 	Loss: 0.000518
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 4, 25, 0, 17, 8, 24, 9, 20, 11, 2]
# Validated causes:  []
#  Analysis started for target:  FOP
# Epoch:  1 [0%] 	Loss: 1.002280
# Epoch: 500 [50%] 	Loss: 0.000182
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 0, 14, 25, 18, 16, 8, 24, 20, 1]
# Validated causes:  [4]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.002267
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [11, 2, 1, 20, 8, 18, 24, 0, 4, 25]
# Validated causes:  []
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 0.999383
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 9, 10, 3, 22, 17, 21, 5, 0]
# Validated causes:  []
#  Analysis started for target:  DBDC
# Epoch:  1 [0%] 	Loss: 0.000094
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 29, 23, 15, 30]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.998131
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [11, 20, 26, 22, 21, 18, 9, 0, 3, 24]
# Validated causes:  []
# ===================Results for pl_2016_2022_tcdf.csv ==================================
# QOR causes FOP with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/pl_2016_2022_tcdf.csv=data/demo_groundtruth_pl_2016_2022_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/pl_2016_2022_tcdf.csv': 'data/demo_groundtruth_pl_2016_2022_tcdf.csv'}, data=None)
#
#  Dataset:  pl_2016_2022_tcdf.csv
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 1.001424
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 1, 27, 25, 24, 8, 17, 20, 2, 9]
# Validated causes:  []
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 1.001684
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [25, 0, 27, 4, 24, 8, 17, 20, 2, 11, 9]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.001212
# Epoch: 250 [50%] 	Loss: 0.000019
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 1, 17, 0, 8, 20, 9, 25, 27, 21, 26]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998279
# Epoch: 250 [50%] 	Loss: 0.000009
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [22, 9]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.001303
# Epoch: 250 [50%] 	Loss: 0.000016
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [11, 24, 14, 26, 21, 0, 25, 20]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.002507
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [4, 11, 26, 24, 25, 2, 8, 13, 14, 18, 20]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.002246
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000014
# Potential causes:  [16, 27, 1, 4, 24, 14, 0, 18, 8, 25, 2, 20]
# Validated causes:  []
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.002250
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000135
# Potential causes:  [12, 14, 24, 13, 23, 16, 4, 25, 5, 8]
# Validated causes:  []
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.997444
# Epoch: 250 [50%] 	Loss: 0.000164
# Epoch: 500 [100%] 	Loss: 0.000033
# Potential causes:  [11, 26, 21, 9, 22, 0, 17, 3]
# Validated causes:  []
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 0.998579
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [11, 26, 21, 24, 0, 16, 18, 5, 4]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 1.000700
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [16, 4, 24, 12, 14, 18, 8, 20, 0]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.000464
# Epoch: 250 [50%] 	Loss: 0.000076
# Epoch: 500 [100%] 	Loss: 0.000107
# Potential causes:  [0, 1, 8, 25, 22, 17, 26, 13, 9, 14]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 0.999247
# Epoch: 250 [50%] 	Loss: 0.000074
# Epoch: 500 [100%] 	Loss: 0.000092
# Potential causes:  [12, 3, 26, 25, 19, 14]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.997635
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000012
# Potential causes:  [24, 16, 21, 5, 11, 9, 0, 26, 25]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.000064
# Epoch: 250 [50%] 	Loss: 0.000068
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [12, 19, 4]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.002077
# Epoch: 250 [50%] 	Loss: 0.000922
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [26, 14, 4, 24, 16, 8, 18, 25, 20]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.000979
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [12, 5, 14, 24, 21, 4]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.998337
# Epoch: 250 [50%] 	Loss: 0.000008
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 22, 26, 9, 3, 21, 2, 5, 0]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.997654
# Epoch: 250 [50%] 	Loss: 0.000028
# Epoch: 500 [100%] 	Loss: 0.000081
# Potential causes:  [9, 26, 11, 5, 3, 21, 0, 22, 2]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.001666
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14, 4, 11, 25, 24, 5, 13, 26, 2, 8]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.997881
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [11, 9, 26, 22, 21, 0, 3, 18, 5, 17]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.000277
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 0, 17, 8, 25, 9, 2, 11]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 0.998594
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 9, 26, 2, 21, 3, 0, 5, 18, 17]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 0.999887
# Epoch: 250 [50%] 	Loss: 0.000021
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 19, 28, 12, 13, 25, 9, 14]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 0.998271
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [0, 11, 4, 21, 24, 26, 9]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.001174
# Epoch: 250 [50%] 	Loss: 0.000020
# Epoch: 500 [100%] 	Loss: 0.000150
# Potential causes:  [4, 2, 1, 8, 0, 28, 25, 9, 21, 13, 11]
# Validated causes:  []
#  Analysis started for target:  JI
# Epoch:  1 [0%] 	Loss: 1.001278
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000518
# Potential causes:  [1, 4, 25, 0, 17, 8, 24, 9, 20, 11, 2]
# Validated causes:  []
#  Analysis started for target:  FOP
# Epoch:  1 [0%] 	Loss: 1.002280
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000182
# Potential causes:  [4, 0, 14, 25, 18, 16, 8, 24, 20, 1]
# Validated causes:  [4]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.002267
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [11, 2, 1, 20, 8, 18, 24, 0, 4, 25]
# Validated causes:  []
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 0.999383
# Epoch: 250 [50%] 	Loss: 0.000007
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 9, 10, 3, 22, 17, 21, 5, 0]
# Validated causes:  []
#  Analysis started for target:  DBDC
# Epoch:  1 [0%] 	Loss: 0.000094
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 29, 23, 15, 30]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.998131
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 20, 26, 22, 21, 18, 9, 0, 3, 24]
# Validated causes:  []
# ===================Results for pl_2016_2022_tcdf.csv ==================================
# QOR causes FOP with a delay of 0 time steps.
#
# ===================Evaluation for pl_2016_2022_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  1
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  1
# TPs':  [(27, 4)]
# FPs':  []
# TPs direct:  [(27, 4)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/pl_2007_2015_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/pl_2007_2015_tcdf.csv'])
#
#  Analysis started for target:  UR
# Epoch:  1 [0%] 	Loss: 1.008027
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  URFF
# Epoch:  1 [0%] 	Loss: 0.907228
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.198394
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000158
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.252137
# Epoch: 500 [50%] 	Loss: 0.000056
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.546627
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.577188
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 0.797469
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.248439
# Epoch: 500 [50%] 	Loss: 0.000397
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  P65
# Epoch:  1 [0%] 	Loss: 0.481683
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  P014
# Epoch:  1 [0%] 	Loss: 1.170403
# Epoch: 500 [50%] 	Loss: 0.000035
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 1.265500
# Epoch: 500 [50%] 	Loss: 0.000039
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.859403
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.217729
# Epoch: 500 [50%] 	Loss: 0.000038
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.063610
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.252381
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000274
#
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.225025
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.874213
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.813472
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.901856
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.127359
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.193213
# Epoch: 500 [50%] 	Loss: 0.000158
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.173863
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 0.304589
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 0.962011
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000005
#
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.085337
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.056007
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 1.083442
# Epoch: 500 [50%] 	Loss: 0.000068
# Epoch: 1000 [100%] 	Loss: 0.000226
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.110520
# Epoch: 500 [50%] 	Loss: 0.000054
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.973926
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000312
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.078191
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 0.931027
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.029341
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000006
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/pl_2007_2015_tcdf.csv : 8.530593430091075 with standard deviation 15.427037636503805
