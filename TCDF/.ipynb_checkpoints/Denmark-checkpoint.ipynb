# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/dk_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/dk_tcdf.csv'])
#
#  Dataset:  dk_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.999861
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000434
# Potential causes:  [9, 1, 17, 15, 6, 11, 21, 13, 10]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.002689
# Epoch: 500 [50%] 	Loss: 0.000077
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 8]
# Validated causes:  [8]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999073
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 6, 18, 8]
# Validated causes:  [10]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.997893
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000063
# Potential causes:  [0, 13, 9, 17]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.002294
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 16, 17, 4]
# Validated causes:  [6, 4]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.001093
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 23, 18, 8, 10, 2, 11, 7, 17]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.002265
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 18, 10, 2, 16, 5, 23, 7, 17]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.007392
# Epoch: 500 [50%] 	Loss: 0.000111
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 18, 5, 21, 14, 12]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002738
# Epoch: 500 [50%] 	Loss: 0.000026
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 8, 16, 1, 21, 12, 5]
# Validated causes:  [17, 8]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.000498
# Epoch: 500 [50%] 	Loss: 0.000022
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [6, 1, 20, 17, 21, 0]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.003726
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000047
# Potential causes:  [11, 17, 18, 23]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.003187
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 16, 9, 22, 7, 1, 14, 20, 12, 15, 0, 21]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.999493
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 16, 8, 12]
# Validated causes:  [1]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006750
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000008
# Potential causes:  [12, 14]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997306
# Epoch: 500 [50%] 	Loss: 0.000067
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 21, 17]
# Validated causes:  [1]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.001791
# Epoch: 500 [50%] 	Loss: 0.000121
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 1, 15, 16, 17, 8]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.002339
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 23, 14, 11, 7, 4, 8, 17, 12]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.004960
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000148
# Potential causes:  [18, 16]
# Validated causes:  [16]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.002623
# Epoch: 500 [50%] 	Loss: 0.000064
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 23, 6, 10, 7, 2, 5, 11]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.004933
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [8, 18]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.003957
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 18]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.002285
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000168
# Potential causes:  [20, 8, 22]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.006049
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 9, 12, 14, 21]
# Validated causes:  [9]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.003245
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 17]
# Validated causes:  []
# ===================Results for dk_tcdf.csv ==================================
# GGAG causes GDPCG with a delay of 0 time steps.
# CO2 causes VABI with a delay of 2 time steps.
# QOR causes PAG with a delay of 2 time steps.
# PAG causes PAG with a delay of 2 time steps.
# ROL causes GGAG with a delay of 3 time steps.
# GGAG causes GGAG with a delay of 1 time steps.
# GDPCG causes FDI with a delay of 1 time steps.
# GDPCG causes LBGD with a delay of 0 time steps.
# ARP causes ROL with a delay of 2 time steps.
# REST causes PT with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/dk_tcdf.csv=data/demo_groundtruth_dk_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/dk_tcdf.csv': 'data/demo_groundtruth_dk_tcdf.csv'}, data=None)
#
#  Dataset:  dk_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.999861
# Epoch: 250 [50%] 	Loss: 0.000154
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [9, 1, 17, 15, 6, 11, 21, 13, 10]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.002689
# Epoch: 250 [50%] 	Loss: 0.000180
# Epoch: 500 [100%] 	Loss: 0.000077
# Potential causes:  [14, 8]
# Validated causes:  [8]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999073
# Epoch: 250 [50%] 	Loss: 0.000366
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [10, 6, 18, 8]
# Validated causes:  [10]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.997893
# Epoch: 250 [50%] 	Loss: 0.000346
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [0, 13, 9, 17]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.002294
# Epoch: 250 [50%] 	Loss: 0.000011
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [6, 16, 17, 4]
# Validated causes:  [6, 4]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.001093
# Epoch: 250 [50%] 	Loss: 0.000018
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [6, 23, 18, 8, 10, 2, 11, 7, 17]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.002265
# Epoch: 250 [50%] 	Loss: 0.000153
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [11, 18, 10, 2, 16, 5, 23, 7, 17]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.007392
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000111
# Potential causes:  [11, 18, 5, 21, 14, 12]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002738
# Epoch: 250 [50%] 	Loss: 0.000119
# Epoch: 500 [100%] 	Loss: 0.000026
# Potential causes:  [17, 8, 16, 1, 21, 12, 5]
# Validated causes:  [17, 8]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.000498
# Epoch: 250 [50%] 	Loss: 0.000011
# Epoch: 500 [100%] 	Loss: 0.000022
# Potential causes:  [6, 1, 20, 17, 21, 0]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.003726
# Epoch: 250 [50%] 	Loss: 0.000032
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [11, 17, 18, 23]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.003187
# Epoch: 250 [50%] 	Loss: 0.000015
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [8, 16, 9, 22, 7, 1, 14]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.999493
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 16, 8, 12]
# Validated causes:  [1]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006750
# Epoch: 250 [50%] 	Loss: 0.000058
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997306
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000067
# Potential causes:  [1, 21, 17]
# Validated causes:  [1]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.001791
# Epoch: 250 [50%] 	Loss: 0.000121
# Epoch: 500 [100%] 	Loss: 0.000121
# Potential causes:  [12, 1, 15, 16, 17, 8]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.002339
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [16, 23, 14, 11, 7, 4, 8, 17, 12]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.004960
# Epoch: 250 [50%] 	Loss: 0.000009
# Epoch: 500 [100%] 	Loss: 0.000008
# Potential causes:  [18, 16]
# Validated causes:  [16]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.002623
# Epoch: 250 [50%] 	Loss: 0.000172
# Epoch: 500 [100%] 	Loss: 0.000064
# Potential causes:  [21, 23, 6, 10, 7, 2, 5, 11]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.004933
# Epoch: 250 [50%] 	Loss: 0.000143
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [8, 18]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.003957
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [8, 18]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.002285
# Epoch: 250 [50%] 	Loss: 0.000340
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [20, 8, 22]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.006049
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [11, 9, 12, 14, 21]
# Validated causes:  [9]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.003245
# Epoch: 250 [50%] 	Loss: 0.000026
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [8, 17]
# Validated causes:  []
# ===================Results for dk_tcdf.csv ==================================
# GGAG causes GDPCG with a delay of 0 time steps.
# CO2 causes VABI with a delay of 2 time steps.
# QOR causes PAG with a delay of 2 time steps.
# PAG causes PAG with a delay of 2 time steps.
# ROL causes GGAG with a delay of 3 time steps.
# GGAG causes GGAG with a delay of 1 time steps.
# GDPCG causes FDI with a delay of 1 time steps.
# GDPCG causes LBGD with a delay of 0 time steps.
# ARP causes ROL with a delay of 2 time steps.
# REST causes PT with a delay of 0 time steps.
#
# ===================Evaluation for dk_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  10
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  10
# TPs':  [(1, 8), (2, 10), (4, 6), (4, 4), (8, 17), (8, 8), (12, 1), (14, 1), (17, 16), (22, 9)]
# FPs':  []
# TPs direct:  [(1, 8), (2, 10), (4, 6), (4, 4), (8, 17), (8, 8), (12, 1), (14, 1), (17, 16), (22, 9)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/dk_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/dk_tcdf.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.523749
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 0.701899
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.206442
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000006
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.618121
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.064830
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.204569
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.140342
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.160973
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.307039
# Epoch: 500 [50%] 	Loss: 0.000237
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.812208
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.854663
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.813567
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.808762
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.696668
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.023038
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.547665
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000011
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.297297
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000004
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.137934
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.250384
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.960951
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.020952
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000497
#
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.131072
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.338430
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.264563
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000076
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/dk_tcdf.csv : 2.752418527509335 with standard deviation 3.4749185344535003
