# %%
import warnings
from causalnex.structure import StructureModel
warnings.filterwarnings("ignore")  # silence warnings
from causalnex.structure.notears import from_pandas
from causalnex.plots import plot_structure, NODE_STYLE, EDGE_STYLE
from causalnex.network import BayesianNetwork
import pandas as pd
from causalnex.discretiser import Discretiser
import numpy as np
from sklearn.model_selection import train_test_split
from causalnex.structure.notears import from_pandas_lasso
from IPython.display import Image
from causalnex.evaluation import classification_report
from causalnex.evaluation import roc_auc
from causalnex.inference import InferenceEngine
from causalnex.evaluation import classification_report
import copy
import networkx as nx
import turtorial_utils as utils

# %%
df_lt = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/de_2016_2022_bn.csv")

# %%
df_de = df_lt.drop(["Unnamed: 0"], axis = 1)

# %%
df_de
# Out:
#     FDI  QOR       QOA  EIAP        PDPS   PGP   VABI       GCFP       GGFC  \
# 0  1.64  5.6  5.900000  1.31  236.000000  0.81  26.22  19.734865  19.519072
# 1  2.89  5.5  5.800000  1.28  237.000000  0.37  26.12  20.513282  19.459550
# 2  4.00  5.5  5.600000  1.25  237.000000  0.30  25.94  21.470536  19.502234
# 3  1.91  5.3  5.500000  1.20  238.000000  0.23  25.63  21.300072  19.903024
# 4  4.49  5.5  6.166923  1.22  238.000000  0.08  25.38  21.666734  21.731321
# 5  2.93  5.5  6.166923  1.25  238.000000  0.04  25.31  22.461389  21.674219
# 6  2.09  5.5  6.166923  1.24  234.933333  0.72  25.69  23.021055  21.521327
#
#       GDPCG  ...   FEM   LFG         EPFRG          GGAG    DI   COC   CPI  \
# 0  1.472293  ...  73.6  0.43   -682.000000   3007.000000  8.63  1.78  81.0
# 1  2.332866  ...  74.3  0.27  27047.000000 -17289.000000  8.61  1.80  81.0
# 2  0.813017  ...  75.0  0.22   8209.000000 -28666.000000  8.68  1.90  80.0
# 3  0.760402  ...  75.7  0.37  16219.010000 -50838.000000  8.68  1.87  80.0
# 4 -4.173453  ...  74.6 -0.61  12158.990000 -58901.000000  8.67  1.83  80.0
# 5  3.626129  ...  75.9 -0.09 -21616.800000 -17183.714286  8.67  1.78  80.0
# 6  0.641609  ...  77.0  0.67  10577.546667 -17183.714286  8.80  1.82  79.0
#
#     ROL   VAA          EUPC
# 0  1.58  1.36  2.350574e+06
# 1  1.57  1.43  1.710234e+07
# 2  1.59  1.44  2.260392e+07
# 3  1.58  1.35  2.762046e+07
# 4  1.52  1.37  2.586161e+07
# 5  1.57  1.42  3.239572e+07
# 6  1.53  1.41  3.509775e+07
#
# [7 rows x 27 columns]

# %%
sm = StructureModel()

# %%
sm.add_edges_from([
    ('FEM', 'EUPC'),
])

# %%
sm.edges
# Out:
# OutEdgeView([('FEM', 'EUPC')])

# %%
viz = plot_structure(
    sm,
    all_node_attributes=NODE_STYLE.WEAK,
    all_edge_attributes=EDGE_STYLE.WEAK,
)

viz.toggle_physics(False)
viz.show("Graphs/fully_connected_lt_2016_2022.html")
# Out:
# Graphs/fully_connected_lt_2016_2022.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="Graphs/fully_connected_lt_2016_2022.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
bn = BayesianNetwork(sm)

# %%
discretised_de = pd.DataFrame(index=df_de.index)

for col in df_de.columns:
    no_unique = df_de[col].nunique()
    
    if no_unique <= 1:
        discretised_de[col] = 0
    else:
        try:
            discretised_de[col] = pd.qcut(
                df_de[col], 
                q=min(3, no_unique),  
                labels=False,
                duplicates='drop'
            ).astype(int)
        except ValueError:
            discretised_de[col] = df_de[col].rank(method='dense').astype(int) - 1

print("Discretised data:")
print(discretised_de)
# Out:
# Discretised data:
#    FDI  QOR  QOA  EIAP  PDPS  PGP  VABI  GCFP  GGFC  GDPCG  ...  FEM  LFG  \
# 0    0    1    1     2     0    2     2     0     0      1  ...    0    2
# 1    1    0    0     2     0    1     2     0     0      2  ...    0    1
# 2    2    0    0     1     0    1     1     1     0      1  ...    1    0
# 3    0    0    0     0     1    0     0     0     1      0  ...    1    1
# 4    2    0    1     0     1    0     0     1     2      0  ...    0    0
# 5    1    0    1     1     1    0     0     2     2      2  ...    2    0
# 6    0    0    1     0     0    2     1     2     1      0  ...    2    2
#
#    EPFRG  GGAG  DI  COC  CPI  ROL  VAA  EUPC
# 0      0     2   0    0    1    1    0     0
# 1      2     1   0    0    1    0    2     0
# 2      0     0   1    2    0    2    2     0
# 3      2     0   1    2    0    1    0     1
# 4      1     0   0    1    0    0    0     1
# 5      0     1   0    0    0    0    1     2
# 6      1     1   2    1    0    0    1     2
#
# [7 rows x 27 columns]

# %%
discretised_de = discretised_de.reset_index(drop=True)
bn.fit_node_states(discretised_de)
baseline_auc = utils.get_avg_auc_all_info(discretised_de, bn)
print(f"Baseline AUC: {baseline_auc}")
# Out:
# Processing fold 0 using 7 cores takes 3.714531183242798 seconds
# Processing fold 1 using 7 cores takes 2.8850817680358887 seconds
# Processing fold 2 using 7 cores takes 2.940380096435547 seconds
# Processing fold 3 using 7 cores takes 2.9379680156707764 seconds
# Processing fold 4 using 7 cores takes 2.92348313331604 seconds
# Baseline AUC: 0.6375

# %%
edges_to_add = [('LV', 'FEM'), ('LV', 'EUPC')]
edges_to_remove = [('FEM', 'EUPC')]

bn_with_lv = copy.deepcopy(bn)
bn_with_lv.add_node(
    "LV",
    edges_to_add=edges_to_add,
    edges_to_remove=edges_to_remove,
)

# %%
viz = utils.plot_pretty_structure(bn_with_lv.structure, edges_to_highlight=edges_to_add)
viz.show("Graphs/node_added_lt_2016_2022.html")
# Out:
# Graphs/node_added_lt_2016_2022.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="Graphs/node_added_lt_2016_2022.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
discretised_de['LV'] = None
lv_states = [0, 1, 2, 3, 4]

proposed_auc = utils.get_avg_auc_lvs(discretised_de, bn_with_lv, lv_states)
print(f"AUC from adding LV between 'FEM' and 'EUPC': {proposed_auc}")
# Out:
# Processing fold 0 using 7 cores takes 3.19940185546875 seconds
# Processing fold 1 using 7 cores takes 2.9549779891967773 seconds
# Processing fold 2 using 7 cores takes 2.9557981491088867 seconds
# Processing fold 3 using 7 cores takes 2.9539639949798584 seconds
# Processing fold 4 using 7 cores takes 2.932590961456299 seconds
# AUC from adding LV between 'FEM' and 'EUPC': 0.65
