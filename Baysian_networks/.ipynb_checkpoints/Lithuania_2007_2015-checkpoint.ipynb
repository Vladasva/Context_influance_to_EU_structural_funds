# %%
import warnings
from causalnex.structure import StructureModel
warnings.filterwarnings("ignore")  # silence warnings
from causalnex.structure.notears import from_pandas
from causalnex.plots import plot_structure, NODE_STYLE, EDGE_STYLE
from causalnex.network import BayesianNetwork
import pandas as pd
from causalnex.discretiser import Discretiser
import numpy as np
from sklearn.model_selection import train_test_split
from causalnex.structure.notears import from_pandas_lasso
from IPython.display import Image
from causalnex.evaluation import classification_report
from causalnex.evaluation import roc_auc
from causalnex.inference import InferenceEngine
from causalnex.evaluation import classification_report
import copy
import networkx as nx
import turtorial_utils as utils
# Out:
# WARNING:root:MDLP was not imported successfully

# %%
df_lt = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lt_2007_2015_bn.csv")

# %%
df_lt = df_lt.drop(["Unnamed: 0"], axis = 1)

# %%
df_lt
# Out:
#     FDI   QOR   QOA   EIAP  PDPS   PGP   VABI       GCFP       GGFC  \
# 0  6.55  4.97  4.40  11.33  52.0 -1.19  29.65  32.439675  17.451336
# 1  3.61  5.21  4.61   8.06  51.0 -1.03  29.20  28.246152  18.666542
# 2 -0.96  5.28  4.22   8.98  50.0 -1.11  25.02  12.979845  21.205413
# 3  3.01  5.27  3.57   8.83  49.0 -2.10  26.21  17.857801  20.110710
# 4  4.36  5.23  3.73   8.49  48.0 -2.26  28.35  22.367203  18.467399
# 5  1.59  5.17  4.23   8.80  48.0 -1.34  28.20  20.270408  17.543879
# 6  1.66  5.02  4.32   8.42  47.0 -1.01  27.62  20.418290  16.735544
# 7  0.74  4.94  4.19   9.17  47.0 -0.86  27.73  20.300477  16.691874
# 8  2.50  4.96  4.12   9.07  46.0 -0.94  26.96  22.555227  17.168991
#
#        GDPCG  ...        FEM   LFG   EPFRG    GGAG  PR    RQ   COC   ROL  \
# 0  12.405345  ...  72.364286  0.00  122.00  1013.0  50  1.01  0.10  0.69
# 1   3.660125  ...  72.364286  0.00   40.09  -563.0  50  1.04  0.11  0.68
# 2 -13.887757  ...  67.200000  0.01   60.00 -3576.0  50  0.95  0.23  0.72
# 3   2.555336  ...  65.000000 -0.03  111.00   806.0  55  0.96  0.37  0.78
# 4   8.752239  ...  66.600000 -0.01  261.18  -532.0  60  0.93  0.32  0.77
# 5   5.743976  ...  67.900000 -0.01  127.73   -81.0  60  1.12  0.39  0.84
# 6   5.026825  ...  68.600000  0.00  245.00  -892.0  60  1.15  0.42  0.83
# 7   4.620353  ...  70.600000  0.01  107.00  -452.0  60  1.19  0.55  0.94
# 8   3.756324  ...  72.200000 -0.01  217.00   260.0  60  1.26  0.58  0.98
#
#     CPI          EUPC
# 0  48.0  4.552199e+07
# 1  46.0  7.072410e+07
# 2  49.0  3.379351e+08
# 3  50.0  2.812316e+08
# 4  48.0  3.095020e+08
# 5  54.0  3.391262e+08
# 6  57.0  3.623330e+08
# 7  58.0  3.446086e+08
# 8  61.0  2.963516e+07
#
# [9 rows x 27 columns]

# %%
lt = pd.DataFrame()
lt = df_lt.copy()
lt['PDPS_1'] = lt['PDPS'].shift(1)
lt['GDPC_1'] = lt['GDPC'].shift(1)
lt['EIAP_3'] = lt['EIAP'].shift(3)
lt['FDI_3'] = lt['FDI'].shift(3)

# %%
lt = lt.dropna()

# %%
sm = StructureModel()

# %%
sm.add_edges_from([
    ('FDI_3', 'EUPC'),
])

# %%
sm.edges
# Out:
# OutEdgeView([('FDI_3', 'EUPC')])

# %%
viz = plot_structure(
    sm,
    all_node_attributes=NODE_STYLE.WEAK,
    all_edge_attributes=EDGE_STYLE.WEAK,
)

viz.toggle_physics(False)
viz.show("Graphs/fully_connected_lt_2016_2022.html")
# Out:
# Graphs/fully_connected_lt_2016_2022.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="Graphs/fully_connected_lt_2016_2022.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
bn = BayesianNetwork(sm)

# %%
discretised_lt = pd.DataFrame(index=lt.index)

for col in lt.columns:
    no_unique = lt[col].nunique()
    
    if no_unique <= 1:
        discretised_lt[col] = 0
    else:
        try:
            discretised_lt[col] = pd.qcut(
                lt[col], 
                q=min(3, no_unique),  
                labels=False,
                duplicates='drop'
            ).astype(int)
        except ValueError:
            discretised_lt[col] = lt[col].rank(method='dense').astype(int) - 1

print("Discretised data:")
print(discretised_lt)
# Out:
# Discretised data:
#    FDI  QOR  QOA  EIAP  PDPS  PGP  VABI  GCFP  GGFC  GDPCG  ...  PR  RQ  COC  \
# 3    2    2    0     1     2    0     0     0     2      0  ...   0   0    0
# 4    2    2    0     0     1    0     2     2     2      2  ...   0   0    0
# 5    0    1    2     1     1    1     2     0     1      2  ...   0   1    1
# 6    1    1    2     0     0    1     1     1     0      1  ...   0   1    1
# 7    0    0    1     2     0    2     1     1     0      1  ...   0   2    2
# 8    1    0    1     2     0    2     0     2     1      0  ...   0   2    2
#
#    ROL  CPI  EUPC  PDPS_1  GDPC_1  EIAP_3  FDI_3
# 3    0    0     0       2       0       2      2
# 4    0    0     1       2       0       0      1
# 5    1    1     1       1       1       2      0
# 6    1    1     2       1       1       1      1
# 7    2    2     2       0       2       0      2
# 8    2    2     0       0       2       1      0
#
# [6 rows x 31 columns]

# %%
discretised_lt = discretised_lt.reset_index(drop=True)
bn.fit_node_states(discretised_lt)
baseline_auc = utils.get_avg_auc_all_info(discretised_lt, bn)
print(f"Baseline AUC: {baseline_auc}")
# Out:
# Processing fold 0 using 7 cores takes 3.8241751194000244 seconds
# Processing fold 1 using 7 cores takes 2.935138702392578 seconds
# Processing fold 2 using 7 cores takes 2.8834140300750732 seconds
# Processing fold 3 using 7 cores takes 2.8411121368408203 seconds
# Processing fold 4 using 7 cores takes 2.9221768379211426 seconds
# Baseline AUC: 0.14375

# %%
edges_to_add = [('LV', 'FDI_3'), ('LV', 'EUPC')]
edges_to_remove = [('FDI_3', 'EUPC')]

bn_with_lv = copy.deepcopy(bn)
bn_with_lv.add_node(
    "LV",
    edges_to_add=edges_to_add,
    edges_to_remove=edges_to_remove,
)

# %%
viz = utils.plot_pretty_structure(bn_with_lv.structure, edges_to_highlight=edges_to_add)
viz.show("Graphs/node_added_lt_2016_2022.html")
# Out:
# Graphs/node_added_lt_2016_2022.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="Graphs/node_added_lt_2016_2022.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
discretised_lt['LV'] = None
lv_states = [0, 1, 2, 3, 4]

proposed_auc = utils.get_avg_auc_lvs(discretised_lt, bn_with_lv, lv_states)
print(f"AUC from adding LV between 'FDI_3' and 'EUPC': {proposed_auc}")
# Out:
# Processing fold 0 using 7 cores takes 3.1451058387756348 seconds
# Processing fold 1 using 7 cores takes 3.0895071029663086 seconds
# Processing fold 2 using 7 cores takes 2.9267349243164062 seconds
# Processing fold 3 using 7 cores takes 2.9384100437164307 seconds
# Processing fold 4 using 7 cores takes 3.0020017623901367 seconds
# AUC from adding LV between 'FDI_3' and 'EUPC': 0.025
