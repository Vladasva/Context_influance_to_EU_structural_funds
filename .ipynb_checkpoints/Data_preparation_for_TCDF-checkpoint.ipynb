# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
def missing_values(df):
    for feature in df.columns:
        missing_values = df[feature].isna().sum()
        percentage = missing_values/len(df) * 100
        print(f'{feature} - {missing_values} - {round(percentage, 1)} %')
        
def fill_with_mode(df, feature_list):
    for feature in feature_list:
        mode = df[feature].mode()[0]
        df[feature].fillna(value=mode, inplace=True)

def fill_with_mean(df, feature_list):
    for feature in feature_list:
        df[feature] = pd.to_numeric(df[feature], errors='coerce')
        mean = df[feature].mean()
        df[feature].fillna(value=mean, inplace=True)

# %%
df_dk = pd.read_csv("Data/y/Denmark.csv")

# %%
df_dk = df_dk.loc[6:22]

# %%
df_dk
# Out:
#     Unnamed: 0 REF_AREA_LABEL  TIME_PERIOD    HI    LF    UR  URFF    YUA  \
# 6            6        Denmark         2006   NaN  2.93  3.90  4.53   7.69
# 7            7        Denmark         2007   NaN  2.93  3.80  4.20   7.49
# 8            8        Denmark         2008   NaN  2.92  3.68  4.07   9.47
# 9            9        Denmark         2009   NaN  2.91  6.41  5.67  13.44
# 10          10        Denmark         2010   NaN  2.89  7.75  6.76  15.55
# 11          11        Denmark         2011   NaN  2.89  7.77  7.62  16.31
# 12          12        Denmark         2012   NaN  2.88  7.80  7.79  15.77
# 13          13        Denmark         2013  7.69  2.85  7.38  7.67  14.77
# 14          14        Denmark         2014   NaN  2.87  6.93  7.14  14.20
# 15          15        Denmark         2015  7.53  2.90  6.28  6.53  12.15
# 16          16        Denmark         2016  7.53  2.94  5.99  6.38  12.15
# 17          17        Denmark         2017  7.52  2.97  5.83  6.05  12.38
# 18          18        Denmark         2018  7.56  2.99  5.13  5.35  10.52
# 19          19        Denmark         2019  7.60  3.03  5.02  5.27  10.04
# 20          20        Denmark         2020  7.62  3.03  5.64  5.98  11.59
# 21          21        Denmark         2021  7.64  3.08  5.04  5.14  10.81
# 22          22        Denmark         2022  7.59  3.15  4.43  4.49  10.53
#
#      FDI   QOR  ...       EIA      EBSG           GDPC           GDP  \
# 6   0.84  6.36  ...  3.088325  3.938871  309942.332478  2.087455e+12
# 7   3.69  6.42  ...  2.963823  2.747300  319173.149269  2.108062e+12
# 8   0.62  6.23  ...  2.705862  3.471527  329422.223703  2.099268e+12
# 9   1.17  6.06  ...  2.759311  4.602963  313144.896657  1.994840e+12
# 10 -3.57  6.17  ...  2.543765  6.793833  326784.316443  2.026416e+12
# 11  3.94  6.29  ...  2.394463  6.154324  331838.652835  2.052979e+12
# 12 -5.00  5.73  ...  2.637166  5.799405  338534.135302  2.052867e+12
# 13  0.20  5.45  ...  2.593595  6.229005  344715.698783  2.081457e+12
# 14  1.86  5.43  ...  2.480217  6.455948  350893.947080  2.108058e+12
# 15  0.61  5.59  ...  2.491587  6.498281  357211.575191  2.152420e+12
# 16  2.50  5.70  ...  2.334158  6.035122  366884.878867  2.218565e+12
# 17  1.09  5.50  ...  2.110610  6.476226  379808.676526  2.286375e+12
# 18  2.47  5.50  ...  2.191696  5.152751  387242.522658  2.328902e+12
# 19 -1.10  5.60  ...  2.222962  6.009741  396193.582956  2.368759e+12
# 20  0.36   NaN  ...  2.114530  5.640362  398976.348406  2.326592e+12
# 21  4.16   NaN  ...  2.044519  6.236804  438387.741596  2.498343e+12
# 22  7.67   NaN  ...  2.117067  9.553789  481824.514568  2.536822e+12
#
#           EIS      NINA      LBGD   EMP  LTU   FEM
# 6   73.580644  1.362713  5.490254     :    :   NaN
# 7   73.529373  1.734853  5.548536     :    :     :
# 8   74.038959  1.614779  3.835619     :    :     :
# 9   76.669794  1.614948 -2.111442  76.1  0.6  73.1
# 10  77.590382  1.782949 -2.441067  74.9  1.4  72.0
# 11  77.570639  1.709736 -1.887012  74.8  1.8  71.4
# 12  77.594093  2.043067 -3.257951  74.3  2.1  71.1
# 13  77.765169  2.004696 -1.181728  74.3  1.8  71.2
# 14  78.149649  2.200518  1.252108  74.7  1.7  71.0
# 15  78.083956  2.024130 -1.143677  75.4  1.6  71.5
# 16  78.617617  2.175615 -0.070663  76.0  1.2  72.5
# 17  78.951173       NaN  1.457031  76.6  1.2  73.2
# 18  78.898577       NaN  0.801500  77.5  1.0  73.9
# 19  79.231066       NaN  4.079333  78.3  0.8  74.7
# 20  78.996916       NaN  0.081707  77.8  0.9  74.3
# 21  78.620328       NaN  3.868870  79.0  1.0  75.5
# 22  78.808652       NaN  3.323468  80.1  0.5  77.4
#
# [17 rows x 35 columns]

# %%
df_dk = df_dk.copy()
df_dk['LFG'] = df_dk['LF'].diff()
df_dk['EPFRG'] = df_dk['EPFR'].diff()
df_dk['GGAG'] = df_dk['GGA'].diff()
df_dk = df_dk.drop(6)

# %%
df_dk = df_dk.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_dk["EMP"] = df_dk["EMP"].replace(':', np.nan)
df_dk["LTU"] = df_dk["LTU"].replace(':', np.nan)
df_dk["FEM"] = df_dk["FEM"].replace(':', np.nan)

# %%
missing_values(df_dk)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 2 - 12.5 %
# LTU - 2 - 12.5 %
# FEM - 2 - 12.5 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
fill_with_mode(df_dk, ["QOR", "QOA"])

# %%
fill_with_mean(df_dk, ["EMP", "LTU", "FEM", "EPFRG", "GGAG", "PDPS"])

# %%
dk_context_2007_2015 = pd.read_csv("Data/Context/Denmark_2007_2015.csv")

# %%
dk_context_2007_2015 = dk_context_2007_2015[["TIME_PERIOD", "ROL", "GE", "COC", "VAA", "CPI"]]

# %%
dk_context_2007_2015
# Out:
#    TIME_PERIOD   ROL    GE   COC   VAA   CPI
# 0         2007  2.00  2.35  2.43  1.48  94.0
# 1         2008  1.95  2.24  2.38  1.54  93.0
# 2         2009  1.92  2.23  2.44  1.54  93.0
# 3         2010  1.90  2.10  2.35  1.54  93.0
# 4         2011  1.92  2.10  2.39  1.55  94.0
# 5         2012  1.88  1.99  2.38  1.67  90.0
# 6         2013  1.90  1.94  2.40  1.67  91.0
# 7         2014  2.10  1.78  2.25  1.52  92.0
# 8         2015  2.02  1.79  2.19  1.55  91.0

# %%
eu_payments = pd.read_csv("Raw_Data/Variables/Historic_EU_payments_annual_timeseries_-_regionalised_and_modelled_20251209.csv")

# %%
eu_payments = eu_payments.drop(['NUTS1_ID', 'NUTS2 code+name', 'NUTS2_ID', 'NUTS2_name', 'Modelled_annual_expenditure',
                  'Standard_Deviation_of_annual_expenditure', 'Standard_Error_of_modelled_annual_expenditure'], axis=1)

# %%
dk_eu_payments = eu_payments[eu_payments['Country'] == 'DK'].copy()

# %%
dk_eu_payments
# Out:
#      Country  Fund  Year Programming_Period EU_Payment_annual
# 833       DK  ERDF  2007          2007-2013         1,194,717
# 834       DK  ERDF  2008          2007-2013         1,792,076
# 835       DK  ERDF  2009          2007-2013         2,228,417
# 836       DK  ERDF  2010          2007-2013         4,678,038
# 837       DK  ERDF  2011          2007-2013        15,425,586
# ...      ...   ...   ...                ...               ...
# 2483      DK   ESF  2018          2014-2020         2,077,670
# 2484      DK   ESF  2019          2014-2020         2,615,692
# 2485      DK   ESF  2020          2014-2020         2,376,965
# 2486      DK   ESF  2021          2014-2020         4,074,111
# 2487      DK   ESF  2022          2014-2020         3,321,554
#
# [180 rows x 5 columns]

# %%
dk_eu_payments['EU_Payment_annual'] = pd.to_numeric(dk_eu_payments['EU_Payment_annual'].str.replace(',', ''))

# %%
dk_eu_payments_2007_2015 = dk_eu_payments[dk_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

# %%
dk_eu_payments_2007_2015 = dk_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

# %%
dk_eu_payments_2007_2015
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 0         2007           10191540
# 1         2008           15287312
# 2         2009           33350959
# 3         2010           41600829
# 4         2011           94651644
# 5         2012           35523496
# 6         2013           46669931
# 7         2014          134429401
# 8         2015           72393232
# 9         2017           25478856

# %%
dk_eu_payments_2007_2015 = dk_eu_payments_2007_2015.loc[0:8]

# %%
df_dk_2007_2015 = df_dk.loc[7:15]

# %%
df_dk_2007_2015
# Out:
#     TIME_PERIOD    UR  URFF    YUA   FDI   QOR   QOA  EIAP    PS   PDPS  ...  \
# 7          2007  3.80  4.20   7.49  3.69  6.42  6.45  2.96  5.46  137.0  ...
# 8          2008  3.68  4.07   9.47  0.62  6.23  6.44  2.71  5.49  137.0  ...
# 9          2009  6.41  5.67  13.44  1.17  6.06  6.43  2.76  5.52  138.0  ...
# 10         2010  7.75  6.76  15.55 -3.57  6.17  6.37  2.54  5.55  139.0  ...
# 11         2011  7.77  7.62  16.31  3.94  6.29  6.32  2.39  5.57  139.0  ...
# 12         2012  7.80  7.79  15.77 -5.00  5.73  5.97  2.64  5.59  140.0  ...
# 13         2013  7.38  7.67  14.77  0.20  5.45  5.64  2.59  5.61  140.0  ...
# 14         2014  6.93  7.14  14.20  1.86  5.43  5.56  2.48  5.64  141.0  ...
# 15         2015  6.28  6.53  12.15  0.61  5.59  5.58  2.49  5.68  142.0  ...
#
#         EBSG           GDPC        EIS      LBGD        EMP       LTU  \
# 7   2.747300  319173.149269  73.529373  5.548536  76.414286  1.257143
# 8   3.471527  329422.223703  74.038959  3.835619  76.414286  1.257143
# 9   4.602963  313144.896657  76.669794 -2.111442  76.100000  0.600000
# 10  6.793833  326784.316443  77.590382 -2.441067  74.900000  1.400000
# 11  6.154324  331838.652835  77.570639 -1.887012  74.800000  1.800000
# 12  5.799405  338534.135302  77.594093 -3.257951  74.300000  2.100000
# 13  6.229005  344715.698783  77.765169 -1.181728  74.300000  1.800000
# 14  6.455948  350893.947080  78.149649  1.252108  74.700000  1.700000
# 15  6.498281  357211.575191  78.083956 -1.143677  75.400000  1.600000
#
#           FEM   LFG    EPFRG    GGAG
# 7   73.057143  0.00  1099.00 -4900.0
# 8   73.057143 -0.01  -207.00 -3557.0
# 9   73.100000 -0.01   -25.80 -2932.0
# 10  72.000000 -0.02  2364.18   251.0
# 11  71.400000  0.00  1755.68 -5488.0
# 12  71.100000 -0.01   656.38 -5127.0
# 13  71.200000 -0.03  1134.28  1404.0
# 14  71.000000  0.02  2013.96 -4198.0
# 15  71.500000  0.03   950.39 -2024.0
#
# [9 rows x 28 columns]

# %%
df_dk_2007_2015 = pd.merge(df_dk_2007_2015, dk_context_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_dk_2007_2015 = pd.merge(df_dk_2007_2015, dk_eu_payments_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_dk_2007_2015['EUPC'] = df_dk_2007_2015['EU_Payment_annual'] / df_dk_2007_2015['PS']

# %%
df_dk_2007_2015 = df_dk_2007_2015.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_dk_2007_2015.to_csv('Data/y/dk_2007_2015_bn.csv', index=True)

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_dk_2007_2015.values)

df_dk_2007_2015_scaled = pd.DataFrame(scaled_features, index=df_dk_2007_2015.index, columns=df_dk_2007_2015.columns)

# %%
df_dk_2007_2015_scaled.to_csv('Data/y/dk_2007_2015_tcdf.csv')

# %%
df_dk_2007_2015_scaled
# Out:
#          UR      URFF       YUA       FDI       QOR       QOA      EIAP  \
# 0 -1.713828 -1.611191 -2.019567  1.173421  1.358899  0.978300  2.094124
# 1 -1.792257 -1.707124 -1.323999  0.081416  0.831979  0.951538  0.564326
# 2 -0.007988 -0.526404  0.070650  0.277052  0.360524  0.924776  0.870285
# 3  0.867807  0.277961  0.811886 -1.408974  0.665583  0.764204 -0.475937
# 4  0.880878  0.912598  1.078872  1.262346  0.998375  0.630394 -1.393816
# 5  0.900486  1.038050  0.889172 -1.917628 -0.554653 -0.306276  0.135982
# 6  0.625983  0.949496  0.537875 -0.067979 -1.331167 -1.189423 -0.169978
# 7  0.331873  0.558382  0.337635  0.522486 -1.386632 -1.403519 -0.843089
# 8 -0.092953  0.108233 -0.382523  0.077859 -0.942910 -1.349995 -0.781897
#
#        PDPS       P65      P014  ...       FEM       LFG     EPFRG      GGAG  \
# 0 -1.373606 -1.445918  1.457446  ...  1.323882  0.188982  0.020307 -0.852555
# 1 -1.373606 -1.195834  1.157200  ...  1.323882 -0.377964 -1.571716 -0.264682
# 2 -0.755483 -0.874299  0.819422  ...  1.374440 -0.377964 -1.350832  0.008901
# 3 -0.137361 -0.463448  0.444114  ...  0.076774 -0.944911  1.562571  1.402200
# 4 -0.137361  0.000992  0.050041  ... -0.631044  0.188982  0.820805 -1.109941
# 5  0.480762  0.465433 -0.362798  ... -0.984953 -0.377964 -0.519250 -0.951920
# 6  0.480762  0.867352 -0.794402  ... -0.866983 -1.511858  0.063314  1.906904
# 7  1.098885  1.197819 -1.207241  ... -1.102923  1.322876  1.135650 -0.545267
# 8  1.717007  1.447902 -1.563783  ... -0.513074  1.889822 -0.160849  0.406361
#
#         ROL        GE       COC       VAA   CPI      EUPC
# 0  0.671500  1.551791  0.933008 -1.346568  1.25 -1.156710
# 1 -0.065512  0.967657  0.296866 -0.363937  0.50 -1.019475
# 2 -0.507719  0.914554  1.060236 -0.363937  0.50 -0.532527
# 3 -0.802524  0.224213 -0.084819 -0.363937  0.50 -0.315189
# 4 -0.507719  0.224213  0.424094 -0.200165  1.25  1.104643
# 5 -1.097329 -0.359921  0.296866  1.765096 -1.75 -0.485736
# 6 -0.802524 -0.625437  0.551323  1.765096 -1.00 -0.192092
# 7  2.145524 -1.475087 -1.357102 -0.691481 -0.25  2.127476
# 8  0.966305 -1.421984 -2.120472 -0.200165 -1.00  0.469610
#
# [9 rows x 32 columns]

# %%
column_index = df_dk_2007_2015_scaled.columns.get_loc('QOA')
print(column_index)
# Out:
# 5

# %% [markdown]
# 18,5,0

# %%
dk_context_2016_2022 = pd.read_csv("Data/Context/Denmark_2016_2022.csv")

dk_context_2016_2022 = dk_context_2016_2022[["TIME_PERIOD", "DI", "COC", "CPI", "ROL", "VAA"]]

df_dk_2016_2022 = df_dk.loc[15:22]
dk_eu_payments_2016_2022 = dk_eu_payments[dk_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

# %%
dk_eu_payments_2016_2022 = dk_eu_payments_2016_2022.loc[1:7]
dk_eu_payments_2016_2022
# Out:
#    Year  EU_Payment_annual
# 1  2016            2300472
# 2  2017           33510236
# 3  2018           39263352
# 4  2019           51874270
# 5  2020           52197125
# 6  2021           80908322
# 7  2022           75033080

# %%
dk_eu_payments_2016_2022 = dk_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)

df_dk_2016_2022 = pd.merge(df_dk_2016_2022, dk_context_2016_2022, on='TIME_PERIOD', how='outer')

df_dk_2016_2022 = pd.merge(df_dk_2016_2022, dk_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_dk_2016_2022['EUPC'] = df_dk_2016_2022['EU_Payment_annual'] / df_dk_2016_2022['PS']

df_dk_2016_2022 = df_dk_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# fill_with_mode(df_dk_2016_2022, ["DI", "CPI"])
# fill_with_mean(df_dk_2016_2022, ["COC", "ROL", "VAA"])
df_dk_2016_2022 = df_dk_2016_2022.drop(0)

# %%
df_dk_2016_2022
# Out:
#      UR  URFF    YUA   FDI  QOR  QOA  EIAP        PDPS    P65   P014  ...  \
# 1  5.99  6.38  12.15  2.50  5.7  5.8  2.33  143.000000  18.94  16.77  ...
# 2  5.83  6.05  12.38  1.09  5.5  6.1  2.11  144.000000  19.18  16.67  ...
# 3  5.13  5.35  10.52  2.47  5.5  5.8  2.19  145.000000  19.44  16.55  ...
# 4  5.02  5.27  10.04 -1.10  5.6  5.8  2.22  145.000000  19.71  16.43  ...
# 5  5.64  5.98  11.59  0.36  5.5  5.8  2.11  146.000000  20.00  16.31  ...
# 6  5.04  5.14  10.81  4.16  5.5  5.8  2.04  146.000000  20.25  16.17  ...
# 7  4.43  4.49  10.53  7.67  5.5  5.8  2.12  141.466667  20.40  16.04  ...
#
#     FEM   LFG     EPFRG         GGAG    DI   COC   CPI   ROL   VAA  \
# 1  72.5  0.04  -548.050  1635.000000  9.20  2.20  90.0  1.88  1.54
# 2  73.2  0.03  3409.890 -2276.000000  9.22  2.19  88.0  1.80  1.52
# 3  73.9  0.02 -1035.440  -555.000000  9.22  2.16  88.0  1.77  1.57
# 4  74.7  0.04  2311.730 -3538.000000  9.22  2.12  87.0  1.83  1.54
# 5  74.3  0.00   372.670 -2434.000000  9.15  2.24  88.0  1.81  1.51
# 6  75.5  0.05  2650.040 -2409.928571  9.09  2.33  88.0  1.90  1.54
# 7  77.4  0.07  1126.794 -2409.928571  9.28  2.40  90.0  1.90  1.59
#
#            EUPC
# 1  4.014785e+05
# 2  5.817749e+06
# 3  6.781235e+06
# 4  8.928446e+06
# 5  8.953195e+06
# 6  1.380688e+07
# 7  1.271747e+07
#
# [7 rows x 32 columns]

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_dk_2016_2022.values)

df_dk_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_dk_2016_2022.index, columns=df_dk_2016_2022.columns)

# %%
df_dk_2016_2022_scaled.to_csv('Data/y/dk_2016_2022_tcdf.csv')

# %%
column_index = df_dk_2016_2022_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 31

# %% [markdown]
# ====================================================================

# %%
df_de = pd.read_csv("Data/y/Germany.csv")

# %%
df_de = df_de.loc[6:22]

# %%
df_de
# Out:
#     Unnamed: 0 REF_AREA_LABEL  TIME_PERIOD    HI     LF     UR   URFF    YUA  \
# 6            6        Germany         2006   NaN  41.69  10.28  10.27  13.40
# 7            7        Germany         2007   NaN  41.80   8.73   8.77  11.82
# 8            8        Germany         2008   NaN  41.80   7.51   7.72  10.93
# 9            9        Germany         2009   NaN  41.82   7.88   7.49  11.31
# 10          10        Germany         2010   NaN  41.86   7.04   6.59  10.42
# 19  71.613724       NaN  0.767070  79.7  1.2  75.7
# 20  71.407459       NaN -3.657127  78.3  1.1  74.6
# 21  71.251982       NaN -3.522981  79.6  1.2  75.9
# 22  71.892018       NaN -2.692237  80.8  1.1  77.0
#
# [17 rows x 35 columns]

# %%
df_de = df_de.copy()
df_de['LFG'] = df_de['LF'].diff()
df_de['EPFRG'] = df_de['EPFR'].diff()
df_de['GGAG'] = df_de['GGA'].diff()
df_de = df_de.drop(6)

# %%
df_de = df_de.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_de["EMP"] = df_de["EMP"].replace(':', np.nan)
df_de["LTU"] = df_de["LTU"].replace(':', np.nan)
df_de["FEM"] = df_de["FEM"].replace(':', np.nan)

# %%
missing_values(df_de)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 2 - 12.5 %
# LTU - 2 - 12.5 %
# FEM - 2 - 12.5 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
df_de = df_de.copy()
fill_with_mode(df_de, ["QOR"])

# %%
fill_with_mean(df_de, ["EMP", "LTU", "FEM", "QOA", "PDPS", "EPFRG", "GGAG"])

# %%
de_context_2007_2015 = pd.read_csv("Data/Context/Germany_2007_2015.csv")

# %%
de_context_2007_2015 = de_context_2007_2015[["TIME_PERIOD", "PMSI", "JI", "DBP", "PR", "DWCP"]]

# %%
de_context_2007_2015["DBPG"] = de_context_2007_2015["DBP"].diff()
de_context_2007_2015 = de_context_2007_2015.drop(0)
de_context_2007_2015 = de_context_2007_2015.drop(["DBP"], axis=1)
de_context_2007_2015
# Out:
#    TIME_PERIOD  PMSI     JI  PR       DWCP  DBPG
# 1         2007  50.0  0.952  90  82.709673   0.0
# 2         2008  50.0  0.952  90  82.821877   0.0
# 3         2009  50.0  0.952  90  82.758552   0.0
# 4         2010  50.0  0.952  90  82.888440   0.0
# 5         2011  50.0  0.952  90  82.852483   0.0
# 6         2012  50.0  0.952  90  82.818229   0.0
# 7         2013  50.0  0.952  90  82.870361   0.0
# 8         2014  50.0  0.952  90  82.919183   0.0
# 9         2015  50.0  0.952  90  82.829850   0.0

# %%
de_eu_payments = eu_payments[eu_payments['Country'] == 'DE'].copy()

# %%
de_eu_payments
# Out:
#      Country  Fund  Year Programming_Period EU_Payment_annual
# 0         DE  ERDF  2007          2007-2013         1,017,013
# 1         DE  ERDF  2008          2007-2013         1,525,519
# 2         DE  ERDF  2009          2007-2013         1,271,266
# 3         DE  ERDF  2010          2007-2013         3,453,592
# 4         DE  ERDF  2011          2007-2013         2,385,830
# ...      ...   ...   ...                ...               ...
# 2403      DE   ESF  2018          2014-2020        52,908,298
# 2404      DE   ESF  2019          2014-2020       149,834,127
# 2405      DE   ESF  2020          2014-2020        93,167,064
# 2406      DE   ESF  2021          2014-2020        96,597,249
# 2407      DE   ESF  2022          2014-2020       112,397,843
#
# [1441 rows x 5 columns]

# %%
de_eu_payments['EU_Payment_annual'] = pd.to_numeric(de_eu_payments['EU_Payment_annual'].str.replace(',', ''))

# %%
de_eu_payments_2007_2015 = de_eu_payments[de_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

# %%
de_eu_payments_2007_2015 = de_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

# %%
de_eu_payments_2007_2015 = de_eu_payments_2007_2015.loc[0:8]

# %%
de_eu_payments_2007_2015
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 0         2007          509772297
# 1         2008          822140887
# 2         2009         3112147864
# 3         2010         2845429356
# 4         2011         3199322121
# 5         2012         3291270489
# 6         2013         4250139425
# 7         2014         3182120645
# 8         2015         2285834656

# %%
df_de_2007_2015 = df_de.loc[7:15]

# %%
df_de_2007_2015 = pd.merge(df_de_2007_2015, de_context_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_de_2007_2015 = pd.merge(df_de_2007_2015, de_eu_payments_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_de_2007_2015['EUPC'] = df_de_2007_2015['EU_Payment_annual'] / df_de_2007_2015['PS']

# %%
df_de_2007_2015 = df_de_2007_2015.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_de_2007_2015
# Out:
#      UR  URFF    YUA   FDI   QOR   QOA  EIAP   PDPS    P65   P014  ...  \
# 0  8.73  8.77  11.82  1.46  6.55  6.71  2.26  236.0  19.99  13.99  ...
# 1  7.51  7.72  10.93  0.81  6.54  6.67  1.78  236.0  20.29  13.84  ...
# 2  7.88  7.49  11.31  1.63  6.49  6.61  1.68  235.0  20.52  13.76  ...
# 3  7.04  6.59  10.42  2.48  6.42  6.61  1.65  235.0  20.57  13.70  ...
# 4  5.97  5.71   8.93  2.55  6.15  6.45  1.64  230.0  20.52  13.58  ...
# 5  5.37  5.23   8.12  1.82  6.09  6.35  1.56  231.0  20.64  13.39  ...
# 6  5.32  4.99   7.82  1.76  6.01  6.08  1.45  231.0  20.81  13.23  ...
# 7  4.98  4.63   7.61  0.44  5.88  5.94  1.43  232.0  20.96  13.18  ...
# 8  4.61  4.20   7.33  1.82  5.72  5.95  1.39  234.0  21.05  13.21  ...
#
#          FEM   LFG    EPFRG     GGAG  PMSI     JI  PR       DWCP  DBPG  \
# 0  72.864286  0.11  15719.0 -28436.0  50.0  0.952  90  82.709673   0.0
# 1  72.864286  0.00   5641.0   2834.0  50.0  0.952  90  82.821877   0.0
# 2  67.800000  0.02   3068.0 -56474.0  50.0  0.952  90  82.758552   0.0
# 3  68.800000  0.04   7319.0  30446.0  50.0  0.952  90  82.888440   0.0
# 4  70.300000 -0.34  22139.0 -29687.0  50.0  0.952  90  82.852483   0.0
# 5  70.700000  0.24  14921.0  13203.0  50.0  0.952  90  82.818229   0.0
# 6  71.500000  0.42   8054.0  16374.0  50.0  0.952  90  82.870361   0.0
# 7  72.200000  0.27  13598.0 -40820.0  50.0  0.952  90  82.919183   0.0
# 8  72.700000  0.24  26869.0   4675.0  50.0  0.952  90  82.829850   0.0
#
#            EUPC
# 0  6.196333e+06
# 1  1.001268e+07
# 2  3.799936e+07
# 3  3.479371e+07
# 4  3.985701e+07
# 5  4.092093e+07
# 6  5.269857e+07
# 7  3.929514e+07
# 8  2.798182e+07
#
# [9 rows x 32 columns]

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_de_2007_2015.values)

df_de_2007_2015_scaled = pd.DataFrame(scaled_features, index=df_de_2007_2015.index, columns=df_de_2007_2015.columns)

# %%
df_de_2007_2015_scaled.to_csv('Data/y/de_2007_2015_tcdf.csv')

# %%
df_de.columns.equals(df_dk.columns)
# Out:
# True

# %%
column_index = df_de_2007_2015_scaled.columns.get_loc('DWCP')
print(column_index)
# Out:
# 29

# %%
6,0,0
24,3,0
1,6,0
18,8,0
15,18,0
29,25,0
6,29,0
23,29,3
# Out:
# (23, 29, 3)

# %%
de_context_2016_2022 = pd.read_csv("Data/Context/Germany_2016_2022.csv")

de_context_2016_2022 = de_context_2016_2022[["TIME_PERIOD", "DI", "COC", "CPI", "ROL", "VAA"]]

df_de_2016_2022 = df_de.loc[16:22]

# %%
de_eu_payments_2016_2022 = de_eu_payments[de_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()
de_eu_payments_2016_2022 = de_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)
de_eu_payments_2016_2022 = de_eu_payments_2016_2022.loc[1:7]
de_eu_payments_2016_2022
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 1         2016          193569759
# 2         2017         1413679591
# 3         2018         1874091083
# 4         2019         2294983953
# 5         2020         2150651412
# 6         2021         2695323886
# 7         2022         2941191622

# %%
df_de_2016_2022 = pd.merge(df_de_2016_2022, de_context_2016_2022, on='TIME_PERIOD', how='outer')

df_de_2016_2022 = pd.merge(df_de_2016_2022, de_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_de_2016_2022['EUPC'] = df_de_2016_2022['EU_Payment_annual'] / df_de_2016_2022['PS']

df_de_2016_2022 = df_de_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_de_2016_2022.values)

df_de_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_de_2016_2022.index, columns=df_de_2016_2022.columns)

# %%
df_de_2016_2022_scaled.to_csv('Data/y/de_2016_2022_tcdf.csv')

# %%
column_index = df_de_2016_2022_scaled.columns.get_loc('EPFRG')
print(column_index)
# Out:
# 24

# %% [markdown]
# ===================================================================================================================

# %%
df_pl = pd.read_csv("Data/y/Poland.csv")

# %%
df_pl = df_pl.loc[6:22]

# %%
df_pl
# Out:
#     Unnamed: 0 REF_AREA_LABEL  TIME_PERIOD    HI     LF     UR   URFF    YUA  \
# 14  57.966922  2.013741 -3.367862  64.9  3.9  58.2
# 15  57.928061  2.243049 -2.532527  66.3  3.0  59.9
# 16  57.966782  2.062852 -2.650770  68.2  2.2  61.5
# 17  58.110881       NaN -1.585809  70.0  1.5  63.0
# 18  58.565010       NaN  0.071103  71.4  1.0  64.5
# 19  58.712268       NaN -0.525643  72.6  0.7  65.3
# 20  58.725043       NaN -7.027947  72.8  0.6  65.4
# 21  60.667970       NaN -2.303009  75.5  0.9  68.5
# 22  60.913014       NaN -3.005692  76.7  0.9  70.3
#
# [17 rows x 35 columns]

# %%
df_pl = df_pl.copy()
df_pl['LFG'] = df_pl['LF'].diff()
df_pl['EPFRG'] = df_pl['EPFR'].diff()
df_pl['GGAG'] = df_pl['GGA'].diff()
df_pl = df_pl.drop(6)

# %%
df_pl = df_pl.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_pl["EMP"] = df_pl["EMP"].replace(':', np.nan)
df_pl["LTU"] = df_pl["LTU"].replace(':', np.nan)
df_pl["FEM"] = df_pl["FEM"].replace(':', np.nan)

# %%
missing_values(df_pl)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 2 - 12.5 %
# LTU - 2 - 12.5 %
# FEM - 2 - 12.5 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
df_pl = df_pl.copy()
fill_with_mode(df_pl, ["QOR", "QOA", "FEM", "PDPS"])

# %%
fill_with_mean(df_pl, ["EMP", "LTU", "EPFRG", "GGAG"])

# %%
pl_context_2007_2015 = pd.read_csv("Data/Context/Poland_2007_2015.csv")

# %%
pl_context_2007_2015 = pl_context_2007_2015[["TIME_PERIOD", "PR", "RQ", "COC", "ROL", "CPI"]]

# %%
pl_eu_payments = eu_payments[eu_payments['Country'] == 'PL'].copy()

# %%
pl_eu_payments
# Out:
#      Country Fund  Year Programming_Period EU_Payment_annual
# 1125      PL   CF  2007          2007-2013        45,219,844
# 1126      PL   CF  2008          2007-2013        72,351,752
# 1127      PL   CF  2009          2007-2013       129,326,232
# 1128      PL   CF  2010          2007-2013       108,332,216
# 1129      PL   CF  2011          2007-2013       207,533,488
# ...      ...  ...   ...                ...               ...
# 3022      PL  ESF  2018          2014-2020       110,564,312
# 3023      PL  ESF  2019          2014-2020        98,266,373
# 3024      PL  ESF  2020          2014-2020       103,054,231
# 3025      PL  ESF  2021          2014-2020       111,579,443
# 3026      PL  ESF  2022          2014-2020       114,688,295
#
# [897 rows x 5 columns]

# %%
pl_eu_payments['EU_Payment_annual'] = pd.to_numeric(pl_eu_payments['EU_Payment_annual'].str.replace(',', ''))

# %%
pl_eu_payments_2007_2015 = pl_eu_payments[pl_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

# %%
pl_eu_payments_2007_2015 = pl_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

# %%
pl_eu_payments_2007_2015
# Out:
#     TIME_PERIOD  EU_Payment_annual
# 0          2007         1400802662
# 1          2008         2192935247
# 2          2009         5155672523
# 3          2010         6850960177
# 4          2011         9415548745
# 5          2012        10098196875
# 6          2013        10475714683
# 7          2014        11686980907
# 8          2015         6458114981
# 9          2016           91344706
# 10         2017         1942750121
# 11         2018         1322743760
# 12         2019           93430136

# %%
pl_eu_payments_2007_2015 = pl_eu_payments_2007_2015.loc[0:8]

# %%
df_pl_2007_2015 = df_pl.loc[7:15]

# %%
df_pl_2007_2015 = pd.merge(df_pl_2007_2015, pl_context_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_pl_2007_2015 = pd.merge(df_pl_2007_2015, pl_eu_payments_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_pl_2007_2015['EUPC'] = df_pl_2007_2015['EU_Payment_annual'] / df_pl_2007_2015['PS']

# %%
df_pl_2007_2015 = df_pl_2007_2015.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_pl_2007_2015.values)

df_pl_2007_2015_scaled = pd.DataFrame(scaled_features, index=df_pl_2007_2015.index, columns=df_pl_2007_2015.columns)

# %%
df_pl_2007_2015_scaled.to_csv('Data/y/pl_2007_2015_tcdf.csv')

# %%
df_de.columns.equals(df_pl.columns)
# Out:
# True

# %%
column_index = df_pl_2007_2015_scaled.columns.get_loc('GGAG')
print(column_index)
# Out:
# 25

# %%
pl_context_2016_2022 = pd.read_csv("Data/Context/Poland_2016_2022.csv")

pl_context_2016_2022 = pl_context_2016_2022[["TIME_PERIOD", "JI", "FOP", "DBD", "PT", "PR"]]

pl_context_2016_2022["DBDC"] = pl_context_2016_2022["DBD"].diff()

pl_context_2016_2022 = pl_context_2016_2022.drop(["DBD"], axis=1)

pl_context_2016_2022 = pl_context_2016_2022.loc[2:8]

df_pl_2016_2022 = df_pl.loc[16:22]

# %%
pl_context_2016_2022
# Out:
#    TIME_PERIOD     JI    FOP         PT  PR  DBDC
# 2         2016  0.783  0.745  79.141239  65   0.0
# 3         2017  0.690  0.709  79.105836  61   0.0
# 4         2018  0.595  0.709  79.495816  62   0.0
# 5         2019  0.572  0.704  76.490761  62   0.0
# 6         2020  0.570  0.707  76.831746  63   0.0
# 7         2021  0.542  0.641  76.516572  63   0.0
# 8         2022  0.570  0.616  76.516572  72   0.0

# %%
pl_eu_payments_2016_2022 = pl_eu_payments[pl_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()
pl_eu_payments_2016_2022 = pl_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)
pl_eu_payments_2016_2022 = pl_eu_payments_2016_2022.loc[1:7]
pl_eu_payments_2016_2022
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 1         2016         2804505749
# 2         2017         4638222529
# 3         2018         9582436519
# 4         2019        10639507736
# 5         2020        12091039828
# 6         2021        13811714640
# 7         2022        11413018878

# %%
df_pl_2016_2022 = pd.merge(df_pl_2016_2022, pl_context_2016_2022, on='TIME_PERIOD', how='outer')

df_pl_2016_2022 = pd.merge(df_pl_2016_2022, pl_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_pl_2016_2022['EUPC'] = df_pl_2016_2022['EU_Payment_annual'] / df_pl_2016_2022['PS']
df_pl_2016_2022 = df_pl_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_pl_2016_2022.columns
# Out:
# Index(['UR', 'URFF', 'YUA', 'FDI', 'QOR', 'QOA', 'EIAP', 'PDPS', 'P65', 'P014',
#        'PGP', 'VABI', 'GCFP', 'GGFC', 'GDPCG', 'EII', 'EBSG', 'GDPC', 'EIS',
#        'LBGD', 'EMP', 'LTU', 'FEM', 'LFG', 'EPFRG', 'GGAG', 'JI', 'FOP', 'PT',
#        'PR', 'DBDC', 'EUPC'],
#       dtype='object')

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_pl_2016_2022.values)

df_pl_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_pl_2016_2022.index, columns=df_pl_2016_2022.columns)

# %%
df_pl_2016_2022_scaled.to_csv('Data/y/pl_2016_2022_tcdf.csv')

# %%
column_index = df_pl_2016_2022_scaled.columns.get_loc('FOP')
print(column_index)
# Out:
# 27

# %% [markdown]
# 4,27,0

# %% [markdown]
# ==================================================================================================================

# %%
df_lt = pd.read_csv("Data/y/Lithuania.csv")

# %%
df_lt = df_lt.loc[6:22]

# %%
df_lt
# Out:
#     Unnamed: 0 REF_AREA_LABEL  TIME_PERIOD    HI    LF     UR   URFF    YUA  \
# 6            6      Lithuania         2006   NaN  1.51   5.78   5.61   9.98
# 7            7      Lithuania         2007   NaN  1.51   4.25   4.33   8.39
# 8            8      Lithuania         2008   NaN  1.51   5.83   5.63  13.35
# 9            9      Lithuania         2009   NaN  1.52  13.78  10.52  29.58
# 10          10      Lithuania         2010   NaN  1.49  17.81  14.52  35.74
# 11          11      Lithuania         2011   NaN  1.48  15.39  12.91  32.59
# 12          12      Lithuania         2012   NaN  1.47  13.36  11.57  26.68
# 13          13      Lithuania         2013  5.43  1.47  11.77  10.48  21.90
# 14          14      Lithuania         2014   NaN  1.48  10.70   9.22  19.26
# 15          15      Lithuania         2015  5.83  1.47   9.12   8.16  16.30
# 16          16      Lithuania         2016  5.81  1.48   7.86   6.65  14.45
# 17          17      Lithuania         2017  5.90  1.47   7.07   5.67  13.27
# 18          18      Lithuania         2018  5.95  1.47   6.15   5.41  11.12
# 19          19      Lithuania         2019  6.15  1.48   6.26   5.49  11.85
# 20          20      Lithuania         2020  6.26  1.49   8.49   7.69  19.56
# 21          21      Lithuania         2021  6.45  1.49   7.11   6.61  14.30
# 22          22      Lithuania         2022  6.76  1.51   5.95   5.48  11.87
#
#      FDI   QOR  ...        EIA       EBSG          GDPC           GDP  \
# 6   7.50  4.92  ...  13.832556 -10.283491   7339.529632  3.546242e+10
# 7   6.55  4.97  ...  11.325410 -13.094653   8985.274630  3.939093e+10
# 8   3.61  5.21  ...   8.064581 -11.598256  10219.116755  4.041488e+10
# 9  -0.96  5.28  ...   8.983906  -1.755188   8528.034573  3.441787e+10
# 10  3.01  5.27  ...   8.830495  -2.029481   8931.519313  3.456490e+10
# 11  4.36  5.23  ...   8.486140  -2.706873  10259.331961  3.675066e+10
# 12  1.59  5.17  ...   8.796753   0.613211  11120.403233  3.836141e+10
# 13  1.66  5.02  ...   8.422800   1.457239  11776.792571  3.991386e+10
# 14  0.74  4.94  ...   9.165997   1.930309  12395.979849  4.141963e+10
# 15  2.50  4.96  ...   9.069029  -0.986813  12861.323296  4.259297e+10
# 16  2.74  4.90  ...   7.975508   0.728400  13491.939909  4.373102e+10
# 17  2.90  4.70  ...   7.784081   2.294288  14871.586227  4.574800e+10
# 18  2.40  4.70  ...   7.182582   1.856906  16298.029583  4.799806e+10
# 19  6.23  4.80  ...   6.436241   5.262450  17516.070462  5.024310e+10
# 20  7.94   NaN  ...   5.689861   9.072805  17885.411844  5.026461e+10
# 21  3.74   NaN  ...   5.312821   4.453149  20182.333587  5.347150e+10
# 22  3.41   NaN  ...   5.455592  -2.091914  23822.056413  5.482835e+10
#
#           EIS      NINA      LBGD   EMP  LTU   FEM
# 6   56.596662  3.118363  0.075001     :    :   NaN
# 7   58.126069  3.723648 -0.493558     :    :     :
# 8   61.418727  3.480952 -2.844590     :    :     :
# 9   64.167134  2.773311 -8.626258  67.0  3.3  67.2
# 10  66.610059  2.591630 -7.016844  64.3  7.4  65.0
# 11  66.955836  2.373246 -5.541350  66.9  8.0  66.6
# 12  66.119954  1.956453 -2.893765  68.5  6.6  67.9
# 13  66.052053  2.151628 -2.417272  69.9  5.1  68.6
# 14  66.110306  2.113033 -1.911556  71.8  4.8  70.6
# 15  65.858411  2.545603 -1.093729  73.3  3.9  72.2
# 16  66.887072  1.972772 -0.460837  75.2  3.0  74.3
# 17  67.082072       NaN  0.165584  76.0  2.7  75.5
# 18  67.050133       NaN  0.413734  77.8  2.0  76.7
# 19  67.864065       NaN  0.441721  78.2  1.9  77.4
# 20  68.945663       NaN -6.374068  76.7  2.5  75.8
# 21  68.433746       NaN -1.419204  77.4  2.6  76.7
# 22  68.817155       NaN -0.897036  79.0  2.3  78.6
#
# [17 rows x 35 columns]

# %%
df_lt = df_lt.copy()
df_lt['LFG'] = df_lt['LF'].diff()
df_lt['EPFRG'] = df_lt['EPFR'].diff()
df_lt['GGAG'] = df_lt['GGA'].diff()
df_lt = df_lt.drop(6)

# %%
df_lt = df_lt.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_lt["EMP"] = df_lt["EMP"].replace(':', np.nan)
df_lt["LTU"] = df_lt["LTU"].replace(':', np.nan)
df_lt["FEM"] = df_lt["FEM"].replace(':', np.nan)

# %%
missing_values(df_lt)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 2 - 12.5 %
# LTU - 2 - 12.5 %
# FEM - 2 - 12.5 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
df_lt = df_lt.copy()
fill_with_mode(df_lt, ["QOR", "QOA"])

# %%
fill_with_mean(df_lt, ["EMP", "LTU", "FEM"])

# %%
lt_context_2007_2015 = pd.read_csv("Data/Context/Lithuania_2007_2015.csv")

# %%
lt_context_2007_2015 = lt_context_2007_2015[["TIME_PERIOD", "PR", "RQ", "COC", "ROL", "CPI"]]

# %%
lt_eu_payments = eu_payments[eu_payments['Country'] == 'LT'].copy()

# %%
lt_eu_payments['EU_Payment_annual'] = pd.to_numeric(lt_eu_payments['EU_Payment_annual'].str.replace(',', ''))

# %%
lt_eu_payments_2007_2015 = lt_eu_payments[lt_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

# %%
lt_eu_payments_2007_2015 = lt_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

# %%
lt_eu_payments_2007_2015
# Out:
#     TIME_PERIOD  EU_Payment_annual
# 0          2007          147036030
# 1          2008          226317129
# 2          2009         1067875010
# 3          2010          871817905
# 4          2011          937791043
# 5          2012         1013987411
# 6          2013         1072505603
# 7          2014         1013149415
# 8          2015           86238312
# 9          2017           50722512
# 10         2018          287359288

# %%
lt_eu_payments_2007_2015 = lt_eu_payments_2007_2015.loc[0:8]

# %%
lt_eu_payments_2007_2015
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 0         2007          147036030
# 1         2008          226317129
# 2         2009         1067875010
# 3         2010          871817905
# 4         2011          937791043
# 5         2012         1013987411
# 6         2013         1072505603
# 7         2014         1013149415
# 8         2015           86238312

# %%
df_lt_2007_2015 = df_lt.loc[7:15]

# %%
df_lt_2007_2015 = pd.merge(df_lt_2007_2015, lt_context_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_lt_2007_2015 = pd.merge(df_lt_2007_2015, lt_eu_payments_2007_2015, on='TIME_PERIOD', how='outer')

# %%
df_lt_2007_2015['EUPC'] = df_lt_2007_2015['EU_Payment_annual'] / df_lt_2007_2015['PS']

# %%
df_lt_2007_2015 = df_lt_2007_2015.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df
# 22  ...  -2.091914  23822.056413  68.817155 -0.897036  79.0  2.300000
#
#           FEM   LFG   EPFRG    GGAG
# 7   72.364286  0.00  122.00  1013.0
# 8   72.364286  0.00   40.09  -563.0
# 9   67.200000  0.01   60.00 -3576.0
# 10  65.000000 -0.03  111.00   806.0
# 11  66.600000 -0.01  261.18  -532.0
# 12  67.900000 -0.01  127.73   -81.0
# 13  68.600000  0.00  245.00  -892.0
# 14  70.600000  0.01  107.00  -452.0
# 15  72.200000 -0.01  217.00   260.0
# 16  74.300000  0.01  312.00    25.0
# 17  75.500000 -0.01  294.85   -79.0
# 18  76.700000  0.00 -161.65    86.0
# 19  77.400000  0.01  350.20   128.0
# 20  75.800000  0.01  150.30     5.0
# 21  76.700000  0.00  -35.80     NaN
# 22  78.600000  0.02     NaN     NaN
#
# [16 rows x 28 columns]

# %%
df_lt_2016_2022 = df_lt.loc[16:22]

# %%
lt_eu_payments_2016_2022 = lt_eu_payments[lt_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()
lt_eu_payments_2016_2022 = lt_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)

# %%
lt_eu_payments_2016_2022 = lt_eu_payments_2016_2022.loc[1:7]
lt_eu_payments_2016_2022
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 1         2016          332852729
# 2         2017          434501955
# 3         2018          809554069
# 4         2019          529282582
# 5         2020         1445805827
# 6         2021         1139822052
# 7         2022          937545028

# %%
df_lt_2016_2022
# Out:
#     TIME_PERIOD    UR  URFF    YUA   FDI  QOR  QOA  EIAP    PS  PDPS  ...  \
# 16         2016  7.86  6.65  14.45  2.74  4.9  4.4  7.98  2.88  46.0  ...
# 17         2017  7.07  5.67  13.27  2.90  4.7  4.4  7.78  2.84  45.0  ...
# 18         2018  6.15  5.41  11.12  2.40  4.7  4.6  7.18  2.82  45.0  ...
# 19         2019  6.26  5.49  11.85  6.23  4.8  4.9  6.44  2.81  45.0  ...
# 20         2020  8.49  7.69  19.56  7.94  4.7  4.4  5.69  2.81  45.0  ...
# 21         2021  7.11  6.61  14.30  3.74  4.7  4.4  5.31  2.81  45.0  ...
# 22         2022  5.95  5.48  11.87  3.41  4.7  4.4  5.46  2.83   NaN  ...
#
#         EBSG          GDPC        EIS      LBGD   EMP  LTU   FEM   LFG  \
# 16  0.728400  13491.939909  66.887072 -0.460837  75.2  3.0  74.3  0.01
# 17  2.294288  14871.586227  67.082072  0.165584  76.0  2.7  75.5 -0.01
# 18  1.856906  16298.029583  67.050133  0.413734  77.8  2.0  76.7  0.00
# 19  5.262450  17516.070462  67.864065  0.441721  78.2  1.9  77.4  0.01
# 20  9.072805  17885.411844  68.945663 -6.374068  76.7  2.5  75.8  0.01
# 21  4.453149  20182.333587  68.433746 -1.419204  77.4  2.6  76.7  0.00
# 22 -2.091914  23822.056413  68.817155 -0.897036  79.0  2.3  78.6  0.02
#
#      EPFRG   GGAG
# 16  312.00   25.0
# 17  294.85  -79.0
# 18 -161.65   86.0
# 19  350.20  128.0
# 20  150.30    5.0
# 21  -35.80    NaN
# 22     NaN    NaN
#
# [7 rows x 28 columns]

# %%
df_lt_2016_2022 = pd.merge(df_lt_2016_2022, lt_context_2016_2022, on='TIME_PERIOD', how='outer')

df_lt_2016_2022 = pd.merge(df_lt_2016_2022, lt_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_lt_2016_2022['EUPC'] = df_lt_2016_2022['EU_Payment_annual'] / df_lt_2016_2022['PS']
fill_with_mode(df_lt_2016_2022, ["PDPS"])
fill_with_mean(df_lt_2016_2022, ["EPFRG", "GGAG"])
df_lt_2016_2022
df_lt_2016_2022 = df_lt_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_lt_2016_2022.to_csv('Data/y/lt_2016_2022_bn.csv', index=True)

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_lt_2016_2022.values)

df_lt_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_lt_2016_2022.index, columns=df_lt_2016_2022.columns)

# %%
df_lt_2016_2022_scaled.to_csv('Data/y/lt_2016_2022_tcdf.csv')

# %%
column_index = df_lt_2007_2015_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 31

# %%
24,31,2
# Out:
# (24, 31, 2)

# %% [markdown]
# ===================================================================================================================

# %%
df_lv = pd.read_csv("Data/y/Latvia.csv")

# %%
df_lv = df_lv.loc[6:22]

# %%
df_lv = df_lv.copy()
df_lv['LFG'] = df_lv['LF'].diff()
df_lv['EPFRG'] = df_lv['EPFR'].diff()
df_lv['GGAG'] = df_lv['GGA'].diff()
df_lv = df_lv.drop(6)

# %%
df_lv = df_lv.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_lv["EMP"] = df_lv["EMP"].replace(':', np.nan)
df_lv["LTU"] = df_lv["LTU"].replace(':', np.nan)
df_lv["FEM"] = df_lv["FEM"].replace(':', np.nan)

# %%
missing_values(df_lv)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 2 - 12.5 %
# LTU - 2 - 12.5 %
# FEM - 2 - 12.5 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
# df_lv = df_lv.copy()
# fill_with_mode(df_lv, ["QOR", "QOA"])

# %%
fill_with_mean(df_lv, ["EMP", "LTU", "FEM", "QOR", "QOA", "PDPS", "EPFRG", "GGAG"])

# %%
lv_context_2007_2015 = pd.read_csv("Data/Context/Latvia_2007_2015.csv")

# %%
lv_context_2007_2015 = lv_context_2007_2015[["TIME_PERIOD", "PR", "RQ", "COC", "ROL", "CPI"]]

# %%
lv_context_2007_2015
# Out:
#    TIME_PERIOD  PR    RQ   COC   ROL   CPI
# 0         2007  50  0.95  0.34  0.72  48.0
# 1         2008  55  0.97  0.23  0.78  50.0
# 2         2009  55  0.92  0.20  0.79  45.0
# 3         2010  55  0.93  0.20  0.76  43.0
# 4         2011  50  0.95  0.28  0.74  42.0
# 5         2012  50  1.01  0.24  0.78  49.0
# 6         2013  50  1.04  0.32  0.76  53.0
# 7         2014  50  1.17  0.41  0.87  55.0
# 8         2015  50  1.07  0.43  0.77  55.0

# %%
lv_eu_payments = eu_payments[eu_payments['Country'] == 'LV'].copy()

lv_eu_payments['EU_Payment_annual'] = pd.to_numeric(lv_eu_payments['EU_Payment_annual'].str.replace(',', ''))

lv_eu_payments_2007_2015 = lv_eu_payments[lv_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

lv_eu_payments_2007_2015 = lv_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

# %%
lv_eu_payments_2007_2015 = lv_eu_payments_2007_2015.loc[0:8]

# %%
df_lv_2007_2015 = df_lv.loc[7:15]

df_lv_2007_2015 = pd.merge(df_lv_2007_2015, lv_context_2007_2015, on='TIME_PERIOD', how='outer')

df_lv_2007_2015 = pd.merge(df_lv_2007_2015, lv_eu_payments_2007_2015, on='TIME_PERIOD', how='outer')

df_lv_2007_2015['EUPC'] = df_lv_2007_2015['EU_Payment_annual'] / df_lv_2007_2015['PS']

df_lv_2007_2015 = df_lv_2007_2015.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_lv_2007_2015
# Out:
#       UR   URFF    YUA   FDI   QOR   QOA   EIAP  PDPS    P65   P014  ...  \
# 0   6.05   5.57  10.56  9.22  3.11  5.39  10.18  35.0  17.51  14.11  ...
# 1   7.74   7.07  13.65  4.20  2.85  5.59   7.96  35.0  17.72  14.04  ...
# 2  17.51  14.13  33.43 -0.58  3.19  5.48   8.75  34.0  17.98  14.12  ...
# 3  19.48  16.29  36.24  2.02  3.11  5.44   8.61  34.0  18.25  14.18  ...
# 4  16.21  13.79  31.07  5.72  3.10  5.17   8.90  33.0  18.48  14.24  ...
# 5  15.05  13.94  28.56  3.99  3.16  5.27   8.37  33.0  18.68  14.36  ...
# 6  11.87  11.14  23.24  3.39  3.00  5.39   8.06  32.0  18.93  14.57  ...
# 7  10.85   9.83  19.59  3.45  3.09  5.35   7.50  32.0  19.24  14.85  ...
# 8   9.87   8.64  16.32  3.09  3.31  5.37   7.94  32.0  19.52  15.12  ...
#
#          FEM   LFG   EPFRG    GGAG  PR    RQ   COC   ROL   CPI          EUPC
# 0  70.435714  0.02    6.80   424.0  50  0.95  0.34  0.72  48.0  4.468538e+07
# 1  70.435714  0.01    7.81  -338.0  55  0.97  0.23  0.78  50.0  6.940880e+07
# 2  66.200000 -0.05   -3.95  -780.0  55  0.92  0.20  0.79  45.0  1.985811e+08
# 3  64.200000 -0.04   16.38  1140.0  55  0.93  0.20  0.76  43.0  2.209354e+08
# 4  65.100000 -0.03   75.29  -641.0  50  0.95  0.28  0.74  42.0  2.485579e+08
# 22  32.333333  ...  -4.888329  19208.258774  69.582521 -4.914751  77.000000
#
#          LTU        FEM   LFG       EPFRG         GGAG
# 7   5.014286  70.435714  0.02    6.800000   424.000000
# 8   5.014286  70.435714  0.01    7.810000  -338.000000
# 9   5.000000  66.200000 -0.05   -3.950000  -780.000000
# 10  9.700000  64.200000 -0.04   16.380000  1140.000000
# 11  9.800000  65.100000 -0.03   75.290000  -641.000000
# 12  8.600000  66.200000  0.01  212.380000  -201.000000
# 13  6.300000  67.500000 -0.02  218.900000   -72.000000
# 14  5.100000  68.400000 -0.01  187.310000   -55.000000
# 15  4.900000  70.500000  0.00  107.290000    44.000000
# 16  4.400000  71.700000 -0.01   35.050000  -165.000000
# 17  3.600000  72.600000  0.00  129.910000   -62.000000
# 18  3.400000  74.700000 -0.01  -14.100000   536.000000
# 19  2.700000  75.500000 -0.01   17.510000  -152.000000
# 20  2.400000  75.100000  0.00  -38.580000  -649.000000
# 21  2.300000  72.900000 -0.03  -35.700000   -69.357143
# 22  2.000000  75.500000  0.01   61.486667   -69.357143
#
# [16 rows x 28 columns]

# %%
df_lv_2016_2022 = df_lv.loc[16:22]

# %%
lv_context_2016_2022 = pd.read_csv("Data/Context/Latvia_2016_2022.csv")

lv_context_2016_2022 = lv_context_2016_2022[["TIME_PERIOD", "EC", "DI", "SSB", "COC", "CPI"]]
lv_context_2016_2022 = lv_context_2016_2022.loc[0:6]

# %%
lv_context_2016_2022
# Out:
#    TIME_PERIOD         EC    DI        SSB   COC   CPI
# 0         2016  71.655374  7.31  94.107515  0.40  57.0
# 1         2017  71.655374  7.25  94.112781  0.50  58.0
# 2         2018  73.507226  7.38  94.113949  0.30  58.0
# 3         2019  73.507226  7.49  94.116764  0.48  56.0
# 4         2020  73.507226  7.24  94.114435  0.69  57.0
# 5         2021  72.766485  7.31  94.117799  0.72  59.0
# 6         2022  72.766485  7.37  94.117799  0.69  59.0

# %%
lv_eu_payments_2016_2022 = lv_eu_payments[lv_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()
lv_eu_payments_2016_2022 = lv_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)
lv_eu_payments_2016_2022 = lv_eu_payments_2016_2022.loc[1:7]
lv_eu_payments_2016_2022
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 1         2016          155094196
# 2         2017          160481758
# 3         2018          342377779
# 4         2019          728058421
# 5         2020          591900430
# 6         2021          564767158
# 7         2022          578719541

# %%
df_lv_2016_2022 = pd.merge(df_lv_2016_2022, lv_context_2016_2022, on='TIME_PERIOD', how='outer')

df_lv_2016_2022 = pd.merge(df_lv_2016_2022, lv_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_lv_2016_2022['EUPC'] = df_lv_2016_2022['EU_Payment_annual'] / df_lv_2016_2022['PS']

df_lv_2016_2022 = df_lv_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_lv_2016_2022
# Out:
#      UR  URFF    YUA   FDI       QOR       QOA  EIAP       PDPS    P65   P014  \
# 0  9.64  8.40  17.27  1.24  3.200000  5.100000  7.69  31.000000  19.78  15.41
# 1  8.72  7.67  16.97  4.05  3.000000  5.200000  6.87  31.000000  20.01  15.67
# 2  7.41  6.42  12.19  1.32  3.500000  5.500000  6.97  31.000000  20.20  15.83
# 3  6.31  5.42  12.41  3.37  3.600000  5.700000  7.29  31.000000  20.41  15.94
# 4  8.10  7.07  14.87  2.81  3.170769  5.380769  7.22  31.000000  20.67  16.00
# 5  7.51  6.54  14.78  9.78  3.170769  5.380769  6.79  30.000000  20.85  16.00
# 6  6.82  5.51  15.27  3.20  3.170769  5.380769  6.78  32.333333  21.01  15.93
#
#    ...   FEM   LFG       EPFRG        GGAG         EC    DI        SSB   COC  \
# 0  ...  71.7 -0.01   35.050000 -165.000000  71.655374  7.31  94.107515  0.40
# 1  ...  72.6  0.00  129.910000  -62.000000  71.655374  7.25  94.112781  0.50
# 2  ...  74.7 -0.01  -14.100000  536.000000  73.507226  7.38  94.113949  0.30
# 3  ...  75.5 -0.01   17.510000 -152.000000  73.507226  7.49  94.116764  0.48
# 4  ...  75.1  0.00  -38.580000 -649.000000  73.507226  7.24  94.114435  0.69
# 5  ...  72.9 -0.03  -35.700000  -69.357143  72.766485  7.31  94.117799  0.72
# 6  ...  75.5  0.01   61.486667  -69.357143  72.766485  7.37  94.117799  0.69
#
#     CPI          EUPC
# 0  57.0  7.912969e+07
# 1  58.0  8.272256e+07
# 2  58.0  1.773978e+08
# 3  56.0  3.811824e+08
# 4  57.0  3.115265e+08
# 5  59.0  3.004081e+08
# 6  59.0  3.078295e+08
#
# [7 rows x 32 columns]

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_lv_2016_2022.values)

df_lv_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_lv_2016_2022.index, columns=df_lv_2016_2022.columns)

# %%
df_lv_2016_2022_scaled.to_csv('Data/y/lv_2016_2022_tcdf.csv')

# %%
column_index = df_lv_2016_2022_scaled.columns.get_loc('LFG')
print(column_index)
# Out:
# 23

# %% [markdown]
# ===================================================================================================================

# %%
df_ee = pd.read_csv("Data/y/Estonia.csv")

df_ee = df_ee.loc[6:22]

df_ee
# Out:
#     Unnamed: 0 REF_AREA_LABEL  TIME_PERIOD    HI    LF     UR   URFF    YUA  \
# 6            6        Estonia         2006   NaN  0.69   5.91   5.59  12.12
# 7            7        Estonia         2007   NaN  0.69   4.59   3.76  10.10
# 8            8        Estonia         2008   NaN  0.70   5.45   5.14  12.03
# 9            9        Estonia         2009   NaN  0.69  13.55  10.30  27.41
# 10          10        Estonia         2010   NaN  0.68  16.71  14.09  32.94
# 11          11        Estonia         2011   NaN  0.69  12.33  11.58  22.39
# 12          12        Estonia         2012   NaN  0.68  10.02   9.10  20.86
# 13          13        Estonia         2013  5.43  0.68   8.63   8.15  18.70
# 14          14        Estonia         2014   NaN  0.68   7.35   6.81  14.98
# 15          15        Estonia         2015  5.43  0.68   6.41   6.32  14.34
# 16          16        Estonia         2016  5.52  0.69   6.88   6.16  14.13
# 17          17        Estonia         2017  5.61  0.70   5.81   5.24  12.18
# %%
df_ee = df_ee.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_ee["EMP"] = df_ee["EMP"].replace(':', np.nan)
df_ee["LTU"] = df_ee["LTU"].replace(':', np.nan)
df_ee["FEM"] = df_ee["FEM"].replace(':', np.nan)

# %%
missing_values(df_ee)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 2 - 12.5 %
# LTU - 2 - 12.5 %
# FEM - 2 - 12.5 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
df_ee = df_ee.copy()
fill_with_mode(df_ee, ["QOR", "QOA", "PDPS"])

# %%
fill_with_mean(df_ee, ["EMP", "LTU", "FEM", "EPFRG", "GGAG"])

# %%
ee_context_2007_2015 = pd.read_csv("Data/Context/Estonia_2007_2015.csv")

# %%
ee_context_2007_2015 = ee_context_2007_2015[["TIME_PERIOD", "PMSI", "JI", "DBP", "DWCP", "PR"]]
ee_context_2007_2015["DBPG"] = ee_context_2007_2015["DBP"].diff()
ee_context_2007_2015 = ee_context_2007_2015.drop(0)
ee_context_2007_2015 = ee_context_2007_2015.drop(["DBP"], axis=1)
ee_context_2007_2015
# Out:
#    TIME_PERIOD       PMSI     JI       DWCP  PR  DBPG
# 1         2007  56.666667  0.955  86.112980  90   0.0
# 2         2008  56.666667  0.955  86.252845  90   0.0
# 3         2009  56.666667  0.955  85.403987  90   0.0
# 4         2010  56.666667  0.955  85.415456  80   0.0
# 5         2011  56.666667  0.955  85.358224  80   0.0
# 6         2012  56.666667  0.955  85.374812  80   0.0
# 7         2013  56.666667  0.955  85.428313  85   0.0
# 8         2014  56.666667  0.955  85.462140  90   0.0
# 9         2015  56.666667  0.955  85.640301  90   0.0

# %%
ee_eu_payments = eu_payments[eu_payments['Country'] == 'EE'].copy()

ee_eu_payments['EU_Payment_annual'] = pd.to_numeric(ee_eu_payments['EU_Payment_annual'].str.replace(',', ''))

ee_eu_payments_2007_2015 = ee_eu_payments[ee_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

ee_eu_payments_2007_2015  = ee_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

ee_eu_payments_2007_2015 = ee_eu_payments_2007_2015.loc[0:8]

# %%
ee_eu_payments_2007_2015
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 0         2007           73827848
# 1         2008          113621099
# 2         2009          474611080
# 3         2010          527916818
# 4         2011          239059742
# 5         2012          658762433
# 6         2013          678590982
# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_ee_2007_2015.values)

df_ee_2007_2015_scaled = pd.DataFrame(scaled_features, index=df_ee_2007_2015.index, columns=df_ee_2007_2015.columns)

# %%
df_ee_2007_2015_scaled.to_csv('Data/y/ee_2007_2015_tcdf.csv')

# %%
df_lv.columns.equals(df_ee.columns)
# Out:
# True

# %%
column_index = df_ee_2007_2015_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 31

# %%
24,3,1
3,23,1
24,24,1
18,31,1
# Out:
# (18, 31, 1)

# %%
df_ee_2016_2022 = df_ee.loc[16:22]

# %%
df_ee_2016_2022
# Out:
#     TIME_PERIOD    UR  URFF    YUA    FDI  QOR  QOA  EIAP    PS  PDPS  ...  \
# 16         2016  6.88  6.16  14.13   3.77  4.7  4.5  3.90  1.32  30.0  ...
# 17         2017  5.81  5.24  12.18   6.32  4.7  5.1  3.63  1.32  31.0  ...
# 18         2018  5.41  5.26  12.08   4.08  4.7  4.6  3.43  1.32  31.0  ...
# 19         2019  4.51  4.93  11.62   9.77  4.7  4.6  3.34  1.33  31.0  ...
# 20         2020  6.96  6.77  18.42  12.01  4.7  4.6  3.08  1.33  31.0  ...
# 21         2021  6.18  5.54  16.62  20.31  4.7  4.6  2.68  1.33  31.0  ...
# 22         2022  5.57  5.06  18.39   4.89  4.7  4.6  2.60  1.35  31.0  ...
#
#         EBSG          GDPC        EIS      LBGD   EMP  LTU   FEM   LFG  \
# 16  3.207492  16863.602095  65.884179 -0.181622  77.0  2.2  73.7  0.01
# 17  3.975466  18457.882440  66.200409 -0.229889  79.2  2.0  76.8  0.01
# 18  2.315765  19999.192119  66.410718 -0.760256  79.7  1.3  76.8  0.00
# 19  3.686161  21457.612416  67.284038  0.196333  80.5  0.9  77.5  0.00
# 20 -1.083534  20954.364802  67.203161 -5.358715  79.1  1.2  76.9  0.00
# 21 -1.302298  23634.746178  68.295247 -2.149653  79.3  1.6  77.5  0.00
# 22 -1.236321  27017.885739  68.785368 -0.692318  81.9  1.3  80.4  0.04
#
#          EPFRG         GGAG
# 16   14.140000  1404.000000
# 17  279.830000   902.000000
# 18  141.280000 -1081.000000
# 19  149.720000 -5643.000000
# 20  817.170000 -2976.000000
# 21  -85.160000  -642.928571
# 22  182.648667  -642.928571
#
# [7 rows x 28 columns]

# %%
ee_context_2016_2022 = pd.read_csv("Data/Context/Estonia_2016_2022.csv")

ee_context_2016_2022 = ee_context_2016_2022[["TIME_PERIOD", "EC", "DI", "SSB", "COC", "CPI"]]

ee_context_2016_2022
# Out:
#    TIME_PERIOD         EC    DI        SSB   COC   CPI
# 0         2016  77.575862  7.85  94.560514  1.23  70.0
# 1         2017  77.428880  7.79  94.623643  1.20  71.0
# 2         2018  77.616357  7.97  94.652164  1.47  73.0
# 3         2019  77.691347  7.90  94.752132  1.53  74.0
# 4         2020  77.575862  7.84  94.661131  1.58  75.0
# 5         2021  77.571362  7.84  94.689166  1.51  74.0
# 6         2022  77.571362  7.96  94.689166  1.54  74.0

# %%
ee_eu_payments_2016_2022 = ee_eu_payments[ee_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

ee_eu_payments_2016_2022  = ee_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)

ee_eu_payments_2016_2022 = ee_eu_payments_2016_2022.loc[2:8]

ee_eu_payments_2016_2022
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 2         2016          192914599
# 3         2017          284117863
# 4         2018          435232587
# 5         2019          500627021
# 6         2020          511141090
# 7         2021          570113413
# 8         2022          546809658

# %%
df_ee_2016_2022 = pd.merge(df_ee_2016_2022, ee_context_2016_2022, on='TIME_PERIOD', how='outer')

df_ee_2016_2022 = pd.merge(df_ee_2016_2022, ee_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_ee_2016_2022['EUPC'] = df_ee_2016_2022['EU_Payment_annual'] / df_ee_2016_2022['PS']

df_ee_2016_2022 = df_ee_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_ee_2016_2022
# Out:
#      UR  URFF    YUA    FDI  QOR  QOA  EIAP  PDPS    P65   P014  ...   FEM  \
# 0  6.88  6.16  14.13   3.77  4.7  4.5  3.90  30.0  19.19  16.15  ...  73.7
# 1  5.81  5.24  12.18   6.32  4.7  5.1  3.63  31.0  19.47  16.28  ...  76.8
# 2  5.41  5.26  12.08   4.08  4.7  4.6  3.43  31.0  19.68  16.36  ...  76.8
# 3  4.51  4.93  11.62   9.77  4.7  4.6  3.34  31.0  19.90  16.43  ...  77.5
# 4  6.96  6.77  18.42  12.01  4.7  4.6  3.08  31.0  20.20  16.44  ...  76.9
# 5  6.18  5.54  16.62  20.31  4.7  4.6  2.68  31.0  20.43  16.38  ...  77.5
# 6  5.57  5.06  18.39   4.89  4.7  4.6  2.60  31.0  20.63  16.23  ...  80.4
#
#     LFG       EPFRG         GGAG         EC    DI        SSB   COC   CPI  \
# 0  0.01   14.140000  1404.000000  77.575862  7.85  94.560514  1.23  70.0
# 1  0.01  279.830000   902.000000  77.428880  7.79  94.623643  1.20  71.0
# 2  0.00  141.280000 -1081.000000  77.616357  7.97  94.652164  1.47  73.0
# 3  0.00  149.720000 -5643.000000  77.691347  7.90  94.752132  1.53  74.0
# 4  0.00  817.170000 -2976.000000  77.575862  7.84  94.661131  1.58  75.0
# 5  0.00  -85.160000  -642.928571  77.571362  7.84  94.689166  1.51  74.0
# 6  0.04  182.648667  -642.928571  77.571362  7.96  94.689166  1.54  74.0
#
#            EUPC
# 0  1.461474e+08
# 1  2.152408e+08
# 2  3.297217e+08
# 3  3.764113e+08
# 4  3.843166e+08
# 5  4.286567e+08
# 6  4.050442e+08
#
# [7 rows x 32 columns]

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_ee_2016_2022.values)

df_ee_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_ee_2016_2022.index, columns=df_ee_2016_2022.columns)

# %%
df_ee_2016_2022_scaled.to_csv('Data/y/ee_2016_2022_tcdf.csv')

# %%
column_index = df_ee_2016_2022_scaled.columns.get_loc('P014')
print(column_index)
# Out:
# 9

# %%
12,7,1
12,9,1
18,9,0
# Out:
# (18, 9, 0)

# %% [markdown]
# ===================================================================================================================

# %%
df_fi = pd.read_csv("Data/y/Finland.csv")

df_fi = df_fi.loc[6:22]

df_fi
# Out:
#     Unnamed: 0 REF_AREA_LABEL  TIME_PERIOD    HI    LF    UR  URFF    YUA  \
# 6            6        Finland         2006   NaN  2.72  8.94  9.14  25.77
# 15  74.072208  1.472224 -1.810725  71.8  2.9  70.7
# 16  73.979307  1.541867 -1.298460  72.4  2.9  70.8
# 17  74.081069       NaN -0.443691  73.2  2.6  71.3
# 18  73.950902       NaN -0.006899  75.3  2.0  73.4
# 19  74.581431       NaN  0.316119  76.2  1.5  74.5
# 20  74.395815       NaN -5.502841  75.5  1.5  73.8
# 21  74.478112       NaN -2.322281  76.8  1.8  75.8
# 22  74.855666       NaN -0.031939  78.4  1.5  77.8
#
# [17 rows x 35 columns]

# %%
df_fi = df_fi.copy()
df_fi['LFG'] = df_fi['LF'].diff()
df_fi['EPFRG'] = df_fi['EPFR'].diff()
df_fi['GGAG'] = df_fi['GGA'].diff()
df_fi = df_fi.drop(6)

# %%
df_fi = df_fi.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_fi["EMP"] = df_fi["EMP"].replace(':', np.nan)
df_fi["LTU"] = df_fi["LTU"].replace(':', np.nan)
df_fi["FEM"] = df_fi["FEM"].replace(':', np.nan)

# %%
missing_values(df_fi)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 2 - 12.5 %
# LTU - 2 - 12.5 %
# FEM - 2 - 12.5 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
df_fi = df_fi.copy()
fill_with_mode(df_fi, ["QOR", "QOA", "PDPS"])

fill_with_mean(df_fi, ["EMP", "LTU", "FEM", "EPFRG", "GGAG"])

# %%
fi_context_2007_2015 = pd.read_csv("Data/Context/Finland_2007_2015.csv")

fi_context_2007_2015 = fi_context_2007_2015[["TIME_PERIOD", "DI", "GE", "CPI", "RQ", "VAA"]]

fi_context_2007_2015
# Out:
#    TIME_PERIOD    DI    GE   CPI    RQ   VAA
# 0         2007  9.03  1.97  94.0  1.55  1.46
# 1         2008  9.25  2.04  90.0  1.61  1.46
# 2         2009  9.03  2.23  89.0  1.81  1.47
# 3         2010  9.19  2.22  92.0  1.87  1.49
# 4         2011  9.06  2.24  94.0  1.81  1.51
# 5         2012  9.06  2.21  90.0  1.82  1.60
# 6         2013  9.03  2.18  89.0  1.84  1.57
# 7         2014  9.03  2.03  89.0  1.88  1.54
# 8         2015  9.03  1.84  90.0  1.83  1.54

# %%
fi_eu_payments = eu_payments[eu_payments['Country'] == 'FI'].copy()

fi_eu_payments['EU_Payment_annual'] = pd.to_numeric(fi_eu_payments['EU_Payment_annual'].str.replace(',', ''))

fi_eu_payments_2007_2015 = fi_eu_payments[fi_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

fi_eu_payments_2007_2015  = fi_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

fi_eu_payments_2007_2015 = fi_eu_payments_2007_2015.loc[0:8]

fi_eu_payments_2007_2015 = fi_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

# %%
fi_eu_payments_2007_2015
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 0         2007           31919318
# 1         2008           47878976
# 2         2009          184114804
# 3         2010          147719657
# 4         2011          241478104
# 5         2012          220369451
# 6         2013          334713129
# 7         2014          215151249
# 8         2015           92469029

# %%
df_fi_2007_2015 = df_fi.loc[7:15]

# %%
df_fi_2007_2015 = pd.merge(df_fi_2007_2015, fi_context_2007_2015, on='TIME_PERIOD', how='outer')

df_fi_2007_2015 = pd.merge(df_fi_2007_2015, fi_eu_payments_2007_2015, on='TIME_PERIOD', how='outer')

df_fi_2007_2015['EUPC'] = df_fi_2007_2015['EU_Payment_annual'] / df_fi_2007_2015['PS']

df_fi_2007_2015 = df_fi_2007_2015.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_fi_2007_2015
# Out:
#      UR  URFF    YUA   FDI   QOR   QOA  EIAP  PDPS    P65   P014  ...  \
# 0  6.85  7.19  16.43  8.57  5.64  6.31  4.54  17.0  16.49  16.98  ...
# 1  6.37  6.69  16.34  6.79  5.84  6.43  4.52  17.0  16.63  16.80  ...
# 2  8.25  7.57  21.38 -3.48  5.89  6.33  4.63  18.0  16.88  16.67  ...
# 3  8.39  7.64  21.29  4.90  5.86  6.15  4.44  18.0  17.26  16.56  ...
# 4  7.78  7.10  19.93 -2.18  5.83  6.16  4.23  18.0  17.82  16.49  ...
# 5  7.69  7.05  18.87  1.92  6.09  6.20  4.16  18.0  18.45  16.44  ...
# 6  8.19  7.52  19.82 -1.83  6.10  6.22  4.13  18.0  19.07  16.42  ...
# 7  8.66  7.95  20.45  6.42  5.87  6.17  4.26  18.0  19.67  16.40  ...
# 8  9.38  8.84  22.30  7.54  5.78  6.05  4.22  18.0  20.21  16.36  ...
#
#          FEM   LFG    EPFRG    GGAG    DI    GE   CPI    RQ   VAA  \
# 0  72.435714 -0.04  -825.28 -2010.0  9.03  1.97  94.0  1.55  1.46
# 1  72.435714  0.04   522.16 -8272.0  9.25  2.04  90.0  1.61  1.46
# 2  71.500000 -0.03 -1655.62 -3519.0  9.03  2.23  89.0  1.81  1.47
# 3  70.300000 -0.02  2260.08  8024.0  9.19  2.22  92.0  1.87  1.49
# 4  70.700000  0.02   457.68 -7687.0  9.06  2.24  94.0  1.81  1.51
# 5  71.300000  0.01   -29.53 -5657.0  9.06  2.21  90.0  1.82  1.60
# 6  71.000000 -0.01  1090.54   770.0  9.03  2.18  89.0  1.84  1.57
# 7  71.200000 -0.01    82.22 -4059.0  9.03  2.03  89.0  1.88  1.54
# 8  70.700000  0.01   884.41 -3477.0  9.03  1.84  90.0  1.83  1.54
#
#            EUPC
# 0  6.033898e+06
# 1  9.016756e+06
# 2  3.447843e+07
# 3  2.755964e+07
# 4  4.480113e+07
# 5  4.073372e+07
# 6  6.152815e+07
# 7  3.940499e+07
# 8  1.687391e+07
#
# [9 rows x 32 columns]

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_fi_2007_2015.values)

df_fi_2007_2015_scaled = pd.DataFrame(scaled_features, index=df_fi_2007_2015.index, columns=df_fi_2007_2015.columns)

# %%
df_fi_2007_2015_scaled.to_csv('Data/y/fi_2007_2015_tcdf.csv')

# %%
df_ee.columns.equals(df_fi.columns)
# Out:
# True

# %%
column_index = df_fi_2007_2015_scaled.columns.get_loc('DI')
print(column_index)
# Out:
# 26

# %%
28,3,3
28,23,2
24,24,4
23,26,0
# Out:
# (23, 26, 0)

# %%
df_fi_2016_2022 = df_fi.loc[16:22]

# %%
df_fi_2016_2022
# Out:
#     TIME_PERIOD    UR  URFF    YUA   FDI  QOR  QOA  EIAP    PS  PDPS  ...  \
# 16         2016  8.82  8.58  20.06  2.19  5.7  6.2  3.86  5.50  18.0  ...
# 17         2017  8.64  8.39  20.04  6.66  5.4  6.3  3.76  5.51  18.0  ...
# 18         2018  7.36  7.30  16.96 -3.84  5.3  6.2  3.71  5.52  18.0  ...
# 19         2019  6.70  6.17  17.13  6.10  5.3  6.3  3.78  5.52  18.0  ...
# 20         2020  7.76  7.49  21.19 -0.94  5.3  6.2  3.66  5.53  18.0  ...
# 21         2021  7.62  7.04  17.06  8.01  5.3  6.2  4.11  5.54  18.0  ...
# 22         2022  6.72  6.37  14.14  4.67  5.3  6.2  3.76  5.56  18.0  ...
#
#         EBSG          GDPC        EIS      LBGD   EMP  LTU   FEM   LFG  \
# 16 -1.055550  39254.796323  73.979307 -1.298460  72.4  2.9  70.8  0.00
# 17  0.393848  40794.711317  74.081069 -0.443691  73.2  2.6  71.3  0.02
# 18 -0.845174  42045.861455  73.950902 -0.006899  75.3  2.0  73.4  0.04
# 19  0.672486  43197.214723  74.581431  0.316119  76.2  1.5  74.5  0.00
# 20  0.244091  42749.825799  74.395815 -5.502841  75.5  1.5  73.8 -0.01
# 21  0.054268  44895.007541  74.478112 -2.322281  76.8  1.8  75.8  0.06
# 22 -1.992973  47899.554112  74.855666 -0.031939  78.4  1.5  77.8  0.05
#
#        EPFRG         GGAG
# 16   854.870  2692.000000
# 17  2089.940 -2859.000000
# 18  2134.820  1157.000000
# 19   624.410 -3437.000000
# 20   582.080 -5023.000000
# 21  2337.900 -2382.642857
# 22   760.712 -2382.642857
#
# [7 rows x 28 columns]

# %%
fi_context_2016_2022 = pd.read_csv("Data/Context/Finland_2016_2022.csv")

fi_context_2016_2022 = fi_context_2016_2022[["TIME_PERIOD", "DI", "COC", "CPI", "VAA", "ROL"]]

# %%
fi_context_2016_2022
# Out:
#    TIME_PERIOD    DI   COC   CPI   VAA   ROL
# 0         2016  9.03  2.19  89.0  1.53  2.01
# 1         2017  9.03  2.16  85.0  1.56  2.02
# 2         2018  9.14  2.17  85.0  1.59  2.03
# 3         2019  9.25  2.11  86.0  1.56  2.01
# 4         2020  9.20  2.17  85.0  1.61  2.02
# 5         2021  9.27  2.24  88.0  1.61  2.01
# 6         2022  9.29  2.25  87.0  1.61  1.96

# %%
fi_eu_payments_2016_2022 = fi_eu_payments[fi_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

fi_eu_payments_2016_2022  = fi_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)

fi_eu_payments_2016_2022 = fi_eu_payments_2016_2022.loc[2:8]

fi_eu_payments_2016_2022
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 2         2016           99461071
# 3         2017          137852680
# 4         2018          185187826
# 5         2019          155710017
# 6         2020          146257401
# 7         2021          226744273
# 8         2022          181427308

# %%
df_fi_2016_2022 = pd.merge(df_fi_2016_2022, fi_context_2016_2022, on='TIME_PERIOD', how='outer')

df_fi_2016_2022 = pd.merge(df_fi_2016_2022, fi_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_fi_2016_2022['EUPC'] = df_fi_2016_2022['EU_Payment_annual'] / df_fi_2016_2022['PS']

df_fi_2016_2022 = df_fi_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_fi_2016_2022
# Out:
#      UR  URFF    YUA   FDI  QOR  QOA  EIAP  PDPS    P65   P014  ...   FEM  \
# 0  8.82  8.58  20.06  2.19  5.7  6.2  3.86  18.0  20.68  16.29  ...  70.8
# 1  8.64  8.39  20.04  6.66  5.4  6.3  3.76  18.0  21.15  16.20  ...  71.3
# 2  7.36  7.30  16.96 -3.84  5.3  6.2  3.71  18.0  21.62  16.07  ...  73.4
# 3  6.70  6.17  17.13  6.10  5.3  6.3  3.78  18.0  22.06  15.88  ...  74.5
# 4  7.76  7.49  21.19 -0.94  5.3  6.2  3.66  18.0  22.49  15.66  ...  73.8
# 5  7.62  7.04  17.06  8.01  5.3  6.2  4.11  18.0  22.87  15.45  ...  75.8
# 6  6.72  6.37  14.14  4.67  5.3  6.2  3.76  18.0  23.23  15.22  ...  77.8
#
#     LFG     EPFRG         GGAG    DI   COC   CPI   VAA   ROL          EUPC
# 0  0.00   854.870  2692.000000  9.03  2.19  89.0  1.53  2.01  1.808383e+07
# 1  0.02  2089.940 -2859.000000  9.03  2.16  85.0  1.56  2.02  2.501864e+07
# 2  0.04  2134.820  1157.000000  9.14  2.17  85.0  1.59  2.03  3.354852e+07
# 3  0.00   624.410 -3437.000000  9.25  2.11  86.0  1.56  2.01  2.820834e+07
# 4 -0.01   582.080 -5023.000000  9.20  2.17  85.0  1.61  2.02  2.644799e+07
# 5  0.06  2337.900 -2382.642857  9.27  2.24  88.0  1.61  2.01  4.092857e+07
# 6  0.05   760.712 -2382.642857  9.29  2.25  87.0  1.61  1.96  3.263081e+07
#
# [7 rows x 32 columns]

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_fi_2016_2022.values)

df_fi_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_fi_2016_2022.index, columns=df_fi_2016_2022.columns)

# %%
df_fi_2016_2022_scaled.to_csv('Data/y/fi_2016_2022_tcdf.csv')

# %% [markdown]
# ===================================================================================================================

# %%
df_se = pd.read_csv("Data/y/Sweden.csv")

df_se = df_se.loc[6:22]

df_se
# Out:
#     Unnamed: 0 REF_AREA_LABEL  TIME_PERIOD    HI    LF    UR  URFF    YUA  \
# 6            6         Sweden         2006   NaN  4.77  7.07  7.26  21.48
# 7            7         Sweden         2007   NaN  4.84  6.16  6.47  19.26
# 8            8         Sweden         2008   NaN  4.90  6.24  6.57  20.21
# 9            9         Sweden         2009   NaN  4.91  8.35  8.01  25.02
# 10          10         Sweden         2010   NaN  4.94  8.61  8.52  24.76
# 11          11         Sweden         2011   NaN  5.00  7.80  7.76  22.78
# 12          12         Sweden         2012   NaN  5.03  7.98  7.71  23.61
# 13          13         Sweden         2013  7.48  5.09  8.05  7.89  23.52
# 14          14         Sweden         2014   NaN  5.13  7.95  7.70  22.82
# 15          15         Sweden         2015  7.36  5.18  7.43  7.29  20.36
# 16          16         Sweden         2016  7.29  5.25  6.99  6.59  18.90
# 17          17         Sweden         2017  7.28  5.33  6.72  6.44  17.88
# 18          18         Sweden         2018  7.31  5.40  6.36  6.24  17.40
# 19          19         Sweden         2019  7.34  5.46  6.83  6.96  20.09
# 20          20         Sweden         2020  7.36  5.47  8.29  8.28  23.90
# 21          21         Sweden         2021  7.38  5.52  8.72  9.05  24.60
# 22          22         Sweden         2022  7.40  5.60  7.39  7.91  21.61
#
#      FDI   QOR  ...       EIA      EBSG           GDPC           GDP  \
# 6   5.22  5.50  ...  2.226741  6.865310  343319.451947  4.093849e+12
# 7   9.42  5.65  ...  2.251167  5.900063  362059.214096  4.225872e+12
# 8   8.05  5.63  ...  2.122367  5.218714  367898.323980  4.186862e+12
# 9   2.06  5.69  ...  2.177660  4.958800  357492.674906  4.008687e+12
# 10  0.13  5.71  ...  2.100519  4.661454  378703.698372  4.239216e+12
# 11  1.22  5.66  ...  1.989988  4.436392  392078.684225  4.373341e+12
# 12  0.78  5.58  ...  2.058833  4.367928  391255.979647  4.355215e+12
# 13  0.25  5.52  ...  2.033299  3.831176  396337.894577  4.404765e+12
# 14 -1.05  5.50  ...  1.974281  3.093335  408791.051257  4.505888e+12
# 15  1.95  5.36  ...  2.036107  3.259861  431846.583992  4.704604e+12
# 16  3.01  5.30  ...  1.885519  2.557094  443685.809403  4.815150e+12
# 17  4.53  5.50  ...  1.830963  1.867221  455661.623564  4.903034e+12
# 18 -0.13  5.60  ...  1.731348  1.652194  470977.219742  4.996337e+12
# 19  2.98  5.30  ...  1.688915  3.961344  489687.550802  5.123726e+12
# 20  3.40   NaN  ...  1.727511  4.189104  484957.369733  5.020978e+12
# 21  9.10   NaN  ...  1.972657  4.321306  524671.194591  5.319099e+12
# 22  9.30   NaN  ...  1.860571  1.905541  559287.117187  5.396720e+12
#
#           EIS      NINA      LBGD   EMP  LTU   FEM
# 6   75.860085  2.498465  1.972020  78.4  1.0   NaN
# 7   76.103068  2.407499  3.214195  79.7  0.8  76.5
# 8   76.553322  2.438199  2.032230  80.0  0.8  76.7
# 9   77.662551  2.561376 -0.614954  77.9  1.1  75.1
# 10  77.996697  2.592290 -0.240938  77.7  1.5  74.4
# 11  78.085683  2.433631  0.015331  79.0  1.4  76.0
# 12  78.297872  2.455194 -0.914026  79.1  1.4  76.4
# 13  78.807199  2.346443 -1.371356  79.4  1.4  76.7
# 14  79.421139  2.229543 -1.129253  79.6  1.3  77.2
# 15  79.676015  2.098638  0.377740  80.1  1.3  77.9
# 16  79.915037  2.109440  1.576112  80.8  1.2  78.7
# 17  80.003899       NaN  1.661827  81.4  1.1  79.2
# 18  80.089851       NaN  1.473616  82.0  0.9  79.7
# 19  79.890515       NaN  1.471518  81.7  0.8  79.1
# 20  79.959705       NaN -2.994377  80.2  1.0  77.5
# 21  79.882330       NaN -0.653958  80.4  1.8  77.7
# 22  80.900552       NaN  0.754005  82.0  1.9  79.1
#
# [17 rows x 35 columns]

# %%
df_se = df_se.copy()
df_se['LFG'] = df_se['LF'].diff()
df_se['EPFRG'] = df_se['EPFR'].diff()
df_se['GGAG'] = df_se['GGA'].diff()
df_se = df_se.drop(6)

# %%
df_se = df_se.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP"], axis=1)

# %%
df_se["EMP"] = df_se["EMP"].replace(':', np.nan)
df_se["LTU"] = df_se["LTU"].replace(':', np.nan)
df_se["FEM"] = df_se["FEM"].replace(':', np.nan)

# %%
missing_values(df_se)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# UR - 0 - 0.0 %
# URFF - 0 - 0.0 %
# YUA - 0 - 0.0 %
# FDI - 0 - 0.0 %
# QOR - 3 - 18.8 %
# QOA - 3 - 18.8 %
# EIAP - 0 - 0.0 %
# PS - 0 - 0.0 %
# PDPS - 1 - 6.2 %
# P65 - 0 - 0.0 %
# P014 - 0 - 0.0 %
# PGP - 0 - 0.0 %
# VABI - 0 - 0.0 %
# GCFP - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# EII - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# EIS - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# EMP - 0 - 0.0 %
# LTU - 0 - 0.0 %
# FEM - 0 - 0.0 %
# LFG - 0 - 0.0 %
# EPFRG - 1 - 6.2 %
# GGAG - 2 - 12.5 %

# %%
df_se = df_se.copy()
fill_with_mode(df_se, ["QOR"])

fill_with_mean(df_se, ["QOA", "FEM", "EPFRG", "GGAG", "PDPS"])

# %%
se_context_2007_2015 = pd.read_csv("Data/Context/Sweden_2007_2015.csv")

se_context_2007_2015 = se_context_2007_2015[["TIME_PERIOD", "DI", "GE", "CPI", "RQ", "VAA"]]

se_eu_payments = eu_payments[eu_payments['Country'] == 'SE'].copy()

se_eu_payments['EU_Payment_annual'] = pd.to_numeric(se_eu_payments['EU_Payment_annual'].str.replace(',', ''))

se_eu_payments_2007_2015 = se_eu_payments[se_eu_payments['Programming_Period'] == '2007-2013'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

se_eu_payments_2007_2015  = se_eu_payments_2007_2015.rename({"Year":"TIME_PERIOD"}, axis=1)

se_eu_payments_2007_2015 = se_eu_payments_2007_2015.loc[0:8]

# %%
se_eu_payments_2007_2015
# Out:
#    TIME_PERIOD  EU_Payment_annual
# 0         2007           32521830
# 1         2008           48782752
# 2         2009          181387148
# 3         2010          175258079
# 4         2011          318545277
# 5         2012          110051001
# 6         2013          250369417
# 7         2014          344723150
# 8         2015           78408753

# %%
df_se_2007_2015 = df_se.loc[7:15]

df_se_2007_2015 = pd.merge(df_se_2007_2015, se_context_2007_2015, on='TIME_PERIOD', how='outer')

df_se_2007_2015 = pd.merge(df_se_2007_2015, se_eu_payments_2007_2015, on='TIME_PERIOD', how='outer')

df_se_2007_2015['EUPC'] = df_se_2007_2015['EU_Payment_annual'] / df_se_2007_2015['PS']

df_se_2007_2015 = df_se_2007_2015.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_se_2007_2015.to_csv('Data/y/se_2007_2015_bn.csv')

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_se_2007_2015.values)

df_se_2007_2015_scaled = pd.DataFrame(scaled_features, index=df_se_2007_2015.index, columns=df_se_2007_2015.columns)

# %%
df_se_2007_2015_scaled.to_csv('Data/y/se_2007_2015_tcdf.csv')

# %%
df_fi.columns.equals(df_se.columns)
# Out:
# True

# %%
column_index = df_se_2007_2015_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 31

# %%
13,6,3
13,7,0
19,14,0
26,24,3
12,25,0
6,25,1
24,26,0
24,31,0
# Out:
# (24, 31, 0)

# %%
se_context_2016_2022 = pd.read_csv("Data/Context/Sweden_2016_2022.csv")

se_context_2016_2022 = se_context_2016_2022[["TIME_PERIOD", "DI", "COC", "CPI", "VAA", "ROL"]]

df_se_2016_2022 = df_se.loc[16:22]

se_eu_payments_2016_2022 = se_eu_payments[se_eu_payments['Programming_Period'] == '2014-2020'].groupby('Year')['EU_Payment_annual'].sum().reset_index()

se_eu_payments_2016_2022  = se_eu_payments_2016_2022.rename({"Year":"TIME_PERIOD"}, axis=1)

se_eu_payments_2016_2022 = se_eu_payments_2016_2022.loc[1:7]

df_se_2016_2022 = pd.merge(df_se_2016_2022, se_context_2016_2022, on='TIME_PERIOD', how='outer')

df_se_2016_2022 = pd.merge(df_se_2016_2022, se_eu_payments_2016_2022, on='TIME_PERIOD', how='outer')

df_se_2016_2022['EUPC'] = df_se_2016_2022['EU_Payment_annual'] / df_se_2016_2022['PS']

df_se_2016_2022 = df_se_2016_2022.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)

# %%
df_se_2016_2022.to_csv('Data/y/se_2016_2022_bn.csv')

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_se_2016_2022.values)

df_se_2016_2022_scaled = pd.DataFrame(scaled_features, index=df_se_2016_2022.index, columns=df_se_2016_2022.columns)

# %%
df_se_2016_2022_scaled.to_csv('Data/y/se_2016_2022_tcdf.csv')

# %%
column_index = df_se_2016_2022_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 31

# %%
18,12,1
18,17,2
5,28,0
24,28,1
18,31,1
# Out:
# (18, 31, 1)
