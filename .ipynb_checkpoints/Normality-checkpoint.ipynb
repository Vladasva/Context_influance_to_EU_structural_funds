# %%
from scipy.stats import shapiro 
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df_dk = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/dk_bn.csv")

# %%
def shapiro_test(df):
    for feature in df.columns:
        if feature != "Unnamed: 0":
            print(feature)
            print(shapiro(df[feature]))
            
def fix_outliers_with_mean(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    clean_mean = df.loc[(df[column_name] >= lower) & (df[column_name] <= upper), column_name].mean()

    df.loc[(df[column_name] < lower) | (df[column_name] > upper), column_name] = clean_mean
    
    return df

def fix_outliers_with_mode(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    clean_mode = df.loc[(df[column_name] >= lower) & (df[column_name] <= upper), column_name].mode()[0]

    df.loc[(df[column_name] < lower) | (df[column_name] > upper), column_name] = clean_mode
    
    return df

def transform_log(df, feature):
    df_lg = df.copy() 
    df_lg[feature] = np.log1p(df_lg[feature])
    return df_lg

def transform_sqrt(df, feature):
    df_sq = df.copy()
    df_sq[feature] = np.sqrt(df_sq[feature])
    return df_sq

def transform_cbrt(df, feature):
    df_cb = df.copy()
    df_cb[feature] = np.cbrt(df_cb[feature])
    return df_cb

# %%
shapiro_test(df_dk)
# Out:
# GDPC
# ShapiroResult(statistic=0.9330787062644958, pvalue=0.27264758944511414)
# VABI
# ShapiroResult(statistic=0.8220870494842529, pvalue=0.005434150341898203)
# EMP
# ShapiroResult(statistic=0.9369145035743713, pvalue=0.31292134523391724)
# QOA
# ShapiroResult(statistic=0.8577366471290588, pvalue=0.017743488773703575)
# QOR
# ShapiroResult(statistic=0.8105772137641907, pvalue=0.003776611527428031)
# YUA
# ShapiroResult(statistic=0.9674388766288757, pvalue=0.7956098318099976)
# REST
# ShapiroResult(statistic=0.9575539827346802, pvalue=0.6177088022232056)
# EBSG
# ShapiroResult(statistic=0.8828245401382446, pvalue=0.04295153543353081)
# GGFC
# ShapiroResult(statistic=0.9617161750793457, pvalue=0.6930301189422607)
# LBGD
# ShapiroResult(statistic=0.9448797702789307, pvalue=0.4131315350532532)
# FDI
# ShapiroResult(statistic=0.9613683819770813, pvalue=0.6866920590400696)
# PC
# ShapiroResult(statistic=0.9257813096046448, pvalue=0.2088562697172165)
# ARP
# ShapiroResult(statistic=0.9135500192642212, pvalue=0.13276956975460052)
# CO2C
# ShapiroResult(statistic=0.92138671875, pvalue=0.17757339775562286)
# PAM
# ShapiroResult(statistic=0.9762706160545349, pvalue=0.9270948767662048)
# ROL
# ShapiroResult(statistic=0.9492360949516296, pvalue=0.47768324613571167)
# GE
# ShapiroResult(statistic=0.9157573580741882, pvalue=0.1441131830215454)
# COC
# ShapiroResult(statistic=0.8975591063499451, pvalue=0.0734601840376854)
# RQ
# ShapiroResult(statistic=0.9134527444839478, pvalue=0.1322907954454422)
# SSB
# ShapiroResult(statistic=0.870017409324646, pvalue=0.027212198823690414)
# PT
# ShapiroResult(statistic=0.8645956516265869, pvalue=0.022502413019537926)
# EUPC
# ShapiroResult(statistic=0.9498410820960999, pvalue=0.48717305064201355)

# %%
df_dk = fix_outliers_with_mean(df_dk, "SSB")

# %%
df_dk = fix_outliers_with_mean(df_dk, "PT")

# %%
df_dk_lg = transform_log(df_dk, "SSB")

# %%
df_dk_lg = transform_log(df_dk, "PT")

# %%
df_dk_sq = transform_sqrt(df_dk, "SSB")

# %%
df_dk_sq = transform_sqrt(df_dk, "PT")

# %%
df_dk_cb = transform_cbrt(df_dk, "SSB")

# %%
df_dk_cb = transform_cbrt(df_dk, "PT")

# %%
shapiro_test(df_dk_cb)
# Out:
# GDPC
# ShapiroResult(statistic=0.9330787062644958, pvalue=0.27264758944511414)
# VABI
# ShapiroResult(statistic=0.8220870494842529, pvalue=0.005434150341898203)
# EMP
# ShapiroResult(statistic=0.9369145035743713, pvalue=0.31292134523391724)
# QOA
# ShapiroResult(statistic=0.8577366471290588, pvalue=0.017743488773703575)
# QOR
# ShapiroResult(statistic=0.8105772137641907, pvalue=0.003776611527428031)
# YUA
# ShapiroResult(statistic=0.9674388766288757, pvalue=0.7956098318099976)
# REST
# ShapiroResult(statistic=0.9575539827346802, pvalue=0.6177088022232056)
# EBSG
# ShapiroResult(statistic=0.8828245401382446, pvalue=0.04295153543353081)
# GGFC
# ShapiroResult(statistic=0.9617161750793457, pvalue=0.6930301189422607)
# LBGD
# ShapiroResult(statistic=0.9448797702789307, pvalue=0.4131315350532532)
# FDI
# ShapiroResult(statistic=0.9613683819770813, pvalue=0.6866920590400696)
# PC
# ShapiroResult(statistic=0.9257813096046448, pvalue=0.2088562697172165)
# ARP
# ShapiroResult(statistic=0.9135500192642212, pvalue=0.13276956975460052)
# CO2C
# ShapiroResult(statistic=0.92138671875, pvalue=0.17757339775562286)
# PAM
# ShapiroResult(statistic=0.9762706160545349, pvalue=0.9270948767662048)
# ROL
# ShapiroResult(statistic=0.9492360949516296, pvalue=0.47768324613571167)
# GE
# ShapiroResult(statistic=0.9157573580741882, pvalue=0.1441131830215454)
# COC
# ShapiroResult(statistic=0.8975591063499451, pvalue=0.0734601840376854)
# RQ
# ShapiroResult(statistic=0.9134527444839478, pvalue=0.1322907954454422)
# SSB
# ShapiroResult(statistic=0.870017409324646, pvalue=0.027212198823690414)
# PT
# ShapiroResult(statistic=0.8645806312561035, pvalue=0.02249063178896904)
# EUPC
# ShapiroResult(statistic=0.9498410820960999, pvalue=0.48717305064201355)

# %%
df_de = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/de_bn.csv")

# %%
shapiro_test(df_de)
# Out:
# GDPC
# ShapiroResult(statistic=0.9551502466201782, pvalue=0.5753679871559143)
# VABI
# ShapiroResult(statistic=0.8001845479011536, pvalue=0.0027389044407755136)
# EMP
# ShapiroResult(statistic=0.9821909070014954, pvalue=0.9785429835319519)
# QOA
# ShapiroResult(statistic=0.952107310295105, pvalue=0.523792028427124)
# QOR
# ShapiroResult(statistic=0.9450674057006836, pvalue=0.41577091813087463)
# YUA
# ShapiroResult(statistic=0.891751229763031, pvalue=0.059376735240221024)
# REST
# ShapiroResult(statistic=0.9601640105247498, pvalue=0.6647705435752869)
# EBSG
# ShapiroResult(statistic=0.9159300327301025, pvalue=0.14504022896289825)
# GGFC
# ShapiroResult(statistic=0.8862470388412476, pvalue=0.04860445111989975)
# LBGD
# ShapiroResult(statistic=0.8207314014434814, pvalue=0.005203837063163519)
# FDI
# ShapiroResult(statistic=0.9397264719009399, pvalue=0.34567710757255554)
# PC
# ShapiroResult(statistic=0.8866395950317383, pvalue=0.04930075258016586)
# ARP
# ShapiroResult(statistic=0.9334166049957275, pvalue=0.275998055934906)
# CO2C
# ShapiroResult(statistic=0.848675012588501, pvalue=0.013027000240981579)
# PAM
# ShapiroResult(statistic=0.7432725429534912, pvalue=0.0005277642048895359)
# ROL
# ShapiroResult(statistic=0.926408052444458, pvalue=0.2137281596660614)
# GE
# ShapiroResult(statistic=0.8770915269851685, pvalue=0.034970492124557495)
# COC
# ShapiroResult(statistic=0.9496738910675049, pvalue=0.4845379590988159)
# RQ
# ShapiroResult(statistic=0.9133756756782532, pvalue=0.1319124698638916)
# SSB
# ShapiroResult(statistic=0.9141526222229004, pvalue=0.13577495515346527)
# PT
# ShapiroResult(statistic=0.8264157772064209, pvalue=0.006245139054954052)
# EUPC
# ShapiroResult(statistic=0.9413030743598938, pvalue=0.36528298258781433)

# %%
df_de = fix_outliers_with_mean(df_de, "GE")
df_de = fix_outliers_with_mean(df_de, "PT")

# %%
df_de_lg = transform_log(df_de, "GE")
df_de_lg = transform_log(df_de, "PT")

# %%
df_de_sq = transform_sqrt(df_de, "GE")
df_de_sq = transform_sqrt(df_de, "PT")

# %%
df_de_cb = transform_cbrt(df_de, "GE")
df_de_cb = transform_cbrt(df_de, "PT")

# %%
df_de["GE"]
# Out:
# 0     1.630000
# 1     1.510000
# 2     1.580000
# 3     1.520000
# 4     1.500000
# 5     1.530000
# 6     1.510000
# 7     1.660000
# 8     1.660000
# 9     1.660000
# 10    1.610000
# 11    1.520000
# 12    1.500000
# 13    1.568462
# 14    1.568462
# 15    1.568462
# Name: GE, dtype: float64

# %%
shapiro_test(df_de_cb)
# Out:
# GDPC
# ShapiroResult(statistic=0.9551502466201782, pvalue=0.5753679871559143)
# VABI
# ShapiroResult(statistic=0.8001845479011536, pvalue=0.0027389044407755136)
# EMP
# ShapiroResult(statistic=0.9821909070014954, pvalue=0.9785429835319519)
# QOA
# ShapiroResult(statistic=0.952107310295105, pvalue=0.523792028427124)
# QOR
# ShapiroResult(statistic=0.9450674057006836, pvalue=0.41577091813087463)
# YUA
# ShapiroResult(statistic=0.891751229763031, pvalue=0.059376735240221024)
# REST
# ShapiroResult(statistic=0.9601640105247498, pvalue=0.6647705435752869)
# EBSG
# ShapiroResult(statistic=0.9159300327301025, pvalue=0.14504022896289825)
# GGFC
# ShapiroResult(statistic=0.8862470388412476, pvalue=0.04860445111989975)
# LBGD
# ShapiroResult(statistic=0.8207314014434814, pvalue=0.005203837063163519)
# FDI
# ShapiroResult(statistic=0.9397264719009399, pvalue=0.34567710757255554)
# PC
# ShapiroResult(statistic=0.8866395950317383, pvalue=0.04930075258016586)
# ARP
# ShapiroResult(statistic=0.9334166049957275, pvalue=0.275998055934906)
# CO2C
# ShapiroResult(statistic=0.848675012588501, pvalue=0.013027000240981579)
# PAM
# ShapiroResult(statistic=0.7432725429534912, pvalue=0.0005277642048895359)
# ROL
# ShapiroResult(statistic=0.926408052444458, pvalue=0.2137281596660614)
# GE
# ShapiroResult(statistic=0.8770915269851685, pvalue=0.034970492124557495)
# COC
# ShapiroResult(statistic=0.9496738910675049, pvalue=0.4845379590988159)
# RQ
# ShapiroResult(statistic=0.9133756756782532, pvalue=0.1319124698638916)
# SSB
# ShapiroResult(statistic=0.9141526222229004, pvalue=0.13577495515346527)
# PT
# ShapiroResult(statistic=0.8282289505004883, pvalue=0.006622267886996269)
# EUPC
# ShapiroResult(statistic=0.9413030743598938, pvalue=0.36528298258781433)

# %%
df_pl = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/pl_bn.csv")

# %%
shapiro_test(df_pl)
# Out:
# GDPC
# ShapiroResult(statistic=0.9411523342132568, pvalue=0.3633691072463989)
# VABI
# ShapiroResult(statistic=0.9082755446434021, pvalue=0.1091570258140564)
# EMP
# ShapiroResult(statistic=0.922377347946167, pvalue=0.1842023879289627)
# QOA
# ShapiroResult(statistic=0.8722735643386841, pvalue=0.02946835197508335)
# QOR
# ShapiroResult(statistic=0.9361411929130554, pvalue=0.30440041422843933)
# YUA
# ShapiroResult(statistic=0.9139413833618164, pvalue=0.13471369445323944)
# REST
# ShapiroResult(statistic=0.932355523109436, pvalue=0.2656003534793854)
# EBSG
# ShapiroResult(statistic=0.9650987386703491, pvalue=0.7543336153030396)
# GGFC
# ShapiroResult(statistic=0.9784814715385437, pvalue=0.9503998160362244)
# LBGD
# ShapiroResult(statistic=0.9573471546173096, pvalue=0.6140203475952148)
# FDI
# ShapiroResult(statistic=0.935751736164093, pvalue=0.30018725991249084)
# PC
# ShapiroResult(statistic=0.4747471809387207, pvalue=1.3190451682021376e-06)
# ARP
# ShapiroResult(statistic=0.8249432444572449, pvalue=0.0059556798078119755)
# CO2C
# ShapiroResult(statistic=0.9340066909790039, pvalue=0.2819395959377289)
# PAM
# ShapiroResult(statistic=0.8996049761772156, pvalue=0.07920687645673752)
# ROL
# ShapiroResult(statistic=0.8785110712051392, pvalue=0.03678974509239197)
# GE
# ShapiroResult(statistic=0.9383973479270935, pvalue=0.3298446238040924)
# COC
# ShapiroResult(statistic=0.9420352578163147, pvalue=0.37469616532325745)
# RQ
# ShapiroResult(statistic=0.9524144530296326, pvalue=0.5288786888122559)
# SSB
# ShapiroResult(statistic=0.8551570773124695, pvalue=0.016240132972598076)
# PT
# ShapiroResult(statistic=0.8717644214630127, pvalue=0.028942594304680824)
# EUPC
# ShapiroResult(statistic=0.9305616021156311, pvalue=0.24883431196212769)

# %%
df_pl = fix_outliers_with_mean(df_pl, "ROL")
df_pl = fix_outliers_with_mean(df_pl, "SSB")
df_pl = fix_outliers_with_mean(df_pl, "PT")

# %%
df_pl_lg = transform_log(df_pl, "ROL")
df_pl_lg = transform_log(df_pl, "SSB")
df_pl_lg = transform_log(df_pl, "PT")

# %%
df_pl_sq = transform_sqrt(df_pl, "ROL")
df_pl_sq = transform_sqrt(df_pl, "SSB")
df_pl_sq = transform_sqrt(df_pl, "PT")

# %%
df_pl_cb = transform_cbrt(df_pl, "ROL")
df_pl_cb = transform_cbrt(df_pl, "SSB")
df_pl_cb = transform_cbrt(df_pl, "PT")

# %%
shapiro_test(df_pl_sq)
# Out:
# GDPC
# ShapiroResult(statistic=0.9411523342132568, pvalue=0.3633691072463989)
# VABI
# ShapiroResult(statistic=0.9082755446434021, pvalue=0.1091570258140564)
# EMP
# ShapiroResult(statistic=0.922377347946167, pvalue=0.1842023879289627)
# QOA
# ShapiroResult(statistic=0.8722735643386841, pvalue=0.02946835197508335)
# QOR
# ShapiroResult(statistic=0.9361411929130554, pvalue=0.30440041422843933)
# YUA
# ShapiroResult(statistic=0.9139413833618164, pvalue=0.13471369445323944)
# REST
# ShapiroResult(statistic=0.932355523109436, pvalue=0.2656003534793854)
# EBSG
# ShapiroResult(statistic=0.9650987386703491, pvalue=0.7543336153030396)
# GGFC
# ShapiroResult(statistic=0.9784814715385437, pvalue=0.9503998160362244)
# LBGD
# ShapiroResult(statistic=0.9573471546173096, pvalue=0.6140203475952148)
# FDI
# ShapiroResult(statistic=0.935751736164093, pvalue=0.30018725991249084)
# PC
# ShapiroResult(statistic=0.4747471809387207, pvalue=1.3190451682021376e-06)
# ARP
# ShapiroResult(statistic=0.8249432444572449, pvalue=0.0059556798078119755)
# CO2C
# ShapiroResult(statistic=0.9340066909790039, pvalue=0.2819395959377289)
# PAM
# ShapiroResult(statistic=0.8996049761772156, pvalue=0.07920687645673752)
# ROL
# ShapiroResult(statistic=0.8785110712051392, pvalue=0.03678974509239197)
# GE
# ShapiroResult(statistic=0.9383973479270935, pvalue=0.3298446238040924)
# COC
# ShapiroResult(statistic=0.9420352578163147, pvalue=0.37469616532325745)
# RQ
# ShapiroResult(statistic=0.9524144530296326, pvalue=0.5288786888122559)
# SSB
# ShapiroResult(statistic=0.8551570773124695, pvalue=0.016240132972598076)
# PT
# ShapiroResult(statistic=0.8613881468772888, pvalue=0.020128069445490837)
# EUPC
# ShapiroResult(statistic=0.9305616021156311, pvalue=0.24883431196212769)

# %%
df_lt = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lt_bn.csv")

# %%
shapiro_test(df_lt)
# Out:
# GDPC
# ShapiroResult(statistic=0.9364999532699585, pvalue=0.308328241109848)
# VABI
# ShapiroResult(statistic=0.9134343266487122, pvalue=0.13220039010047913)
# EMP
# ShapiroResult(statistic=0.9378567934036255, pvalue=0.32358595728874207)
# QOA
# ShapiroResult(statistic=0.9193337559700012, pvalue=0.16456757485866547)
# QOR
# ShapiroResult(statistic=0.9328317642211914, pvalue=0.27022239565849304)
# YUA
# ShapiroResult(statistic=0.8949037194252014, pvalue=0.0666358545422554)
# REST
# ShapiroResult(statistic=0.9622192978858948, pvalue=0.7021985054016113)
# EBSG
# ShapiroResult(statistic=0.8969070315361023, pvalue=0.07172030955553055)
# GGFC
# ShapiroResult(statistic=0.8530471324920654, pvalue=0.015110763721168041)
# LBGD
# ShapiroResult(statistic=0.8764352798461914, pvalue=0.03416154161095619)
# FDI
# ShapiroResult(statistic=0.9599186182022095, pvalue=0.6603145599365234)
# PC
# ShapiroResult(statistic=0.8965780735015869, pvalue=0.07085864990949631)
# ARP
# ShapiroResult(statistic=0.9414340853691101, pvalue=0.3669528663158417)
# CO2C
# ShapiroResult(statistic=0.9482098817825317, pvalue=0.46187058091163635)
# PAM
# ShapiroResult(statistic=0.9588757157325745, pvalue=0.6414365768432617)
# ROL
# ShapiroResult(statistic=0.930461049079895, pvalue=0.2479243129491806)
# GE
# ShapiroResult(statistic=0.918949544429779, pvalue=0.16223952174186707)
# COC
# ShapiroResult(statistic=0.9604027271270752, pvalue=0.6691102981567383)
# RQ
# ShapiroResult(statistic=0.9587256908416748, pvalue=0.6387311816215515)
# SSB
# ShapiroResult(statistic=0.8511991500854492, pvalue=0.014189894311130047)
# PT
# ShapiroResult(statistic=0.8621209859848022, pvalue=0.02064621075987816)
# EUPC
# ShapiroResult(statistic=0.9289188981056213, pvalue=0.23434801399707794)

# %%
df_lt = fix_outliers_with_mean(df_lt, "SSB")
df_lt = fix_outliers_with_mean(df_lt, "PT")

# %%
df_lt_lg = transform_log(df_lt, "SSB")
df_lt_lg = transform_log(df_lt, "PT")

# %%
df_lt_sq = transform_sqrt(df_lt, "SSB")
df_lt_sq = transform_sqrt(df_lt, "PT")

# %%
df_lt_cb = transform_cbrt(df_lt, "SSB")
df_lt_cb = transform_cbrt(df_lt, "PT")

# %%
shapiro_test(df_lt_cb)
# Out:
# GDPC
# ShapiroResult(statistic=0.9364999532699585, pvalue=0.308328241109848)
# VABI
# ShapiroResult(statistic=0.9134343266487122, pvalue=0.13220039010047913)
# EMP
# ShapiroResult(statistic=0.9378567934036255, pvalue=0.32358595728874207)
# QOA
# ShapiroResult(statistic=0.9193337559700012, pvalue=0.16456757485866547)
# QOR
# ShapiroResult(statistic=0.9328317642211914, pvalue=0.27022239565849304)
# YUA
# ShapiroResult(statistic=0.8949037194252014, pvalue=0.0666358545422554)
# REST
# ShapiroResult(statistic=0.9622192978858948, pvalue=0.7021985054016113)
# EBSG
# ShapiroResult(statistic=0.8969070315361023, pvalue=0.07172030955553055)
# GGFC
# ShapiroResult(statistic=0.8530471324920654, pvalue=0.015110763721168041)
# LBGD
# ShapiroResult(statistic=0.8764352798461914, pvalue=0.03416154161095619)
# FDI
# ShapiroResult(statistic=0.9599186182022095, pvalue=0.6603145599365234)
# PC
# ShapiroResult(statistic=0.8965780735015869, pvalue=0.07085864990949631)
# ARP
# ShapiroResult(statistic=0.9414340853691101, pvalue=0.3669528663158417)
# CO2C
# ShapiroResult(statistic=0.9482098817825317, pvalue=0.46187058091163635)
# PAM
# ShapiroResult(statistic=0.9588757157325745, pvalue=0.6414365768432617)
# ROL
# ShapiroResult(statistic=0.930461049079895, pvalue=0.2479243129491806)
# GE
# ShapiroResult(statistic=0.918949544429779, pvalue=0.16223952174186707)
# COC
# ShapiroResult(statistic=0.9604027271270752, pvalue=0.6691102981567383)
# RQ
# ShapiroResult(statistic=0.9587256908416748, pvalue=0.6387311816215515)
# SSB
# ShapiroResult(statistic=0.8511991500854492, pvalue=0.014189894311130047)
# PT
# ShapiroResult(statistic=0.8659610748291016, pvalue=0.023601217195391655)
# EUPC
# ShapiroResult(statistic=0.9289188981056213, pvalue=0.23434801399707794)

# %%
df_lv = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lv_bn.csv")

# %%
shapiro_test(df_lv)
# Out:
# GDPC
# ShapiroResult(statistic=0.9568334221839905, pvalue=0.6048933267593384)
# VABI
# ShapiroResult(statistic=0.9304149150848389, pvalue=0.24750785529613495)
# EMP
# ShapiroResult(statistic=0.9324625730514526, pvalue=0.266632616519928)
# QOA
# ShapiroResult(statistic=0.9596464037895203, pvalue=0.6553761959075928)
# QOR
# ShapiroResult(statistic=0.8992637395858765, pvalue=0.07821725308895111)
# YUA
# ShapiroResult(statistic=0.8607217073440552, pvalue=0.019668785855174065)
# REST
# ShapiroResult(statistic=0.9452607035636902, pvalue=0.4185032546520233)
# EBSG
# ShapiroResult(statistic=0.9686548113822937, pvalue=0.8163741827011108)
# GGFC
# ShapiroResult(statistic=0.881106436252594, pvalue=0.04037698730826378)
# LBGD
# ShapiroResult(statistic=0.8619498014450073, pvalue=0.02052389457821846)
# FDI
# ShapiroResult(statistic=0.9163545370101929, pvalue=0.14734424650669098)
# PC
# ShapiroResult(statistic=0.8885976672172546, pvalue=0.05293218046426773)
# ARP
# ShapiroResult(statistic=0.9390843510627747, pvalue=0.3379489481449127)
# CO2C
# ShapiroResult(statistic=0.9627439975738525, pvalue=0.7117523550987244)
# PAM
# ShapiroResult(statistic=0.8978967666625977, pvalue=0.07437822222709656)
# ROL
# ShapiroResult(statistic=0.8833662867546082, pvalue=0.04379856958985329)
# GE
# ShapiroResult(statistic=0.9573984146118164, pvalue=0.6149342656135559)
# COC
# ShapiroResult(statistic=0.8937666416168213, pvalue=0.06391707062721252)
# RQ
# ShapiroResult(statistic=0.9084144830703735, pvalue=0.10972092300653458)
# SSB
# ShapiroResult(statistic=0.8723667860031128, pvalue=0.0295657217502594)
# PT
# ShapiroResult(statistic=0.8962137699127197, pvalue=0.06991695612668991)
# EUPC
# ShapiroResult(statistic=0.8775869011878967, pvalue=0.0355944000184536)

# %%
df_lv = fix_outliers_with_mean(df_lv, "FDI")
df_lv = fix_outliers_with_mean(df_lv, "ROL")
df_lv = fix_outliers_with_mean(df_lv, "SSB")
df_lv = fix_outliers_with_mean(df_lv, "EUPC")
df_lv = fix_outliers_with_mean(df_lv, "EBSG")
df_lv = fix_outliers_with_mean(df_lv, "YUA")

# %%
df_lv_lg = transform_log(df_lv, "ROL")
df_lv_lg = transform_log(df_lv, "SSB")
df_lv_lg = transform_log(df_lv, "EUPC")
df_lv_lg = transform_log(df_lv, "YUA")

# %%
df_lv_sq = transform_sqrt(df_lv, "ROL")
df_lv_sq = transform_sqrt(df_lv, "SSB")
df_lv_sq = transform_sqrt(df_lv, "EUPC")

# %%
df_lv_cb = transform_cbrt(df_lv, "ROL")
df_lv_cb = transform_cbrt(df_lv, "SSB")
df_lv_cb = transform_cbrt(df_lv, "EUPC")

# %%
shapiro_test(df_lv_cb)
# Out:
# GDPC
# ShapiroResult(statistic=0.9568334221839905, pvalue=0.6048933267593384)
# VABI
# ShapiroResult(statistic=0.9304149150848389, pvalue=0.24750785529613495)
# EMP
# ShapiroResult(statistic=0.9324625730514526, pvalue=0.266632616519928)
# QOA
# ShapiroResult(statistic=0.9596464037895203, pvalue=0.6553761959075928)
# QOR
# ShapiroResult(statistic=0.8992637395858765, pvalue=0.07821725308895111)
# YUA
# ShapiroResult(statistic=0.8607217073440552, pvalue=0.019668785855174065)
# REST
# ShapiroResult(statistic=0.9452607035636902, pvalue=0.4185032546520233)
# EBSG
# ShapiroResult(statistic=0.9686548113822937, pvalue=0.8163741827011108)
# GGFC
# ShapiroResult(statistic=0.881106436252594, pvalue=0.04037698730826378)
# LBGD
# ShapiroResult(statistic=0.8619498014450073, pvalue=0.02052389457821846)
# FDI
# ShapiroResult(statistic=0.9163545370101929, pvalue=0.14734424650669098)
# PC
# ShapiroResult(statistic=0.8885976672172546, pvalue=0.05293218046426773)
# ARP
# ShapiroResult(statistic=0.9390843510627747, pvalue=0.3379489481449127)
# CO2C
# ShapiroResult(statistic=0.9627439975738525, pvalue=0.7117523550987244)
# PAM
# ShapiroResult(statistic=0.8978967666625977, pvalue=0.07437822222709656)
# ROL
# ShapiroResult(statistic=0.8833662867546082, pvalue=0.04379856958985329)
# GE
# ShapiroResult(statistic=0.9573984146118164, pvalue=0.6149342656135559)
# COC
# ShapiroResult(statistic=0.8937666416168213, pvalue=0.06391707062721252)
# RQ
# ShapiroResult(statistic=0.9084144830703735, pvalue=0.10972092300653458)
# SSB
# ShapiroResult(statistic=0.8723667860031128, pvalue=0.0295657217502594)
# PT
# ShapiroResult(statistic=0.8962137699127197, pvalue=0.06991695612668991)
# EUPC
# ShapiroResult(statistic=0.8239479064941406, pvalue=0.005768129136413336)

# %%
df_ee = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/ee_bn.csv")

# %%
shapiro_test(df_ee)
# Out:
# GDPC
# ShapiroResult(statistic=0.9619383215904236, pvalue=0.6970786452293396)
# VABI
# ShapiroResult(statistic=0.9401664733886719, pvalue=0.35105761885643005)
# EMP
# ShapiroResult(statistic=0.9553104043006897, pvalue=0.5781500935554504)
# QOA
# ShapiroResult(statistic=0.9047059416770935, pvalue=0.095630943775177)
# QOR
# ShapiroResult(statistic=0.8284640908241272, pvalue=0.0066729323007166386)
# YUA
# ShapiroResult(statistic=0.8892203569412231, pvalue=0.05414455756545067)
# REST
# ShapiroResult(statistic=0.9572560787200928, pvalue=0.6123988032341003)
# EBSG
# ShapiroResult(statistic=0.8891724944114685, pvalue=0.054050397127866745)
# GGFC
# ShapiroResult(statistic=0.9039019346237183, pvalue=0.09282742440700531)
# LBGD
# ShapiroResult(statistic=0.9048200845718384, pvalue=0.0960359051823616)
# FDI
# ShapiroResult(statistic=0.9547197818756104, pvalue=0.5679217576980591)
# PC
# ShapiroResult(statistic=0.608408510684967, pvalue=1.945305302797351e-05)
# ARP
# ShapiroResult(statistic=0.9257975816726685, pvalue=0.2089814394712448)
# CO2C
# ShapiroResult(statistic=0.8412123918533325, pvalue=0.01014292985200882)
# PAM
# ShapiroResult(statistic=0.8711166977882385, pvalue=0.028287917375564575)
# ROL
# ShapiroResult(statistic=0.9009941816329956, pvalue=0.08337065577507019)
# GE
# ShapiroResult(statistic=0.878516435623169, pvalue=0.036796800792217255)
# COC
# ShapiroResult(statistic=0.90211021900177, pvalue=0.08687803149223328)
# RQ
# ShapiroResult(statistic=0.9183798432350159, pvalue=0.15884727239608765)
# SSB
# ShapiroResult(statistic=0.8047379851341248, pvalue=0.0031502493657171726)
# PT
# ShapiroResult(statistic=0.8803454637527466, pvalue=0.03928874060511589)
# EUPC
# ShapiroResult(statistic=0.9190288782119751, pvalue=0.16271774470806122)

# %%
df_ee = fix_outliers_with_mean(df_ee, "PAM")
df_ee = fix_outliers_with_mean(df_ee, 'GE')
df_ee = fix_outliers_with_mean(df_ee, "SSB")
df_ee = fix_outliers_with_mean(df_ee, "PT")

# %%
df_ee_lg = transform_log(df_ee, "PAM")
df_ee_lg = transform_log(df_ee, "GE")
df_ee_lg = transform_log(df_ee, "SSB")
df_ee_lg = transform_log(df_ee, "PT")

# %%
df_ee_sq = transform_sqrt(df_ee, "PAM")
df_ee_sq = transform_sqrt(df_ee, "GE")
df_ee_sq = transform_sqrt(df_ee, "SSB")
df_ee_sq = transform_sqrt(df_ee, "PT")

# %%
df_ee_cb = transform_cbrt(df_ee, "PAM")
df_ee_cb = transform_cbrt(df_ee, "GE")
df_ee_cb = transform_cbrt(df_ee, "SSB")
df_ee_cb = transform_cbrt(df_ee, "PT")

# %%
shapiro_test(df_ee_cb)
# Out:
# GDPC
# ShapiroResult(statistic=0.9619383215904236, pvalue=0.6970786452293396)
# VABI
# ShapiroResult(statistic=0.9401664733886719, pvalue=0.35105761885643005)
# EMP
# ShapiroResult(statistic=0.9553104043006897, pvalue=0.5781500935554504)
# QOA
# ShapiroResult(statistic=0.9047059416770935, pvalue=0.095630943775177)
# QOR
# ShapiroResult(statistic=0.8284640908241272, pvalue=0.0066729323007166386)
# YUA
# ShapiroResult(statistic=0.8892203569412231, pvalue=0.05414455756545067)
# REST
# ShapiroResult(statistic=0.9572560787200928, pvalue=0.6123988032341003)
# EBSG
# ShapiroResult(statistic=0.8891724944114685, pvalue=0.054050397127866745)
# GGFC
# ShapiroResult(statistic=0.9039019346237183, pvalue=0.09282742440700531)
# LBGD
# ShapiroResult(statistic=0.9048200845718384, pvalue=0.0960359051823616)
# FDI
# ShapiroResult(statistic=0.9547197818756104, pvalue=0.5679217576980591)
# PC
# ShapiroResult(statistic=0.608408510684967, pvalue=1.945305302797351e-05)
# ARP
# ShapiroResult(statistic=0.9257975816726685, pvalue=0.2089814394712448)
# CO2C
# ShapiroResult(statistic=0.8412123918533325, pvalue=0.01014292985200882)
# PAM
# ShapiroResult(statistic=0.8711166977882385, pvalue=0.028287917375564575)
# ROL
# ShapiroResult(statistic=0.9009941816329956, pvalue=0.08337065577507019)
# GE
# ShapiroResult(statistic=0.878516435623169, pvalue=0.036796800792217255)
# COC
# ShapiroResult(statistic=0.90211021900177, pvalue=0.08687803149223328)
# RQ
# ShapiroResult(statistic=0.9183798432350159, pvalue=0.15884727239608765)
# SSB
# ShapiroResult(statistic=0.8047379851341248, pvalue=0.0031502493657171726)
# PT
# ShapiroResult(statistic=0.8785440921783447, pvalue=0.036833178251981735)
# EUPC
# ShapiroResult(statistic=0.9190288782119751, pvalue=0.16271774470806122)

# %%
df_fi = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/fi_bn.csv")

# %%
shapiro_test(df_fi)
# Out:
# GDPC
# ShapiroResult(statistic=0.9064499139785767, pvalue=0.10201219469308853)
# VABI
# ShapiroResult(statistic=0.7650399804115295, pvalue=0.0009698467329144478)
# EMP
# ShapiroResult(statistic=0.8797801733016968, pvalue=0.03850017860531807)
# QOA
# ShapiroResult(statistic=0.9611701965332031, pvalue=0.6830812692642212)
# QOR
# ShapiroResult(statistic=0.8616771697998047, pvalue=0.020330755040049553)
# YUA
# ShapiroResult(statistic=0.9296169281005859, pvalue=0.2404049187898636)
# REST
# ShapiroResult(statistic=0.950162947177887, pvalue=0.49227234721183777)
# EBSG
# ShapiroResult(statistic=0.8842254877090454, pvalue=0.04517769068479538)
# GGFC
# ShapiroResult(statistic=0.8519001007080078, pvalue=0.014532015658915043)
# LBGD
# ShapiroResult(statistic=0.8617319464683533, pvalue=0.0203693900257349)
# FDI
# ShapiroResult(statistic=0.8859407305717468, pvalue=0.04806831479072571)
# PC
# ShapiroResult(statistic=0.8865100145339966, pvalue=0.049069710075855255)
# ARP
# ShapiroResult(statistic=0.9615541696548462, pvalue=0.6900772452354431)
# CO2C
# ShapiroResult(statistic=0.9595724940299988, pvalue=0.6540371775627136)
# PAM
# ShapiroResult(statistic=0.9328587055206299, pvalue=0.27048608660697937)
# ROL
# ShapiroResult(statistic=0.9447280764579773, pvalue=0.4110064208507538)
# GE
# ShapiroResult(statistic=0.9278029203414917, pvalue=0.22496098279953003)
# COC
# ShapiroResult(statistic=0.9071869254112244, pvalue=0.10483769327402115)
# RQ
# ShapiroResult(statistic=0.9498138427734375, pvalue=0.48674312233924866)
# SSB
# ShapiroResult(statistic=0.5871254205703735, pvalue=1.2269343642401509e-05)
# PT
# ShapiroResult(statistic=0.7870356440544128, pvalue=0.0018416285747662187)
# EUPC
# ShapiroResult(statistic=0.9674376249313354, pvalue=0.7955886125564575)

# %%
df_fi = fix_outliers_with_mean(df_fi, 'RQ')
df_fi = fix_outliers_with_mean(df_fi, "PT")

# %%
df_fi_lg = transform_log(df_fi, "PT")

# %%
df_fi_sq = transform_sqrt(df_fi, "PT")

# %%
df_fi_cb = transform_cbrt(df_fi, "PT")

# %%
shapiro_test(df_fi_cb)
# Out:
# GDPC
# ShapiroResult(statistic=0.9064499139785767, pvalue=0.10201219469308853)
# VABI
# ShapiroResult(statistic=0.7650399804115295, pvalue=0.0009698467329144478)
# EMP
# ShapiroResult(statistic=0.8797801733016968, pvalue=0.03850017860531807)
# QOA
# ShapiroResult(statistic=0.9611701965332031, pvalue=0.6830812692642212)
# QOR
# ShapiroResult(statistic=0.8616771697998047, pvalue=0.020330755040049553)
# YUA
# ShapiroResult(statistic=0.9296169281005859, pvalue=0.2404049187898636)
# REST
# ShapiroResult(statistic=0.950162947177887, pvalue=0.49227234721183777)
# EBSG
# ShapiroResult(statistic=0.8842254877090454, pvalue=0.04517769068479538)
# GGFC
# ShapiroResult(statistic=0.8519001007080078, pvalue=0.014532015658915043)
# LBGD
# ShapiroResult(statistic=0.8617319464683533, pvalue=0.0203693900257349)
# FDI
# ShapiroResult(statistic=0.8859407305717468, pvalue=0.04806831479072571)
# PC
# ShapiroResult(statistic=0.8865100145339966, pvalue=0.049069710075855255)
# ARP
# ShapiroResult(statistic=0.9615541696548462, pvalue=0.6900772452354431)
# CO2C
# ShapiroResult(statistic=0.9595724940299988, pvalue=0.6540371775627136)
# PAM
# ShapiroResult(statistic=0.9328587055206299, pvalue=0.27048608660697937)
# ROL
# ShapiroResult(statistic=0.9447280764579773, pvalue=0.4110064208507538)
# GE
# ShapiroResult(statistic=0.9278029203414917, pvalue=0.22496098279953003)
# COC
# ShapiroResult(statistic=0.9071869254112244, pvalue=0.10483769327402115)
# RQ
# ShapiroResult(statistic=0.9498138427734375, pvalue=0.48674312233924866)
# SSB
# ShapiroResult(statistic=0.5871254205703735, pvalue=1.2269343642401509e-05)
# PT
# ShapiroResult(statistic=0.7771105766296387, pvalue=0.001374198473058641)
# EUPC
# ShapiroResult(statistic=0.9674376249313354, pvalue=0.7955886125564575)

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(df_fi.values)

df_fi_scaled = pd.DataFrame(scaled_features, index=df_fi.index, columns=df_fi.columns)

# %%
df_fi_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/fi_normal.csv')

# %%
df_se = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/se_bn.csv")

# %%
shapiro_test(df_se)
# Out:
# GDPC
# ShapiroResult(statistic=0.9560461640357971, pvalue=0.5910073518753052)
# VABI
# ShapiroResult(statistic=0.8952399492263794, pvalue=0.06746241450309753)
# EMP
# ShapiroResult(statistic=0.9568906426429749, pvalue=0.6059073805809021)
# QOA
# ShapiroResult(statistic=0.9565019011497498, pvalue=0.599030077457428)
# QOR
# ShapiroResult(statistic=0.8565880060195923, pvalue=0.0170566625893116)
# YUA
# ShapiroResult(statistic=0.9282621145248413, pvalue=0.22878001630306244)
# REST
# ShapiroResult(statistic=0.9486936926841736, pvalue=0.46927958726882935)
# EBSG
# ShapiroResult(statistic=0.9494915008544922, pvalue=0.48167386651039124)
# GGFC
# ShapiroResult(statistic=0.9002007842063904, pvalue=0.08096596598625183)
# LBGD
# ShapiroResult(statistic=0.9766830205917358, pvalue=0.9317976236343384)
# FDI
# ShapiroResult(statistic=0.867590606212616, pvalue=0.024987131357192993)
# PC
# ShapiroResult(statistic=0.9601584076881409, pvalue=0.6646685004234314)
# ARP
# ShapiroResult(statistic=0.7735835313796997, pvalue=0.0012401043204590678)
# CO2C
# ShapiroResult(statistic=0.9262407422065735, pvalue=0.21241669356822968)
# PAM
# ShapiroResult(statistic=0.928078830242157, pvalue=0.2272481918334961)
# ROL
# ShapiroResult(statistic=0.881070077419281, pvalue=0.04032430425286293)
# GE
# ShapiroResult(statistic=0.8580288887023926, pvalue=0.01792285218834877)
# COC
# ShapiroResult(statistic=0.8964669704437256, pvalue=0.07057011127471924)
# RQ
# ShapiroResult(statistic=0.9361326098442078, pvalue=0.3043074309825897)
# SSB
# ShapiroResult(statistic=0.8853723406791687, pvalue=0.04708963260054588)
# PT
# ShapiroResult(statistic=0.833318829536438, pvalue=0.007816337049007416)
# EUPC
# ShapiroResult(statistic=0.953586995601654, pvalue=0.5485535264015198)

# %%
df_se = fix_outliers_with_mean(df_se, "FDI")
df_se = fix_outliers_with_mean(df_se, "QOR")
df_se = fix_outliers_with_mean(df_se, "ROL")
df_se = fix_outliers_with_mean(df_se, "GE")
df_se = fix_outliers_with_mean(df_se, "SSB")
df_se = fix_outliers_with_mean(df_se, "PT")

# %%
df_se_lg = transform_log(df_se, "FDI")
df_se_lg = transform_log(df_se, "ROL")
df_se_lg = transform_log(df_se, "GE")
df_se_lg = transform_log(df_se, "SSB")
df_se_lg = transform_log(df_se, "PT")
# Out:
# /Users/vladasverkelis/anaconda3/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_se_sq = transform_sqrt(df_se, "ROL")
df_se_sq = transform_sqrt(df_se, "GE")
df_se_sq = transform_sqrt(df_se, "SSB")
df_se_sq = transform_sqrt(df_se, "PT")

# %%
df_se['FDI']
# Out:
# 0     9.42
# 1     8.05
# 2     2.06
# 3     0.13
# 4     1.22
# 5     0.78
# 6     0.25
# 7    -1.05
# 8     1.95
# 9     3.01
# 10    4.53
# 11   -0.13
# 12    2.98
# 13    3.40
# 14    9.10
# 15    9.30
# Name: FDI, dtype: float64

# %%
df_se_cb = transform_cbrt(df_se, "ROL")
df_se_cb = transform_cbrt(df_se, "GE")
df_se_cb = transform_cbrt(df_se, "SSB")
df_se_cb = transform_cbrt(df_se, "PT")

# %%
shapiro_test(df_se_sq)
# Out:
# GDPC
# ShapiroResult(statistic=0.9560461640357971, pvalue=0.5910073518753052)
# VABI
# ShapiroResult(statistic=0.8952399492263794, pvalue=0.06746241450309753)
# EMP
# ShapiroResult(statistic=0.9568906426429749, pvalue=0.6059073805809021)
# QOA
# ShapiroResult(statistic=0.9565019011497498, pvalue=0.599030077457428)
# QOR
# ShapiroResult(statistic=0.8565880060195923, pvalue=0.0170566625893116)
# YUA
# ShapiroResult(statistic=0.9282621145248413, pvalue=0.22878001630306244)
# REST
# ShapiroResult(statistic=0.9486936926841736, pvalue=0.46927958726882935)
# EBSG
# ShapiroResult(statistic=0.9494915008544922, pvalue=0.48167386651039124)
# GGFC
# ShapiroResult(statistic=0.9002007842063904, pvalue=0.08096596598625183)
# LBGD
# ShapiroResult(statistic=0.9766830205917358, pvalue=0.9317976236343384)
# FDI
# ShapiroResult(statistic=0.867590606212616, pvalue=0.024987131357192993)
# PC
# ShapiroResult(statistic=0.9601584076881409, pvalue=0.6646685004234314)
# ARP
# ShapiroResult(statistic=0.7735835313796997, pvalue=0.0012401043204590678)
# CO2C
# ShapiroResult(statistic=0.9262407422065735, pvalue=0.21241669356822968)
# PAM
# ShapiroResult(statistic=0.928078830242157, pvalue=0.2272481918334961)
# ROL
# ShapiroResult(statistic=0.881070077419281, pvalue=0.04032430425286293)
# GE
# ShapiroResult(statistic=0.8580288887023926, pvalue=0.01792285218834877)
# COC
# ShapiroResult(statistic=0.8964669704437256, pvalue=0.07057011127471924)
# RQ
# ShapiroResult(statistic=0.9361326098442078, pvalue=0.3043074309825897)
# SSB
# ShapiroResult(statistic=0.8853723406791687, pvalue=0.04708963260054588)
# PT
# ShapiroResult(statistic=0.8344102501869202, pvalue=0.008101033046841621)
# EUPC
# ShapiroResult(statistic=0.953586995601654, pvalue=0.5485535264015198)
