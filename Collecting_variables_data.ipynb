# %%
import pandas as pd
pd.options.mode.copy_on_write = True

# %%
def clean_world_bank_data(df):
    df_1 = df.loc[df['Country Name'].isin(["Denmark", "Germany", "Poland", "Lithuania", "Latvia", "Estonia", "Finland", "Sweden"])]
    df_2 = df_1.drop(["Country Code", "Indicator Code", "Indicator Name"], axis=1)
    df_3 = df_2.transpose()
    df_4 = df_3.rename({55:"Germany", 58:"Denmark", 71:"Estonia",
                                              75:"Finland", 143:"Lithuania", 145:"Latvia", 190:"Poland",
                                              223:"Sweden"}, axis=1)
    df_5 = df_4.tail(df_4.shape[0] - 1)
    df_6 = df_5.reset_index()
    df_7 = df_6.rename({"index":"TIME_PERIOD"}, axis=1)
    df_7 = df_7[df_7['TIME_PERIOD'].astype(str).str.isnumeric()]
    df_7['TIME_PERIOD'] = pd.to_numeric(df_7['TIME_PERIOD'])
    df_8 = df_7[df_7['TIME_PERIOD'].astype(str).str.isnumeric()]
    df_9 = df_8.set_index("TIME_PERIOD")
    return df_9

# %%
def return_spefifc_country(df, name):
    df_1 = df.loc[df['REF_AREA_LABEL'].isin([name])]
    return df_1

# %%
global_economy = pd.read_csv("Raw_data/Variables/theglobaleconomy.csv")

# %%
global_economy = global_economy.rename({"Labor force million people":"LF",
                                       "Unemployment rate":"UR",
                                       "Unemployment rate for females":"URFF",
                                       "Youth unemployment ages 15-24s":"YUA",
                                        "Foreign Direct Investment percent of GDP":"FDI",
                                        "Quality of roads 1(low) - 7(high)":"QOR",
                                        "Quality of air transport infrastructure 1(low) - 7(high)":"QOA",
                                        "Electricity production from renewable sources million kWh":"EPFR",
                                        "Greenhouse gas emissions":"GGA",
                                        "Oil consumption thousand barrels per day":"OCTB",
                                        "Employment in agriculture % of total employment":"EIAP",
                                        "Population size in millions":"PS",
                                        "Population density people per square km":"PDPS",
                                        "Population ages 65 and above percent of total":"P65",
                                        "Population ages 0-14 percent of total":"P014",
                                        "Population growth percent":"PGP",
                                       "Value added by industry as percent of GDP":"VABI",
                                       "Youth unemployment ages 15-24":"YUA",
                                       "Country":"REF_AREA_LABEL",
                                       "Year":"TIME_PERIOD"}, axis=1)

# %%
global_economy = global_economy.drop(["Code", "ContinentCode",
                                      "Primary school enrollment percent of all eligible children",
                                     "Secondary school enrollment percent of all eligible children",
                                     "Tertiary school enrollment percent of all eligible children"], axis=1)

# %%
df_dk = return_spefifc_country(global_economy, "Denmark")
df_de = return_spefifc_country(global_economy, "Germany")
df_pl = return_spefifc_country(global_economy, "Poland")
df_lt = return_spefifc_country(global_economy, "Lithuania")
df_lv = return_spefifc_country(global_economy, "Latvia")
df_es = return_spefifc_country(global_economy, "Estonia")
df_fi = return_spefifc_country(global_economy, "Finland")
df_sv = return_spefifc_country(global_economy, "Sweden")

# %%
global_economy_1 = pd.read_csv("Raw_data/Variables/globaleconomy.csv")

# %%
global_economy_1 = global_economy_1.rename({"Happiness Index 0 (unhappy) - 10 (happy)":"HI",
                                           "Country":"REF_AREA_LABEL",
                                            "Year":"TIME_PERIOD"}, axis=1)

# %%
global_economy_1 = global_economy_1.drop(["Code", "ContinentCode", "Oil consumption thousand barrels per day", 
                                          "Industry value added billion USD"], axis=1)

# %%
dk_ge = return_spefifc_country(global_economy_1, "Denmark")
de_ge = return_spefifc_country(global_economy_1, "Germany")
pl_ge = return_spefifc_country(global_economy_1, "Poland")
lt_ge = return_spefifc_country(global_economy_1, "Lithuania")
lv_ge = return_spefifc_country(global_economy_1, "Latvia")
es_ge = return_spefifc_country(global_economy_1, "Estonia")
fi_ge = return_spefifc_country(global_economy_1, "Finland")
sv_ge = return_spefifc_country(global_economy_1, "Sweden")

# %%
df_dk = pd.merge(dk_ge, df_dk, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')
df_de = pd.merge(de_ge, df_de, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')
df_pl = pd.merge(pl_ge, df_pl, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')
df_lt = pd.merge(lt_ge, df_lt, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')
df_lv = pd.merge(lv_ge, df_lv, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')
df_es = pd.merge(es_ge, df_es, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')
df_fi = pd.merge(fi_ge, df_fi, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')
df_sv = pd.merge(sv_ge, df_sv, on=['REF_AREA_LABEL', 'TIME_PERIOD'], how='outer')

# %%
gross_capital = pd.read_csv("Raw_data/Variables/gross_capital_formation.csv", skiprows=4)

# %%
dk_GC = clean_world_bank_data(gross_capital)
de_GC = clean_world_bank_data(gross_capital)
pl_GC = clean_world_bank_data(gross_capital)
lt_GC = clean_world_bank_data(gross_capital)
lv_GC = clean_world_bank_data(gross_capital)
es_GC = clean_world_bank_data(gross_capital)
fi_GC = clean_world_bank_data(gross_capital)
sv_GC = clean_world_bank_data(gross_capital)

# %%
df_dk = pd.merge(df_dk, dk_GC["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_GC["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_GC["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_GC["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_GC["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_GC["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_GC["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_GC["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"GCFP"}, axis=1)
df_de = df_de.rename({"Germany":"GCFP"}, axis=1)
df_pl = df_pl.rename({"Poland":"GCFP"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"GCFP"}, axis=1)
df_lv = df_lv.rename({"Latvia":"GCFP"}, axis=1)
df_es = df_es.rename({"Estonia":"GCFP"}, axis=1)
df_fi = df_fi.rename({"Finland":"GCFP"}, axis=1)
df_sv = df_sv.rename({"Sweden":"GCFP"}, axis=1)

# %%
government_consumption = pd.read_csv("Raw_data/Variables/government_consumption.csv", skiprows=4)

# %%
dk_GG = clean_world_bank_data(government_consumption)
de_GG = clean_world_bank_data(government_consumption)
pl_GG = clean_world_bank_data(government_consumption)
lt_GG = clean_world_bank_data(government_consumption)
lv_GG = clean_world_bank_data(government_consumption)
es_GG = clean_world_bank_data(government_consumption)
fi_GG = clean_world_bank_data(government_consumption)
sv_GG = clean_world_bank_data(government_consumption)

# %%
df_dk = pd.merge(df_dk, dk_GG["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_GG["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_GG["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_GG["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_GG["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_GG["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_GG["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_GG["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"GGFC"}, axis=1)
df_de = df_de.rename({"Germany":"GGFC"}, axis=1)
df_pl = df_pl.rename({"Poland":"GGFC"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"GGFC"}, axis=1)
df_lv = df_lv.rename({"Latvia":"GGFC"}, axis=1)
df_es = df_es.rename({"Estonia":"GGFC"}, axis=1)
df_fi = df_fi.rename({"Finland":"GGFC"}, axis=1)
df_sv = df_sv.rename({"Sweden":"GGFC"}, axis=1)

# %%
gdp_per_capita_g = pd.read_csv("Raw_data/Variables/GDP_per_capita_growth.csv", skiprows=4)

# %%
dk_GDPCG = clean_world_bank_data(gdp_per_capita_g)
de_GDPCG = clean_world_bank_data(gdp_per_capita_g)
pl_GDPCG = clean_world_bank_data(gdp_per_capita_g)
lt_GDPCG = clean_world_bank_data(gdp_per_capita_g)
lv_GDPCG = clean_world_bank_data(gdp_per_capita_g)
es_GDPCG = clean_world_bank_data(gdp_per_capita_g)
fi_GDPCG = clean_world_bank_data(gdp_per_capita_g)
sv_GDPCG = clean_world_bank_data(gdp_per_capita_g)

# %%
df_dk = pd.merge(df_dk, dk_GDPCG["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_GDPCG["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_GDPCG["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_GDPCG["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_GDPCG["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_GDPCG["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_GDPCG["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_GDPCG["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"GDPCG"}, axis=1)
df_de = df_de.rename({"Germany":"GDPCG"}, axis=1)
df_pl = df_pl.rename({"Poland":"GDPCG"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"GDPCG"}, axis=1)
df_lv = df_lv.rename({"Latvia":"GDPCG"}, axis=1)
df_es = df_es.rename({"Estonia":"GDPCG"}, axis=1)
df_fi = df_fi.rename({"Finland":"GDPCG"}, axis=1)
df_sv = df_sv.rename({"Sweden":"GDPCG"}, axis=1)

# %%
employment_industry = pd.read_csv("Raw_data/Variables/employment_industry.csv", skiprows=4)

# %%
dk_EII = clean_world_bank_data(employment_industry)
de_EII = clean_world_bank_data(employment_industry)
pl_EII = clean_world_bank_data(employment_industry)
lt_EII = clean_world_bank_data(employment_industry)
lv_EII = clean_world_bank_data(employment_industry)
es_EII = clean_world_bank_data(employment_industry)
fi_EII = clean_world_bank_data(employment_industry)
sv_EII = clean_world_bank_data(employment_industry)

# %%
df_dk = pd.merge(df_dk, dk_EII["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_EII["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_EII["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_EII["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_EII["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_EII["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_EII["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_EII["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"EII"}, axis=1)
df_de = df_de.rename({"Germany":"EII"}, axis=1)
df_pl = df_pl.rename({"Poland":"EII"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"EII"}, axis=1)
df_lv = df_lv.rename({"Latvia":"EII"}, axis=1)
df_es = df_es.rename({"Estonia":"EII"}, axis=1)
df_fi = df_fi.rename({"Finland":"EII"}, axis=1)
df_sv = df_sv.rename({"Sweden":"EII"}, axis=1)

# %%
employment_agriculture = pd.read_csv("Raw_data/Variables/employment_agriculture.csv", skiprows=4)

# %%
dk_EIA = clean_world_bank_data(employment_agriculture)
de_EIA = clean_world_bank_data(employment_agriculture)
pl_EIA = clean_world_bank_data(employment_agriculture)
lt_EIA = clean_world_bank_data(employment_agriculture)
lv_EIA = clean_world_bank_data(employment_agriculture)
es_EIA = clean_world_bank_data(employment_agriculture)
fi_EIA = clean_world_bank_data(employment_agriculture)
sv_EIA = clean_world_bank_data(employment_agriculture)

# %%
df_dk = pd.merge(df_dk, dk_EIA["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_EIA["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_EIA["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_EIA["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_EIA["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_EIA["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_EIA["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_EIA["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"EIA"}, axis=1)
df_de = df_de.rename({"Germany":"EIA"}, axis=1)
df_pl = df_pl.rename({"Poland":"EIA"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"EIA"}, axis=1)
df_lv = df_lv.rename({"Latvia":"EIA"}, axis=1)
df_es = df_es.rename({"Estonia":"EIA"}, axis=1)
df_fi = df_fi.rename({"Finland":"EIA"}, axis=1)
df_sv = df_sv.rename({"Sweden":"EIA"}, axis=1)

# %%
external_balance = pd.read_csv("Raw_data/Variables/External_balance.csv", skiprows=4)

# %%
dk_EBSG = clean_world_bank_data(external_balance)
de_EBSG = clean_world_bank_data(external_balance)
pl_EBSG = clean_world_bank_data(external_balance)
lt_EBSG = clean_world_bank_data(external_balance)
lv_EBSG = clean_world_bank_data(external_balance)
es_EBSG = clean_world_bank_data(external_balance)
fi_EBSG = clean_world_bank_data(external_balance)
sv_EBSG = clean_world_bank_data(external_balance)

# %%
df_dk = pd.merge(df_dk, dk_EBSG["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_EBSG["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_EBSG["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_EBSG["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_EBSG["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_EBSG["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_EBSG["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_EBSG["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"EBSG"}, axis=1)
df_de = df_de.rename({"Germany":"EBSG"}, axis=1)
df_pl = df_pl.rename({"Poland":"EBSG"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"EBSG"}, axis=1)
df_lv = df_lv.rename({"Latvia":"EBSG"}, axis=1)
df_es = df_es.rename({"Estonia":"EBSG"}, axis=1)
df_fi = df_fi.rename({"Finland":"EBSG"}, axis=1)
df_sv = df_sv.rename({"Sweden":"EBSG"}, axis=1)

# %%
gdp_per_capita = pd.read_csv("Raw_data/Variables/GDP_per_Capita.csv", skiprows=4)

# %%
dk_GDPC = clean_world_bank_data(gdp_per_capita)
de_GDPC = clean_world_bank_data(gdp_per_capita)
pl_GDPC = clean_world_bank_data(gdp_per_capita)
lt_GDPC = clean_world_bank_data(gdp_per_capita)
lv_GDPC = clean_world_bank_data(gdp_per_capita)
es_GDPC = clean_world_bank_data(gdp_per_capita)
fi_GDPC = clean_world_bank_data(gdp_per_capita)
sv_GDPC = clean_world_bank_data(gdp_per_capita)

# %%
df_dk = pd.merge(df_dk, dk_GDPC["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_GDPC["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_GDPC["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_GDPC["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_GDPC["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_GDPC["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_GDPC["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_GDPC["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"GDPC"}, axis=1)
df_de = df_de.rename({"Germany":"GDPC"}, axis=1)
df_pl = df_pl.rename({"Poland":"GDPC"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"GDPC"}, axis=1)
df_lv = df_lv.rename({"Latvia":"GDPC"}, axis=1)
df_es = df_es.rename({"Estonia":"GDPC"}, axis=1)
df_fi = df_fi.rename({"Finland":"GDPC"}, axis=1)
df_sv = df_sv.rename({"Sweden":"GDPC"}, axis=1)

# %%
gdp = pd.read_csv("Raw_data/Variables/GDP.csv", skiprows=4)

# %%
dk_GDP = clean_world_bank_data(gdp)
de_GDP = clean_world_bank_data(gdp)
pl_GDP = clean_world_bank_data(gdp)
lt_GDP = clean_world_bank_data(gdp)
lv_GDP = clean_world_bank_data(gdp)
es_GDP = clean_world_bank_data(gdp)
fi_GDP = clean_world_bank_data(gdp)
sv_GDP = clean_world_bank_data(gdp)

# %%
df_dk = pd.merge(df_dk, dk_GDP["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_GDP["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_GDP["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_GDP["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_GDP["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_GDP["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_GDP["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_GDP["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"GDP"}, axis=1)
df_de = df_de.rename({"Germany":"GDP"}, axis=1)
df_pl = df_pl.rename({"Poland":"GDP"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"GDP"}, axis=1)
df_lv = df_lv.rename({"Latvia":"GDP"}, axis=1)
df_es = df_es.rename({"Estonia":"GDP"}, axis=1)
df_fi = df_fi.rename({"Finland":"GDP"}, axis=1)
df_sv = df_sv.rename({"Sweden":"GDP"}, axis=1)

# %%
employment_services = pd.read_csv("Raw_data/Variables/employment_services.csv", skiprows=4)

# %%
dk_EIS = clean_world_bank_data(employment_services)
de_EIS = clean_world_bank_data(employment_services)
pl_EIS = clean_world_bank_data(employment_services)
lt_EIS = clean_world_bank_data(employment_services)
lv_EIS = clean_world_bank_data(employment_services)
es_EIS = clean_world_bank_data(employment_services)
fi_EIS = clean_world_bank_data(employment_services)
sv_EIS = clean_world_bank_data(employment_services)

# %%
df_dk = pd.merge(df_dk, dk_EIS["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_EIS["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_EIS["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_EIS["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_EIS["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_EIS["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_EIS["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_EIS["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"EIS"}, axis=1)
df_de = df_de.rename({"Germany":"EIS"}, axis=1)
df_pl = df_pl.rename({"Poland":"EIS"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"EIS"}, axis=1)
df_lv = df_lv.rename({"Latvia":"EIS"}, axis=1)
df_es = df_es.rename({"Estonia":"EIS"}, axis=1)
df_fi = df_fi.rename({"Finland":"EIS"}, axis=1)
df_sv = df_sv.rename({"Sweden":"EIS"}, axis=1)

# %%
net_investment = pd.read_csv("Raw_data/Variables/Net_investments_to_nonefinancial_assets.csv", skiprows=4)

# %%
dk_NINA = clean_world_bank_data(net_investment)
de_NINA = clean_world_bank_data(net_investment)
pl_NINA = clean_world_bank_data(net_investment)
lt_NINA = clean_world_bank_data(net_investment)
lv_NINA = clean_world_bank_data(net_investment)
es_NINA = clean_world_bank_data(net_investment)
fi_NINA = clean_world_bank_data(net_investment)
sv_NINA = clean_world_bank_data(net_investment)

# %%
df_dk = pd.merge(df_dk, dk_NINA["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_NINA["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_NINA["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_NINA["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_NINA["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_NINA["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_NINA["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_NINA["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"NINA"}, axis=1)
df_de = df_de.rename({"Germany":"NINA"}, axis=1)
df_pl = df_pl.rename({"Poland":"NINA"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"NINA"}, axis=1)
df_lv = df_lv.rename({"Latvia":"NINA"}, axis=1)
df_es = df_es.rename({"Estonia":"NINA"}, axis=1)
df_fi = df_fi.rename({"Finland":"NINA"}, axis=1)
df_sv = df_sv.rename({"Sweden":"NINA"}, axis=1)

# %%
lending_borrowing = pd.read_csv("Raw_data/Variables/net_lending_borrowing.csv", skiprows=4)

# %%
dk_LBGD = clean_world_bank_data(lending_borrowing)
de_LBGD = clean_world_bank_data(lending_borrowing)
pl_LBGD = clean_world_bank_data(lending_borrowing)
lt_LBGD = clean_world_bank_data(lending_borrowing)
lv_LBGD = clean_world_bank_data(lending_borrowing)
es_LBGD = clean_world_bank_data(lending_borrowing)
fi_LBGD = clean_world_bank_data(lending_borrowing)
sv_LBGD = clean_world_bank_data(lending_borrowing)

# %%
df_dk = pd.merge(df_dk, dk_LBGD["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, de_LBGD["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, pl_LBGD["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, lt_LBGD["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, lv_LBGD["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, es_LBGD["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, fi_LBGD["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, sv_LBGD["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"LBGD"}, axis=1)
df_de = df_de.rename({"Germany":"LBGD"}, axis=1)
df_pl = df_pl.rename({"Poland":"LBGD"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"LBGD"}, axis=1)
df_lv = df_lv.rename({"Latvia":"LBGD"}, axis=1)
df_es = df_es.rename({"Estonia":"LBGD"}, axis=1)
df_fi = df_fi.rename({"Finland":"LBGD"}, axis=1)
df_sv = df_sv.rename({"Sweden":"LBGD"}, axis=1)

# %%
employment = pd.read_excel("Raw_data/Variables/Employment.xlsx", sheet_name='Sheet 1', skiprows=9, header=1)

# %%
def clean_eurostat_data(df):
    df_1 = df.drop(["Unnamed: 2", "Unnamed: 4", "Unnamed: 6", "Unnamed: 8", "Unnamed: 10", "Unnamed: 12",
                              "Unnamed: 14", "Unnamed: 16", "Unnamed: 18", "Unnamed: 20", "Unnamed: 22", "Unnamed: 24", "Unnamed: 26", 
                              "Unnamed: 28", "Unnamed: 30", "Unnamed: 32", "Unnamed: 34", "Unnamed: 36", "Unnamed: 38"], axis=1)
    df_2 = df_1.transpose()
    df_3 = df_2.drop([0, 9, 10, 11, 12, 13], axis=1)
    df_4 = df_3.rename({2:"Germany", 1:"Denmark", 3:"Estonia", 7:"Finland", 5:"Lithuania", 4:"Latvia", 6:"Poland", 8:"Sweden"}, axis=1)
    df_5 = df_4.tail(df_4.shape[0] - 1)
    df_6 = df_5.reset_index()
    df_7 = df_6.rename({'index':'TIME_PERIOD'}, axis=1)
    df_7 = df_7[df_7['TIME_PERIOD'].astype(str).str.isnumeric()]
    df_7['TIME_PERIOD'] = pd.to_numeric(df_7['TIME_PERIOD'])
    df_8 = df_7[df_7['TIME_PERIOD'].astype(str).str.isnumeric()]
    df_9 = df_8.set_index("TIME_PERIOD")
    return df_9

# %%
def clean_eurostat_data_1(df):
    df_1 = df.drop(["Unnamed: 2", "Unnamed: 4", "Unnamed: 6", "Unnamed: 8", "Unnamed: 10", "Unnamed: 12",
                              "Unnamed: 14", "Unnamed: 16", "Unnamed: 18", "Unnamed: 20", "Unnamed: 22", "Unnamed: 24", "Unnamed: 26", 
                              "Unnamed: 28", "Unnamed: 30", "Unnamed: 32", "Unnamed: 34"], axis=1)
    df_2 = df_1.transpose()
    df_3 = df_2.drop([0, 9, 10, 11, 12, 13], axis=1)
    df_4 = df_3.rename({2:"Germany", 1:"Denmark", 3:"Estonia", 7:"Finland", 5:"Lithuania", 4:"Latvia", 6:"Poland", 8:"Sweden"}, axis=1)
    df_5 = df_4.tail(df_4.shape[0] - 1)
    df_6 = df_5.reset_index()
    df_7 = df_6.rename({'index':'TIME_PERIOD'}, axis=1)
    df_7 = df_7[df_7['TIME_PERIOD'].astype(str).str.isnumeric()]
    df_7['TIME_PERIOD'] = pd.to_numeric(df_7['TIME_PERIOD'])
    df_8 = df_7[df_7['TIME_PERIOD'].astype(str).str.isnumeric()]
    df_9 = df_8.set_index("TIME_PERIOD")
    return df_9

# %%
EMP = clean_eurostat_data(employment)

# %%
df_dk = pd.merge(df_dk, EMP["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, EMP["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, EMP["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, EMP["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, EMP["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, EMP["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, EMP["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, EMP["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"EMP"}, axis=1)
df_de = df_de.rename({"Germany":"EMP"}, axis=1)
df_pl = df_pl.rename({"Poland":"EMP"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"EMP"}, axis=1)
df_lv = df_lv.rename({"Latvia":"EMP"}, axis=1)
df_es = df_es.rename({"Estonia":"EMP"}, axis=1)
df_fi = df_fi.rename({"Finland":"EMP"}, axis=1)
df_sv = df_sv.rename({"Sweden":"EMP"}, axis=1)

# %%
long_term_unemployment = pd.read_excel("Raw_data/Variables/Long_term_unemployment.xlsx", sheet_name='Sheet 1', skiprows=9, header=1)
# Out:
# /Users/vladasverkelis/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
LTU = clean_eurostat_data(long_term_unemployment)

# %%
df_dk = pd.merge(df_dk, LTU["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, LTU["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, LTU["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, LTU["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, LTU["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, LTU["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, LTU["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, LTU["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"LTU"}, axis=1)
df_de = df_de.rename({"Germany":"LTU"}, axis=1)
df_pl = df_pl.rename({"Poland":"LTU"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"LTU"}, axis=1)
df_lv = df_lv.rename({"Latvia":"LTU"}, axis=1)
df_es = df_es.rename({"Estonia":"LTU"}, axis=1)
df_fi = df_fi.rename({"Finland":"LTU"}, axis=1)
df_sv = df_sv.rename({"Sweden":"LTU"}, axis=1)

# %%
female_unemployment = pd.read_excel("Raw_data/Variables/Female_employment.xlsx", sheet_name='Sheet 1', skiprows=9, header=1)
# Out:
# /Users/vladasverkelis/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
FEM = clean_eurostat_data_1(female_unemployment)

# %%
df_dk = pd.merge(df_dk, FEM["Denmark"], on='TIME_PERIOD', how='outer')
df_de = pd.merge(df_de, FEM["Germany"], on='TIME_PERIOD', how='outer')
df_pl = pd.merge(df_pl, FEM["Poland"], on='TIME_PERIOD', how='outer')
df_lt = pd.merge(df_lt, FEM["Lithuania"], on='TIME_PERIOD', how='outer')
df_lv = pd.merge(df_lv, FEM["Latvia"], on='TIME_PERIOD', how='outer')
df_es = pd.merge(df_es, FEM["Estonia"], on='TIME_PERIOD', how='outer')
df_fi = pd.merge(df_fi, FEM["Finland"], on='TIME_PERIOD', how='outer')
df_sv = pd.merge(df_sv, FEM["Sweden"], on='TIME_PERIOD', how='outer')

# %%
df_dk = df_dk.rename({"Denmark":"FEM"}, axis=1)
df_de = df_de.rename({"Germany":"FEM"}, axis=1)
df_pl = df_pl.rename({"Poland":"FEM"}, axis=1)
df_lt = df_lt.rename({"Lithuania":"FEM"}, axis=1)
df_lv = df_lv.rename({"Latvia":"FEM"}, axis=1)
df_es = df_es.rename({"Estonia":"FEM"}, axis=1)
df_fi = df_fi.rename({"Finland":"FEM"}, axis=1)
df_sv = df_sv.rename({"Sweden":"FEM"}, axis=1)

# %%
df_dk.to_csv('Data/y/Denmark.csv')
df_de.to_csv('Data/y/Germany.csv')
df_pl.to_csv('Data/y/Poland.csv')
df_lt.to_csv('Data/y/Lithuania.csv')
df_lv.to_csv('Data/y/Latvia.csv')
df_es.to_csv('Data/y/Estonia.csv')
df_fi.to_csv('Data/y/Finland.csv')
df_sv.to_csv('Data/y/Sweden.csv')

# %%
# Out:
#    REF_AREA_LABEL  TIME_PERIOD  HI    LF    UR  URFF   YUA    FDI  QOR  QOA  \
# 0         Denmark         2000 NaN  2.86  4.48  4.97  6.73  21.95  NaN  NaN
# 1         Denmark         2001 NaN  2.85  4.16  4.78  8.23   5.63  NaN  NaN
# 2         Denmark         2002 NaN  2.88  4.27  4.32  7.04   2.48  NaN  NaN
# 3         Denmark         2003 NaN  2.88  5.40  5.75  9.80   0.54  NaN  NaN
# 4         Denmark         2004 NaN  2.90  5.20  5.44  7.78  -3.49  NaN  NaN
# ..            ...          ...  ..   ...   ...   ...   ...    ...  ...  ...
# 60            NaN         1995 NaN   NaN   NaN   NaN   NaN    NaN  NaN  NaN
# 61            NaN         1996 NaN   NaN   NaN   NaN   NaN    NaN  NaN  NaN
# 62            NaN         1997 NaN   NaN   NaN   NaN   NaN    NaN  NaN  NaN
# 63            NaN         1998 NaN   NaN   NaN   NaN   NaN    NaN  NaN  NaN
# 64            NaN         1999 NaN   NaN   NaN   NaN   NaN    NaN  NaN  NaN
#
# ...
