# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/fi_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/fi_no_context.csv'])
#
#  Dataset:  fi_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001583
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 3, 4]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.997992
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000003
# Potential causes:  [7, 14, 8, 13, 10, 3, 6, 15]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002474
# Epoch: 500 [50%] 	Loss: 0.000015
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [2, 4, 11, 13, 3]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.003947
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 13, 8, 3]
# Validated causes:  [4, 13]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.998803
# Epoch: 500 [50%] 	Loss: 0.000081
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 6, 13, 12, 4]
# Validated causes:  [14]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.002681
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [15, 14, 9, 2]
# Validated causes:  [15, 9]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.004091
# Epoch: 500 [50%] 	Loss: 0.000018
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 13]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001398
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000005
# Potential causes:  [1, 6, 8, 3]
# Validated causes:  [1, 6]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.003135
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000180
# Potential causes:  [13, 1]
# Validated causes:  [13]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000271
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000021
# Potential causes:  [3, 8, 13, 1, 5, 7]
# Validated causes:  [3]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.999786
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 15]
# Validated causes:  [10, 15]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.997321
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 3, 4, 12, 6]
# Validated causes:  [14]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.998147
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 15, 14]
# Validated causes:  [15]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.998196
# Epoch: 500 [50%] 	Loss: 0.000266
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 6]
# Validated causes:  [1, 6]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.998211
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 3, 1, 4, 14, 12]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.003413
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 10, 12, 15, 7, 13, 4]
# Validated causes:  [12]
# ===================Results for fi_no_context.csv ==================================
# QOR causes QOA with a delay of 2 time steps.
# CO2C causes QOA with a delay of 1 time steps.
# PAM causes QOR with a delay of 1 time steps.
# EUPC causes YUA with a delay of 3 time steps.
# LBGD causes YUA with a delay of 2 time steps.
# VABI causes EBSG with a delay of 0 time steps.
# REST causes EBSG with a delay of 0 time steps.
# CO2C causes GGFC with a delay of 0 time steps.
# QOA causes LBGD with a delay of 0 time steps.
# FDI causes FDI with a delay of 4 time steps.
# EUPC causes FDI with a delay of 0 time steps.
# PAM causes PC with a delay of 1 time steps.
# EUPC causes ARP with a delay of 0 time steps.
# VABI causes CO2C with a delay of 0 time steps.
# REST causes CO2C with a delay of 0 time steps.
# ARP causes EUPC with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/fi_no_context.csv=data/groundtruth_fi.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/fi_no_context.csv': 'data/groundtruth_fi.csv'}, data=None)
#
#  Dataset:  fi_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001583
# Epoch: 250 [50%] 	Loss: 0.000347
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [1, 3, 4]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.997992
# Epoch: 250 [50%] 	Loss: 0.000011
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [7, 14, 8, 13, 10, 3, 6, 15]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002474
# Epoch: 250 [50%] 	Loss: 0.000411
# Epoch: 500 [100%] 	Loss: 0.000015
# Potential causes:  [2, 4, 11, 13, 3]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.003947
# Epoch: 250 [50%] 	Loss: 0.000141
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 13, 8, 3]
# Validated causes:  [4, 13]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.998803
# Epoch: 250 [50%] 	Loss: 0.002097
# Epoch: 500 [100%] 	Loss: 0.000081
# Potential causes:  [14, 6, 12, 13, 4, 15, 11]
# Validated causes:  [14]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.002681
# Epoch: 250 [50%] 	Loss: 0.000058
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 14, 9, 2]
# Validated causes:  [15, 9]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.004091
# Epoch: 250 [50%] 	Loss: 0.000532
# Epoch: 500 [100%] 	Loss: 0.000018
# Potential causes:  [1, 13]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001398
# Epoch: 250 [50%] 	Loss: 0.000143
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 6, 8, 3]
# Validated causes:  [1, 6]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.003135
# Epoch: 250 [50%] 	Loss: 0.000089
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [13, 1]
# Validated causes:  [13]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000271
# Epoch: 250 [50%] 	Loss: 0.000036
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [3, 8, 13, 1, 5, 7]
# Validated causes:  [3]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.999786
# Epoch: 250 [50%] 	Loss: 0.000351
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [10, 15]
# Validated causes:  [10, 15]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.997321
# Epoch: 250 [50%] 	Loss: 0.000220
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 3, 4, 12, 6]
# Validated causes:  [14]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.998147
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 15, 14]
# Validated causes:  [15]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.998196
# Epoch: 250 [50%] 	Loss: 0.004541
# Epoch: 500 [100%] 	Loss: 0.000266
# Potential causes:  [1, 6]
# Validated causes:  [1]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.998211
# Epoch: 250 [50%] 	Loss: 0.000090
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [7, 3, 1, 4, 14, 12]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.003413
# Epoch: 250 [50%] 	Loss: 0.000025
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [8, 10, 12, 15, 7, 13, 4]
# Validated causes:  [12]
# ===================Results for fi_no_context.csv ==================================
# QOR causes QOA with a delay of 2 time steps.
# CO2C causes QOA with a delay of 1 time steps.
# PAM causes QOR with a delay of 1 time steps.
# EUPC causes YUA with a delay of 3 time steps.
# LBGD causes YUA with a delay of 2 time steps.
# VABI causes EBSG with a delay of 0 time steps.
# REST causes EBSG with a delay of 0 time steps.
# CO2C causes GGFC with a delay of 0 time steps.
# QOA causes LBGD with a delay of 0 time steps.
# FDI causes FDI with a delay of 4 time steps.
# EUPC causes FDI with a delay of 0 time steps.
# PAM causes PC with a delay of 1 time steps.
# EUPC causes ARP with a delay of 0 time steps.
# VABI causes CO2C with a delay of 0 time steps.
# ARP causes EUPC with a delay of 0 time steps.
#
# ===================Evaluation for fi_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  15
# Total False Negatives:  1
# Total Direct False Positives:  0
# Total Direct True Positives:  15
# TPs':  [(3, 4), (3, 13), (4, 14), (5, 15), (5, 9), (7, 1), (7, 6), (8, 13), (9, 3), (10, 10), (10, 15), (11, 14), (12, 15), (13, 1), (15, 12)]
# FPs':  []
# TPs direct:  [(3, 4), (3, 13), (4, 14), (5, 15), (5, 9), (7, 1), (7, 6), (8, 13), (9, 3), (10, 10), (10, 15), (11, 14), (12, 15), (13, 1), (15, 12)]
# FPs direct:  []
# FNs:  [(13, 6)]
# Precision':  1.0
# Recall':  0.9375
# F1' score:  0.967741935483871 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  0.9375
# F1 score:  0.967741935483871 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/fi_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/fi_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.060648
# Epoch: 500 [50%] 	Loss: 0.000018
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.287876
# Epoch: 500 [50%] 	Loss: 0.000090
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.538946
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.289956
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.781057
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.739116
# Epoch: 500 [50%] 	Loss: 0.000084
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.797637
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.188776
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.184535
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000039
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.961363
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.104893
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.941142
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.889997
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.800050
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.189296
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.282748
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/fi_no_context.csv : 1.5206118878659216 with standard deviation 1.365603821835266
