# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/ee_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/ee_no_context.csv'])
#
#  Dataset:  ee_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001905
# Epoch: 500 [50%] 	Loss: 0.000097
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [15, 1, 13, 12, 2, 4]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999725
# Epoch: 500 [50%] 	Loss: 0.000072
# Epoch: 1000 [100%] 	Loss: 0.000007
# Potential causes:  [13, 6, 4, 8, 15, 7, 3]
# Validated causes:  [13]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.004677
# Epoch: 500 [50%] 	Loss: 0.000025
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 12, 1]
# Validated causes:  [12]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.004151
# Epoch: 500 [50%] 	Loss: 0.000133
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 3, 1, 14]
# Validated causes:  [12]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.001062
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 8]
# Validated causes:  [7, 8]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.997702
# Epoch: 500 [50%] 	Loss: 0.000038
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [14, 4, 7, 8, 9, 13, 3, 15]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.000955
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 7, 15, 1, 8, 3, 4, 12]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.002543
# Epoch: 500 [50%] 	Loss: 0.000047
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 8, 4, 15]
# Validated causes:  [6, 4, 15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.003098
# Epoch: 500 [50%] 	Loss: 0.000244
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 9, 7, 13]
# Validated causes:  [4, 9]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000286
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 8, 13]
# Validated causes:  [3, 8, 13]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998657
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [13, 3]
# Validated causes:  [13]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.001348
# Epoch: 500 [50%] 	Loss: 0.000040
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 12, 10]
# Validated causes:  [13]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.006628
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 7, 2, 12, 15, 3, 13, 1]
# Validated causes:  [7]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.000765
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 1]
# Validated causes:  []
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.001376
# Epoch: 500 [50%] 	Loss: 0.000017
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 4, 3, 1, 6, 8, 5]
# Validated causes:  [7, 4]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002579
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 3, 8, 1, 7]
# Validated causes:  [14, 1]
# ===================Results for ee_no_context.csv ==================================
# CO2C causes VABI with a delay of 0 time steps.
# ARP causes EMP with a delay of 0 time steps.
# ARP causes QOA with a delay of 3 time steps.
# EBSG causes QOR with a delay of 0 time steps.
# GGFC causes QOR with a delay of 0 time steps.
# REST causes EBSG with a delay of 0 time steps.
# QOR causes EBSG with a delay of 0 time steps.
# EUPC causes EBSG with a delay of 3 time steps.
# QOR causes GGFC with a delay of 0 time steps.
# LBGD causes GGFC with a delay of 0 time steps.
# QOA causes LBGD with a delay of 1 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# CO2C causes LBGD with a delay of 3 time steps.
# CO2C causes FDI with a delay of 3 time steps.
# CO2C causes PC with a delay of 3 time steps.
# EBSG causes ARP with a delay of 3 time steps.
# EBSG causes PAM with a delay of 0 time steps.
# QOR causes PAM with a delay of 2 time steps.
# PAM causes EUPC with a delay of 1 time steps.
# VABI causes EUPC with a delay of 2 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/ee_no_context.csv=data/groundtruth_ee.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/ee_no_context.csv': 'data/groundtruth_ee.csv'}, data=None)
#
#  Dataset:  ee_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001905
# Epoch: 250 [50%] 	Loss: 0.000696
# Epoch: 500 [100%] 	Loss: 0.000097
# Potential causes:  [15, 1, 13, 12, 2, 4]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.999725
# Epoch: 250 [50%] 	Loss: 0.000976
# Epoch: 500 [100%] 	Loss: 0.000072
# Potential causes:  [13, 6, 4, 8, 15, 7, 3]
# Validated causes:  [13]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.004677
# Epoch: 250 [50%] 	Loss: 0.000348
# Epoch: 500 [100%] 	Loss: 0.000025
# Potential causes:  [7, 12, 1]
# Validated causes:  [12]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.004151
# Epoch: 250 [50%] 	Loss: 0.002072
# Epoch: 500 [100%] 	Loss: 0.000133
# Potential causes:  [12, 3, 1, 14]
# Validated causes:  [12]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.001062
# Epoch: 250 [50%] 	Loss: 0.000872
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [7, 8]
# Validated causes:  [7, 8]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.997702
# Epoch: 250 [50%] 	Loss: 0.000770
# Epoch: 500 [100%] 	Loss: 0.000038
# Potential causes:  [14, 4, 7, 8, 13, 9, 3, 15]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.000955
# Epoch: 250 [50%] 	Loss: 0.000300
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [13, 7, 15, 1, 8, 3, 4, 12]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.002543
# Epoch: 250 [50%] 	Loss: 0.000066
# Epoch: 500 [100%] 	Loss: 0.000047
# Potential causes:  [6, 8, 4, 15]
# Validated causes:  [6, 4, 15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.003098
# Epoch: 250 [50%] 	Loss: 0.000068
# Epoch: 500 [100%] 	Loss: 0.000244
# Potential causes:  [4, 9, 7, 13]
# Validated causes:  [4, 9]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000286
# Epoch: 250 [50%] 	Loss: 0.000138
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 8, 13]
# Validated causes:  [3, 8, 13]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998657
# Epoch: 250 [50%] 	Loss: 0.002314
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [13, 3]
# Validated causes:  [13]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.001348
# Epoch: 250 [50%] 	Loss: 0.000060
# Epoch: 500 [100%] 	Loss: 0.000040
# Potential causes:  [13, 12, 10]
# Validated causes:  [13]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.006628
# Epoch: 250 [50%] 	Loss: 0.000829
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [10, 7, 2, 12, 15, 3, 13, 1]
# Validated causes:  [7]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.000765
# Epoch: 250 [50%] 	Loss: 0.000348
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 1]
# Validated causes:  []
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.001376
# Epoch: 250 [50%] 	Loss: 0.002738
# Epoch: 500 [100%] 	Loss: 0.000017
# Potential causes:  [7, 4, 3, 1, 6, 8, 5]
# Validated causes:  [7, 4]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002579
# Epoch: 250 [50%] 	Loss: 0.000042
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 3, 8, 1, 7]
# Validated causes:  [14, 1]
# ===================Results for ee_no_context.csv ==================================
# CO2C causes VABI with a delay of 0 time steps.
# ARP causes EMP with a delay of 0 time steps.
# ARP causes QOA with a delay of 3 time steps.
# EBSG causes QOR with a delay of 0 time steps.
# GGFC causes QOR with a delay of 0 time steps.
# REST causes EBSG with a delay of 0 time steps.
# QOR causes EBSG with a delay of 0 time steps.
# EUPC causes EBSG with a delay of 3 time steps.
# QOR causes GGFC with a delay of 0 time steps.
# LBGD causes GGFC with a delay of 0 time steps.
# QOA causes LBGD with a delay of 1 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# CO2C causes LBGD with a delay of 3 time steps.
# CO2C causes FDI with a delay of 3 time steps.
# CO2C causes PC with a delay of 3 time steps.
# EBSG causes ARP with a delay of 3 time steps.
# EBSG causes PAM with a delay of 0 time steps.
# QOR causes PAM with a delay of 2 time steps.
# PAM causes EUPC with a delay of 1 time steps.
# VABI causes EUPC with a delay of 2 time steps.
#
# ===================Evaluation for ee_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  20
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  20
# TPs':  [(1, 13), (2, 12), (3, 12), (4, 7), (4, 8), (7, 6), (7, 4), (7, 15), (8, 4), (8, 9), (9, 3), (9, 8), (9, 13), (10, 13), (11, 13), (12, 7), (14, 7), (14, 4), (15, 14), (15, 1)]
# FPs':  []
# TPs direct:  [(1, 13), (2, 12), (3, 12), (4, 7), (4, 8), (7, 6), (7, 4), (7, 15), (8, 4), (8, 9), (9, 3), (9, 8), (9, 13), (10, 13), (11, 13), (12, 7), (14, 7), (14, 4), (15, 14), (15, 1)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/ee_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/ee_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.626205
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.896067
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.957766
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.334131
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.104812
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.244248
# Epoch: 500 [50%] 	Loss: 0.000178
# Epoch: 1000 [100%] 	Loss: 0.000003
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.713514
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.167905
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.090291
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.617312
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.774066
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.272977
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.121403
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.423813
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.148679
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.110932
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/ee_no_context.csv : 1.6785662562319508 with standard deviation 1.2891973087280442
