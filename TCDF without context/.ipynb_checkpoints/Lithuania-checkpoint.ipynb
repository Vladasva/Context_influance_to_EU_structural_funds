# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/lt_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/lt_no_context.csv'])
#
#  Dataset:  lt_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.996743
# Epoch: 500 [50%] 	Loss: 0.000055
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [1, 7, 14]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.002082
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 8, 5, 15, 12, 14, 10, 1]
# Validated causes:  [6]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.998056
# Epoch: 500 [50%] 	Loss: 0.000028
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 7, 8, 4, 3, 1]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.003304
# Epoch: 500 [50%] 	Loss: 0.000144
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 3, 7, 4, 15, 1, 9]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.005695
# Epoch: 500 [50%] 	Loss: 0.000074
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [8, 6, 3]
# Validated causes:  [6]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.004459
# Epoch: 500 [50%] 	Loss: 0.000062
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 8, 9, 6]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.996464
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 14]
# Validated causes:  [1, 14]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.000034
# Epoch: 500 [50%] 	Loss: 0.000042
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 4, 15, 1]
# Validated causes:  [14, 4]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.007034
# Epoch: 500 [50%] 	Loss: 0.000048
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 6, 4]
# Validated causes:  [6]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.996830
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000004
# Potential causes:  [3, 15]
# Validated causes:  [3]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998392
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 15, 12, 4, 10]
# Validated causes:  [1, 15, 12]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.998889
# Epoch: 500 [50%] 	Loss: 0.000184
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 15, 3]
# Validated causes:  [13, 15]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.002059
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 12, 1, 3]
# Validated causes:  [14, 12, 1]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.997138
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000074
# Potential causes:  [12, 10]
# Validated causes:  [12, 10]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.001762
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000306
# Potential causes:  [7, 6, 10, 15, 14, 13]
# Validated causes:  [7, 6, 10]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002377
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000004
# Potential causes:  [1, 3, 7, 10, 4, 12]
# Validated causes:  [1, 3, 7, 10, 12]
# ===================Results for lt_no_context.csv ==================================
# REST causes VABI with a delay of 0 time steps.
# REST causes QOR with a delay of 1 time steps.
# VABI causes REST with a delay of 0 time steps.
# PAM causes REST with a delay of 0 time steps.
# PAM causes EBSG with a delay of 0 time steps.
# QOR causes EBSG with a delay of 2 time steps.
# REST causes GGFC with a delay of 2 time steps.
# QOA causes LBGD with a delay of 1 time steps.
# VABI causes FDI with a delay of 1 time steps.
# EUPC causes FDI with a delay of 2 time steps.
# ARP causes FDI with a delay of 2 time steps.
# CO2C causes PC with a delay of 3 time steps.
# EUPC causes PC with a delay of 0 time steps.
# PAM causes ARP with a delay of 3 time steps.
# ARP causes ARP with a delay of 4 time steps.
# VABI causes ARP with a delay of 1 time steps.
# ARP causes CO2C with a delay of 2 time steps.
# FDI causes CO2C with a delay of 3 time steps.
# EBSG causes PAM with a delay of 2 time steps.
# REST causes PAM with a delay of 1 time steps.
# FDI causes PAM with a delay of 3 time steps.
# VABI causes EUPC with a delay of 2 time steps.
# QOA causes EUPC with a delay of 3 time steps.
# EBSG causes EUPC with a delay of 3 time steps.
# FDI causes EUPC with a delay of 1 time steps.
# ARP causes EUPC with a delay of 3 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/lt_no_context.csv=data/groundtruth_lt.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/lt_no_context.csv': 'data/groundtruth_lt.csv'}, data=None)
#
#  Dataset:  lt_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.996743
# Epoch: 250 [50%] 	Loss: 0.002130
# Epoch: 500 [100%] 	Loss: 0.000055
# Potential causes:  [1, 7, 14, 15, 2, 3, 4]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.002082
# Epoch: 250 [50%] 	Loss: 0.000563
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [6, 8, 5, 15, 12, 14, 10, 1]
# Validated causes:  [6]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.998056
# Epoch: 250 [50%] 	Loss: 0.000380
# Epoch: 500 [100%] 	Loss: 0.000028
# Potential causes:  [14, 7, 8, 4, 3, 1]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.003304
# Epoch: 250 [50%] 	Loss: 0.000623
# Epoch: 500 [100%] 	Loss: 0.000144
# Potential causes:  [14, 3, 7, 4, 15, 1, 9]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.005695
# Epoch: 250 [50%] 	Loss: 0.000235
# Epoch: 500 [100%] 	Loss: 0.000074
# Potential causes:  [8, 6, 3]
# Validated causes:  [6]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.004459
# Epoch: 250 [50%] 	Loss: 0.000632
# Epoch: 500 [100%] 	Loss: 0.000062
# Potential causes:  [7, 8, 9, 6]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.996464
# Epoch: 250 [50%] 	Loss: 0.000027
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 14]
# Validated causes:  [1, 14]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.000034
# Epoch: 250 [50%] 	Loss: 0.000183
# Epoch: 500 [100%] 	Loss: 0.000042
# Potential causes:  [14, 4, 15, 1]
# Validated causes:  [14, 4]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.007034
# Epoch: 250 [50%] 	Loss: 0.000746
# Epoch: 500 [100%] 	Loss: 0.000048
# Potential causes:  [3, 6, 4]
# Validated causes:  [6]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.996830
# Epoch: 250 [50%] 	Loss: 0.001211
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [3, 15]
# Validated causes:  [3]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998392
# Epoch: 250 [50%] 	Loss: 0.000917
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [1, 15, 12, 4, 10]
# Validated causes:  [1, 15, 12]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.998889
# Epoch: 250 [50%] 	Loss: 0.000608
# Epoch: 500 [100%] 	Loss: 0.000184
# Potential causes:  [13, 15, 3]
# Validated causes:  [13, 15]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.002059
# Epoch: 250 [50%] 	Loss: 0.000080
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 12, 1, 3]
# Validated causes:  [14, 12, 1]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.997138
# Epoch: 250 [50%] 	Loss: 0.000149
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [12, 10]
# Validated causes:  [12, 10]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.001762
# Epoch: 250 [50%] 	Loss: 0.000775
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [7, 10, 6, 15, 14, 13]
# Validated causes:  [7, 10, 6]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002377
# Epoch: 250 [50%] 	Loss: 0.000015
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 3, 7, 10, 4, 12]
# Validated causes:  [1, 3, 7, 10, 12]
# ===================Results for lt_no_context.csv ==================================
# REST causes VABI with a delay of 0 time steps.
# REST causes QOR with a delay of 1 time steps.
# VABI causes REST with a delay of 0 time steps.
# PAM causes REST with a delay of 0 time steps.
# PAM causes EBSG with a delay of 0 time steps.
# QOR causes EBSG with a delay of 2 time steps.
# REST causes GGFC with a delay of 2 time steps.
# QOA causes LBGD with a delay of 1 time steps.
# VABI causes FDI with a delay of 1 time steps.
# EUPC causes FDI with a delay of 2 time steps.
# ARP causes FDI with a delay of 2 time steps.
# CO2C causes PC with a delay of 3 time steps.
# EUPC causes PC with a delay of 0 time steps.
# PAM causes ARP with a delay of 3 time steps.
# ARP causes ARP with a delay of 4 time steps.
# VABI causes ARP with a delay of 1 time steps.
# ARP causes CO2C with a delay of 2 time steps.
# FDI causes CO2C with a delay of 3 time steps.
# EBSG causes PAM with a delay of 2 time steps.
# FDI causes PAM with a delay of 3 time steps.
# REST causes PAM with a delay of 1 time steps.
# VABI causes EUPC with a delay of 2 time steps.
# QOA causes EUPC with a delay of 3 time steps.
# EBSG causes EUPC with a delay of 3 time steps.
# FDI causes EUPC with a delay of 1 time steps.
# ARP causes EUPC with a delay of 3 time steps.
#
# ===================Evaluation for lt_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  26
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  26
# TPs':  [(1, 6), (4, 6), (6, 1), (6, 14), (7, 14), (7, 4), (8, 6), (9, 3), (10, 1), (10, 15), (10, 12), (11, 13), (11, 15), (12, 14), (12, 12), (12, 1), (13, 12), (13, 10), (14, 7), (14, 10), (14, 6), (15, 1), (15, 3), (15, 7), (15, 10), (15, 12)]
# FPs':  []
# TPs direct:  [(1, 6), (4, 6), (6, 1), (6, 14), (7, 14), (7, 4), (8, 6), (9, 3), (10, 1), (10, 15), (10, 12), (11, 13), (11, 15), (12, 14), (12, 12), (12, 1), (13, 12), (13, 10), (14, 7), (14, 10), (14, 6), (15, 1), (15, 3), (15, 7), (15, 10), (15, 12)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/lt_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/lt_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.709897
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.958041
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.952673
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.010844
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.215088
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.173314
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.880004
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.933295
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.233697
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.030357
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.806868
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.584749
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.304897
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.914231
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.287469
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.957241
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/lt_no_context.csv : 2.4304524081883616 with standard deviation 2.496407680831318
