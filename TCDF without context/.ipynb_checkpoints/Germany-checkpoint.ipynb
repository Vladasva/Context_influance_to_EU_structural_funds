# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/de_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/de_no_context.csv'])
#
#  Dataset:  de_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.006977
# Epoch: 500 [50%] 	Loss: 0.000017
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [8, 5, 4, 13]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.996702
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000003
# Potential causes:  [15, 8, 2, 3, 1]
# Validated causes:  [15, 8]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.007401
# Epoch: 500 [50%] 	Loss: 0.000090
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 4]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.999899
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 4]
# Validated causes:  [5]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.999052
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 5]
# Validated causes:  [5]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.998393
# Epoch: 500 [50%] 	Loss: 0.000094
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [4, 6, 3]
# Validated causes:  [4, 6]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.006493
# Epoch: 500 [50%] 	Loss: 0.000025
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 4, 13, 5, 15]
# Validated causes:  [8]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.999108
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000276
# Potential causes:  [15, 3, 12, 14, 10, 1]
# Validated causes:  [15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.007129
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000033
# Potential causes:  [13, 4, 1]
# Validated causes:  [13]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000308
# Epoch: 500 [50%] 	Loss: 0.000016
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [14, 8, 10, 3, 12, 15]
# Validated causes:  [8]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003240
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 7]
# Validated causes:  [10, 7]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.999048
# Epoch: 500 [50%] 	Loss: 0.000010
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [15, 12]
# Validated causes:  [15, 12]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.998281
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000026
# Potential causes:  [14, 15, 10, 3]
# Validated causes:  [14, 15, 10]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.994495
# Epoch: 500 [50%] 	Loss: 0.000129
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 8, 6, 10, 14, 1, 15]
# Validated causes:  []
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.998675
# Epoch: 500 [50%] 	Loss: 0.000126
# Epoch: 1000 [100%] 	Loss: 0.000030
# Potential causes:  [3, 13, 10]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.003629
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 11, 15, 8, 10, 1, 6]
# Validated causes:  [3, 11, 8, 10]
# ===================Results for de_no_context.csv ==================================
# EUPC causes VABI with a delay of 0 time steps.
# GGFC causes VABI with a delay of 0 time steps.
# YUA causes QOA with a delay of 0 time steps.
# YUA causes QOR with a delay of 0 time steps.
# QOR causes YUA with a delay of 0 time steps.
# REST causes YUA with a delay of 0 time steps.
# GGFC causes REST with a delay of 0 time steps.
# EUPC causes EBSG with a delay of 0 time steps.
# CO2C causes GGFC with a delay of 2 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# FDI causes FDI with a delay of 4 time steps.
# EBSG causes FDI with a delay of 3 time steps.
# EUPC causes PC with a delay of 0 time steps.
# ARP causes PC with a delay of 1 time steps.
# PAM causes ARP with a delay of 3 time steps.
# EUPC causes ARP with a delay of 3 time steps.
# FDI causes ARP with a delay of 0 time steps.
# QOA causes EUPC with a delay of 0 time steps.
# PC causes EUPC with a delay of 1 time steps.
# GGFC causes EUPC with a delay of 2 time steps.
# FDI causes EUPC with a delay of 2 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/de_no_context.csv=data/groundtruth_de.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/de_no_context.csv': 'data/groundtruth_de.csv'}, data=None)
#
#  Dataset:  de_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.006977
# Epoch: 250 [50%] 	Loss: 0.000615
# Epoch: 500 [100%] 	Loss: 0.000017
# Potential causes:  [8, 5, 4, 13]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.996702
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 8, 2, 3, 1]
# Validated causes:  [15, 8]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.007401
# Epoch: 250 [50%] 	Loss: 0.000837
# Epoch: 500 [100%] 	Loss: 0.000090
# Potential causes:  [13, 4]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.999899
# Epoch: 250 [50%] 	Loss: 0.000144
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [5, 4]
# Validated causes:  [5]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.999052
# Epoch: 250 [50%] 	Loss: 0.000251
# Epoch: 500 [100%] 	Loss: 0.000012
# Potential causes:  [3, 5]
# Validated causes:  [5]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.998393
# Epoch: 250 [50%] 	Loss: 0.000804
# Epoch: 500 [100%] 	Loss: 0.000094
# Potential causes:  [4, 6, 3]
# Validated causes:  [4, 6]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.006493
# Epoch: 250 [50%] 	Loss: 0.002481
# Epoch: 500 [100%] 	Loss: 0.000025
# Potential causes:  [8, 4, 13, 5, 15]
# Validated causes:  [8]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.999108
# Epoch: 250 [50%] 	Loss: 0.004193
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [15, 3, 12, 14, 10, 1]
# Validated causes:  [15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.007129
# Epoch: 250 [50%] 	Loss: 0.000162
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [13, 4, 1]
# Validated causes:  [13]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000308
# Epoch: 250 [50%] 	Loss: 0.000389
# Epoch: 500 [100%] 	Loss: 0.000016
# Potential causes:  [14, 8, 10, 3, 12, 15]
# Validated causes:  [8]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003240
# Epoch: 250 [50%] 	Loss: 0.000031
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [10, 7]
# Validated causes:  [10, 7]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.999048
# Epoch: 250 [50%] 	Loss: 0.005882
# Epoch: 500 [100%] 	Loss: 0.000010
# Potential causes:  [15, 12]
# Validated causes:  [15, 12]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.998281
# Epoch: 250 [50%] 	Loss: 0.005105
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [14, 15, 10, 3]
# Validated causes:  [14, 15, 10]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.994495
# Epoch: 250 [50%] 	Loss: 0.000289
# Epoch: 500 [100%] 	Loss: 0.000129
# Potential causes:  [3, 8, 6, 10, 14, 1, 15]
# Validated causes:  []
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.998675
# Epoch: 250 [50%] 	Loss: 0.002142
# Epoch: 500 [100%] 	Loss: 0.000126
# Potential causes:  [3, 13, 10]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.003629
# Epoch: 250 [50%] 	Loss: 0.000374
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 11, 15, 8, 10, 1, 6]
# Validated causes:  [3, 11, 8, 10]
# ===================Results for de_no_context.csv ==================================
# EUPC causes VABI with a delay of 0 time steps.
# GGFC causes VABI with a delay of 0 time steps.
# YUA causes QOA with a delay of 0 time steps.
# YUA causes QOR with a delay of 0 time steps.
# QOR causes YUA with a delay of 0 time steps.
# REST causes YUA with a delay of 0 time steps.
# GGFC causes REST with a delay of 0 time steps.
# EUPC causes EBSG with a delay of 0 time steps.
# CO2C causes GGFC with a delay of 2 time steps.
# GGFC causes LBGD with a delay of 0 time steps.
# FDI causes FDI with a delay of 4 time steps.
# EBSG causes FDI with a delay of 3 time steps.
# EUPC causes PC with a delay of 0 time steps.
# ARP causes PC with a delay of 1 time steps.
# PAM causes ARP with a delay of 3 time steps.
# EUPC causes ARP with a delay of 3 time steps.
# FDI causes ARP with a delay of 0 time steps.
# QOA causes EUPC with a delay of 0 time steps.
# PC causes EUPC with a delay of 1 time steps.
# GGFC causes EUPC with a delay of 2 time steps.
# FDI causes EUPC with a delay of 2 time steps.
#
# ===================Evaluation for de_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  21
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  21
# TPs':  [(1, 15), (1, 8), (3, 5), (4, 5), (5, 4), (5, 6), (6, 8), (7, 15), (8, 13), (9, 8), (10, 10), (10, 7), (11, 15), (11, 12), (12, 14), (12, 15), (12, 10), (15, 3), (15, 11), (15, 8), (15, 10)]
# FPs':  []
# TPs direct:  [(1, 15), (1, 8), (3, 5), (4, 5), (5, 4), (5, 6), (6, 8), (7, 15), (8, 13), (9, 8), (10, 10), (10, 7), (11, 15), (11, 12), (12, 14), (12, 15), (12, 10), (15, 3), (15, 11), (15, 8), (15, 10)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/de_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/de_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.751539
# Epoch: 500 [50%] 	Loss: 0.000253
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.189079
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.844543
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.043752
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.049989
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.022382
# Epoch: 500 [50%] 	Loss: 0.000018
# Epoch: 1000 [100%] 	Loss: 0.000097
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.685153
# Epoch: 500 [50%] 	Loss: 0.000262
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.626450
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.556841
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.613330
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.866222
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.222202
# Epoch: 500 [50%] 	Loss: 0.000132
# Epoch: 1000 [100%] 	Loss: 0.000009
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.768255
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.409400
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.258731
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.316150
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000052
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/de_no_context.csv : 2.3043470893773126 with standard deviation 1.5762254353561083
