# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/pl_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/pl_no_context.csv'])
#
#  Dataset:  pl_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.991749
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000020
# Potential causes:  [14, 15, 7, 3, 11, 1]
# Validated causes:  [11]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.001561
# Epoch: 500 [50%] 	Loss: 0.000176
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 10, 8, 1, 12, 14, 6]
# Validated causes:  [10]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.992984
# Epoch: 500 [50%] 	Loss: 0.000493
# Epoch: 1000 [100%] 	Loss: 0.000010
# Potential causes:  [3, 7]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.996341
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 14, 7, 4]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.992672
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 7, 14]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.008773
# Epoch: 500 [50%] 	Loss: 0.000125
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 8]
# Validated causes:  [8]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.991077
# Epoch: 500 [50%] 	Loss: 0.000207
# Epoch: 1000 [100%] 	Loss: 0.000036
# Potential causes:  [14, 15]
# Validated causes:  [15]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.992758
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 3, 15, 13, 10]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.005679
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000175
# Potential causes:  [1, 13, 4, 9]
# Validated causes:  [1, 4]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997377
# Epoch: 500 [50%] 	Loss: 0.000153
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 13, 8]
# Validated causes:  [13]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.995552
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 1, 3]
# Validated causes:  [7, 1, 3]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.006160
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 6, 13, 9, 8, 12]
# Validated causes:  [3]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.008608
# Epoch: 500 [50%] 	Loss: 0.000016
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [5, 15, 2, 4, 13, 6, 10]
# Validated causes:  [15]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.005598
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 1, 13, 11, 9, 10, 15]
# Validated causes:  [7, 11, 9]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.996427
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000047
# Potential causes:  [10, 15]
# Validated causes:  [10, 15]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.997227
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 1]
# Validated causes:  [14, 1]
# ===================Results for pl_no_context.csv ==================================
# PC causes GDPC with a delay of 3 time steps.
# FDI causes VABI with a delay of 3 time steps.
# GGFC causes YUA with a delay of 0 time steps.
# EUPC causes REST with a delay of 0 time steps.
# VABI causes GGFC with a delay of 0 time steps.
# QOR causes GGFC with a delay of 2 time steps.
# CO2C causes LBGD with a delay of 1 time steps.
# EBSG causes FDI with a delay of 1 time steps.
# VABI causes FDI with a delay of 0 time steps.
# QOA causes FDI with a delay of 1 time steps.
# QOA causes PC with a delay of 0 time steps.
# EUPC causes ARP with a delay of 0 time steps.
# EBSG causes CO2C with a delay of 1 time steps.
# PC causes CO2C with a delay of 2 time steps.
# LBGD causes CO2C with a delay of 2 time steps.
# FDI causes PAM with a delay of 3 time steps.
# EUPC causes PAM with a delay of 0 time steps.
# PAM causes EUPC with a delay of 0 time steps.
# VABI causes EUPC with a delay of 1 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/pl_no_context.csv=data/groundtruth_pl.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/pl_no_context.csv': 'data/groundtruth_pl.csv'}, data=None)
#
#  Dataset:  pl_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.991749
# Epoch: 250 [50%] 	Loss: 0.002203
# Epoch: 500 [100%] 	Loss: 0.000008
# Potential causes:  [14, 15, 7, 3, 11, 1]
# Validated causes:  [11]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.001561
# Epoch: 250 [50%] 	Loss: 0.000535
# Epoch: 500 [100%] 	Loss: 0.000176
# Potential causes:  [13, 10, 8, 1, 12, 14, 6]
# Validated causes:  [10]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.992984
# Epoch: 250 [50%] 	Loss: 0.002589
# Epoch: 500 [100%] 	Loss: 0.000493
# Potential causes:  [3, 7, 1, 15, 14]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.996341
# Epoch: 250 [50%] 	Loss: 0.000405
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [8, 14, 7, 4]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.992672
# Epoch: 250 [50%] 	Loss: 0.000915
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [3, 7, 14]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.008773
# Epoch: 250 [50%] 	Loss: 0.003029
# Epoch: 500 [100%] 	Loss: 0.000125
# Potential causes:  [4, 8]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.991077
# Epoch: 250 [50%] 	Loss: 0.004551
# Epoch: 500 [100%] 	Loss: 0.000207
# Potential causes:  [14, 15]
# Validated causes:  [15]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.992758
# Epoch: 250 [50%] 	Loss: 0.001205
# Epoch: 500 [100%] 	Loss: 0.000014
# Potential causes:  [14, 3, 15, 13, 10]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.005679
# Epoch: 250 [50%] 	Loss: 0.002183
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 13, 4, 9]
# Validated causes:  [1, 4]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997377
# Epoch: 250 [50%] 	Loss: 0.000087
# Epoch: 500 [100%] 	Loss: 0.000153
# Potential causes:  [14, 13, 8]
# Validated causes:  [13]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.995552
# Epoch: 250 [50%] 	Loss: 0.000109
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [7, 1, 3]
# Validated causes:  [7, 1, 3]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.006160
# Epoch: 250 [50%] 	Loss: 0.001019
# Epoch: 500 [100%] 	Loss: 0.000012
# Potential causes:  [3, 6, 13, 9, 8, 12]
# Validated causes:  [3]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.008608
# Epoch: 250 [50%] 	Loss: 0.001410
# Epoch: 500 [100%] 	Loss: 0.000016
# Potential causes:  [5, 15, 2, 4, 13, 6, 10, 0]
# Validated causes:  [15]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.005598
# Epoch: 250 [50%] 	Loss: 0.000622
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [7, 1, 13, 11, 9, 10, 15]
# Validated causes:  [7, 11, 9]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.996427
# Epoch: 250 [50%] 	Loss: 0.000124
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [10, 15]
# Validated causes:  [10, 15]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.997227
# Epoch: 250 [50%] 	Loss: 0.000141
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [14, 1]
# Validated causes:  [14, 1]
# ===================Results for pl_no_context.csv ==================================
# PC causes GDPC with a delay of 3 time steps.
# FDI causes VABI with a delay of 3 time steps.
# EUPC causes REST with a delay of 0 time steps.
# VABI causes GGFC with a delay of 0 time steps.
# QOR causes GGFC with a delay of 2 time steps.
# CO2C causes LBGD with a delay of 1 time steps.
# EBSG causes FDI with a delay of 1 time steps.
# VABI causes FDI with a delay of 0 time steps.
# QOA causes FDI with a delay of 1 time steps.
# QOA causes PC with a delay of 0 time steps.
# EUPC causes ARP with a delay of 0 time steps.
# EBSG causes CO2C with a delay of 1 time steps.
# PC causes CO2C with a delay of 2 time steps.
# LBGD causes CO2C with a delay of 2 time steps.
# FDI causes PAM with a delay of 3 time steps.
# EUPC causes PAM with a delay of 0 time steps.
# PAM causes EUPC with a delay of 0 time steps.
# VABI causes EUPC with a delay of 1 time steps.
#
# ===================Evaluation for pl_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  18
# Total False Negatives:  1
# Total Direct False Positives:  0
# Total Direct True Positives:  18
# TPs':  [(0, 11), (1, 10), (6, 15), (8, 1), (8, 4), (9, 13), (10, 7), (10, 1), (10, 3), (11, 3), (12, 15), (13, 7), (13, 11), (13, 9), (14, 10), (14, 15), (15, 14), (15, 1)]
# FPs':  []
# TPs direct:  [(0, 11), (1, 10), (6, 15), (8, 1), (8, 4), (9, 13), (10, 7), (10, 1), (10, 3), (11, 3), (12, 15), (13, 7), (13, 11), (13, 9), (14, 10), (14, 15), (15, 14), (15, 1)]
# FPs direct:  []
# FNs:  [(5, 8)]
# Precision':  1.0
# Recall':  0.9473684210526315
# F1' score:  0.972972972972973 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  0.9473684210526315
# F1 score:  0.972972972972973 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/pl_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/pl_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.534661
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.005824
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.686269
# Epoch: 500 [50%] 	Loss: 0.000044
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.994465
# Epoch: 500 [50%] 	Loss: 0.000018
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.136693
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.755563
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.725247
# Epoch: 500 [50%] 	Loss: 0.000373
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.934883
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.079761
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.804136
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.922938
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000067
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.111457
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.669580
# Epoch: 500 [50%] 	Loss: 0.000090
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.870104
# Epoch: 500 [50%] 	Loss: 0.000013
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.289839
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.964680
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/pl_no_context.csv : 2.7038693022767237 with standard deviation 2.2063849696015816
