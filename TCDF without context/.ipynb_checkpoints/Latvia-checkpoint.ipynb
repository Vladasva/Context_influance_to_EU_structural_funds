# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/lv_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/lv_no_context.csv'])
#
#  Dataset:  lv_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001034
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 15, 2, 1]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.002992
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 14, 3, 7, 10, 8]
# Validated causes:  [6]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002060
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [2, 1, 7]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.004084
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [15, 1, 13, 12, 4, 3, 2]
# Validated causes:  [15, 1]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.999955
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [15, 13]
# Validated causes:  [15, 13]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.001402
# Epoch: 500 [50%] 	Loss: 0.000010
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 7, 6, 14, 3, 10]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.000185
# Epoch: 500 [50%] 	Loss: 0.000011
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 15, 1]
# Validated causes:  [15]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.002479
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 10, 15]
# Validated causes:  [1, 15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.003613
# Epoch: 500 [50%] 	Loss: 0.000040
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 12, 13]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000787
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 3, 8]
# Validated causes:  [7]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.001131
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000020
# Potential causes:  [15, 7, 1]
# Validated causes:  [15, 7, 1]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.999804
# Epoch: 500 [50%] 	Loss: 0.000029
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 7]
# Validated causes:  [7]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.005843
# Epoch: 500 [50%] 	Loss: 0.000083
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 9, 11, 1]
# Validated causes:  [9]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.000969
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [15, 7, 4, 3, 5, 10, 6, 13]
# Validated causes:  [15, 5]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.002277
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 13, 14, 10, 1, 6]
# Validated causes:  [3, 13]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002229
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 7, 3, 5]
# Validated causes:  [3, 5]
# ===================Results for lv_no_context.csv ==================================
# REST causes VABI with a delay of 0 time steps.
# EUPC causes QOA with a delay of 0 time steps.
# VABI causes QOA with a delay of 0 time steps.
# EUPC causes QOR with a delay of 1 time steps.
# CO2C causes QOR with a delay of 2 time steps.
# EUPC causes REST with a delay of 0 time steps.
# VABI causes EBSG with a delay of 1 time steps.
# EUPC causes EBSG with a delay of 0 time steps.
# EBSG causes LBGD with a delay of 0 time steps.
# EUPC causes FDI with a delay of 2 time steps.
# EBSG causes FDI with a delay of 0 time steps.
# VABI causes FDI with a delay of 0 time steps.
# EBSG causes PC with a delay of 0 time steps.
# LBGD causes ARP with a delay of 0 time steps.
# EUPC causes CO2C with a delay of 2 time steps.
# YUA causes CO2C with a delay of 0 time steps.
# QOA causes PAM with a delay of 3 time steps.
# CO2C causes PAM with a delay of 3 time steps.
# QOA causes EUPC with a delay of 0 time steps.
# YUA causes EUPC with a delay of 2 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/lv_no_context.csv=data/groundtruth_lv.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/lv_no_context.csv': 'data/groundtruth_lv.csv'}, data=None)
#
#  Dataset:  lv_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001034
# Epoch: 250 [50%] 	Loss: 0.000709
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [7, 15, 2, 1]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.002992
# Epoch: 250 [50%] 	Loss: 0.000608
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [6, 14, 3, 7, 10, 8]
# Validated causes:  [6]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002060
# Epoch: 250 [50%] 	Loss: 0.000103
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [2, 1, 7]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.004084
# Epoch: 250 [50%] 	Loss: 0.000284
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 1, 13, 12, 4, 3, 2]
# Validated causes:  [15, 1]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.999955
# Epoch: 250 [50%] 	Loss: 0.000105
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [15, 13]
# Validated causes:  [15, 13]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.001402
# Epoch: 250 [50%] 	Loss: 0.001008
# Epoch: 500 [100%] 	Loss: 0.000010
# Potential causes:  [11, 7, 6, 14, 3, 10]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.000185
# Epoch: 250 [50%] 	Loss: 0.001545
# Epoch: 500 [100%] 	Loss: 0.000011
# Potential causes:  [7, 15, 1]
# Validated causes:  [15]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.002479
# Epoch: 250 [50%] 	Loss: 0.000029
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 10, 15]
# Validated causes:  [1, 15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.003613
# Epoch: 250 [50%] 	Loss: 0.000007
# Epoch: 500 [100%] 	Loss: 0.000040
# Potential causes:  [3, 12, 13]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000787
# Epoch: 250 [50%] 	Loss: 0.000106
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [7, 3, 8]
# Validated causes:  [7]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.001131
# Epoch: 250 [50%] 	Loss: 0.000006
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 7, 1]
# Validated causes:  [15, 7, 1]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.999804
# Epoch: 250 [50%] 	Loss: 0.000358
# Epoch: 500 [100%] 	Loss: 0.000029
# Potential causes:  [10, 7]
# Validated causes:  [7]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.005843
# Epoch: 250 [50%] 	Loss: 0.000021
# Epoch: 500 [100%] 	Loss: 0.000083
# Potential causes:  [8, 9, 11, 1]
# Validated causes:  [9]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.000969
# Epoch: 250 [50%] 	Loss: 0.002995
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [15, 7, 4, 3, 5, 10, 6, 13]
# Validated causes:  [15, 5]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.002277
# Epoch: 250 [50%] 	Loss: 0.003726
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 13, 14, 10, 1, 6]
# Validated causes:  [3, 13]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002229
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [4, 7, 3, 5]
# Validated causes:  [3, 5]
# ===================Results for lv_no_context.csv ==================================
# REST causes VABI with a delay of 0 time steps.
# EUPC causes QOA with a delay of 0 time steps.
# VABI causes QOA with a delay of 0 time steps.
# EUPC causes QOR with a delay of 1 time steps.
# CO2C causes QOR with a delay of 2 time steps.
# EUPC causes REST with a delay of 0 time steps.
# VABI causes EBSG with a delay of 1 time steps.
# EUPC causes EBSG with a delay of 0 time steps.
# EBSG causes LBGD with a delay of 0 time steps.
# EUPC causes FDI with a delay of 2 time steps.
# EBSG causes FDI with a delay of 0 time steps.
# VABI causes FDI with a delay of 0 time steps.
# EBSG causes PC with a delay of 0 time steps.
# LBGD causes ARP with a delay of 0 time steps.
# EUPC causes CO2C with a delay of 2 time steps.
# YUA causes CO2C with a delay of 0 time steps.
# QOA causes PAM with a delay of 3 time steps.
# CO2C causes PAM with a delay of 3 time steps.
# QOA causes EUPC with a delay of 0 time steps.
# YUA causes EUPC with a delay of 2 time steps.
#
# ===================Evaluation for lv_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  20
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  20
# TPs':  [(1, 6), (3, 15), (3, 1), (4, 15), (4, 13), (6, 15), (7, 1), (7, 15), (9, 7), (10, 15), (10, 7), (10, 1), (11, 7), (12, 9), (13, 15), (13, 5), (14, 3), (14, 13), (15, 3), (15, 5)]
# FPs':  []
# TPs direct:  [(1, 6), (3, 15), (3, 1), (4, 15), (4, 13), (6, 15), (7, 1), (7, 15), (9, 7), (10, 15), (10, 7), (10, 1), (11, 7), (12, 9), (13, 15), (13, 5), (14, 3), (14, 13), (15, 3), (15, 5)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/lv_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/lv_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.614729
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.226824
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.938806
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.957139
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.851716
# Epoch: 500 [50%] 	Loss: 0.000065
# Epoch: 1000 [100%] 	Loss: 0.000027
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.151554
# Epoch: 500 [50%] 	Loss: 0.000048
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.858298
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.212636
# Epoch: 500 [50%] 	Loss: 0.000161
# Epoch: 1000 [100%] 	Loss: 0.000547
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.647863
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.035625
# Epoch: 500 [50%] 	Loss: 0.000010
# Epoch: 1000 [100%] 	Loss: 0.000011
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.874810
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000302
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.800352
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.290656
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000157
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.973894
# Epoch: 500 [50%] 	Loss: 0.000173
# Epoch: 1000 [100%] 	Loss: 0.000007
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.088857
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.125046
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/lv_no_context.csv : 2.363590204668784 with standard deviation 2.0059613146127866
