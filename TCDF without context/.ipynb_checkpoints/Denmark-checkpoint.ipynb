# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/dk_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/dk_no_context.csv'])
#
#  Dataset:  dk_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.003418
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 13, 2, 4, 15]
# Validated causes:  [7]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.001953
# Epoch: 500 [50%] 	Loss: 0.000355
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 1, 3, 4, 9]
# Validated causes:  [13, 1]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.005926
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 2, 13]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.003813
# Epoch: 500 [50%] 	Loss: 0.000549
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 4]
# Validated causes:  [14, 4]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.000724
# Epoch: 500 [50%] 	Loss: 0.000012
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 13, 1, 6, 3]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.998847
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 1, 6, 8, 3, 9]
# Validated causes:  [7]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.003011
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [7, 1, 13, 4]
# Validated causes:  [7]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001793
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 15]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.000728
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000032
# Potential causes:  [0, 6, 5]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.004708
# Epoch: 500 [50%] 	Loss: 0.000098
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 7]
# Validated causes:  [1, 7]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003181
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 10, 2, 15]
# Validated causes:  [1, 10, 15]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.999798
# Epoch: 500 [50%] 	Loss: 0.000046
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 11, 7, 1, 15, 12]
# Validated causes:  [10, 11]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.004341
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [15, 12, 7, 1, 14, 3, 9]
# Validated causes:  [15, 12]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.000544
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 6, 3, 1, 14]
# Validated causes:  [6]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.000791
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 1, 15]
# Validated causes:  [6]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002994
# Epoch: 500 [50%] 	Loss: 0.000019
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 7, 1]
# Validated causes:  [10]
# ===================Results for dk_no_context.csv ==================================
# EBSG causes GDPC with a delay of 0 time steps.
# CO2C causes VABI with a delay of 2 time steps.
# VABI causes VABI with a delay of 2 time steps.
# PAM causes QOA with a delay of 1 time steps.
# QOR causes QOA with a delay of 3 time steps.
# EBSG causes YUA with a delay of 2 time steps.
# EBSG causes REST with a delay of 2 time steps.
# VABI causes LBGD with a delay of 0 time steps.
# EBSG causes LBGD with a delay of 1 time steps.
# VABI causes FDI with a delay of 1 time steps.
# FDI causes FDI with a delay of 1 time steps.
# EUPC causes FDI with a delay of 2 time steps.
# FDI causes PC with a delay of 3 time steps.
# PC causes PC with a delay of 4 time steps.
# EUPC causes ARP with a delay of 0 time steps.
# ARP causes ARP with a delay of 2 time steps.
# REST causes CO2C with a delay of 0 time steps.
# REST causes PAM with a delay of 2 time steps.
# FDI causes EUPC with a delay of 3 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/dk_no_context.csv=data/demo_groundtruth_dk.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/dk_no_context.csv': 'data/demo_groundtruth_dk.csv'}, data=None)
#
#  Dataset:  dk_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.003418
# Epoch: 250 [50%] 	Loss: 0.002346
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [7, 13, 2, 4, 15]
# Validated causes:  [7]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.001953
# Epoch: 250 [50%] 	Loss: 0.000023
# Epoch: 500 [100%] 	Loss: 0.000355
# Potential causes:  [13, 1, 3, 4, 9]
# Validated causes:  [13, 1]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.005926
# Epoch: 250 [50%] 	Loss: 0.001204
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [8, 2, 13]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.003813
# Epoch: 250 [50%] 	Loss: 0.002484
# Epoch: 500 [100%] 	Loss: 0.000549
# Potential causes:  [14, 4]
# Validated causes:  [14, 4]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.000724
# Epoch: 250 [50%] 	Loss: 0.000739
# Epoch: 500 [100%] 	Loss: 0.000012
# Potential causes:  [14, 13, 1, 6, 3]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.998847
# Epoch: 250 [50%] 	Loss: 0.000440
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [7, 1, 6, 8, 3, 9]
# Validated causes:  [7]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.003011
# Epoch: 250 [50%] 	Loss: 0.001146
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [7, 1, 13, 4]
# Validated causes:  [7]
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001793
# Epoch: 250 [50%] 	Loss: 0.000035
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [13, 15]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.000728
# Epoch: 250 [50%] 	Loss: 0.000198
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [0, 6, 5]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.004708
# Epoch: 250 [50%] 	Loss: 0.000269
# Epoch: 500 [100%] 	Loss: 0.000098
# Potential causes:  [1, 7]
# Validated causes:  [1, 7]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003181
# Epoch: 250 [50%] 	Loss: 0.000682
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [1, 10, 2, 15]
# Validated causes:  [1, 10, 15]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.999798
# Epoch: 250 [50%] 	Loss: 0.002407
# Epoch: 500 [100%] 	Loss: 0.000046
# Potential causes:  [10, 11, 7, 1, 15, 12]
# Validated causes:  [10, 11]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.004341
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 12, 7, 1, 14, 3, 9]
# Validated causes:  [15, 12]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 1.000544
# Epoch: 250 [50%] 	Loss: 0.000567
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [4, 6, 3, 1, 14]
# Validated causes:  [6]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 1.000791
# Epoch: 250 [50%] 	Loss: 0.000364
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [6, 1, 15]
# Validated causes:  [6]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002994
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000019
# Potential causes:  [10, 7, 1]
# Validated causes:  [10]
# ===================Results for dk_no_context.csv ==================================
# EBSG causes GDPC with a delay of 0 time steps.
# CO2C causes VABI with a delay of 2 time steps.
# VABI causes VABI with a delay of 2 time steps.
# PAM causes QOA with a delay of 1 time steps.
# QOR causes QOA with a delay of 0 time steps.
# EBSG causes YUA with a delay of 2 time steps.
# EBSG causes REST with a delay of 2 time steps.
# VABI causes LBGD with a delay of 0 time steps.
# EBSG causes LBGD with a delay of 1 time steps.
# VABI causes FDI with a delay of 1 time steps.
# FDI causes FDI with a delay of 1 time steps.
# EUPC causes FDI with a delay of 2 time steps.
# FDI causes PC with a delay of 3 time steps.
# PC causes PC with a delay of 4 time steps.
# EUPC causes ARP with a delay of 0 time steps.
# ARP causes ARP with a delay of 2 time steps.
# REST causes CO2C with a delay of 0 time steps.
# REST causes PAM with a delay of 2 time steps.
# FDI causes EUPC with a delay of 3 time steps.
#
# ===================Evaluation for dk_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  19
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  19
# TPs':  [(0, 7), (1, 13), (1, 1), (3, 14), (3, 4), (5, 7), (6, 7), (9, 1), (9, 7), (10, 1), (10, 10), (10, 15), (11, 10), (11, 11), (12, 15), (12, 12), (13, 6), (14, 6), (15, 10)]
# FPs':  []
# TPs direct:  [(0, 7), (1, 13), (1, 1), (3, 14), (3, 4), (5, 7), (6, 7), (9, 1), (9, 7), (10, 1), (10, 10), (10, 15), (11, 10), (11, 11), (12, 15), (12, 12), (13, 6), (14, 6), (15, 10)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  94.73684210526315 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/dk_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/dk_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.515240
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.211029
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.614717
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.214661
# Epoch: 500 [50%] 	Loss: 0.000279
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.145792
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.157214
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.803644
# Epoch: 500 [50%] 	Loss: 0.000028
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.805347
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.699684
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.024394
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.810288
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.546865
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000555
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.298867
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.863931
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.736278
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.261369
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000064
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/dk_no_context.csv : 1.4614709506507055 with standard deviation 1.1906687327930898
