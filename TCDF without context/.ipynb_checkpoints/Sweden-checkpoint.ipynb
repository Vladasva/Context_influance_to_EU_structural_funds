# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/se_no_context.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/se_no_context.csv'])
#
#  Dataset:  se_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.005282
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 13, 4, 1]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.997185
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 3]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.007777
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 12]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.999275
# Epoch: 500 [50%] 	Loss: 0.000017
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 1, 15, 2]
# Validated causes:  [3]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.997551
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 15, 3, 1]
# Validated causes:  [15]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.997851
# Epoch: 500 [50%] 	Loss: 0.000034
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 7]
# Validated causes:  [11]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.005400
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [4, 13, 12]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.998194
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 15]
# Validated causes:  [15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006598
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 1, 15, 10, 9]
# Validated causes:  [12]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.003108
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [1, 4]
# Validated causes:  [1, 4]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003461
# Epoch: 500 [50%] 	Loss: 0.000016
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [15, 7, 1, 4]
# Validated causes:  [15, 4]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.004476
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [15, 14, 10, 9, 3, 2, 8, 1]
# Validated causes:  [15, 14]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.005691
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000016
# Potential causes:  [8, 4, 13, 6, 9, 10, 15, 1]
# Validated causes:  [8, 4, 6, 9]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.996150
# Epoch: 500 [50%] 	Loss: 0.000099
# Epoch: 1000 [100%] 	Loss: 0.000013
# Potential causes:  [6, 1, 14, 7]
# Validated causes:  [6]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.998702
# Epoch: 500 [50%] 	Loss: 0.000028
# Epoch: 1000 [100%] 	Loss: 0.000004
# Potential causes:  [1, 14]
# Validated causes:  [14]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002706
# Epoch: 500 [50%] 	Loss: 0.000056
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [3, 8, 12, 5, 14, 13]
# Validated causes:  [3, 8]
# ===================Results for se_no_context.csv ==================================
# QOA causes QOA with a delay of 1 time steps.
# EUPC causes QOR with a delay of 2 time steps.
# PC causes YUA with a delay of 2 time steps.
# EUPC causes EBSG with a delay of 2 time steps.
# ARP causes GGFC with a delay of 0 time steps.
# VABI causes LBGD with a delay of 0 time steps.
# QOR causes LBGD with a delay of 1 time steps.
# EUPC causes FDI with a delay of 0 time steps.
# QOR causes FDI with a delay of 2 time steps.
# EUPC causes PC with a delay of 1 time steps.
# PAM causes PC with a delay of 3 time steps.
# GGFC causes ARP with a delay of 0 time steps.
# QOR causes ARP with a delay of 2 time steps.
# REST causes ARP with a delay of 3 time steps.
# LBGD causes ARP with a delay of 3 time steps.
# REST causes CO2C with a delay of 0 time steps.
# PAM causes PAM with a delay of 4 time steps.
# QOA causes EUPC with a delay of 2 time steps.
# GGFC causes EUPC with a delay of 3 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/se_no_context.csv=data/groundtruth_se.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/se_no_context.csv': 'data/groundtruth_se.csv'}, data=None)
#
#  Dataset:  se_no_context.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.005282
# Epoch: 250 [50%] 	Loss: 0.000148
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [12, 13, 4, 1]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.997185
# Epoch: 250 [50%] 	Loss: 0.000465
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [8, 3]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.007777
# Epoch: 250 [50%] 	Loss: 0.000173
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [4, 12]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.999275
# Epoch: 250 [50%] 	Loss: 0.001636
# Epoch: 500 [100%] 	Loss: 0.000017
# Potential causes:  [3, 1, 15, 2]
# Validated causes:  [3]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.997551
# Epoch: 250 [50%] 	Loss: 0.000159
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 15, 3, 1]
# Validated causes:  [15]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 0.997851
# Epoch: 250 [50%] 	Loss: 0.000136
# Epoch: 500 [100%] 	Loss: 0.000034
# Potential causes:  [11, 7]
# Validated causes:  [11]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.005400
# Epoch: 250 [50%] 	Loss: 0.000261
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [4, 13, 12]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.998194
# Epoch: 250 [50%] 	Loss: 0.000664
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [3, 15]
# Validated causes:  [15]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006598
# Epoch: 250 [50%] 	Loss: 0.000020
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [12, 1, 15, 10, 9]
# Validated causes:  [12]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.003108
# Epoch: 250 [50%] 	Loss: 0.000037
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [1, 4]
# Validated causes:  [1, 4]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003461
# Epoch: 250 [50%] 	Loss: 0.000550
# Epoch: 500 [100%] 	Loss: 0.000016
# Potential causes:  [15, 7, 1, 4]
# Validated causes:  [15, 4]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.004476
# Epoch: 250 [50%] 	Loss: 0.000036
# Epoch: 500 [100%] 	Loss: 0.000007
# Potential causes:  [15, 14, 10, 9, 3, 2, 8, 1]
# Validated causes:  [15, 14]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.005691
# Epoch: 250 [50%] 	Loss: 0.000453
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [8, 4, 13, 6, 9, 10, 15, 1]
# Validated causes:  [8, 4, 6, 9]
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.996150
# Epoch: 250 [50%] 	Loss: 0.000582
# Epoch: 500 [100%] 	Loss: 0.000099
# Potential causes:  [6, 1, 14, 7]
# Validated causes:  [6]
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.998702
# Epoch: 250 [50%] 	Loss: 0.000366
# Epoch: 500 [100%] 	Loss: 0.000028
# Potential causes:  [1, 14]
# Validated causes:  [14]
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.002706
# Epoch: 250 [50%] 	Loss: 0.000047
# Epoch: 500 [100%] 	Loss: 0.000056
# Potential causes:  [3, 8, 12, 5, 14, 13]
# Validated causes:  [3, 8]
# ===================Results for se_no_context.csv ==================================
# QOA causes QOA with a delay of 1 time steps.
# EUPC causes QOR with a delay of 2 time steps.
# PC causes YUA with a delay of 2 time steps.
# EUPC causes EBSG with a delay of 2 time steps.
# ARP causes GGFC with a delay of 0 time steps.
# VABI causes LBGD with a delay of 0 time steps.
# QOR causes LBGD with a delay of 1 time steps.
# EUPC causes FDI with a delay of 0 time steps.
# QOR causes FDI with a delay of 2 time steps.
# EUPC causes PC with a delay of 1 time steps.
# PAM causes PC with a delay of 3 time steps.
# GGFC causes ARP with a delay of 0 time steps.
# QOR causes ARP with a delay of 2 time steps.
# REST causes ARP with a delay of 3 time steps.
# LBGD causes ARP with a delay of 3 time steps.
# REST causes CO2C with a delay of 0 time steps.
# PAM causes PAM with a delay of 4 time steps.
# QOA causes EUPC with a delay of 2 time steps.
# GGFC causes EUPC with a delay of 3 time steps.
#
# ===================Evaluation for se_no_context.csv ===============================
# Total False Positives':  0
# Total True Positives':  19
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  19
# TPs':  [(3, 3), (4, 15), (5, 11), (7, 15), (8, 12), (9, 1), (9, 4), (10, 15), (10, 4), (11, 15), (11, 14), (12, 8), (12, 4), (12, 6), (12, 9), (13, 6), (14, 14), (15, 3), (15, 8)]
# FPs':  []
# TPs direct:  [(3, 3), (4, 15), (5, 11), (7, 15), (8, 12), (9, 1), (9, 4), (10, 15), (10, 4), (11, 15), (11, 14), (12, 8), (12, 4), (12, 6), (12, 9), (13, 6), (14, 14), (15, 3), (15, 8)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/se_no_context.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/se_no_context.csv'])
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.820234
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.089525
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.023233
# Epoch: 500 [50%] 	Loss: 0.000035
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.240504
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.771974
# Epoch: 500 [50%] 	Loss: 0.000096
# Epoch: 1000 [100%] 	Loss: 0.000004
#
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.117947
# Epoch: 500 [50%] 	Loss: 0.000040
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 0.576878
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.105428
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.186344
# Epoch: 500 [50%] 	Loss: 0.000015
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.849982
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.903464
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.914899
# Epoch: 500 [50%] 	Loss: 0.000023
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.190003
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CO2C
# Epoch:  1 [0%] 	Loss: 0.856732
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PAM
# Epoch:  1 [0%] 	Loss: 0.869270
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.315864
# Epoch: 500 [50%] 	Loss: 0.000013
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/se_no_context.csv : 1.5020534307372981 with standard deviation 0.9530126960863562
