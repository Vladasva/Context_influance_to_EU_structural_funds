# %%
import pandas as pd
import numpy as np

# %%
pl = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland.csv")

# %%
pl = pl.drop(["Unnamed: 0"], axis=1)

# %%
pl_2007_2015 = pl.loc[7:15]

# %%
pl_2007_2015
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ   VAA   CPI    FOP     JI   IUI  ...  \
# 7          2007  0.41  0.36  0.28  0.77  0.88  42.0  0.957  0.959  48.6  ...
# 8          2008  0.55  0.46  0.45  0.84  0.95  46.0  0.979  0.963  53.1  ...
# 9          2009  0.65  0.52  0.44  0.98  1.03  50.0  0.979  0.963  59.0  ...
# 10         2010  0.71  0.63  0.51  1.02  1.04  53.0  0.978  0.964  62.3  ...
# 11         2011  0.79  0.60  0.56  0.96  1.03  55.0  0.978  0.964  62.0  ...
# 12         2012  0.82  0.66  0.66  1.00  1.06  58.0  0.978  0.964  62.3  ...
# 13         2013  0.84  0.66  0.65  1.05  1.00  60.0  0.975  0.961  62.8  ...
# 14         2014  0.87  0.77  0.68  1.06  1.11  61.0  0.975  0.957  66.6  ...
# 15         2015  0.80  0.74  0.69  0.95  1.04  62.0  0.965  0.874  68.0  ...
#
#     WTDA       EDBS   DBP   DBD        SSB       DWCP  PMSI         PT  \
# 7   3.93        NaN  11.0  45.0  58.940544  50.164067  60.0  51.654726
# ...

# %%
def missing_values(df):
    for feature in df.columns:
        missing_values = df[feature].isna().sum()
        percentage = missing_values/len(df) * 100
        print(f'{feature} - {missing_values} - {round(percentage, 1)} %')

# %%
missing_values(pl_2007_2015)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# VAA - 0 - 0.0 %
# CPI - 0 - 0.0 %
# FOP - 0 - 0.0 %
# JI - 0 - 0.0 %
# IUI - 0 - 0.0 %
# CFI - 4 - 44.4 %
# PR - 0 - 0.0 %
# DI - 2 - 22.2 %
# SOARS - 0 - 0.0 %
# TOGP - 0 - 0.0 %
# IPAB - 3 - 33.3 %
# PTIP - 0 - 0.0 %
# QOES - 0 - 0.0 %
# AOLT - 0 - 0.0 %
# FLTA - 0 - 0.0 %
# EBOF - 0 - 0.0 %
# FOWD - 0 - 0.0 %
# QOMS - 0 - 0.0 %
# CLER - 0 - 0.0 %
# WTDA - 0 - 0.0 %
# EDBS - 3 - 33.3 %
# DBP - 0 - 0.0 %
# DBD - 0 - 0.0 %
# SSB - 0 - 0.0 %
# DWCP - 0 - 0.0 %
# PMSI - 0 - 0.0 %
# PT - 0 - 0.0 %
# EC - 0 - 0.0 %
# ELFE - 8 - 88.9 %

# %%
mode = pl_2007_2015['DI'].mode()[0]
pl_2007_2015['DI'].fillna(value=mode, inplace=True)
# Out:
# /var/folders/41/w_0mz3gn2vn0w0dz8wywr8_r0000gn/T/ipykernel_73875/2704250115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pl_2007_2015['DI'].fillna(value=mode, inplace=True)

# %%
pl_2007_2015 = pl_2007_2015.drop(["ELFE", "CFI", "IPAB", "EDBS"], axis=1)

# %%
def fill_with_mean(df):
    for feature in df.columns:
        mean = df[feature].mean()
        df[feature].fillna(value=mean, inplace=True)

# %%
continuous_data = ['DBP', "DBD", "EDBS", "SSB", "DWCP", "PT", "EC", "IUI", "PMSI"]

# %%
def handle_outliers(df, continuous_features):

    print("Original Shape:", df.shape)
    
    outlier_summary = {}
    
    for feature in continuous_features:
        if feature in df.columns:
            Q1 = df[feature].quantile(0.25)
            Q3 = df[feature].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            
            outlier_mask = (df[feature] < lower_bound) | (df[feature] > upper_bound)
            num_outliers = outlier_mask.sum()
            
            if num_outliers > 0:
                non_outlier_mean = df.loc[~outlier_mask, feature].mean()
                
                df.loc[outlier_mask, feature] = non_outlier_mean
                
                print(f"{feature}: Found {num_outliers} outliers, replaced with mean = {non_outlier_mean:.2f}")
            else:
                print(f"{feature}: No outliers found")
    
    print("\nFinal Shape:", df.shape)
    print(f"Total features processed: {len(continuous_features)}")
    
    return df

# %%
pl_2007_2015_no_o = handle_outliers(pl_2007_2015, continuous_data)
# Out:
# Original Shape: (9, 30)
# DBP: No outliers found
# DBD: No outliers found
# SSB: No outliers found
# DWCP: No outliers found
# PT: No outliers found
# EC: No outliers found
# IUI: Found 2 outliers, replaced with mean = 63.29
# PMSI: Found 2 outliers, replaced with mean = 60.00
#
# Final Shape: (9, 30)
# Total features processed: 9

# %%
pl_2007_2015_no_o
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ   VAA   CPI    FOP     JI        IUI  \
# 7          2007  0.41  0.36  0.28  0.77  0.88  42.0  0.957  0.959  63.285714
# 8          2008  0.55  0.46  0.45  0.84  0.95  46.0  0.979  0.963  63.285714
# 9          2009  0.65  0.52  0.44  0.98  1.03  50.0  0.979  0.963  59.000000
# 10         2010  0.71  0.63  0.51  1.02  1.04  53.0  0.978  0.964  62.300000
# 11         2011  0.79  0.60  0.56  0.96  1.03  55.0  0.978  0.964  62.000000
# 12         2012  0.82  0.66  0.66  1.00  1.06  58.0  0.978  0.964  62.300000
# 13         2013  0.84  0.66  0.65  1.05  1.00  60.0  0.975  0.961  62.800000
# 14         2014  0.87  0.77  0.68  1.06  1.11  61.0  0.975  0.957  66.600000
# 15         2015  0.80  0.74  0.69  0.95  1.04  62.0  0.965  0.874  68.000000
#
#     ...  QOMS  CLER  WTDA   DBP   DBD        SSB       DWCP  PMSI         PT  \
# 7   ...  4.41  4.00  3.93  11.0  45.0  58.940544  50.164067  60.0  51.654726
# ...

# %%
pl_2007_2015_no_o.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland_2007_2015.csv')

# %%
pl_2007_2015_no_o = pl_2007_2015_no_o.drop(["TIME_PERIOD"], axis=1)

# %%
pl_2007_2013_l = pl_2007_2015_no_o.loc[13]

# %%
pl_2007_2013_l.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland_2007_2013_last.csv')

# %%
pl_2016_2022 = pl.loc[14:22]

# %%
pl_2016_2022
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ   VAA   CPI    FOP     JI   IUI  ...  \
# 14         2014  0.87  0.77  0.68  1.06  1.11  61.0  0.975  0.957  66.6  ...
# 15         2015  0.80  0.74  0.69  0.95  1.04  62.0  0.965  0.874  68.0  ...
# 16         2016  0.59  0.65  0.76  0.91  0.84  62.0  0.745  0.783  73.3  ...
# 17         2017  0.40  0.55  0.70  0.81  0.78  60.0  0.709  0.690  76.0  ...
# 18         2018  0.38  0.55  0.62  0.87  0.71  60.0  0.709  0.595  77.5  ...
# 19         2019  0.39  0.51  0.61  1.01  0.67  58.0  0.704  0.572  80.4  ...
# 20         2020  0.52  0.32  0.62  0.85  0.62  56.0  0.707  0.570  83.2  ...
# 21         2021  0.43  0.25  0.55  0.83  0.58  56.0  0.641  0.542  85.4  ...
# 22         2022  0.43  0.26  0.51  0.72  0.60  55.0  0.616  0.570  86.9  ...
#
#     WTDA       EDBS  DBP   DBD        SSB       DWCP  PMSI         PT  \
# 14  3.83  73.637090  5.0  37.0  82.524812  71.219948  66.0  72.292209
# ...

# %%
missing_values(pl_2016_2022)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# VAA - 0 - 0.0 %
# CPI - 0 - 0.0 %
# FOP - 0 - 0.0 %
# JI - 0 - 0.0 %
# IUI - 0 - 0.0 %
# CFI - 0 - 0.0 %
# PR - 0 - 0.0 %
# DI - 0 - 0.0 %
# SOARS - 5 - 55.6 %
# TOGP - 5 - 55.6 %
# IPAB - 5 - 55.6 %
# PTIP - 5 - 55.6 %
# QOES - 5 - 55.6 %
# AOLT - 5 - 55.6 %
# FLTA - 5 - 55.6 %
# EBOF - 5 - 55.6 %
# FOWD - 5 - 55.6 %
# QOMS - 5 - 55.6 %
# CLER - 5 - 55.6 %
# WTDA - 6 - 66.7 %
# EDBS - 2 - 22.2 %
# DBP - 2 - 22.2 %
# DBD - 2 - 22.2 %
# SSB - 2 - 22.2 %
# DWCP - 2 - 22.2 %
# PMSI - 2 - 22.2 %
# PT - 2 - 22.2 %
# EC - 2 - 22.2 %
# ELFE - 1 - 11.1 %

# %%
pl_2016_2022 = pl_2016_2022.drop(["SOARS", "TOGP", "IPAB", "PTIP", "QOES", "AOLT", "FLTA", "EBOF",
                                 "FOWD", "QOMS", "CLER", "WTDA"], axis=1)

# %%
fill_with_mean(pl_2016_2022)

# %%
continuous_data = ['DBP', "DBD", "EDBS", "SSB", "DWCP", "PT", "EC", "IUI", "PMSI"]

# %%
pl_2016_2022_no_o = handle_outliers(pl_2016_2022, continuous_data)
# Out:
# Original Shape: (9, 22)
# DBP: No outliers found
# DBD: No outliers found
# EDBS: Found 2 outliers, replaced with mean = 76.87
# SSB: Found 3 outliers, replaced with mean = 82.76
# DWCP: Found 1 outliers, replaced with mean = 76.95
# PT: Found 2 outliers, replaced with mean = 77.73
# EC: No outliers found
# IUI: No outliers found
# PMSI: No outliers found
#
# Final Shape: (9, 22)
# Total features processed: 9

# %%
pl_2016_2022_no_o.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland_2016_2022.csv')

# %%
pl_2016_2022_no_o = pl_2016_2022_no_o.drop(["TIME_PERIOD"], axis=1)

# %%
pl_2016_2022_no_o
# Out:
#      ROL    GE   COC    RQ   VAA   CPI    FOP     JI   IUI   CFI  ...    DI  \
# 14  0.87  0.77  0.68  1.06  1.11  61.0  0.975  0.957  66.6  40.6  ...  7.47
# 15  0.80  0.74  0.69  0.95  1.04  62.0  0.965  0.874  68.0  40.2  ...  7.09
# 16  0.59  0.65  0.76  0.91  0.84  62.0  0.745  0.783  73.3  40.2  ...  6.83
# 17  0.40  0.55  0.70  0.81  0.78  60.0  0.709  0.690  76.0  42.0  ...  6.67
# 18  0.38  0.55  0.62  0.87  0.71  60.0  0.709  0.595  77.5  41.7  ...  6.67
# 19  0.39  0.51  0.61  1.01  0.67  58.0  0.704  0.572  80.4  41.3  ...  6.62
# 20  0.52  0.32  0.62  0.85  0.62  56.0  0.707  0.570  83.2  40.0  ...  6.85
# 21  0.43  0.25  0.55  0.83  0.58  56.0  0.641  0.542  85.4  39.9  ...  6.80
# 22  0.43  0.26  0.51  0.72  0.60  55.0  0.616  0.570  86.9  37.5  ...  7.04
#
#          EDBS  DBP   DBD        SSB       DWCP  PMSI         PT         EC  \
# 14  76.865271  5.0  37.0  82.757531  76.953037  66.0  77.728363  64.826246
# ...

# %%
pl_2014_2020_l = pl_2016_2022_no_o.loc[20]

# %%
pl_2014_2020_l
# Out:
# ROL      0.520000
# GE       0.320000
# COC      0.620000
# RQ       0.850000
# VAA      0.620000
# CPI     56.000000
# FOP      0.707000
# JI       0.570000
# IUI     83.200000
# CFI     40.000000
# PR      63.000000
# DI       6.850000
# EDBS    76.389916
# DBP      5.000000
# DBD     37.000000
# SSB     82.757531
# DWCP    78.020022
# PMSI    66.000000
# PT      76.831746
# EC      64.363283
# ELFE     5.300000
# Name: 20, dtype: float64

# %%
pl_2014_2020_l.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland_2014_2020_last.csv')

# %%
pl_2022 = pl_2016_2022_no_o.loc[22]

# %%
pl_2022.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland_2022.csv')
