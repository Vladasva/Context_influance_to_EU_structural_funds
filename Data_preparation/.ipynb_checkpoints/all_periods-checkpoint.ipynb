# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
def missing_values(df):
    for feature in df.columns:
        missing_values = df[feature].isna().sum()
        percentage = missing_values/len(df) * 100
        print(f'{feature} - {missing_values} - {round(percentage, 1)} %')
        
def fill_with_mode(df, feature_list):
    for feature in feature_list:
        mode = df[feature].mode()[0]
        df[feature] = df[feature].fillna(mode)

def fill_with_mean(df, feature_list):
    for feature in feature_list:
        df[feature] = pd.to_numeric(df[feature], errors='coerce')
        mean = df[feature].mean()
        df[feature] = df[feature].fillna(mean)
        
        
def y_data(df):
    df = df[(df['TIME_PERIOD'] >= 2007) & (df['TIME_PERIOD'] <= 2022)]
    df_1 = df.copy()
    df_1['GGAG'] = df_1['GGA'].diff()
#     df_1 = df_1.drop(6)
    df_1 = df_1[["TIME_PERIOD", "GDPC", "VABI", "EMP", "PA", "QOA", "QOR", "YUA", "CO2", "REST", "EBSG", "GGFC", "LBGD", "FDI", "PC", "ARP", "PS"]]
    df_1["EMP"] = df_1["EMP"].replace(':', np.nan)
    return df_1

def merge_df(df_1, df_2):
    frames = [df_1, df_2]
    result = pd.concat(frames)
    return result

def needed_context(country_context, needed_context):
    context = country_context[needed_context]
    return context.loc[7:22]

def eu_payments_for_country(eu_payments, country):
    eu_payments = eu_payments.drop(['NUTS1_ID', 'NUTS2 code+name', 'NUTS2_ID', 'NUTS2_name', 'Modelled_annual_expenditure',
                  'Standard_Deviation_of_annual_expenditure', 'Standard_Error_of_modelled_annual_expenditure'], axis=1)
    country_eu_payments = eu_payments[eu_payments['Country'] == country].copy()
    country_eu_payments['EU_Payment_annual'] = pd.to_numeric(country_eu_payments['EU_Payment_annual'].str.replace(',', ''))
    country_eu_payments_all = country_eu_payments.groupby('Year')['EU_Payment_annual'].sum().reset_index()
    country_eu_payments_all = country_eu_payments_all.rename({"Year":"TIME_PERIOD"}, axis=1)
    return country_eu_payments_all

def merge_data(df_1, df_2, df_3):
    df = pd.merge(df_1, df_2, on='TIME_PERIOD', how='outer')
    df = pd.merge(df, df_3, on='TIME_PERIOD', how='outer')
    return df

def fix_eu_payments(df):
    df['EUPC'] = df['EU_Payment_annual'] / (df['PS'] * 1000000)
    df = df.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)
    return df

def co2_per_capita(df):
    df['CO2C'] = df['CO2'] / (df['PS'] * 1000000)
    df = df.drop(['CO2'], axis=1)
    return df

def patents_per_million(df):
    df['PAM'] = df['PA'] / df['PS']
    df = df.drop(['PA'], axis=1)
    return df
    

def standardize_data(df):
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df.values)
    df_scaled = pd.DataFrame(scaled_features, index=df.index, columns=df.columns)
    return df_scaled

# %%
df_dk = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Denmark.csv")
df_de = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Germany.csv")
df_pl = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Poland.csv")
df_lt = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Lithuania.csv")
df_lv = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Latvia.csv")
df_ee = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Estonia.csv")
df_fi = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Finland.csv")
df_se = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Sweden.csv")
dk_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Denmark.csv")
de_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Germany.csv")
pl_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland.csv")
lt_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Lithuania.csv")
lv_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Latvia.csv")
ee_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Estonia.csv")
fi_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Finland.csv")
se_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Sweden.csv")
eu_payments = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Raw_Data/Variables/Historic_EU_payments_annual_timeseries_-_regionalised_and_modelled_20251209.csv")

# %%
df_dk = y_data(df_dk)

# %%
df_dk
# Out:
#     TIME_PERIOD     GDPC   VABI   EMP      PA   QOA   QOR    YUA      CO2  \
# 47         2007  48820.0  22.06   NaN  1660.0  6.45  6.42   7.49  53.8693
# 48         2008  48330.0  22.61   NaN  1634.0  6.44  6.23   9.47  50.6018
# 49         2009  45680.0  19.85  76.1  1518.0  6.43  6.06  13.44  48.4089
# 50         2010  46190.0  19.37  74.9  1626.0  6.37  6.17  15.55  48.5600
# 51         2011  46610.0  19.85  74.8  1574.0  6.32  6.29  16.31  43.4849
# 52         2012  46430.0  19.85  74.3  1406.0  5.97  5.73  15.77  38.5966
# 53         2013  46890.0  19.73  74.3  1341.0  5.64  5.45  14.77  40.3352
# 54         2014  47240.0  19.40  74.7  1377.0  5.56  5.43  14.20  36.1972
# 55         2015  47900.0  19.56  75.4  1462.0  5.58  5.59  12.15  34.0712
# 56         2016  48970.0  20.23  76.0  1552.0  5.80  5.70  12.15  35.6784
# 57         2017  50150.0  20.42  76.6  1490.0  6.10  5.50  12.38  33.5457
# 58         2018  50830.0  20.58  77.5  1262.0  5.80  5.50  10.52  33.5379
# ...

# %%
missing_values(df_dk)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_dk, ["QOR", "QOA"])

# %%
fill_with_mean(df_dk, ["EMP", "PA"])

# %%
df_dk = co2_per_capita(df_dk)

df_dk = patents_per_million(df_dk)

# %%
df_dk
# Out:
#     TIME_PERIOD     GDPC   VABI        EMP   QOA   QOR    YUA    REST  \
# 47         2007  48820.0  22.06  76.414286  6.45  6.42   7.49  17.747
# 48         2008  48330.0  22.61  76.414286  6.44  6.23   9.47  18.543
# 49         2009  45680.0  19.85  76.100000  6.43  6.06  13.44  19.948
# 50         2010  46190.0  19.37  74.900000  6.37  6.17  15.55  21.888
# 51         2011  46610.0  19.85  74.800000  6.32  6.29  16.31  23.389
# 52         2012  46430.0  19.85  74.300000  5.97  5.73  15.77  25.465
# 53         2013  46890.0  19.73  74.300000  5.64  5.45  14.77  27.173
# 54         2014  47240.0  19.40  74.700000  5.56  5.43  14.20  29.310
# 55         2015  47900.0  19.56  75.400000  5.58  5.59  12.15  30.469
# 56         2016  48970.0  20.23  76.000000  5.80  5.70  12.15  31.715
# 57         2017  50150.0  20.42  76.600000  6.10  5.50  12.38  34.387
# 58         2018  50830.0  20.58  77.500000  5.80  5.50  10.52  35.159
# ...

# %%
# context_DFSG = ["TIME_PERIOD", "DI", "CFI", "COC", "CPI", "VAA"]
# context_LLE = ["TIME_PERIOD", "EC", "DI", "CFI", "COC", "CPI"]
# context_Poland = ["TIME_PERIOD", "JI", "FOP", "DBD", "PR", "PT"]
context = ['TIME_PERIOD', 'ROL', 'GE', 'COC', 'RQ', 'SSB', 'PT']

# %%
dk_context = needed_context(dk_context, context)

# %%
dk_context
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ        SSB         PT
# 7          2007  2.00  2.35  2.43  1.93  89.822480  89.509231
# 8          2008  1.95  2.24  2.38  1.87  90.069128  89.265890
# 9          2009  1.92  2.23  2.44  1.88  90.102783  90.558650
# 10         2010  1.90  2.10  2.35  1.87  90.196051  90.980440
# 11         2011  1.92  2.10  2.39  1.90  91.112127  91.037842
# 12         2012  1.88  1.99  2.38  1.80  91.170983  91.680405
# 13         2013  1.90  1.94  2.40  1.80  91.198876  91.832348
# 14         2014  2.10  1.78  2.25  1.68  91.219461  91.834965
# 15         2015  2.02  1.79  2.19  1.72  91.802316  91.834965
# 16         2016  1.88  1.82  2.20  1.56  91.819264  91.142197
# 17         2017  1.80  1.75  2.19  1.61  91.841026  91.142197
# 18         2018  1.77  1.81  2.16  1.63  91.866931  91.142197
# 19         2019  1.83  1.87  2.12  1.55  91.889599  91.142197
# 20         2020  1.81  1.84  2.24  1.79  92.076386  91.142197
# ...

# %%
missing_values(dk_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(dk_context, ["DI"])

# %%
fill_with_mean(dk_context, ["SSB", "PT"])

# %%
dk_payments = eu_payments_for_country(eu_payments, "DK")

# %%
dk = merge_data(df_dk, dk_context, dk_payments)

# %%
dk = fix_eu_payments(dk)

# %%
dk.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
dk.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/dk_bn.csv')

# %%
dk_scaled = standardize_data(dk)

# %%
dk_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/dk_tcdf.csv')

# %%
column_index = dk_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
12,0,3
10,1,2
12,3,3
22,4,3
6,4,2
6,5,0
9,6,0
10,7,0
5,8,2
8,8,1
9,10,3
22,11,0
11,11,4
1,11,1
12,13,0
14,14,1
11,22,3
10,22,2
# Out:
# (10, 22, 2)

# %%
dk_scaled
# Out:
#         GDPC      VABI       EMP       QOA       QOR       YUA      REST  \
# 0  -0.044236  1.993087  0.000000  1.507482  1.967246 -1.983317 -1.547192
# 1  -0.248239  2.606130  0.000000  1.475493  1.400381 -1.170806 -1.439399
# 2  -1.351525 -0.470232 -0.187326  1.443504  0.893186  0.458320 -1.249136
# 3  -1.139195 -1.005251 -0.902573  1.251570  1.221371  1.324177 -0.986423
# 4  -0.964334 -0.470232 -0.962177  1.091625  1.579391  1.636050 -0.783160
# 5  -1.039275 -0.470232 -1.260196 -0.027990 -0.091370  1.414456 -0.502031
# 6  -0.847761 -0.603987 -1.260196 -1.083627 -0.926750  1.004097 -0.270736
# 7  -0.702044 -0.971813 -1.021781 -1.339539 -0.986420  0.770193  0.018654
# 8  -0.427263 -0.793473 -0.604554 -1.275561 -0.509060 -0.071043  0.175604
# 9   0.018215 -0.046675 -0.246930 -0.571803 -0.180875 -0.071043  0.344336
# 10  0.509489  0.165104  0.110693  0.387867 -0.777575  0.023339  0.706175
# 11  0.792597  0.343443  0.647128 -0.571803 -0.777575 -0.739929  0.810718
# ...

# %%
df_de = y_data(df_de)

# %%
missing_values(df_de)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mean(df_de, ["EMP", "PA", "QOR", "QOA"])

# %%
df_de = co2_per_capita(df_de)

df_de = patents_per_million(df_de)

# %%
de_context = needed_context(de_context, context)

# %%
de_context
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ        SSB         PT
# 7          2007  1.76  1.63  1.73  1.62  78.044700  77.197929
# 8          2008  1.73  1.51  1.75  1.49  79.197611  76.399686
# 9          2009  1.65  1.58  1.75  1.52  79.363510  76.198556
# 10         2010  1.64  1.52  1.77  1.57  79.567065  78.957718
# 11         2011  1.62  1.50  1.74  1.55  80.744231  76.428017
# 12         2012  1.67  1.53  1.82  1.53  80.867728  76.817402
# 13         2013  1.64  1.51  1.80  1.54  80.918824  79.063708
# 14         2014  1.85  1.66  1.81  1.70  80.997172  76.843778
# 15         2015  1.76  1.66  1.78  1.71  80.627202  77.020556
# 16         2016  1.58  1.66  1.78  1.81  81.991794  82.167297
# 17         2017  1.57  1.61  1.80  1.78  82.202748  82.157760
# 18         2018  1.59  1.52  1.90  1.76  82.214093  82.140949
# 19         2019  1.58  1.50  1.87  1.71  82.338520  82.105637
# 20         2020  1.52  1.31  1.83  1.58  82.418073  82.330087
# ...

# %%
fill_with_mean(de_context, ["SSB", "PT"])

# %%
de_payments = eu_payments_for_country(eu_payments, "DE")

# %%
de = merge_data(df_de, de_context, de_payments)

# %%
de = fix_eu_payments(de)

# %%
de.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/de_bn.csv')

# %%
de
# Out:
#        GDPC   VABI        EMP       QOA       QOR    YUA    REST      EBSG  \
# 0   35330.0  26.46  77.264286  6.710000  6.550000  11.82  10.039  6.389770
# 1   35750.0  26.06  77.264286  6.670000  6.540000  10.93  10.072  5.783688
# 2   33880.0  23.87  73.200000  6.610000  6.490000  11.31  10.851  4.768184
# 3   35370.0  26.06  74.000000  6.610000  6.420000  10.42  11.667  5.103897
# 4   36700.0  26.31  75.400000  6.450000  6.150000   8.93  12.470  4.852664
# 5   36820.0  26.58  75.800000  6.350000  6.090000   8.12  13.549  6.037145
# 6   36910.0  25.91  76.300000  6.080000  6.010000   7.82  13.757  5.772928
# 7   37600.0  26.01  76.700000  5.940000  5.880000   7.61  14.381  6.537450
# 8   37950.0  25.92  77.000000  5.950000  5.720000   7.33  14.901  7.417530
# 9   38550.0  26.22  77.600000  5.900000  5.600000   7.08  14.885  7.263048
# 10  39540.0  26.12  78.300000  5.800000  5.500000   6.77  15.472  7.085326
# ...

# %%
de_scaled = standardize_data(de)

# %%
de_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/de_tcdf.csv')

# %%
de_scaled
# Out:
#         GDPC      VABI           EMP           QOA           QOR       YUA  \
# 0  -1.216359  1.012551  7.146179e-15  1.487576e+00  1.508163e+00  1.935508
# 1  -1.006663  0.357311  7.146179e-15  1.378010e+00  1.481668e+00  1.463077
# 2  -1.940308 -3.230130 -2.043798e+00  1.213660e+00  1.349195e+00  1.664789
# 3  -1.196388  0.357311 -1.641504e+00  1.213660e+00  1.163731e+00  1.192358
# 4  -0.532352  0.766836 -9.374890e-01  7.753937e-01  4.483729e-01  0.401434
# 5  -0.472439  1.209123 -7.363420e-01  5.014775e-01  2.894043e-01 -0.028532
# 6  -0.427504  0.111596 -4.849081e-01 -2.380964e-01  7.744622e-02 -0.187778
# 7  -0.083004  0.275406 -2.837610e-01 -6.215792e-01 -2.669857e-01 -0.299251
# 8   0.091742  0.127977 -1.329007e-01 -5.941876e-01 -6.909018e-01 -0.447881
# 9   0.391307  0.619407  1.688199e-01 -7.311457e-01 -1.008839e+00 -0.580586
# 10  0.885589  0.455597  5.208272e-01 -1.005062e+00 -1.273787e+00 -0.745141
# ...

# %%
de.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = de_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
2,1,0
4,1,1
21,2,2 
18,2,1
12,4,0 
7,6,0
23,7,0
18,8,2
4,8,0
17,12,3 
4,12,3
20,15,2
11,16,3
12,16,3
20,16,3
12,17,3
8,18,1
23,19,2
18,21,0
17,22,0
21,23,1
5,23,0
20,23,0
# Out:
# (20, 23, 0)

# %%
df_pl = y_data(df_pl)

# %%
missing_values(df_pl)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
# fill_with_mode(df_pl, ["PDPS", "FEM"])

# %%
fill_with_mean(df_pl, ["EMP", "PA", "QOR", "QOA"])

# %%
df_pl = co2_per_capita(df_pl)

df_pl = patents_per_million(df_pl)

# %%
pl_context = needed_context(pl_context, context)

# %%
missing_values(pl_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(pl_context, ["DBD"])

# %%
fill_with_mean(pl_context, ["SSB", "PT"])

# %%
pl_payments = eu_payments_for_country(eu_payments, "PL")

# %%
pl = merge_data(df_pl, pl_context, pl_payments)

# %%
pl = fix_eu_payments(pl)

# %%
pl.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/pl_bn.csv')

# %%
pl_scaled = standardize_data(pl)

# %%
pl_scaled
# Out:
#         GDPC      VABI       EMP           QOA       QOR       YUA      REST  \
# 0  -1.415421 -0.232693  0.000000 -1.118578e+00 -0.728098  0.520081 -1.680168
# 1  -1.216854 -0.819207  0.000000 -9.564048e-01 -1.593346 -0.204906 -1.415219
# 2  -1.099751  0.634328 -1.157587 -8.212606e-01 -1.396699  0.364606 -1.080226
# 3  -0.931734  0.302820 -1.243562 -1.064520e+00 -1.173832  0.890180 -0.875508
# 4  -0.672070  1.182591 -1.179081 -1.064520e+00 -1.042734  1.219720 -0.518182
# 5  -0.595699  0.978586 -1.093106 -6.320588e-01 -0.662549  1.351535 -0.309065
# 6  -0.554967 -0.997711 -1.028625 -3.617705e-01 -0.098828  1.495181 -0.140892
# 7  -0.341127  0.608827 -0.663233 -6.445337e-02  0.556663  0.915529 -0.089120
# 8  -0.091646  1.947609 -0.362322  7.069079e-02  0.897518  0.400095  0.004272
# 9   0.086554  1.539599  0.046058  6.923539e-01  1.146604 -0.122099 -0.159841
# 10  0.392041 -0.831957  0.432944  1.232931e+00  1.277702 -0.600354 -0.273874
# ...

# %%
pl_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/pl_tcdf.csv')

# %%
pl_scaled.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = de_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
8,2,3
23,4,2
12,4,1
23,8,0
10,8,1
2,8,1
16,9,0
19,12,2
2,12,0
22,12,1
8,13,1
13,14,0
12,17,2
0,19,0
8,20,0
23,20,0 
9,21,3
16,23,1
# Out:
# (16, 23, 1)

# %%
df_lt = y_data(df_lt)

# %%
missing_values(df_lt)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
df_lt
# Out:
#     TIME_PERIOD     GDPC   VABI   EMP     PA   QOA   QOR    YUA      CO2  \
# 47         2007  10720.0  29.65   NaN   62.0  4.40  4.97   8.39  15.5684
# 48         2008  11110.0  29.20   NaN   87.0  4.61  5.21  13.35  15.8313
# 49         2009   9570.0  25.02  67.0   91.0  4.22  5.28  29.58  13.2105
# 50         2010   9810.0  26.21  64.3  108.0  3.57  5.27  35.74  14.0410
# 51         2011  10670.0  28.35  66.9   93.0  3.73  5.23  32.59  14.3203
# 52         2012  11280.0  28.20  68.5  109.0  4.23  5.17  26.68  14.4911
# 53         2013  11850.0  27.62  69.9  117.0  4.32  5.02  21.90  13.3644
# 54         2014  12400.0  27.73  71.8  123.0  4.19  4.94  19.26  13.2117
# 55         2015  12860.0  26.96  73.3  101.0  4.12  4.96  16.30  13.6606
# 56         2016  13360.0  26.00  75.2   95.0  4.40  4.90  14.45  13.5202
# 57         2017  14150.0  25.72  76.0   81.0  4.40  4.70  13.27  13.9642
# 58         2018  14970.0  25.58  77.8   81.0  4.60  4.70  11.12  14.0184
# ...

# %%
fill_with_mean(df_lt, ["EMP","PA", "QOR", "QOA"])

# %%
df_lt = co2_per_capita(df_lt)

df_lt = patents_per_million(df_lt)

# %%
lt_context = needed_context(lt_context, context)

# %%
missing_values(lt_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(lt_context, ["DBD"])

# %%
fill_with_mean(lt_context, ["SSB", "PT"])

# %%
lt_payments = eu_payments_for_country(eu_payments, "LT")

# %%
lt = merge_data(df_lt, lt_context, lt_payments)

# %%
lt = fix_eu_payments(lt)

# %%
lt
# Out:
#        GDPC   VABI   EMP       QOA       QOR    YUA    REST       EBSG  \
# 0   10720.0  29.65  73.0  4.400000  4.970000   8.39  16.482 -13.094653
# 1   11110.0  29.20  73.0  4.610000  5.210000  13.35  17.824 -11.598256
# 2    9570.0  25.02  67.0  4.220000  5.280000  29.58  19.798  -1.755188
# 3    9810.0  26.21  64.3  3.570000  5.270000  35.74  19.639  -2.029481
# 4   10670.0  28.35  66.9  3.730000  5.230000  32.59  19.943  -2.706873
# 5   11280.0  28.20  68.5  4.230000  5.170000  26.68  21.437   0.613211
# 6   11850.0  27.62  69.9  4.320000  5.020000  21.90  22.689   1.457239
# 7   12400.0  27.73  71.8  4.190000  4.940000  19.26  23.592   1.930309
# 8   12860.0  26.96  73.3  4.120000  4.960000  16.30  25.748  -0.986813
# 9   13360.0  26.00  75.2  4.400000  4.900000  14.45  25.612   0.728400
# 10  14150.0  25.72  76.0  4.400000  4.700000  13.27  26.038   2.294288
# 11  14970.0  25.58  77.8  4.600000  4.700000  11.12  24.695   1.856906
# ...

# %%
lt.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lt_bn.csv')

# %%
lt_scaled = standardize_data(lt)

# %%
lt_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lt_tcdf.csv')

# %%
lt_scaled.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = lt_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
9,1,0
23,4,3
8,4,0
5,4,0
20,4,3
13,5,0
11,7,0
12,8,0
10,8,0
22,11,0
13,14,0
1,15,1
16,16,4
23,16,1
12,23,3
22,23,0
11,23,3
# Out:
# (11, 23, 3)

# %%
df_lv = y_data(df_lv)

# %%
missing_values(df_lv)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mean(df_lv, ["EMP", "PA", "QOR", "QOA"])

# %%
df_lv = co2_per_capita(df_lv)

df_lv = patents_per_million(df_lv)

# %%
lv_context = needed_context(lv_context, context)

# %%
missing_values(lv_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
lv_context
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ        SSB         PT
# 7          2007  0.72  0.43  0.34  0.95  88.154100  81.115239
# 8          2008  0.78  0.52  0.23  0.97  88.467773  83.228626
# 9          2009  0.79  0.62  0.20  0.92  89.002428  83.043921
# 10         2010  0.76  0.72  0.20  0.93  89.196552  82.613206
# 11         2011  0.74  0.69  0.28  0.95  89.163024  81.896887
# 12         2012  0.78  0.83  0.24  1.01  91.495552  82.315191
# 13         2013  0.76  0.88  0.32  1.04  91.532399  84.229882
# 14         2014  0.87  0.95  0.41  1.17  92.332633  84.865341
# 15         2015  0.77  1.05  0.43  1.07  92.038243  86.462455
# 16         2016  0.93  0.97  0.40  1.07  94.107515  89.093857
# 17         2017  0.90  0.87  0.50  1.14  94.112781  90.040534
# 18         2018  0.92  1.00  0.30  1.13  94.113949  90.040534
# 19         2019  0.98  1.07  0.48  1.18  94.116764  89.990298
# 20         2020  0.92  0.84  0.69  1.18  94.137989  89.188135
# ...

# %%
fill_with_mean(lv_context, ["SSB", "PT"])

# %%
lv_payments = eu_payments_for_country(eu_payments, "LV")

# %%
lv = merge_data(df_lv, lv_context, lv_payments)

# %%
lv = fix_eu_payments(lv)

# %%
lv.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lv_bn.csv')

# %%
lv_scaled = standardize_data(lv)

# %%
lv_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lv_tcdf.csv')

# %%
lv_scaled.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = lv_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
10,1,0
8,4,3
17,4,0
23,5,0
23,6,2
12,6,3
10,8,0
21,12,0
1,12,1
2,12,3
1,14,1
13,14,0
18,16,1
20,23,0
# Out:
# (20, 23, 0)

# %%
df_ee = y_data(df_ee)

# %%
missing_values(df_ee)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_ee, ["QOR", "QOA"])

# %%
fill_with_mean(df_ee, ["EMP", "PA"])

# %%
df_ee = co2_per_capita(df_ee)

df_ee = patents_per_million(df_ee)

# %%
ee_context = needed_context(ee_context, context)

# %%
missing_values(ee_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(ee_context, ["DBD"])

# %%
fill_with_mean(ee_context, ["SSB", "PT"])

# %%
ee_payments = eu_payments_for_country(eu_payments, "EE")

# %%
ee = merge_data(df_ee, ee_context, ee_payments)

# %%
ee = fix_eu_payments(ee)

# %%
ee.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/ee_bn.csv')

# %%
ee_scaled = standardize_data(ee)

# %%
ee_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/ee_tcdf.csv')

# %%
ee_scaled
# Out:
#         GDPC      VABI       EMP       QOA       QOR       YUA      REST  \
# 0  -0.226219  2.236931  0.000000  1.171421 -2.386756 -1.200121 -1.900719
# 1  -0.612028  1.701951  0.000000  1.456580 -1.607407 -0.879507 -1.596798
# 2  -1.718691 -0.445502 -1.433676  0.860338 -0.828058  1.675435 -0.833725
# 3  -1.546092  0.119617 -2.182804  0.030784  0.270115  2.594084 -0.549072
# 4  -1.013066  1.114227 -1.304516 -0.383993  0.128415  0.841507 -0.378208
# 5  -0.723710  0.571712 -0.762044 -0.202528 -0.828058  0.587342 -0.365302
# 6  -0.561264  0.609387 -0.503724 -1.032082 -0.898908  0.228520 -0.407109
# 7  -0.282060  0.179896 -0.271236 -1.965329 -0.225834 -0.389450 -0.266419
# 8  -0.119614 -0.566061  0.167908 -2.094947  0.270115 -0.495768  0.252900
# 9   0.113903 -0.483177  0.245404 -0.098834  0.872339 -0.530653  0.297434
# 10  0.586011 -0.520852  0.813708  1.456580  0.872339 -0.854589  0.353055
# 11  0.890597 -0.437967  0.942868  0.160402  0.872339 -0.871201  0.431580
# ...

# %%
ee_scaled.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = ee_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
3,2,0
17,4,1
17,5,3
14,7,0
10,8,1
14,9,1
23,10,2
6,11,0
9,11,0
14,12,2
22,12,0
14,13,0
10,14,3
13,14,0
12,15,0
14,18,0
17,20,2
6,21,0
21,23,0
# Out:
# (21, 23, 0)

# %%
df_fi = y_data(df_fi)

# %%
missing_values(df_fi)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_fi, ["QOR"])

# %%
fill_with_mean(df_fi, ["EMP", "PA", "QOA"])

# %%
df_fi = co2_per_capita(df_fi)

df_fi = patents_per_million(df_fi)

# %%
fi_context = needed_context(fi_context, context)

# %%
missing_values(fi_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
fill_with_mean(fi_context, ["SSB", "PT"])

# %%
fi_payments = eu_payments_for_country(eu_payments, "FI")

# %%
fi = merge_data(df_fi, fi_context, fi_payments)

# %%
fi = fix_eu_payments(fi)

# %%
fi.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/fi_bn.csv')

# %%
fi_scaled = standardize_data(fi)

# %%
fi_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/fi_tcdf.csv')

# %%
fi_scaled.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = fi_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
20,2,0
5,4,2
17,5,1
8,8,1
12,8,0
23,8,1
8,12,0
1,12,1
12,12,1
13,14,0
12,19,1
11,20,2
14,20,0
14,21,1
19,21,0
19,22,0
17,23,3
# Out:
# (17, 23, 3)

# %%
df_se = y_data(df_se)

# %%
missing_values(df_se)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 0 - 0.0 %
# PA - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# REST - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# FDI - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_se, ["QOR"])

# %%
fill_with_mean(df_se, ["QOA", "PA"])

# %%
df_se = co2_per_capita(df_se)

df_se = patents_per_million(df_se)

# %%
se_context = needed_context(se_context, context)

# %%
missing_values(se_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
fill_with_mean(se_context, ["SSB", "PT"])

# %%
se_payments = eu_payments_for_country(eu_payments, "SE")

# %%
se = merge_data(df_se, se_context, se_payments)

# %%
se = fix_eu_payments(se)

# %%
se.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/se_bn.csv')

# %%
se_scaled = standardize_data(se)

# %%
se_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/se_tcdf.csv')

# %%
se_scaled.columns
# Out:
# Index(['GDPC', 'VABI', 'EMP', 'QOA', 'QOR', 'YUA', 'REST', 'EBSG', 'GGFC',
#        'LBGD', 'FDI', 'PC', 'ARP', 'CO2C', 'PAM', 'ROL', 'GE', 'COC', 'RQ',
#        'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = se_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 21

# %%
14,1,1
8,4,0
20,5,3
17,6,2
15,7,2
14,7,0
16,8,1
8,8,1
0,9,0
18,11,1
23,12,0
14,13,3
16,13,0
17,15,0
23,15,1
9,16,0
0,16,0
0,17,0
16,20,0 
0,20,1
# Out:
# (0, 20, 1)
