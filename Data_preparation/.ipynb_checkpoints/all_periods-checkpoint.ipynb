# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
def missing_values(df):
    for feature in df.columns:
        missing_values = df[feature].isna().sum()
        percentage = missing_values/len(df) * 100
        print(f'{feature} - {missing_values} - {round(percentage, 1)} %')
        
def fill_with_mode(df, feature_list):
    for feature in feature_list:
        mode = df[feature].mode()[0]
        df[feature].fillna(value=mode, inplace=True)

def fill_with_mean(df, feature_list):
    for feature in feature_list:
        df[feature] = pd.to_numeric(df[feature], errors='coerce')
        mean = df[feature].mean()
        df[feature].fillna(value=mean, inplace=True)
        
def y_data(df):
    df = df.loc[6:22]
    df_1 = df.copy()
#     df_1['LFG'] = df_1['LF'].diff()
#     df_1['EPFRG'] = df_1['EPFR'].diff()
    df_1['GGAG'] = df_1['GGA'].diff()
    df_1['PAG'] = df_1['PA'].diff()
    df_1 = df_1.drop(6)
#     df_1 = df_1.drop(["Unnamed: 0", "REF_AREA_LABEL", "HI", "OCTB", "NINA", "LF", "EPFR", "GGA", "EIA", "GDP",
#                      "UR", "URFF", "YUA", "P014", "P65"], axis=1)
    df_1 = df_1[["TIME_PERIOD", "GDPC", "GDPCG", "VABI", "EMP", "PAG", "QOA", "QOR", "YUA", "GGAG", "REST", "CO2", "EBSG", "FDI", "GGFC", "LBGD", "PC", "ARP", "PS"]]
    df_1["EMP"] = df_1["EMP"].replace(':', np.nan)
#     df_1["LTU"] = df_1["LTU"].replace(':', np.nan)
#     df_1["FEM"] = df_1["FEM"].replace(':', np.nan)
    return df_1

def merge_df(df_1, df_2):
    frames = [df_1, df_2]
    result = pd.concat(frames)
    return result

def needed_context(country_context, needed_context):
    context = country_context[needed_context]
    return context.loc[7:22]

def eu_payments_for_country(eu_payments, country):
    eu_payments = eu_payments.drop(['NUTS1_ID', 'NUTS2 code+name', 'NUTS2_ID', 'NUTS2_name', 'Modelled_annual_expenditure',
                  'Standard_Deviation_of_annual_expenditure', 'Standard_Error_of_modelled_annual_expenditure'], axis=1)
    country_eu_payments = eu_payments[eu_payments['Country'] == country].copy()
    country_eu_payments['EU_Payment_annual'] = pd.to_numeric(country_eu_payments['EU_Payment_annual'].str.replace(',', ''))
    country_eu_payments_all = country_eu_payments.groupby('Year')['EU_Payment_annual'].sum().reset_index()
    country_eu_payments_all = country_eu_payments_all.rename({"Year":"TIME_PERIOD"}, axis=1)
    return country_eu_payments_all

def merge_data(df_1, df_2, df_3):
    df = pd.merge(df_1, df_2, on='TIME_PERIOD', how='outer')
    df = pd.merge(df, df_3, on='TIME_PERIOD', how='outer')
    return df

def fix_eu_payments(df):
    df['EUPC'] = df['EU_Payment_annual'] / (df['PS'] * 1000000)
    df = df.drop(['TIME_PERIOD', 'PS', 'EU_Payment_annual'], axis=1)
    return df

def standardize_data(df):
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df.values)
    df_scaled = pd.DataFrame(scaled_features, index=df.index, columns=df.columns)
    return df_scaled

# %%
df_dk = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Denmark.csv")
df_de = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Germany.csv")
df_pl = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Poland.csv")
df_lt = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Lithuania.csv")
df_lv = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Latvia.csv")
df_ee = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Estonia.csv")
df_fi = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Finland.csv")
df_se = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/Sweden.csv")
dk_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Denmark.csv")
de_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Germany.csv")
pl_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Poland.csv")
lt_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Lithuania.csv")
lv_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Latvia.csv")
ee_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Estonia.csv")
fi_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Finland.csv")
se_context = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/Context/Sweden.csv")
eu_payments = pd.read_csv("/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Raw_Data/Variables/Historic_EU_payments_annual_timeseries_-_regionalised_and_modelled_20251209.csv")

# %%
df_dk = y_data(df_dk)

# %%
missing_values(df_dk)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_dk, ["QOR", "QOA"])

# %%
fill_with_mean(df_dk, ["EMP", "PAG", "GGAG"])

# %%
# context_DFSG = ["TIME_PERIOD", "DI", "CFI", "COC", "CPI", "VAA"]
# context_LLE = ["TIME_PERIOD", "EC", "DI", "CFI", "COC", "CPI"]
# context_Poland = ["TIME_PERIOD", "JI", "FOP", "DBD", "PR", "PT"]
context = ['TIME_PERIOD', 'ROL', 'GE', 'COC', 'RQ', 'SSB', 'PT']

# %%
dk_context = needed_context(dk_context, context)

# %%
dk_context
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ        SSB         PT
# 7          2007  2.00  2.35  2.43  1.93  89.822480  89.509231
# 8          2008  1.95  2.24  2.38  1.87  90.069128  89.265890
# 9          2009  1.92  2.23  2.44  1.88  90.102783  90.558650
# 10         2010  1.90  2.10  2.35  1.87  90.196051  90.980440
# 11         2011  1.92  2.10  2.39  1.90  91.112127  91.037842
# 12         2012  1.88  1.99  2.38  1.80  91.170983  91.680405
# 13         2013  1.90  1.94  2.40  1.80  91.198876  91.832348
# 14         2014  2.10  1.78  2.25  1.68  91.219461  91.834965
# 15         2015  2.02  1.79  2.19  1.72  91.802316  91.834965
# 16         2016  1.88  1.82  2.20  1.56  91.819264  91.142197
# 17         2017  1.80  1.75  2.19  1.61  91.841026  91.142197
# 18         2018  1.77  1.81  2.16  1.63  91.866931  91.142197
# 19         2019  1.83  1.87  2.12  1.55  91.889599  91.142197
# 20         2020  1.81  1.84  2.24  1.79  92.076386  91.142197
# 21         2021  1.90  1.96  2.33  1.80        NaN        NaN
# 22         2022  1.90  1.99  2.40  1.84        NaN        NaN

# %%
missing_values(dk_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(dk_context, ["DI"])

# %%
fill_with_mean(dk_context, ["SSB", "PT"])

# %%
dk_payments = eu_payments_for_country(eu_payments, "DK")

# %%
dk = merge_data(df_dk, dk_context, dk_payments)

# %%
dk = fix_eu_payments(dk)

# %%
dk.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
dk.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/dk_bn.csv')

# %%
dk_scaled = standardize_data(dk)

# %%
dk_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/dk_tcdf.csv')

# %%
column_index = dk_scaled.columns.get_loc('GGAG')
print(column_index)
# Out:
# 8

# %%
8,1,0
10,2,2
6,4,2
4,4,2
17,8,3
8,8,
1,12,1
1,14,0
16,17,2
9,22,0
# Out:
# (9, 22, 0)

# %%
df_de = y_data(df_de)

# %%
missing_values(df_de)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mean(df_de, ["EMP", "PAG", "GGAG", "QOR", "QOA"])

# %%
de_context = needed_context(de_context, context)

# %%
de_context
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ        SSB         PT
# 7          2007  1.76  1.63  1.73  1.62  78.044700  77.197929
# 8          2008  1.73  1.51  1.75  1.49  79.197611  76.399686
# 9          2009  1.65  1.58  1.75  1.52  79.363510  76.198556
# 10         2010  1.64  1.52  1.77  1.57  79.567065  78.957718
# 11         2011  1.62  1.50  1.74  1.55  80.744231  76.428017
# 12         2012  1.67  1.53  1.82  1.53  80.867728  76.817402
# 13         2013  1.64  1.51  1.80  1.54  80.918824  79.063708
# 14         2014  1.85  1.66  1.81  1.70  80.997172  76.843778
# 15         2015  1.76  1.66  1.78  1.71  80.627202  77.020556
# 16         2016  1.58  1.66  1.78  1.81  81.991794  82.167297
# 17         2017  1.57  1.61  1.80  1.78  82.202748  82.157760
# 18         2018  1.59  1.52  1.90  1.76  82.214093  82.140949
# 19         2019  1.58  1.50  1.87  1.71  82.338520  82.105637
# 20         2020  1.52  1.31  1.83  1.58  82.418073  82.330087
# 21         2021  1.57  1.29  1.78  1.63        NaN        NaN
# 22         2022  1.53  1.29  1.82  1.52        NaN        NaN

# %%
fill_with_mean(de_context, ["SSB", "PT"])

# %%
de_payments = eu_payments_for_country(eu_payments, "DE")

# %%
de = merge_data(df_de, de_context, de_payments)

# %%
de = fix_eu_payments(de)

# %%
de.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/de_bn.csv')

# %%
de_scaled = standardize_data(de)

# %%
de_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y
# 4  -0.043073 -0.237235 -0.144862 -1.243934 -0.753661 -0.062380 -1.088955
# 5   0.473804  0.320965  0.103473  0.545095 -0.951343  0.038037 -0.923306
# 6   0.473804 -0.013955 -0.062084  0.097838 -0.852502  0.079584  0.032296
# 7   1.507557  2.330485  1.179591  0.321466  0.728951  0.143290 -0.912085
# 8   1.507557  1.325725  1.179591 -0.349420  0.827792 -0.157537 -0.836882
# 9   1.162972 -0.683795  1.179591 -0.349420  1.816199  0.952027  1.352595
# 10  0.473804 -0.795435  0.765699  0.097838  1.519677  1.123556  1.348538
# 11  0.301511 -0.572155  0.020695  2.334124  1.321996  1.132781  1.341386
# 12 -1.765995 -0.683795 -0.144862  1.663238  0.827792  1.233954  1.326364
# 13  0.473804 -1.353635 -1.717650  0.768723 -0.457139  1.298639  1.421847
# 14  0.301511 -0.795435 -1.883207 -0.349420  0.037065  0.000000  0.000000
# 15 -1.765995 -1.241995 -1.883207  0.545095 -1.050183  0.000000  0.000000
#
#         EUPC
# 0  -1.885554
# 1  -1.575685
# 2   0.696700
# 3   0.436416
# 4   0.847532
# 5   0.933917
# 6   1.890205
# 7   0.801911
# 8  -0.116677
# 9  -1.658277
# 10 -0.586843
# 11 -0.281368
# 12 -0.086931
# 13 -0.118162
# 14  0.241711
# 15  0.461103
#
# [16 rows x 24 columns]

# %%
de.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = de_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 23

# %%
2,1,0
4,1,1
21,2,2 
18,2,1
12,4,0 
7,6,0
23,7,0
18,8,2
4,8,0
17,12,3 
4,12,3
20,15,2
11,16,3
12,16,3
20,16,3
12,17,3
8,18,1
23,19,2
18,21,0
17,22,0
21,23,1
5,23,0
20,23,0

# %%
df_pl = y_data(df_pl)

# %%
missing_values(df_pl)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
# fill_with_mode(df_pl, ["PDPS", "FEM"])

# %%
fill_with_mean(df_pl, ["EMP", "PAG", "GGAG", "QOR", "QOA"])

# %%
pl_context = needed_context(pl_context, context)

# %%
missing_values(pl_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(pl_context, ["DBD"])

# %%
fill_with_mean(pl_context, ["SSB", "PT"])

# %%
pl_payments = eu_payments_for_country(eu_payments, "PL")

# %%
pl = merge_data(df_pl, pl_context, pl_payments)

# %%
pl = fix_eu_payments(pl)

# %%
pl.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y
# 13 -1.264503 -1.384630e+00  1.432561  ... -1.991291 -3.733962 -1.195641
# 14 -1.098888  4.472425e-17  1.264049  ...  0.502128 -0.509275 -1.195641
# 15 -1.311822  4.472425e-17  1.615961  ...  0.131312 -0.283894 -2.051059
#
#          ROL        GE       COC        RQ       SSB        PT      EUPC
# 0  -1.062459 -1.085532 -2.552775 -1.429553 -2.122321 -1.554977 -1.830687
# 1  -0.274410 -0.449323 -1.109210 -0.736436 -2.061568 -1.565233 -1.621839
# 2   0.288482 -0.067597 -1.194126  0.649797 -1.830870 -1.650553 -0.841057
# 3   0.626217  0.632233 -0.599716  1.045863  0.213607 -1.390884 -0.388894
# 4   1.076531  0.441370 -0.175138  0.451763  0.222691 -0.350874  0.287872
# 5   1.245398  0.823096  0.674018  0.847830  0.232469 -0.176970  0.468269
# 6   1.357977  0.823096  0.589102  1.342913  0.282374  0.463032  0.569487
# 7   1.526844  1.522926  0.843849  1.441930  0.699236  0.474145  0.892184
# 8   1.132820  1.332063  0.928764  0.352747  0.703514  0.470821 -0.490514
# 9  -0.049253  0.759475  1.523173 -0.043320  0.721521  1.147557 -1.433209
# 10 -1.118748  0.123266  1.013680 -1.033486  0.726517  1.144076 -0.457070
# 11 -1.231326  0.123266  0.334355 -0.439386  0.729779  1.182420  0.688353
# 12 -1.175037 -0.131218  0.249440  0.946847  0.737903  0.886956  0.642728
# 13 -0.443277 -1.340016  0.334355 -0.637420  0.745150  0.920483  1.040884
# 14 -0.949880 -1.785362 -0.260054 -0.835453  0.000000  0.000000  1.556198
# 15 -0.949880 -1.721741 -0.599716 -1.924636  0.000000  0.000000  0.917295
#
# [16 rows x 24 columns]

# %%
pl_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/pl_tcdf.csv')

# %%
pl_scaled.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = de_scaled.columns.get_loc('EUPC')
print(column_index

# %%
8,2,3
23,4,2
12,4,1
23,8,0
10,8,1
2,8,1
16,9,0
19,12,2
2,12,0
22,12,1
8,13,1
13,14,0
12,17,2
0,19,0
8,20,0
23,20,0 
9,21,3
16,23,1

# %%
df_lt = y_data(df_lt)

# %%
missing_values(df_lt)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %

# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(lt_context, ["DBD"])

# %%
fill_with_mean(lt_context, ["SSB", "PT"])

# %%
lt_payments = eu_payments_for_country(eu_payments, "LT")

# %%
lt = merge_data(df_lt, lt_context, lt_payments)

# %%
lt = fix_eu_payments(lt)

# %%
lt
# Out:
#             GDPC      GDPCG   VABI   EMP        PAG       QOA       QOR  \
# 0    8985.274630  12.405345  29.65  73.0  -3.000000  4.400000  4.970000
# 1   10219.116755   3.660125  29.20  73.0  25.000000  4.610000  5.210000
# 2    8528.034573 -13.887757  25.02  67.0   4.000000  4.220000  5.280000
# 3    8931.519313   2.555336  26.21  64.3  17.000000  3.570000  5.270000
# 4   10259.331961   8.752239  28.35  66.9 -15.000000  3.730000  5.230000
# 5   11120.403233   5.743976  28.20  68.5  16.000000  4.230000  5.170000
# 6   11776.792571   5.026825  27.62  69.9   8.000000  4.320000  5.020000
# 7   12395.979849   4.620353  27.73  71.8   6.000000  4.190000  4.940000
# 8   12861.323296   3.756324  26.96  73.3 -22.000000  4.120000  4.960000
# 9   13491.939909   3.877441  26.00  75.2  -6.000000  4.400000  4.900000
# 10  14871.586227   5.888726  25.72  76.0 -14.000000  4.400000  4.700000
# 11  16298.029583   5.790665  25.58  77.8   0.000000  4.600000  4.700000
# 12  17516.070462   4.979384  25.26  78.2   9.000000  4.900000  4.800000
# 13  17885.411844   0.068446  24.79  76.7   5.000000  4.283846  5.011538
# 14  20182.333587   6.455358  24.86  77.4 -14.000000  4.283846  5.011538
# 15  23822.056413   1.695286  25.64  79.0   1.066667  4.283846  5.011538
#
#       YUA         GGAG    REST  ...      LBGD    PC   ARP   ROL    GE   COC  \
# 0    8.39  1013.000000  16.482  ... -0.493558 -11.6  19.1  0.69  0.66  0.10
# 1   13.35  -563.000000  17.824  ... -2.844590  -9.0  20.9  0.68  0.56  0.11
# 2   29.58 -3576.000000  19.798  ... -8.626258 -13.2  20.3  0.72  0.69  0.23
# 3   35.74   806.000000  19.639  ... -7.016844 -28.9  20.5  0.78  0.74  0.37
# 4   32.59  -532.000000  19.943  ... -5.541350 -16.2  19.2  0.77  0.70  0.32
# 5   26.68   -81.000000  21.437  ... -2.893765  -9.7  18.6  0.84  0.83  0.39
# 6   21.90  -892.000000  22.689  ... -2.417272  -9.0  20.6  0.83  0.83  0.42
# 7   19.26  -452.000000  23.592  ... -1.911556  -7.2  19.1  0.94  0.98  0.55
# 8   16.30   260.000000  25.748  ... -1.093729 -10.7  22.2  0.98  1.15  0.58
# 9   14.45    25.000000  25.612  ... -0.460837 -12.7  21.9  1.00  1.03  0.68
# 10  13.27   -79.000000  26.038  ...  0.165584 -11.6  22.9  0.96  0.93  0.52
# 11  11.12    86.000000  24.695  ...  0.413734  -5.0  22.9  0.92  1.03  0.47
# 12  11.85   128.000000  25.474  ...  0.441721  -0.8  20.6  0.99  1.01  0.67
# 13  19.56     5.000000  26.773  ... -6.374068   0.3  20.9  0.95  1.01  0.78
# 14  14.30  -275.142857  28.167  ... -1.419204  -1.7  20.0  1.07  1.02  0.82
# 15  11.87  -275.142857  29.599  ... -0.897036  18.1  20.9  1.06  0.99  0.75
#
#       RQ        SSB         PT        EUPC
# 0   1.01  81.367724  79.207745   45.521991
# 1   1.04  81.503460  79.492010   70.724103
# 2   0.95  82.186109  79.791757  337.935130
# 3   0.96  82.520151  80.789148  281.231582
# 4   0.93  84.636537  80.127684  309.501994
# 5   1.12  84.670001  81.101556  339.126224
# 6   1.15  84.317188  81.028515  362.332974
# 7   1.19  90.098078  81.075004  344.608645
# 8   1.26  92.436369  81.549466   29.635159
# 9   1.12  92.931332  85.480409  115.573864
# 10  1.15  92.984744  85.497006  170.853686
# 11  1.09  93.053500  87.887522  388.976368
# 12  1.15  93.175686  88.744373  188.356791
# 13  1.08  93.273709  88.915657  514.521647
# 14  1.27  87.796756  82.906275  405.630623
# 15  1.30  87.796756  82.906275  331.287996
#
# [16 rows x 24 columns]

# %%
lt.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lt_bn.csv')

# %%
lt_scaled = standardize_data(lt)

# %%
lt_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lt_tcdf.csv')

# %%
lt_scaled.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = lt_scaled.columns.get_loc('EUPC')
print(column_index)

# %%
9,1,0
23,4,3
8,4,0
5,4,0
20,4,3
13,5,0
11,7,0
12,8,0
10,8,0
22,11,0
13,14,0
1,15,1
16,16,4
23,16,1
12,23,3
22,23,0
11,23,3

# %%
df_lv = y_data(df_lv)

# %%
missing_values(df_lv)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mean(df_lv, ["EMP", "PAG", "GGAG", "QOR", "QOA"])

# %%
lv_context = needed_context(lv_context, context)

# %%
missing_values(lv_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
lv_context
# Out:
#     TIME_PERIOD   ROL    GE   COC    RQ        SSB         PT
# 7          2007  0.72  0.43  0.34  0.95  88.154100  81.115239
# 8          2008  0.78  0.52  0.23  0.97  88.467773  83.228626
# 9          2009  0.79  0.62  0.20  0.92  89.002428  83.043921
# 10         2010  0.76  0.72  0.20  0.93  89.196552  82.613206
# 11         2011  0.74  0.69  0.28  0.95  89.163024  81.896887
# 12         2012  0.78  0.83  0.24  1.01  91.495552  82.315191
# 13         2013  0.76  0.88  0.32  1.04  91.532399  84.229882
# 14         2014  0.87  0.95  0.41  1.17  92.332633  84.865341
# 15         2015  0.77  1.05  0.43  1.07  92.038243  86.462455
# 16         2016  0.93  0.97  0.40  1.07  94.107515  89.093857
# 17         2017  0.90  0.87  0.50  1.14  94.112781  90.040534
# 18         2018  0.92  1.00  0.30  1.13  94.113949  90.040534
# 19         2019  0.98  1.07  0.48  1.18  94.116764  89.990298
# 20         2020  0.92  0.84  0.69  1.18  94.137989  89.188135
# 21         2021  0.95  0.83  0.72  1.22        NaN        NaN
# 22         2022  0.92  0.69  0.69  1.17        NaN        NaN

# %%
fill_with_mean(lv_context, ["SSB", "PT"])

# %%
lv_payments = eu_payments_for_country(eu_payments, "LV")

# %%
lv = merge_data(df_lv, lv_context, lv_payments)

# %%
lv = fix_eu_payments(lv)

# %%
lv.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lv_bn.csv')

# %%
lv_scaled = standardize_data(lv)

# %%
lv_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/lv_tcdf.csv')

# %%
lv_scaled.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = lv_scaled.columns.get_loc('EUPC')
print(column_index)

# %%
10,1,0
8,4,3
17,4,0
23,5,0
23,6,2
12,6,3
10,8,0
21,12,0
1,12,1
2,12,3
1,14,1
13,14,0
18,16,1
20,23,0

# %%
df_ee = y_data(df_ee)

# %%
missing_values(df_ee)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_ee, ["QOR", "QOA"])

# %%
fill_with_mean(df_ee, ["EMP", "PAG", "GGAG"])

# %%
ee_context = needed_context(ee_context, context)

# %%
missing_values(ee_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
# fill_with_mode(ee_context, ["DBD"])

# %%
fill_with_mean(ee_context, ["SSB", "PT"])

# %%
ee_payments = eu_payments_for_country(eu_payments, "EE")

# %%
ee = merge_data(df_ee, ee_context, ee_payments)

# %%
ee = fix_eu_payments(ee)

# %%
ee.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y
# 12 -0.947617 -1.922053  0.751497  ...  0.432313  0.311380  0.837577  0.038656
# 13  0.182006 -0.896845  0.449576  ... -2.703952 -0.029655  0.309969  1.069478
# 14 -0.117012  0.000000  1.771593  ... -0.892182  0.044483  0.257209  1.584888
# 15  0.177023  0.000000  1.989718  ... -0.069401  3.603115  1.417945  1.997217
#
#           GE       COC        RQ           SSB        PT      EUPC
# 0  -0.781556 -1.241310 -1.632933 -3.211033e+00 -0.129121 -1.632853
# 1   0.452480 -1.333046 -1.027342 -3.918685e-01 -0.035113 -1.438183
# 2  -0.863825 -1.103705 -1.027342 -2.962680e-01  0.038600  0.345246
# 3  -0.205673 -1.149573 -1.027342 -2.853289e-01  0.006063  0.607980
# 4  -0.287942 -0.874364 -1.027342 -3.399175e-01 -0.053625 -0.815741
# 5  -1.275170 -0.690891 -0.854316 -3.137592e-01 -1.434389  1.277491
# 6  -1.110632 -0.278076 -0.594777 -2.637139e-01 -2.901003  1.375962
# 7  -0.781556  0.272343  1.395023 -2.320716e-01 -0.317775 -0.111659
# 8  -0.534749  0.088870  1.308510  4.039082e-01 -0.272377 -1.471272
# 9  -0.452480 -0.048735  1.568049  9.474251e-01  0.709937 -1.035978
# 10 -0.287942 -0.186340  1.048971  9.663588e-01  1.031867 -0.583050
# 11  0.370211  1.052103  0.270353  9.749127e-01  1.092744  0.167408
# 12  0.287942  1.327312  0.616405  1.004895e+00  1.092744  1.215738
# 13  1.604246  1.556654  0.183840  1.036461e+00  1.171448  0.621781
# 14  1.933322  1.235576  0.356866 -4.262138e-15  0.000000  0.815959
# 15  1.933322  1.373181  0.443379 -4.262138e-15  0.000000  0.661171
#
# [16 rows x 24 columns]

# %%
ee_scaled.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = ee_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 23

# %%
3,2,0
17,4,1
17,5,3
14,7,0
10,8,1
14,9,1
23,10,2
6,11,0
9,11,0
14,12,2
22,12,0
14,13,0
10,14,3
13,14,0
12,15,0
14,18,0
17,20,2
6,21,0
21,23,0

# %%
df_fi = y_data(df_fi)

# %%
missing_values(df_fi)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 2 - 12.5 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_fi, ["QOR"])

# %%
fill_with_mean(df_fi, ["EMP", "PAG", "GGAG", "QOA"])

# %%
fi_context = needed_context(fi_context, context)

# %%
missing_values(fi_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
fill_with_mean(fi_context, ["SSB", "PT"])

# %%
fi_payments = eu_payments_for_country(eu_payments, "FI")

# %%
fi = merge_data(df_fi, fi_context, fi_payments)

# %%
fi = fix_eu_payments(fi)

# %%
fi.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/fi_bn.csv')

# %%
fi_scaled = standardize_data(fi)

# %%
fi_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/fi_tcdf.csv')

# %%
fi_scaled.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = fi_scaled.columns.get_loc('EUPC')
print(column_index)

# %%
20,2,0
5,4,2
17,5,1
8,8,1
12,8,0
23,8,1
8,12,0
1,12,1
12,12,1
13,14,0
12,19,1
11,20,2
14,20,0
14,21,1
19,21,0
19,22,0
17,23,3

# %%
df_se = y_data(df_se)

# %%
missing_values(df_se)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# GDPC - 0 - 0.0 %
# GDPCG - 0 - 0.0 %
# VABI - 0 - 0.0 %
# EMP - 0 - 0.0 %
# PAG - 1 - 6.2 %
# QOA - 3 - 18.8 %
# QOR - 3 - 18.8 %
# YUA - 0 - 0.0 %
# GGAG - 2 - 12.5 %
# REST - 0 - 0.0 %
# CO2 - 0 - 0.0 %
# EBSG - 0 - 0.0 %
# FDI - 0 - 0.0 %
# GGFC - 0 - 0.0 %
# LBGD - 0 - 0.0 %
# PC - 0 - 0.0 %
# ARP - 0 - 0.0 %
# PS - 0 - 0.0 %

# %%
fill_with_mode(df_se, ["QOR"])

# %%
fill_with_mean(df_se, ["GGAG", "QOA", "PAG"])

# %%
se_context = needed_context(se_context, context)

# %%
missing_values(se_context)
# Out:
# TIME_PERIOD - 0 - 0.0 %
# ROL - 0 - 0.0 %
# GE - 0 - 0.0 %
# COC - 0 - 0.0 %
# RQ - 0 - 0.0 %
# SSB - 2 - 12.5 %
# PT - 2 - 12.5 %

# %%
fill_with_mean(se_context, ["SSB", "PT"])

# %%
se_payments = eu_payments_for_country(eu_payments, "SE")

# %%
se = merge_data(df_se, se_context, se_payments)

# %%
se = fix_eu_payments(se)

# %%
se.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/se_bn.csv')

# %%
se_scaled = standardize_data(se)

# %%
se_scaled.to_csv('/Users/vladasverkelis/Documents/Doktorantūra/Straipsnis_1/Context_influance_to_EU_structural_funds/Data/y/se_tcdf.csv')

# %%
se_scaled.columns
# Out:
# Index(['GDPC', 'GDPCG', 'VABI', 'EMP', 'PAG', 'QOA', 'QOR', 'YUA', 'GGAG',
#        'REST', 'CO2', 'EBSG', 'FDI', 'GGFC', 'LBGD', 'PC', 'ARP', 'ROL', 'GE',
#        'COC', 'RQ', 'SSB', 'PT', 'EUPC'],
#       dtype='object')

# %%
column_index = se_scaled.columns.get_loc('EUPC')
print(column_index)
# Out:
# 23

# %%
14,1,1
8,4,0
20,5,3
17,6,2
15,7,2
14,7,0
16,8,1
8,8,1
0,9,0
18,11,1
23,12,0
14,13,3
16,13,0
17,15,0
23,15,1
9,16,0
0,16,0
0,17,0
16,20,0 
0,20,1
