# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/lv_2007_2015_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/lv_2007_2015_tcdf.csv'])
#
#  Dataset:  lv_2007_2015_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.002350
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 18, 3, 21, 16, 9, 1]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.006662
# Epoch: 500 [50%] 	Loss: 0.000026
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [10, 3, 12, 14, 13]
# Validated causes:  [10]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.000448
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000007
# Potential causes:  [11, 17, 23, 12, 10]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.000511
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 1, 16, 21, 18, 9]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 0.999319
# Epoch: 500 [50%] 	Loss: 0.000024
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 5, 8, 23, 12, 1]
# Validated causes:  [17, 5]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.001385
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000023
# Potential causes:  [12, 23, 11, 1, 16]
# Validated causes:  [12]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.003841
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 13]
# Validated causes:  [17, 13]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.004814
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 23, 11, 12, 14, 15]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002851
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 6, 1, 12, 9, 8, 16, 13]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.003809
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 12, 18, 21, 8, 11, 22, 16, 5]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.004438
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 23, 7, 17, 2, 6, 12, 8]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.004965
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 18, 17, 22, 9, 23, 21]
# Validated causes:  [22]
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.001308
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [21, 10, 17, 8, 1]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.999749
# Epoch: 500 [50%] 	Loss: 0.000048
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 10, 8, 23, 11, 5, 16, 7]
# Validated causes:  [12]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.001146
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 12, 1, 18, 9, 3, 16, 13]
# Validated causes:  []
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.001156
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 21, 9, 13, 1, 18, 3, 16, 8]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.000445
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000025
# Potential causes:  [12, 23, 1, 14, 11, 5, 8, 16, 7]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.003948
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 5, 8, 21]
# Validated causes:  [12]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.005050
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 17, 11, 22, 9, 21, 16]
# Validated causes:  [12]
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.002412
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000008
# Potential causes:  [21, 9, 18, 1, 13, 16, 8]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.003802
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 9, 16, 18, 17]
# Validated causes:  [17]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.004741
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000474
# Potential causes:  [17, 18, 16, 9, 12]
# Validated causes:  [17]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.003125
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000005
# Potential causes:  [17, 18, 1, 16, 12, 21, 9]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004514
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 17, 11, 18, 9, 21, 16, 3]
# Validated causes:  [17]
# ===================Results for lv_2007_2015_tcdf.csv ==================================
# CO2 causes GDPCG with a delay of 0 time steps.
# ROL causes PAG with a delay of 1 time steps.
# QOA causes PAG with a delay of 0 time steps.
# FDI causes QOA with a delay of 0 time steps.
# ROL causes QOR with a delay of 3 time steps.
# GGFC causes QOR with a delay of 2 time steps.
# PT causes EBSG with a delay of 0 time steps.
# FDI causes GGFC with a delay of 0 time steps.
# FDI causes ROL with a delay of 3 time steps.
# FDI causes GE with a delay of 0 time steps.
# ROL causes RQ with a delay of 2 time steps.
# ROL causes SSB with a delay of 0 time steps.
# ROL causes EUPC with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/lv_2007_2015_tcdf.csv=data/demo_groundtruth_lv_2007_2015_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/lv_2007_2015_tcdf.csv': 'data/demo_groundtruth_lv_2007_2015_tcdf.csv'}, data=None)
#
#  Dataset:  lv_2007_2015_tcdf.csv
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.001040
# Epoch: 250 [50%] 	Loss: 0.000048
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [26, 11, 13, 4]
# Validated causes:  [26]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.001087
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [20, 2, 22, 0, 6, 24, 3, 11]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.995383
# Epoch: 250 [50%] 	Loss: 0.000056
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [0, 6, 9, 20, 4, 5, 16, 26]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.003415
# Epoch: 250 [50%] 	Loss: 0.000027
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [11, 4, 26, 24, 7, 22, 9]
# Validated causes:  [11]
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.000078
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000108
# Potential causes:  [3, 11, 13, 26, 6, 16, 4]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.995392
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 9, 17, 23, 22, 26, 13, 19, 15, 18, 4, 5]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.001038
# Epoch: 250 [50%] 	Loss: 0.000045
# Epoch: 500 [100%] 	Loss: 0.000172
# Potential causes:  [11, 26, 13, 4, 3, 0]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 0.997987
# Epoch: 250 [50%] 	Loss: 0.000022
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [13, 3, 11, 26, 4]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.999111
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [0, 3, 9, 15]
# Validated causes:  [3]
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.003881
# Epoch: 250 [50%] 	Loss: 0.000038
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [13, 18, 11]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 0.995638
# Epoch: 250 [50%] 	Loss: 0.000030
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 13, 4, 26, 6, 5, 18, 3, 7, 9]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.003204
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 0, 6, 14, 22]
# Validated causes:  [3]
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.996705
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000008
# Potential causes:  [19, 22, 23, 11, 17, 5, 0, 9, 4, 15]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.006163
# Epoch: 250 [50%] 	Loss: 0.000094
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [0, 22, 6, 14]
# Validated causes:  [0, 14]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.998808
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000107
# Potential causes:  [13, 11]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.994061
# Epoch: 250 [50%] 	Loss: 0.000017
# Epoch: 500 [100%] 	Loss: 0.000010
# Potential causes:  [26, 11, 18, 22, 23, 9, 17, 13, 5, 19, 4]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.008719
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 15, 0, 14, 2]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 0.993458
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [18, 26, 19, 23, 11, 4, 22, 9, 5, 13]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 0.997033
# Epoch: 250 [50%] 	Loss: 0.000019
# Epoch: 500 [100%] 	Loss: 0.000096
# Potential causes:  [4, 0, 11, 9, 20, 13, 5]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.004244
# Epoch: 250 [50%] 	Loss: 0.000009
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [22, 19, 13, 11, 15, 5, 14, 17, 0]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002385
# Epoch: 250 [50%] 	Loss: 0.000022
# Epoch: 500 [100%] 	Loss: 0.000053
# Potential causes:  [18, 9, 20, 8, 11, 2]
# Validated causes:  []
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 1.000397
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000002
# Potential causes:  [0, 6, 4, 2, 26, 16, 14, 3, 15]
# Validated causes:  [0]
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.999991
# Epoch: 250 [50%] 	Loss: 0.000016
# Epoch: 500 [100%] 	Loss: 0.000659
# Potential causes:  [19, 23]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.999243
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [11, 22, 9, 19, 4, 26, 5]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 0.999068
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [22, 6, 0, 20, 19]
# Validated causes:  [22, 6, 0, 20]
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 0.995691
# Epoch: 250 [50%] 	Loss: 0.000021
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [12, 22, 19, 5, 17, 9, 23, 15, 4]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004177
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [0, 6, 22, 19, 13, 15, 5, 20]
# Validated causes:  []
# ===================Results for lv_2007_2015_tcdf.csv ==================================
# EUPC causes FDI with a delay of 3 time steps.
# EBSG causes EIAP with a delay of 1 time steps.
# EIAP causes GGFC with a delay of 3 time steps.
# EIAP causes EBSG with a delay of 0 time steps.
# FDI causes EIS with a delay of 0 time steps.
# LBGD causes EIS with a delay of 0 time steps.
# FDI causes PR with a delay of 1 time steps.
# RQ causes ROL with a delay of 3 time steps.
# VABI causes ROL with a delay of 1 time steps.
# FDI causes ROL with a delay of 3 time steps.
# GGAG causes ROL with a delay of 3 time steps.
#
# ===================Evaluation for lv_2007_2015_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  11
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  11
# TPs':  [(0, 26), (3, 11), (8, 3), (11, 3), (13, 0), (13, 14), (21, 0), (24, 22), (24, 6), (24, 0), (24, 20)]
# FPs':  []
# TPs direct:  [(0, 26), (3, 11), (8, 3), (11, 3), (13, 0), (13, 14), (21, 0), (24, 22), (24, 6), (24, 0), (24, 20)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/lv_2007_2015_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/lv_2007_2015_tcdf.csv'])
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.265153
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000024
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.874109
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.260123
# Epoch: 500 [50%] 	Loss: 0.000010
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 0.938771
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.876742
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 1.058777
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.654899
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.180966
# Epoch: 500 [50%] 	Loss: 0.000020
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.214525
# Epoch: 500 [50%] 	Loss: 0.000083
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.272186
# Epoch: 500 [50%] 	Loss: 0.000026
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.207067
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000056
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.144986
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.791112
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.173506
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.213314
# Epoch: 500 [50%] 	Loss: 0.000018
# Epoch: 1000 [100%] 	Loss: 0.000014
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.043150
# Epoch: 500 [50%] 	Loss: 0.000017
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.097167
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.060343
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.247319
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.132832
# Epoch: 500 [50%] 	Loss: 0.000018
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.285913
# Epoch: 500 [50%] 	Loss: 0.000410
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 1.125953
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.508937
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.636443
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 0.470968
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 0.808074
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.061925
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/lv_2007_2015_tcdf.csv : 3.793205724276431 with standard deviation 4.427757848375422
