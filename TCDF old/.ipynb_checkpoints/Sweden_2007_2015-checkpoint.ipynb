# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/se_2007_2015_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/se_2007_2015_tcdf.csv'])
#
#  Dataset:  se_2007_2015_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.006062
# Epoch: 500 [50%] 	Loss: 0.000098
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 16]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.006153
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 16, 2, 14]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.998465
# Epoch: 500 [50%] 	Loss: 0.000014
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 17, 13, 23, 10, 15, 20, 18, 1, 12]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.002473
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.002147
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 1, 8, 23, 3]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.998727
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000007
# Potential causes:  [15, 6, 18, 10, 20, 16, 23, 8, 12, 7]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.999127
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 23, 18, 10, 20, 17, 15, 12]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.004893
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [17, 16, 14, 12, 20]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002368
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 8, 1, 16, 4, 7]
# Validated causes:  [18]
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.007042
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 17, 12, 14, 21, 11, 22]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.999518
# Epoch: 500 [50%] 	Loss: 0.000006
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 16, 2, 23, 18, 20, 14, 12]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.997656
# Epoch: 500 [50%] 	Loss: 0.000032
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 17, 12, 13, 23]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.998681
# Epoch: 500 [50%] 	Loss: 0.000010
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 18, 23, 10, 13, 16, 2, 17]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.006695
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 16, 12, 14, 9, 21, 22]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.997886
# Epoch: 500 [50%] 	Loss: 0.000052
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 13, 10, 18, 2, 12]
# Validated causes:  []
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.006151
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 22, 9, 11, 21]
# Validated causes:  [17]
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.006748
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 11, 12, 14, 9]
# Validated causes:  [17]
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.006875
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [16, 12]
# Validated causes:  [16]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.998624
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 17, 20, 6, 15, 12, 10, 23]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.001045
# Epoch: 500 [50%] 	Loss: 0.000041
# Epoch: 1000 [100%] 	Loss: 0.000115
# Potential causes:  [23, 8, 20, 15, 17, 1, 18]
# Validated causes:  [23]
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.004677
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 5]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.005842
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 14, 12, 9, 11, 22, 1]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.004823
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [5, 16, 14, 12, 21, 8, 9, 3, 1]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004366
# Epoch: 500 [50%] 	Loss: 0.000881
# Epoch: 1000 [100%] 	Loss: 0.000005
# Potential causes:  [7, 14, 12, 8, 16, 19]
# Validated causes:  []
# ===================Results for se_2007_2015_tcdf.csv ==================================
# GE causes GGAG with a delay of 1 time steps.
# ROL causes PC with a delay of 2 time steps.
# ROL causes ARP with a delay of 0 time steps.
# ARP causes ROL with a delay of 0 time steps.
# EUPC causes COC with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/se_2007_2015_tcdf.csv=data/demo_groundtruth_se_2007_2015_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/se_2007_2015_tcdf.csv': 'data/demo_groundtruth_se_2007_2015_tcdf.csv'}, data=None)
#
#  Dataset:  se_2007_2015_tcdf.csv
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.002691
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000100
# Potential causes:  [3, 22, 6, 8, 13, 10, 23, 14, 26, 16, 18]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.000138
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000104
# Potential causes:  [6, 22, 23, 3, 16, 15]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.001481
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [15, 23, 6, 22, 3, 16]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.001707
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000030
# Potential causes:  [22, 8, 24]
# Validated causes:  [8]
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.001496
# Epoch: 250 [50%] 	Loss: 0.000033
# Epoch: 500 [100%] 	Loss: 0.000085
# Potential causes:  [6, 11, 5, 14, 0]
# Validated causes:  [6]
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 1.003173
# Epoch: 250 [50%] 	Loss: 0.000639
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 11, 6, 5, 25, 17, 0, 22, 21, 15]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.003931
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 13, 10, 18, 26, 9, 8]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.006021
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 8, 14, 18, 13, 9, 25, 4, 26, 24]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.998404
# Epoch: 250 [50%] 	Loss: 0.000022
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [5, 4, 11, 0, 6, 14]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.006878
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 18, 9, 11, 5, 0, 14, 8]
# Validated causes:  [4]
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.001860
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [13, 6, 3, 8, 14, 22, 18, 16, 23]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.001326
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000034
# Potential causes:  [6, 3, 16, 13, 8, 22, 10, 23, 14]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.003419
# Epoch: 250 [50%] 	Loss: 0.000029
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [4, 5, 0, 11, 14, 25, 9, 19]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.001200
# Epoch: 250 [50%] 	Loss: 0.000368
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [6, 4, 11, 0, 5, 14]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.004480
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 10, 8, 24, 6, 13, 18, 9, 23, 16, 26, 22, 4]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.004655
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [18, 14, 0, 4, 17]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 0.999972
# Epoch: 250 [50%] 	Loss: 0.000149
# Epoch: 500 [100%] 	Loss: 0.000011
# Potential causes:  [4, 11, 0]
# Validated causes:  []
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.004039
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 4]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.007872
# Epoch: 250 [50%] 	Loss: 0.000025
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [9, 26, 4, 13, 8, 14, 0, 17]
# Validated causes:  []
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.004131
# Epoch: 250 [50%] 	Loss: 0.000127
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [26, 5, 23, 18, 21, 9, 11, 4, 12, 19]
# Validated causes:  [26, 21]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.002903
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000295
# Potential causes:  [4, 9, 22]
# Validated causes:  [4, 22]
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 0.998853
# Epoch: 250 [50%] 	Loss: 0.000015
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [26, 19, 0, 9, 6, 15, 16, 20]
# Validated causes:  [19]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.001172
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000023
# Potential causes:  [6, 3]
# Validated causes:  []
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 1.003206
# Epoch: 250 [50%] 	Loss: 0.000031
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [16, 6, 18, 26, 3, 22, 14]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.001845
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000656
# Potential causes:  [11, 4, 14, 17, 0, 15, 9, 25]
# Validated causes:  []
#  Analysis started for target:  VAA
# Epoch:  1 [0%] 	Loss: 1.000947
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [2, 14, 11, 0, 15, 17, 9]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.000599
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000009
# Potential causes:  [18, 4]
# Validated causes:  []
# ===================Results for se_2007_2015_tcdf.csv ==================================
# GGFC causes EIAP with a delay of 0 time steps.
# VABI causes PDPS with a delay of 3 time steps.
# PDPS causes GDPCG with a delay of 3 time steps.
# EUPC causes EPFRG with a delay of 2 time steps.
# DI causes EPFRG with a delay of 0 time steps.
# PDPS causes GGAG with a delay of 2 time steps.
# GE causes GGAG with a delay of 1 time steps.
# EPFRG causes DI with a delay of 1 time steps.
#
# ===================Evaluation for se_2007_2015_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  8
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  8
# TPs':  [(3, 8), (4, 6), (9, 4), (19, 26), (19, 21), (20, 4), (20, 22), (21, 19)]
# FPs':  []
# TPs direct:  [(3, 8), (4, 6), (9, 4), (19, 26), (19, 21), (20, 4), (20, 22), (21, 19)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/se_2007_2015_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/se_2007_2015_tcdf.csv'])
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.116794
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.481617
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.659589
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 0.985646
# Epoch: 500 [50%] 	Loss: 0.000021
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.876744
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.482176
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.900715
# Epoch: 500 [50%] 	Loss: 0.000164
# Epoch: 1000 [100%] 	Loss: 0.000072
#
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.177390
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000007
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.100276
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.184102
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 0.745981
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.658855
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.632097
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.814317
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.167006
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.078023
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.264114
# Epoch: 500 [50%] 	Loss: 0.000119
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 0.845039
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.273093
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 0.126295
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.262617
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 0.887907
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.523682
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 0.809631
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.252544
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000225
#
#  Analysis started for target:  VAA
# Epoch:  1 [0%] 	Loss: 1.253320
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.832590
# Epoch: 500 [50%] 	Loss: 0.000124
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/se_2007_2015_tcdf.csv : 1.7638205753700609 with standard deviation 1.9736923423074146
