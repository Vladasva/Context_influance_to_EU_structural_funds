# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/fi_2007_2015_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/fi_2007_2015_tcdf.csv'])
#
#  Dataset:  fi_2007_2015_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.004707
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [9, 19, 8, 1, 11, 22]
# Validated causes:  [19]
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.002886
# Epoch: 500 [50%] 	Loss: 0.000008
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 10, 20, 2, 14]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.997766
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 17, 13, 12, 1, 23, 20]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.997995
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000013
# Potential causes:  [17, 10, 13, 2, 1, 23, 20]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.000522
# Epoch: 500 [50%] 	Loss: 0.000211
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 17, 8, 1, 16, 23]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.998768
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 3, 2, 13, 23, 10, 1, 8]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.007493
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [9, 18, 8, 19, 1, 3, 12, 11]
# Validated causes:  [19]
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.007347
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000103
# Potential causes:  [19, 17, 9, 14, 11, 16, 6, 12, 20]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.003879
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 12, 8, 16, 1, 14, 7, 21]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.007155
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [16, 6, 17, 19, 22, 11, 0, 14, 21]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 0.999720
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000019
# Potential causes:  [13, 6, 20, 12, 23, 1, 2]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 0.997646
# Epoch: 500 [50%] 	Loss: 0.000706
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 13, 2, 20, 23, 12, 18]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.000455
# Epoch: 500 [50%] 	Loss: 0.000233
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [23, 1]
# Validated causes:  [23]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.007680
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000025
# Potential causes:  [6, 19, 9, 17, 14, 12, 7, 11, 18]
# Validated causes:  [19]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 0.996633
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 17, 13, 2, 1, 20, 23, 3]
# Validated causes:  []
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 0.999292
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [18, 17, 23, 10, 6, 16, 8]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 0.998872
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 5, 23, 21, 10, 18, 12, 1]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.005324
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000006
# Potential causes:  [16, 21]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.003719
# Epoch: 500 [50%] 	Loss: 0.000141
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 12, 23, 16, 17]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 0.998431
# Epoch: 500 [50%] 	Loss: 0.000033
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [10, 17, 23, 13, 1, 3, 2, 20, 8]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.007486
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000008
# Potential causes:  [19, 9, 17, 6, 12, 7, 14, 11, 18]
# Validated causes:  []
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.007040
# Epoch: 500 [50%] 	Loss: 0.000221
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14, 16]
# Validated causes:  []
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.007084
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 19, 9, 14, 11, 12, 18]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.005436
# Epoch: 500 [50%] 	Loss: 0.000013
# Epoch: 1000 [100%] 	Loss: 0.000404
# Potential causes:  [12, 6, 18]
# Validated causes:  []
# ===================Results for fi_2007_2015_tcdf.csv ==================================
# COC causes GDPC with a delay of 0 time steps.
# COC causes QOR with a delay of 0 time steps.
# EUPC causes FDI with a delay of 0 time steps.
# COC causes GGFC with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/fi_2007_2015_tcdf.csv=data/demo_groundtruth_fi_2007_2015_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/fi_2007_2015_tcdf.csv': 'data/demo_groundtruth_fi_2007_2015_tcdf.csv'}, data=None)
#
#  Dataset:  fi_2007_2015_tcdf.csv
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.004808
# Epoch: 250 [50%] 	Loss: 0.000006
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [26, 25, 9, 22, 16, 21]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 0.998363
# Epoch: 250 [50%] 	Loss: 0.000007
# Epoch: 500 [100%] 	Loss: 0.000004
# Potential causes:  [15, 23, 11, 5, 22, 6, 0, 20, 9, 4]
# Validated causes:  [23]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.000882
# Epoch: 250 [50%] 	Loss: 0.000062
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [5, 17, 15, 13, 6, 14, 8, 7, 23, 9]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.003267
# Epoch: 250 [50%] 	Loss: 0.000064
# Epoch: 500 [100%] 	Loss: 0.000216
# Potential causes:  [17, 26, 4, 2, 13, 6, 3]
# Validated causes:  []
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.999759
# Epoch: 250 [50%] 	Loss: 0.000017
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 6, 11, 0, 14]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.999265
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000179
# Potential causes:  [23, 22, 0, 6, 15, 11, 3]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.004089
# Epoch: 250 [50%] 	Loss: 0.000018
# Epoch: 500 [100%] 	Loss: 0.000072
# Potential causes:  [9, 23, 17, 10, 8, 24, 26, 13, 6, 3, 14]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.002635
# Epoch: 250 [50%] 	Loss: 0.000026
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [13, 17, 24, 15, 6, 8, 23, 9, 10, 14]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 0.999408
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 11, 6, 4, 14, 0]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.006742
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [24, 4, 23, 26]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.002585
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000448
# Potential causes:  [23, 9, 17, 6]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.004004
# Epoch: 250 [50%] 	Loss: 0.000009
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [9, 6, 10, 17, 26, 24, 8, 13, 0, 3, 22, 14]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.002572
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000028
# Potential causes:  [18, 19, 11, 25, 13, 4, 15, 22, 14]
# Validated causes:  [18]
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.000570
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [15, 11, 6, 14, 4]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.003529
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000006
# Potential causes:  [24, 13, 23, 9, 17, 8, 10, 6, 26, 15]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.001552
# Epoch: 250 [50%] 	Loss: 0.000025
# Epoch: 500 [100%] 	Loss: 0.000071
# Potential causes:  [23, 17, 13, 5, 7, 9, 8, 24, 6, 10, 14]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.006090
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000014
# Potential causes:  [19, 15, 26]
# Validated causes:  [19]
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.002772
# Epoch: 250 [50%] 	Loss: 0.000018
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [13, 26]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.000257
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000643
# Potential causes:  [11, 23, 0, 6, 14, 9]
# Validated causes:  [11]
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.003681
# Epoch: 250 [50%] 	Loss: 0.000001
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [19, 18, 16]
# Validated causes:  [18]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.003274
# Epoch: 250 [50%] 	Loss: 0.000081
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [9, 20, 16, 4, 2, 6, 0, 22]
# Validated causes:  []
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 1.002682
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000053
# Potential causes:  [18, 23]
# Validated causes:  [18]
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.998000
# Epoch: 250 [50%] 	Loss: 0.000057
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [5, 3, 0, 11, 6]
# Validated causes:  []
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 1.003648
# Epoch: 250 [50%] 	Loss: 0.000009
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [24, 9, 4, 10, 3, 15, 14, 6]
# Validated causes:  [10]
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 0.999816
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [15, 11, 6, 0, 4, 14]
# Validated causes:  []
#  Analysis started for target:  VAA
# Epoch:  1 [0%] 	Loss: 1.000420
# Epoch: 250 [50%] 	Loss: 0.000368
# Epoch: 500 [100%] 	Loss: 0.000030
# Potential causes:  [22, 0, 19, 11, 4, 14, 15, 20]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 0.997558
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [5, 0, 22, 19, 6, 11, 4]
# Validated causes:  []
# ===================Results for fi_2007_2015_tcdf.csv ==================================
# CPI causes QOR with a delay of 1 time steps.
# LFG causes GDPC with a delay of 0 time steps.
# EPFRG causes LTU with a delay of 0 time steps.
# EBSG causes LFG with a delay of 1 time steps.
# LFG causes EPFRG with a delay of 0 time steps.
# LFG causes DI with a delay of 0 time steps.
# EII causes CPI with a delay of 1 time steps.
#
# ===================Evaluation for fi_2007_2015_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  7
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  7
# TPs':  [(1, 23), (12, 18), (16, 19), (18, 11), (19, 18), (21, 18), (23, 10)]
# FPs':  []
# TPs direct:  [(1, 23), (12, 18), (16, 19), (18, 11), (19, 18), (21, 18), (23, 10)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/fi_2007_2015_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/fi_2007_2015_tcdf.csv'])
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.093019
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.199694
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.852441
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.164146
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 1.214790
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.293643
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.041524
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.037566
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000006
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.109185
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.287653
# Epoch: 500 [50%] 	Loss: 0.000085
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 0.829394
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.132454
# Epoch: 500 [50%] 	Loss: 0.000007
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.888818
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 0.907454
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.152120
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.958804
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 0.650092
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.176951
# Epoch: 500 [50%] 	Loss: 0.000465
# Epoch: 1000 [100%] 	Loss: 0.000002
#
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.233838
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.245380
# Epoch: 500 [50%] 	Loss: 0.000924
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.273933
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  DI
# Epoch:  1 [0%] 	Loss: 1.162103
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 0.643581
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  CPI
# Epoch:  1 [0%] 	Loss: 1.131526
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.152616
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VAA
# Epoch:  1 [0%] 	Loss: 1.220866
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.144636
# Epoch: 500 [50%] 	Loss: 0.000029
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/fi_2007_2015_tcdf.csv : 3.1584105066989796 with standard deviation 3.941005616503858
