# %% [markdown]
# # TCDF: Temporal Causal Discovery Framework
#
# This notebook shows the functionality of TCDF.
#
# See the corresponding paper for more detail: __["Causal Discovery with Attention-Based Convolutional Neural Networks"](https://www.mdpi.com/2504-4990/1/1/19)__.

# %%
"""Shows all argument options"""

# %run -i "runTCDF.py" --help
# Out:
# usage: runTCDF.py [-h] [--cuda] [--epochs EPOCHS] [--kernel_size KERNEL_SIZE]
#                   [--hidden_layers HIDDEN_LAYERS]
#                   [--learning_rate LEARNING_RATE] [--optimizer {Adam,RMSprop}]
#                   [--log_interval LOG_INTERVAL] [--seed SEED]
#                   [--dilation_coefficient DILATION_COEFFICIENT]
#                   [--significance SIGNIFICANCE] [--plot]
#                   (--ground_truth GROUND_TRUTH | --data DATA [DATA ...])
#
# TCDF: Temporal Causal Discovery Framework
#
# options:
#   -h, --help            show this help message and exit
#   --cuda                Use CUDA (GPU) (default: False)
#   --epochs EPOCHS       Number of epochs (default: 1000)
#   --kernel_size KERNEL_SIZE
#                         Size of kernel, i.e. window size. Maximum delay to be
#                         found is kernel size - 1. Recommended to be equal to
#                         dilation coeffient (default: 4)
#   --hidden_layers HIDDEN_LAYERS
#                         Number of hidden layers in the depthwise convolution
#                         (default: 0)
#   --learning_rate LEARNING_RATE
#                         Learning rate (default: 0.01)
#   --optimizer {Adam,RMSprop}
#                         Optimizer to use (default: Adam)
#   --log_interval LOG_INTERVAL
#                         Epoch interval to report loss (default: 500)
#   --seed SEED           Random seed (default: 1111)
#   --dilation_coefficient DILATION_COEFFICIENT
#                         Dilation coefficient, recommended to be equal to
#                         kernel size (default: 4)
#   --significance SIGNIFICANCE
#                         Significance number stating when an increase in loss
#                         is significant enough to label a potential cause as
#                         true (validated) cause. See paper for more details
#                         (default: 0.8)
#   --plot                Show causal graph (default: False)
#   --ground_truth GROUND_TRUTH
#                         Provide dataset(s) and the ground truth(s) to evaluate
#                         the results of TCDF. Argument format:
#                         DataFile1=GroundtruthFile1,Key2=Value2,... with a key
#                         for each dataset containing multivariate time series
#                         (required file format: csv, a column with header for
#                         each time series) and a value for the corresponding
#                         ground truth (required file format: csv, no header,
#                         index of cause in first column, index of effect in
#                         second column, time delay between cause and effect in
#                         third column)
#   --data DATA [DATA ...]
#                         (Path to) one or more datasets to analyse by TCDF
#                         containing multiple time series. Required file format:
#                         csv with a column (incl. header) for each time series

# %% [markdown]
# To demonstrate the Temporal Causal Discovery Framework, we apply TCDF to a small dataset (`demo_dataset.csv`). This dataset contains 4 timeseries (called `Timeser0`,`Timeser1`,`Timeser2` and `Timeser3`), all containing 4,000 time steps. `Timeser0` and `Timeser3`contain random values. A value of `Timeser1` at timestep `t` is generated based on timestep `t-1` of `Timeser0` plus some noise. Therefore, `Timeser1` is caused by `Timeser0` with a delay of 1 time step. A value of `Timeser2` at timestep `t` is generated based on timestep `t-2` of `Timeser1` plus some noise. Therefore, `Timeser2` is caused by `Timeser1` with a delay of 2 time steps. File `demo_groundtruth` contains the ground truth, i.e. it tells that there is a causal relationship from `Timeser0` to `Timeser1` with a delay of 1 time step, and a causal relationship from `Timeser1` to `Timeser2` with a delay of 2 time steps.

# %%
"""Run TCDF"""
# %matplotlib inline
# %run -i "runTCDF.py" --data data/ee_2007_2015_tcdf.csv
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, significance=0.8, plot=False, ground_truth=None, data=['data/ee_2007_2015_tcdf.csv'])
#
#  Dataset:  ee_2007_2015_tcdf.csv
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.001233
# Epoch: 500 [50%] 	Loss: 0.000118
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 9, 12, 16, 21, 3, 1, 10]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.003498
# Epoch: 500 [50%] 	Loss: 0.000042
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 6, 9, 2, 13, 10, 21, 8]
# Validated causes:  []
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.000176
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [13, 8, 17, 23, 5, 9, 1, 10, 15]
# Validated causes:  [13]
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.000434
# Epoch: 500 [50%] 	Loss: 0.000677
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 9, 1, 16, 8, 10]
# Validated causes:  []
#  Analysis started for target:  PAG
# Epoch:  1 [0%] 	Loss: 1.004176
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000223
# Potential causes:  [17, 11, 1, 23, 8, 18, 6, 14, 7, 5, 16]
# Validated causes:  []
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 1.002905
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 23, 19, 11, 18, 12]
# Validated causes:  []
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.004440
# Epoch: 500 [50%] 	Loss: 0.000005
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14, 17, 11, 9]
# Validated causes:  []
#  Analysis started for target:  YUA
# Epoch:  1 [0%] 	Loss: 1.005997
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000048
# Potential causes:  [23, 14, 11, 6, 9]
# Validated causes:  []
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.003100
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [14, 8, 10]
# Validated causes:  []
#  Analysis started for target:  REST
# Epoch:  1 [0%] 	Loss: 1.003675
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000002
# Potential causes:  [12, 11, 6, 16, 8, 17]
# Validated causes:  []
#  Analysis started for target:  CO2
# Epoch:  1 [0%] 	Loss: 1.003538
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000491
# Potential causes:  [21, 8, 9, 14, 1, 2, 16]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.004004
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [12, 14, 17, 9, 6]
# Validated causes:  []
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.003821
# Epoch: 500 [50%] 	Loss: 0.000016
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 14, 23]
# Validated causes:  [14]
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.005205
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000126
# Potential causes:  [8, 11, 6, 14, 9, 12, 5, 7]
# Validated causes:  []
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.000544
# Epoch: 500 [50%] 	Loss: 0.000004
# Epoch: 1000 [100%] 	Loss: 0.000001
# Potential causes:  [13, 9]
# Validated causes:  [13]
#  Analysis started for target:  PC
# Epoch:  1 [0%] 	Loss: 1.003271
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [6, 12, 16, 8, 18, 17, 21, 0, 23]
# Validated causes:  []
#  Analysis started for target:  ARP
# Epoch:  1 [0%] 	Loss: 1.001473
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [8, 1, 17, 18, 21, 12, 3, 16, 0, 4]
# Validated causes:  []
#  Analysis started for target:  ROL
# Epoch:  1 [0%] 	Loss: 1.001522
# Epoch: 500 [50%] 	Loss: 0.000109
# Epoch: 1000 [100%] 	Loss: 0.000309
# Potential causes:  [8, 9, 21, 16, 12, 18]
# Validated causes:  []
#  Analysis started for target:  GE
# Epoch:  1 [0%] 	Loss: 1.002060
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [21, 6, 8, 11, 2, 23, 7, 14, 12]
# Validated causes:  []
#  Analysis started for target:  COC
# Epoch:  1 [0%] 	Loss: 1.002273
# Epoch: 500 [50%] 	Loss: 0.000155
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 16, 9, 12, 21, 6]
# Validated causes:  []
#  Analysis started for target:  RQ
# Epoch:  1 [0%] 	Loss: 1.002409
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [17, 9, 16, 21, 8, 18, 12]
# Validated causes:  [17]
#  Analysis started for target:  SSB
# Epoch:  1 [0%] 	Loss: 1.005290
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
# Potential causes:  [11, 14, 1, 9, 17, 16, 4, 23]
# Validated causes:  [11, 14]
#  Analysis started for target:  PT
# Epoch:  1 [0%] 	Loss: 1.004316
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000007
# Potential causes:  [12, 18, 23, 5, 17, 11, 20]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.005420
# Epoch: 500 [50%] 	Loss: 0.000035
# Epoch: 1000 [100%] 	Loss: 0.000696
# Potential causes:  [14, 16, 3, 12, 8, 9]
# Validated causes:  []
# ===================Results for ee_2007_2015_tcdf.csv ==================================
# GGFC causes VABI with a delay of 0 time steps.
# LBGD causes FDI with a delay of 2 time steps.
# GGFC causes LBGD with a delay of 1 time steps.
# ROL causes RQ with a delay of 3 time steps.
# EBSG causes SSB with a delay of 2 time steps.
# LBGD causes SSB with a delay of 0 time steps.
# ==================================================================================

# %%
"""Run TCDF and evaluate by comparing the results to the ground truth"""
# %matplotlib inline
# %run -i "runTCDF.py" --ground_truth data/ee_2007_2015_tcdf.csv=data/demo_groundtruth_ee_2007_2015_tcdf.csv  --epochs 500 --log_interval 250 --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=500, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=250, seed=1111, dilation_coefficient=4, significance=0.8, plot=True, ground_truth={'data/ee_2007_2015_tcdf.csv': 'data/demo_groundtruth_ee_2007_2015_tcdf.csv'}, data=None)
#
#  Dataset:  ee_2007_2015_tcdf.csv
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 1.000681
# Epoch: 250 [50%] 	Loss: 0.000003
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [19, 20, 6, 4, 2, 11]
# Validated causes:  [19, 20]
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.004530
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000009
# Potential causes:  [14, 0, 2, 5, 6, 13]
# Validated causes:  [14]
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.998898
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [4, 6, 13, 11, 23]
# Validated causes:  []
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 1.003634
# Epoch: 250 [50%] 	Loss: 0.000027
# Epoch: 500 [100%] 	Loss: 0.000547
# Potential causes:  [20, 11, 14, 8, 5, 19, 4, 9]
# Validated causes:  []
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.999666
# Epoch: 250 [50%] 	Loss: 0.000367
# Epoch: 500 [100%] 	Loss: 0.000079
# Potential causes:  [11, 13, 6, 23, 4, 26]
# Validated causes:  []
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.999757
# Epoch: 250 [50%] 	Loss: 0.000015
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [0, 20, 6, 19]
# Validated causes:  [0]
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 1.001414
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [11, 3, 4, 8, 18, 14, 5]
# Validated causes:  []
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.000501
# Epoch: 250 [50%] 	Loss: 0.000044
# Epoch: 500 [100%] 	Loss: 0.000015
# Potential causes:  [4, 3, 11, 14, 8, 13, 23, 6]
# Validated causes:  []
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.000291
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000036
# Potential causes:  [6, 3, 0, 23, 20, 5, 14]
# Validated causes:  []
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.006865
# Epoch: 250 [50%] 	Loss: 0.000008
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [5, 11, 8, 14, 4, 13]
# Validated causes:  []
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 0.997195
# Epoch: 250 [50%] 	Loss: 0.000176
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [26, 11, 4, 23, 13]
# Validated causes:  []
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.003935
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [0, 2, 6, 14]
# Validated causes:  []
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 1.002529
# Epoch: 250 [50%] 	Loss: 0.000020
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [0, 13, 11, 9, 26, 4, 15, 17]
# Validated causes:  []
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.005140
# Epoch: 250 [50%] 	Loss: 0.000002
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [3, 16, 15, 2, 6, 0]
# Validated causes:  [3]
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.004039
# Epoch: 250 [50%] 	Loss: 0.000006
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [5, 9, 8, 11, 26, 13, 3]
# Validated causes:  []
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 0.998128
# Epoch: 250 [50%] 	Loss: 0.000005
# Epoch: 500 [100%] 	Loss: 0.000003
# Potential causes:  [13, 26, 12, 23, 9, 11, 4, 0, 17]
# Validated causes:  []
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.004976
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [14, 15, 24, 19]
# Validated causes:  [14]
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 0.997127
# Epoch: 250 [50%] 	Loss: 0.000008
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [26, 4, 9, 23, 12, 13, 11, 15]
# Validated causes:  []
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.002171
# Epoch: 250 [50%] 	Loss: 0.000339
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [23, 0, 9, 26, 3]
# Validated causes:  [0]
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.003044
# Epoch: 250 [50%] 	Loss: 0.000014
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [20, 14]
# Validated causes:  [20, 14]
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.003076
# Epoch: 250 [50%] 	Loss: 0.000071
# Epoch: 500 [100%] 	Loss: 0.000001
# Potential causes:  [5, 20, 11, 9, 14, 4, 19]
# Validated causes:  []
#  Analysis started for target:  PMSI
# Epoch:  1 [0%] 	Loss: 0.001524
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [7, 24, 1, 21, 22, 25, 8, 10, 18, 14]
# Validated causes:  []
#  Analysis started for target:  JI
# Epoch:  1 [0%] 	Loss: 0.001524
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [7, 24, 1, 21, 22, 25, 8, 10, 18, 14]
# Validated causes:  []
#  Analysis started for target:  DWCP
# Epoch:  1 [0%] 	Loss: 0.997822
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [11, 14, 4]
# Validated causes:  []
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 0.996291
# Epoch: 250 [50%] 	Loss: 0.000127
# Epoch: 500 [100%] 	Loss: 0.000005
# Potential causes:  [12, 16]
# Validated causes:  []
#  Analysis started for target:  DBPG
# Epoch:  1 [0%] 	Loss: 0.001524
# Epoch: 250 [50%] 	Loss: 0.000000
# Epoch: 500 [100%] 	Loss: 0.000000
# Potential causes:  [7, 24, 1, 21, 22, 25, 8, 10, 18, 14]
# Validated causes:  []
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.004941
# Epoch: 250 [50%] 	Loss: 0.000004
# Epoch: 500 [100%] 	Loss: 0.000072
# Potential causes:  [15, 4, 16, 6, 20, 19, 9, 24]
# Validated causes:  []
# ===================Results for ee_2007_2015_tcdf.csv ==================================
# EPFRG causes FDI with a delay of 2 time steps.
# GGAG causes FDI with a delay of 1 time steps.
# LBGD causes QOR with a delay of 0 time steps.
# FDI causes PGP with a delay of 0 time steps.
# EIAP causes EIS with a delay of 0 time steps.
# LBGD causes LTU with a delay of 0 time steps.
# FDI causes LFG with a delay of 1 time steps.
# GGAG causes EPFRG with a delay of 2 time steps.
# LBGD causes EPFRG with a delay of 2 time steps.
#
# ===================Evaluation for ee_2007_2015_tcdf.csv ===============================
# Total False Positives':  0
# Total True Positives':  9
# Total False Negatives:  0
# Total Direct False Positives:  0
# Total Direct True Positives:  9
# TPs':  [(0, 19), (0, 20), (1, 14), (5, 0), (13, 3), (16, 14), (18, 0), (19, 20), (19, 14)]
# FPs':  []
# TPs direct:  [(0, 19), (0, 20), (1, 14), (5, 0), (13, 3), (16, 14), (18, 0), (19, 20), (19, 14)]
# FPs direct:  []
# FNs:  []
# Precision':  1.0
# Recall':  1.0
# F1' score:  1.0 (includes direct and indirect causal relationships)
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0 (includes only direct causal relationships)
# Percentage of delays that are correctly discovered:  100.0 %
# ==================================================================================

# %%
"""Evaluates the prediction accuracy of TCDF."""
"""For more information about MASE (Mean Absolute Scaled Error), see https://otexts.org/fpp2/accuracy.html"""

# %matplotlib inline
# %run -i "evaluate_predictions_TCDF.py" --data data/ee_2007_2015_tcdf.csv --plot
# Out:
# Arguments: Namespace(cuda=False, epochs=1000, kernel_size=4, hidden_layers=0, learning_rate=0.01, optimizer='Adam', log_interval=500, seed=1111, dilation_coefficient=4, plot=True, train_test_split=0.8, data=['data/ee_2007_2015_tcdf.csv'])
#
#  Analysis started for target:  FDI
# Epoch:  1 [0%] 	Loss: 0.590591
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  QOR
# Epoch:  1 [0%] 	Loss: 1.092788
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000011
#
#  Analysis started for target:  QOA
# Epoch:  1 [0%] 	Loss: 0.626441
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIAP
# Epoch:  1 [0%] 	Loss: 0.968777
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PDPS
# Epoch:  1 [0%] 	Loss: 0.842216
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PGP
# Epoch:  1 [0%] 	Loss: 0.509113
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  VABI
# Epoch:  1 [0%] 	Loss: 0.976054
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GCFP
# Epoch:  1 [0%] 	Loss: 1.237595
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGFC
# Epoch:  1 [0%] 	Loss: 1.243647
# Epoch: 500 [50%] 	Loss: 0.000002
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GDPCG
# Epoch:  1 [0%] 	Loss: 1.279005
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000004
#
#  Analysis started for target:  EII
# Epoch:  1 [0%] 	Loss: 1.120068
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EBSG
# Epoch:  1 [0%] 	Loss: 1.260419
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000004
#
#  Analysis started for target:  GDPC
# Epoch:  1 [0%] 	Loss: 0.720906
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EIS
# Epoch:  1 [0%] 	Loss: 1.111352
# Epoch: 500 [50%] 	Loss: 0.000009
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  LBGD
# Epoch:  1 [0%] 	Loss: 1.239101
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EMP
# Epoch:  1 [0%] 	Loss: 1.065702
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000009
#
#  Analysis started for target:  LTU
# Epoch:  1 [0%] 	Loss: 1.030127
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  FEM
# Epoch:  1 [0%] 	Loss: 1.121041
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000193
#
#  Analysis started for target:  LFG
# Epoch:  1 [0%] 	Loss: 1.284927
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EPFRG
# Epoch:  1 [0%] 	Loss: 1.289371
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  GGAG
# Epoch:  1 [0%] 	Loss: 1.081336
# Epoch: 500 [50%] 	Loss: 0.000003
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  PMSI
# Epoch:  1 [0%] 	Loss: 0.001515
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  JI
# Epoch:  1 [0%] 	Loss: 0.001515
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  DWCP
# Epoch:  1 [0%] 	Loss: 1.249099
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000001
#
#  Analysis started for target:  PR
# Epoch:  1 [0%] 	Loss: 1.093588
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  DBPG
# Epoch:  1 [0%] 	Loss: 0.001515
# Epoch: 500 [50%] 	Loss: 0.000000
# Epoch: 1000 [100%] 	Loss: 0.000000
#
#  Analysis started for target:  EUPC
# Epoch:  1 [0%] 	Loss: 1.077735
# Epoch: 500 [50%] 	Loss: 0.000001
# Epoch: 1000 [100%] 	Loss: 0.000000
#
# Mean Absolute Scaled Error (MASE) averaged over all time series in data/ee_2007_2015_tcdf.csv : 2.574825060347056 with standard deviation 4.723535460823057
